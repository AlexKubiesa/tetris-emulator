# %% [markdown]
# # Experiment 008
#
# In this experiment, we see how well the block landing model learns on an imbalanced dataset. We use the same underlying dataset, but the Dataset object enforces a certain proportion split between positive (block landed) and negative (block not landed) examples.

# %%
import os
from pathlib import Path
import random
import shutil
import datetime

import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.utils.data import Dataset
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter

# %%
class BlockLandingDataset(Dataset):
    def __init__(self, path: str):
        self.path = path
        if not os.path.exists(path):
            raise FileNotFoundError()
        with os.scandir(self.path) as it:
            entry: os.DirEntry = next(iter(it))
            _, self.ext = os.path.splitext(entry.name)
            self.highest_index = max((int(Path(file.path).stem) for file in it))

    def __len__(self):
        return self.highest_index + 1

    def __getitem__(self, idx):
        file = os.path.join(self.path, f"{idx}{self.ext}")
        if not os.path.exists(file):
            raise IndexError()
        boards = np.load(file)
        assert boards.shape[0] == 4
        x = boards[:3]
        b1 = boards[2] # We can identify a block landing by the fact that a block spawns in the next time step
        b2 = boards[3]
        y = (np.all(b1[0] == 0) & np.any(b2[0] == 1)).astype(np.float32)
        x, y = torch.tensor(x), torch.tensor(y)
        return x, y

# %%
class ImbalancedDataset(Dataset):
    def __init__(self, dataset, pos_fraction):
        # Assuming the underlying dataset has 50% positive and negative examples, we take all of the negative examples and a subset of the positive ones,
        # so we need pos_fraction to be at most 50%.
        assert pos_fraction <= 0.5
        pos = []
        neg = []
        for (x, y) in dataset:
            if y:
                pos.append((x, y))
            else:
                neg.append((x, y))
        random.shuffle(pos)
        # Remove positive examples until we reach the desired proportion (or overshoot slightly).
        while len(pos) / (len(pos) + len(neg)) > pos_fraction:
            pos.pop()
        print(f"pos_fraction: requested {pos_fraction:.3f}, got {len(pos) / (len(pos) + len(neg)):.3f}")
        print(f"Total positive examples: {len(pos)}")
        
        # Build up a list of all the examples.
        self.lst = pos + neg
        random.shuffle(self.lst)

        # Set helpful properties
        self.num_pos = len(pos)
        self.num_neg = len(neg)

    def __len__(self):
        return len(self.lst)
    
    def __getitem__(self, idx):
        return self.lst[idx]

# %%
train_dataset = ImbalancedDataset(BlockLandingDataset(os.path.join("data", "block_landing", "train")), 0.5)
test_dataset = ImbalancedDataset(BlockLandingDataset(os.path.join("data", "block_landing", "test")), 0.5)
train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=4, shuffle=True)

x, y = next(iter(train_dataloader))
print(x.shape, x.dtype)
print(y.shape, y.dtype)
# Out:
# pos_fraction: requested 0.500, got 0.492
# Total positive examples: 90
# pos_fraction: requested 0.500, got 0.500
# Total positive examples: 21
# torch.Size([4, 3, 22, 10]) torch.int32
# torch.Size([4]) torch.float32

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
class BlockLandingModel(nn.Module):
    """Predicts whether a block has landed.

    Inputs:
        x: Tensor of int32 of shape (batch_size, seq_length, height, width). height = 22 and width = 10 are the dimensions of the game
           board. seq_length = 2 is the number of game board inputs. The entries should be 0 for empty cells and 1 for blocks.
    
    Returns: float32 scalar, logit for block landing prediction.
    """

    def __init__(self):
        super().__init__()
        self.conv0 = nn.Conv2d(2, 5, 3, padding=1)
        self.conv1 = nn.Conv2d(5, 10, 3, padding=1)
        self.lin = nn.Linear(30, 1)

    def forward(self, x):
        x = F.one_hot(x.long(), 2) # One-hot encode the two cell classes
        x = x.type(torch.float) # Convert to floating-point
        x = x.permute((1, 0, 4, 2, 3)) # Move sequence to dimension 0 and channels/classes to dimension 2
        x = x[-1] # Just take the last board state in the sequence; channels are now dim 1
        x = F.relu(self.conv0(x))          # (22, 10) -> (22, 10)
        x = F.max_pool2d(x, kernel_size=2) # (22, 10) -> (11,  5)
        x = F.relu(self.conv1(x))          # (11,  5) -> (11,  5)
        x = F.max_pool2d(x, kernel_size=3) # (11,  5) -> ( 4,  2)
        x = torch.flatten(x, start_dim=1)
        logits = self.lin(x).squeeze(-1)
        return logits

# %%
model = BlockLandingModel().to(device)
print(model)

with torch.no_grad():
    X, y = next(iter(train_dataloader))
    logits = model(X)[0]
    preds = F.sigmoid(logits)
    print(f"Predicted states: {preds}")
# Out:
# BlockLandingModel(
#   (conv0): Conv2d(2, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1): Conv2d(5, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (lin): Linear(in_features=30, out_features=1, bias=True)
# )
# Predicted states: 0.49169811606407166

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()

    avg_loss = 0.0
    correct = 0.0
    true_pos = 0.0

    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    for batch, (X, y) in enumerate(dataloader):

        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Metric calculations
        avg_loss += loss.item()
        classes = (pred >= 0).type(torch.float)
        correct += (classes == y).type(torch.float).sum().item()
        true_pos += ((y == 1.0) & (classes == 1.0)).type(torch.float).sum().item()

        if batch % 20 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    avg_loss /= num_batches
    accuracy = correct / size
    recall = true_pos / dataloader.dataset.num_pos
    return {
        "loss": avg_loss,
        "acc": accuracy,
        "rec": recall
    }


def test_loop(dataloader, model, loss_fn):
    model.eval()
    
    test_loss = 0.0
    correct = 0.0
    true_pos = 0.0

    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            classes = (pred >= 0).type(torch.float)
            correct += (classes == y).type(torch.float).sum().item()
            true_pos += ((y == 1.0) & (classes == 1.0)).type(torch.float).sum().item()

    test_loss /= num_batches
    accuracy = correct / size
    recall = true_pos / dataloader.dataset.num_pos if dataloader.dataset.num_pos > 0 else np.nan
    print(f"Test Error: \n Recall: {(100*recall):>0.1f}%, Accuracy: {(100*accuracy):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return {
        "loss": test_loss,
        "acc": accuracy,
        "rec": recall
    }

# %%
pos_fracs = [0.5, 0.4, 0.3, 0.2, 0.1]
learning_rate = 1e-2
batch_size = 4
epochs = 300

log_dir = os.path.join("runs", "experiment_008")
shutil.rmtree(log_dir, ignore_errors=True)

for pos_frac in pos_fracs:
    train_dataset = ImbalancedDataset(BlockLandingDataset(os.path.join("data", "block_landing", "train")), pos_frac)
    test_dataset = ImbalancedDataset(BlockLandingDataset(os.path.join("data", "block_landing", "test")), pos_frac)
    train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)
    test_dataloader = DataLoader(test_dataset, batch_size=4, shuffle=True)

    
    model = BlockLandingModel().to(device)
    loss_fn = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    log_subdir = os.path.join(log_dir, "pos_frac_" + str(pos_frac).replace(".", "_") + "_" + datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S"))
    tb = SummaryWriter(log_subdir)

    for t in range(epochs):
        print(f"Epoch {t}\n-------------------------------")
        train_metrics = train_loop(train_dataloader, model, loss_fn, optimizer)
        test_metrics = test_loop(test_dataloader, model, loss_fn)
        tb.add_scalar("Loss/train", train_metrics["loss"], t)
        tb.add_scalar("Accuracy/train", train_metrics["acc"], t)
        tb.add_scalar("Recall/train", train_metrics["rec"], t)
        tb.add_scalar("Loss/test", test_metrics["loss"], t)
        tb.add_scalar("Accuracy/test", test_metrics["acc"], t)
        tb.add_scalar("Recall/test", test_metrics["rec"], t)
        for name, weight in model.named_parameters():
            tb.add_histogram(f"Weights/{name}", weight, t)
            tb.add_histogram(f"Gradients/{name}", weight.grad, t)

    tb.close()
    print("Done!")
# Out:
# pos_fraction: requested 0.500, got 0.492
# Total positive examples: 90
# pos_fraction: requested 0.500, got 0.500
# Total positive examples: 21
# Epoch 0
# -------------------------------
# loss: 0.708550  [    4/  183]
# loss: 0.694710  [   84/  183]
# loss: 0.670528  [  164/  183]
# Test Error:
#  Recall: 14.3%, Accuracy: 57.1%, Avg loss: 0.689238
#
# Epoch 1
# -------------------------------
# loss: 0.695797  [    4/  183]
# loss: 0.687308  [   84/  183]
# loss: 0.688124  [  164/  183]
# Test Error:
#  Recall: 33.3%, Accuracy: 64.3%, Avg loss: 0.688261
#
# Epoch 2
# -------------------------------
# loss: 0.696748  [    4/  183]
# loss: 0.671701  [   84/  183]
# loss: 0.699695  [  164/  183]
# Test Error:
#  Recall: 57.1%, Accuracy: 71.4%, Avg loss: 0.687448
#
# Epoch 3
# -------------------------------
# loss: 0.688724  [    4/  183]
# loss: 0.675721  [   84/  183]
# loss: 0.684409  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 73.8%, Avg loss: 0.685342
#
# Epoch 4
# -------------------------------
# loss: 0.687244  [    4/  183]
# loss: 0.673774  [   84/  183]
# loss: 0.688881  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 71.4%, Avg loss: 0.685340
#
# Epoch 5
# -------------------------------
# loss: 0.699343  [    4/  183]
# loss: 0.673213  [   84/  183]
# loss: 0.690322  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 71.4%, Avg loss: 0.683672
#
# Epoch 6
# -------------------------------
# loss: 0.689039  [    4/  183]
# loss: 0.675740  [   84/  183]
# loss: 0.665572  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 73.8%, Avg loss: 0.681983
#
# Epoch 7
# -------------------------------
# loss: 0.680482  [    4/  183]
# loss: 0.658240  [   84/  183]
# loss: 0.676230  [  164/  183]
# Test Error:
#  Recall: 71.4%, Accuracy: 71.4%, Avg loss: 0.679691
#
# Epoch 8
# -------------------------------
# loss: 0.667513  [    4/  183]
# loss: 0.685623  [   84/  183]
# loss: 0.680187  [  164/  183]
# Test Error:
#  Recall: 71.4%, Accuracy: 71.4%, Avg loss: 0.678427
#
# Epoch 9
# -------------------------------
# loss: 0.680408  [    4/  183]
# loss: 0.675282  [   84/  183]
# loss: 0.673111  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 73.8%, Avg loss: 0.675818
#
# Epoch 10
# -------------------------------
# loss: 0.669327  [    4/  183]
# loss: 0.676268  [   84/  183]
# loss: 0.678602  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 71.4%, Avg loss: 0.673664
#
# Epoch 11
# -------------------------------
# loss: 0.665992  [    4/  183]
# loss: 0.672468  [   84/  183]
# loss: 0.702262  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 69.0%, Avg loss: 0.673884
#
# Epoch 12
# -------------------------------
# loss: 0.628526  [    4/  183]
# loss: 0.689642  [   84/  183]
# loss: 0.670872  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 69.0%, Avg loss: 0.667046
#
# Epoch 13
# -------------------------------
# loss: 0.673634  [    4/  183]
# loss: 0.622863  [   84/  183]
# loss: 0.633232  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 66.7%, Avg loss: 0.666875
#
# Epoch 14
# -------------------------------
# loss: 0.683935  [    4/  183]
# loss: 0.671124  [   84/  183]
# loss: 0.699392  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 69.0%, Avg loss: 0.659299
#
# Epoch 15
# -------------------------------
# loss: 0.754208  [    4/  183]
# loss: 0.634695  [   84/  183]
# loss: 0.630817  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 66.7%, Avg loss: 0.653396
#
# Epoch 16
# -------------------------------
# loss: 0.603442  [    4/  183]
# loss: 0.755160  [   84/  183]
# loss: 0.707611  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 76.2%, Avg loss: 0.650914
#
# Epoch 17
# -------------------------------
# loss: 0.612259  [    4/  183]
# loss: 0.644835  [   84/  183]
# loss: 0.655676  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 69.0%, Avg loss: 0.641194
#
# Epoch 18
# -------------------------------
# loss: 0.535094  [    4/  183]
# loss: 0.528227  [   84/  183]
# loss: 0.742459  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 69.0%, Avg loss: 0.633708
#
# Epoch 19
# -------------------------------
# loss: 0.598786  [    4/  183]
# loss: 0.591317  [   84/  183]
# loss: 0.756726  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 66.7%, Avg loss: 0.638341
#
# Epoch 20
# -------------------------------
# loss: 0.568959  [    4/  183]
# loss: 0.505979  [   84/  183]
# loss: 0.617049  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 76.2%, Avg loss: 0.618692
#
# Epoch 21
# -------------------------------
# loss: 0.597487  [    4/  183]
# loss: 0.681705  [   84/  183]
# loss: 0.679016  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 73.8%, Avg loss: 0.606222
#
# Epoch 22
# -------------------------------
# loss: 0.605755  [    4/  183]
# loss: 0.520665  [   84/  183]
# loss: 0.448407  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 78.6%, Avg loss: 0.599311
#
# Epoch 23
# -------------------------------
# loss: 0.520829  [    4/  183]
# loss: 0.461464  [   84/  183]
# loss: 0.651906  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 78.6%, Avg loss: 0.589060
#
# Epoch 24
# -------------------------------
# loss: 0.458396  [    4/  183]
# loss: 0.443264  [   84/  183]
# loss: 0.619261  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 78.6%, Avg loss: 0.580614
#
# Epoch 25
# -------------------------------
# loss: 0.497987  [    4/  183]
# loss: 0.541619  [   84/  183]
# loss: 0.565285  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 78.6%, Avg loss: 0.576915
#
# Epoch 26
# -------------------------------
# loss: 0.530826  [    4/  183]
# loss: 0.578161  [   84/  183]
# loss: 0.325704  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 69.0%, Avg loss: 0.562992
#
# Epoch 27
# -------------------------------
# loss: 0.756196  [    4/  183]
# loss: 0.238442  [   84/  183]
# loss: 0.637483  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 76.2%, Avg loss: 0.546315
#
# Epoch 28
# -------------------------------
# loss: 0.764839  [    4/  183]
# loss: 0.663861  [   84/  183]
# loss: 0.546543  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 71.4%, Avg loss: 0.561133
#
# Epoch 29
# -------------------------------
# loss: 0.629556  [    4/  183]
# loss: 0.578349  [   84/  183]
# loss: 0.570941  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 76.2%, Avg loss: 0.525286
#
# Epoch 30
# -------------------------------
# loss: 0.624006  [    4/  183]
# loss: 0.622363  [   84/  183]
# loss: 0.325952  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 78.6%, Avg loss: 0.517400
#
# Epoch 31
# -------------------------------
# loss: 0.285471  [    4/  183]
# loss: 0.141455  [   84/  183]
# loss: 0.818621  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 78.6%, Avg loss: 0.511549
#
# Epoch 32
# -------------------------------
# loss: 0.255436  [    4/  183]
# loss: 0.203158  [   84/  183]
# loss: 0.522340  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 78.6%, Avg loss: 0.504722
#
# Epoch 33
# -------------------------------
# loss: 0.836052  [    4/  183]
# loss: 0.360962  [   84/  183]
# loss: 0.201656  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 76.2%, Avg loss: 0.533971
#
# Epoch 34
# -------------------------------
# loss: 0.546491  [    4/  183]
# loss: 0.799253  [   84/  183]
# loss: 0.780524  [  164/  183]
# Test Error:
#  Recall: 61.9%, Accuracy: 76.2%, Avg loss: 0.532960
#
# Epoch 35
# -------------------------------
# loss: 0.454249  [    4/  183]
# loss: 0.162406  [   84/  183]
# loss: 0.491349  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 78.6%, Avg loss: 0.491099
#
# Epoch 36
# -------------------------------
# loss: 0.398327  [    4/  183]
# loss: 0.630103  [   84/  183]
# loss: 0.518809  [  164/  183]
# Test Error:
#  Recall: 57.1%, Accuracy: 73.8%, Avg loss: 0.545296
#
# Epoch 37
# -------------------------------
# loss: 1.195099  [    4/  183]
# loss: 0.278446  [   84/  183]
# loss: 0.642029  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 81.0%, Avg loss: 0.494195
#
# Epoch 38
# -------------------------------
# loss: 0.431546  [    4/  183]
# loss: 0.559686  [   84/  183]
# loss: 0.193034  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 76.2%, Avg loss: 0.540162
#
# Epoch 39
# -------------------------------
# loss: 0.209120  [    4/  183]
# loss: 0.673657  [   84/  183]
# loss: 0.309708  [  164/  183]
# Test Error:
#  Recall: 57.1%, Accuracy: 76.2%, Avg loss: 0.523550
#
# Epoch 40
# -------------------------------
# loss: 0.219900  [    4/  183]
# loss: 0.267321  [   84/  183]
# loss: 0.232789  [  164/  183]
# Test Error:
#  Recall: 57.1%, Accuracy: 76.2%, Avg loss: 0.535923
#
# Epoch 41
# -------------------------------
# loss: 0.201137  [    4/  183]
# loss: 0.418808  [   84/  183]
# loss: 0.585435  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 78.6%, Avg loss: 0.477213
#
# Epoch 42
# -------------------------------
# loss: 0.185216  [    4/  183]
# loss: 0.496328  [   84/  183]
# loss: 0.294883  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 78.6%, Avg loss: 0.472083
#
# Epoch 43
# -------------------------------
# loss: 0.714715  [    4/  183]
# loss: 0.332782  [   84/  183]
# loss: 0.067674  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 83.3%, Avg loss: 0.454822
#
# Epoch 44
# -------------------------------
# loss: 0.445703  [    4/  183]
# loss: 0.272446  [   84/  183]
# loss: 0.179522  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 76.2%, Avg loss: 0.465310
#
# Epoch 45
# -------------------------------
# loss: 0.128715  [    4/  183]
# loss: 0.514367  [   84/  183]
# loss: 0.550905  [  164/  183]
# Test Error:
#  Recall: 57.1%, Accuracy: 76.2%, Avg loss: 0.486613
#
# Epoch 46
# -------------------------------
# loss: 0.288895  [    4/  183]
# loss: 0.165374  [   84/  183]
# loss: 0.218984  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 78.6%, Avg loss: 0.441749
#
# Epoch 47
# -------------------------------
# loss: 0.560652  [    4/  183]
# loss: 0.735043  [   84/  183]
# loss: 0.375821  [  164/  183]
# Test Error:
#  Recall: 71.4%, Accuracy: 78.6%, Avg loss: 0.444457
#
# Epoch 48
# -------------------------------
# loss: 0.387349  [    4/  183]
# loss: 0.358504  [   84/  183]
# loss: 0.897384  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 76.2%, Avg loss: 0.453790
#
# Epoch 49
# -------------------------------
# loss: 0.534670  [    4/  183]
# loss: 0.527559  [   84/  183]
# loss: 0.431185  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 83.3%, Avg loss: 0.420132
#
# Epoch 50
# -------------------------------
# loss: 0.648702  [    4/  183]
# loss: 0.314349  [   84/  183]
# loss: 0.537575  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 76.2%, Avg loss: 0.429044
#
# Epoch 51
# -------------------------------
# loss: 0.122808  [    4/  183]
# loss: 0.409881  [   84/  183]
# loss: 0.360421  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 76.2%, Avg loss: 0.460952
#
# Epoch 52
# -------------------------------
# loss: 0.397606  [    4/  183]
# loss: 0.320189  [   84/  183]
# loss: 0.291149  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 78.6%, Avg loss: 0.430391
#
# Epoch 53
# -------------------------------
# loss: 0.147796  [    4/  183]
# loss: 0.365784  [   84/  183]
# loss: 0.142898  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.395708
#
# Epoch 54
# -------------------------------
# loss: 0.044135  [    4/  183]
# loss: 0.171851  [   84/  183]
# loss: 0.672332  [  164/  183]
# Test Error:
#  Recall: 71.4%, Accuracy: 81.0%, Avg loss: 0.403615
#
# Epoch 55
# -------------------------------
# loss: 0.330139  [    4/  183]
# loss: 0.316546  [   84/  183]
# loss: 0.216314  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 81.0%, Avg loss: 0.394338
#
# Epoch 56
# -------------------------------
# loss: 0.539183  [    4/  183]
# loss: 0.138305  [   84/  183]
# loss: 0.263821  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.366353
#
# Epoch 57
# -------------------------------
# loss: 0.378402  [    4/  183]
# loss: 0.172169  [   84/  183]
# loss: 0.437228  [  164/  183]
# Test Error:
#  Recall: 57.1%, Accuracy: 76.2%, Avg loss: 0.461742
#
# Epoch 58
# -------------------------------
# loss: 0.521486  [    4/  183]
# loss: 0.376540  [   84/  183]
# loss: 0.100693  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.383683
#
# Epoch 59
# -------------------------------
# loss: 0.088265  [    4/  183]
# loss: 0.179724  [   84/  183]
# loss: 0.396489  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 81.0%, Avg loss: 0.367110
#
# Epoch 60
# -------------------------------
# loss: 0.520482  [    4/  183]
# loss: 0.128905  [   84/  183]
# loss: 0.224490  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.347858
#
# Epoch 61
# -------------------------------
# loss: 0.138095  [    4/  183]
# loss: 0.348507  [   84/  183]
# loss: 0.059475  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 83.3%, Avg loss: 0.350955
#
# Epoch 62
# -------------------------------
# loss: 0.083939  [    4/  183]
# loss: 0.302531  [   84/  183]
# loss: 0.149145  [  164/  183]
# Test Error:
#  Recall: 42.9%, Accuracy: 69.0%, Avg loss: 0.507824
#
# Epoch 63
# -------------------------------
# loss: 0.400457  [    4/  183]
# loss: 0.343572  [   84/  183]
# loss: 0.308385  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 85.7%, Avg loss: 0.325723
#
# Epoch 64
# -------------------------------
# loss: 0.079717  [    4/  183]
# loss: 0.143130  [   84/  183]
# loss: 0.285606  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 85.7%, Avg loss: 0.333577
#
# Epoch 65
# -------------------------------
# loss: 0.249631  [    4/  183]
# loss: 0.244811  [   84/  183]
# loss: 0.058961  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 85.7%, Avg loss: 0.328712
#
# Epoch 66
# -------------------------------
# loss: 0.032830  [    4/  183]
# loss: 0.114731  [   84/  183]
# loss: 0.105007  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 83.3%, Avg loss: 0.302979
#
# Epoch 67
# -------------------------------
# loss: 0.044163  [    4/  183]
# loss: 0.077303  [   84/  183]
# loss: 0.241649  [  164/  183]
# Test Error:
#  Recall: 61.9%, Accuracy: 78.6%, Avg loss: 0.414451
#
# Epoch 68
# -------------------------------
# loss: 0.380270  [    4/  183]
# loss: 0.072801  [   84/  183]
# loss: 0.093403  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 83.3%, Avg loss: 0.353611
#
# Epoch 69
# -------------------------------
# loss: 0.230391  [    4/  183]
# loss: 0.238231  [   84/  183]
# loss: 0.170684  [  164/  183]
# Test Error:
#  Recall: 71.4%, Accuracy: 83.3%, Avg loss: 0.346195
#
# Epoch 70
# -------------------------------
# loss: 0.051801  [    4/  183]
# loss: 0.166384  [   84/  183]
# loss: 0.131690  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 85.7%, Avg loss: 0.327272
#
# Epoch 71
# -------------------------------
# loss: 0.115254  [    4/  183]
# loss: 0.238993  [   84/  183]
# loss: 0.573528  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 88.1%, Avg loss: 0.303352
#
# Epoch 72
# -------------------------------
# loss: 0.081042  [    4/  183]
# loss: 0.049404  [   84/  183]
# loss: 0.149591  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 88.1%, Avg loss: 0.304289
#
# Epoch 73
# -------------------------------
# loss: 0.211036  [    4/  183]
# loss: 0.036790  [   84/  183]
# loss: 0.165494  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 81.0%, Avg loss: 0.358739
#
# Epoch 74
# -------------------------------
# loss: 0.201744  [    4/  183]
# loss: 0.313959  [   84/  183]
# loss: 0.063196  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 90.5%, Avg loss: 0.308274
#
# Epoch 75
# -------------------------------
# loss: 0.173215  [    4/  183]
# loss: 0.043734  [   84/  183]
# loss: 0.064075  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 85.7%, Avg loss: 0.277914
#
# Epoch 76
# -------------------------------
# loss: 0.085675  [    4/  183]
# loss: 0.048307  [   84/  183]
# loss: 0.111147  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.326515
#
# Epoch 77
# -------------------------------
# loss: 0.356442  [    4/  183]
# loss: 0.518248  [   84/  183]
# loss: 0.217445  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.283615
#
# Epoch 78
# -------------------------------
# loss: 0.124452  [    4/  183]
# loss: 0.053524  [   84/  183]
# loss: 0.562547  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.262751
#
# Epoch 79
# -------------------------------
# loss: 0.707186  [    4/  183]
# loss: 0.156598  [   84/  183]
# loss: 0.087625  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 83.3%, Avg loss: 0.312571
#
# Epoch 80
# -------------------------------
# loss: 0.119512  [    4/  183]
# loss: 0.086125  [   84/  183]
# loss: 0.204824  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 88.1%, Avg loss: 0.313649
#
# Epoch 81
# -------------------------------
# loss: 0.082774  [    4/  183]
# loss: 0.032343  [   84/  183]
# loss: 0.212324  [  164/  183]
# Test Error:
#  Recall: 61.9%, Accuracy: 78.6%, Avg loss: 0.398151
#
# Epoch 82
# -------------------------------
# loss: 0.187793  [    4/  183]
# loss: 0.036820  [   84/  183]
# loss: 0.074187  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.284303
#
# Epoch 83
# -------------------------------
# loss: 0.241445  [    4/  183]
# loss: 0.291489  [   84/  183]
# loss: 0.021859  [  164/  183]
# Test Error:
#  Recall: 61.9%, Accuracy: 78.6%, Avg loss: 0.372377
#
# Epoch 84
# -------------------------------
# loss: 0.651925  [    4/  183]
# loss: 0.268595  [   84/  183]
# loss: 0.102510  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.255384
#
# Epoch 85
# -------------------------------
# loss: 0.023415  [    4/  183]
# loss: 0.054210  [   84/  183]
# loss: 0.091372  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.267287
#
# Epoch 86
# -------------------------------
# loss: 0.505351  [    4/  183]
# loss: 0.207609  [   84/  183]
# loss: 0.120913  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.261627
#
# Epoch 87
# -------------------------------
# loss: 0.286325  [    4/  183]
# loss: 0.025045  [   84/  183]
# loss: 0.171434  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 78.6%, Avg loss: 0.411566
#
# Epoch 88
# -------------------------------
# loss: 0.309718  [    4/  183]
# loss: 0.047480  [   84/  183]
# loss: 0.194884  [  164/  183]
# Test Error:
#  Recall: 66.7%, Accuracy: 78.6%, Avg loss: 0.360041
#
# Epoch 89
# -------------------------------
# loss: 0.045473  [    4/  183]
# loss: 0.017496  [   84/  183]
# loss: 0.441908  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.264985
#
# Epoch 90
# -------------------------------
# loss: 0.395488  [    4/  183]
# loss: 0.275811  [   84/  183]
# loss: 0.040229  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 88.1%, Avg loss: 0.264390
#
# Epoch 91
# -------------------------------
# loss: 0.062411  [    4/  183]
# loss: 0.238653  [   84/  183]
# loss: 0.077403  [  164/  183]
# Test Error:
#  Recall: 71.4%, Accuracy: 81.0%, Avg loss: 0.302559
#
# Epoch 92
# -------------------------------
# loss: 0.201108  [    4/  183]
# loss: 0.698311  [   84/  183]
# loss: 0.062172  [  164/  183]
# Test Error:
#  Recall: 57.1%, Accuracy: 76.2%, Avg loss: 0.469158
#
# Epoch 93
# -------------------------------
# loss: 0.095761  [    4/  183]
# loss: 0.039540  [   84/  183]
# loss: 0.029423  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 88.1%, Avg loss: 0.261997
#
# Epoch 94
# -------------------------------
# loss: 0.002897  [    4/  183]
# loss: 0.189051  [   84/  183]
# loss: 0.173613  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.238621
#
# Epoch 95
# -------------------------------
# loss: 0.060151  [    4/  183]
# loss: 0.404499  [   84/  183]
# loss: 0.030568  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.231646
#
# Epoch 96
# -------------------------------
# loss: 0.088392  [    4/  183]
# loss: 0.024892  [   84/  183]
# loss: 0.021603  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.235753
#
# Epoch 97
# -------------------------------
# loss: 0.024223  [    4/  183]
# loss: 0.110542  [   84/  183]
# loss: 0.324156  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 88.1%, Avg loss: 0.234737
#
# Epoch 98
# -------------------------------
# loss: 0.148869  [    4/  183]
# loss: 0.071693  [   84/  183]
# loss: 0.237100  [  164/  183]
# Test Error:
#  Recall: 71.4%, Accuracy: 81.0%, Avg loss: 0.317418
#
# Epoch 99
# -------------------------------
# loss: 0.081635  [    4/  183]
# loss: 0.178430  [   84/  183]
# loss: 0.029243  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 85.7%, Avg loss: 0.248390
#
# Epoch 100
# -------------------------------
# loss: 0.289288  [    4/  183]
# loss: 0.117759  [   84/  183]
# loss: 0.040908  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.231909
#
# Epoch 101
# -------------------------------
# loss: 0.120518  [    4/  183]
# loss: 0.239730  [   84/  183]
# loss: 0.346708  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.243657
#
# Epoch 102
# -------------------------------
# loss: 0.017665  [    4/  183]
# loss: 0.124660  [   84/  183]
# loss: 0.024006  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.227252
#
# Epoch 103
# -------------------------------
# loss: 0.060145  [    4/  183]
# loss: 0.077631  [   84/  183]
# loss: 0.032266  [  164/  183]
# Test Error:
#  Recall: 71.4%, Accuracy: 81.0%, Avg loss: 0.312036
#
# Epoch 104
# -------------------------------
# loss: 0.002436  [    4/  183]
# loss: 0.044290  [   84/  183]
# loss: 0.152217  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 88.1%, Avg loss: 0.216961
#
# Epoch 105
# -------------------------------
# loss: 0.076200  [    4/  183]
# loss: 0.324531  [   84/  183]
# loss: 0.020362  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 88.1%, Avg loss: 0.275301
#
# Epoch 106
# -------------------------------
# loss: 0.079000  [    4/  183]
# loss: 0.048440  [   84/  183]
# loss: 0.016799  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 83.3%, Avg loss: 0.285858
#
# Epoch 107
# -------------------------------
# loss: 0.003989  [    4/  183]
# loss: 0.016122  [   84/  183]
# loss: 0.033274  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.233483
#
# Epoch 108
# -------------------------------
# loss: 0.017169  [    4/  183]
# loss: 0.031706  [   84/  183]
# loss: 0.016469  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.224470
#
# Epoch 109
# -------------------------------
# loss: 0.109383  [    4/  183]
# loss: 0.288249  [   84/  183]
# loss: 0.262432  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.262237
#
# Epoch 110
# -------------------------------
# loss: 0.059908  [    4/  183]
# loss: 0.241240  [   84/  183]
# loss: 0.162725  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.224134
#
# Epoch 111
# -------------------------------
# loss: 0.056337  [    4/  183]
# loss: 0.036376  [   84/  183]
# loss: 0.176062  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.217121
#
# Epoch 112
# -------------------------------
# loss: 0.217605  [    4/  183]
# loss: 0.109592  [   84/  183]
# loss: 0.244250  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.218471
#
# Epoch 113
# -------------------------------
# loss: 0.023886  [    4/  183]
# loss: 0.029060  [   84/  183]
# loss: 0.012015  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.209524
#
# Epoch 114
# -------------------------------
# loss: 0.308404  [    4/  183]
# loss: 0.019457  [   84/  183]
# loss: 0.004671  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.237937
#
# Epoch 115
# -------------------------------
# loss: 0.411973  [    4/  183]
# loss: 0.140149  [   84/  183]
# loss: 0.073453  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 83.3%, Avg loss: 0.297237
#
# Epoch 116
# -------------------------------
# loss: 0.000152  [    4/  183]
# loss: 0.034362  [   84/  183]
# loss: 0.062988  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.208222
#
# Epoch 117
# -------------------------------
# loss: 0.013195  [    4/  183]
# loss: 0.141659  [   84/  183]
# loss: 0.017741  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.247490
#
# Epoch 118
# -------------------------------
# loss: 0.198228  [    4/  183]
# loss: 0.019316  [   84/  183]
# loss: 0.030131  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 83.3%, Avg loss: 0.339419
#
# Epoch 119
# -------------------------------
# loss: 0.046775  [    4/  183]
# loss: 0.040230  [   84/  183]
# loss: 0.322838  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.261077
#
# Epoch 120
# -------------------------------
# loss: 0.026156  [    4/  183]
# loss: 0.039442  [   84/  183]
# loss: 0.039284  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 88.1%, Avg loss: 0.225874
#
# Epoch 121
# -------------------------------
# loss: 0.086059  [    4/  183]
# loss: 0.010877  [   84/  183]
# loss: 0.033888  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.228112
#
# Epoch 122
# -------------------------------
# loss: 0.122903  [    4/  183]
# loss: 0.005729  [   84/  183]
# loss: 0.239046  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.209965
#
# Epoch 123
# -------------------------------
# loss: 0.003331  [    4/  183]
# loss: 0.013433  [   84/  183]
# loss: 0.074761  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.245680
#
# Epoch 124
# -------------------------------
# loss: 0.131104  [    4/  183]
# loss: 0.109650  [   84/  183]
# loss: 0.097070  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.211871
#
# Epoch 125
# -------------------------------
# loss: 0.032217  [    4/  183]
# loss: 0.199203  [   84/  183]
# loss: 0.140729  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.233433
#
# Epoch 126
# -------------------------------
# loss: 0.369635  [    4/  183]
# loss: 0.005617  [   84/  183]
# loss: 0.007198  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.201636
#
# Epoch 127
# -------------------------------
# loss: 0.005388  [    4/  183]
# loss: 0.102891  [   84/  183]
# loss: 0.080684  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.236025
#
# Epoch 128
# -------------------------------
# loss: 0.031233  [    4/  183]
# loss: 0.034208  [   84/  183]
# loss: 0.010367  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.206327
#
# Epoch 129
# -------------------------------
# loss: 0.048394  [    4/  183]
# loss: 0.038470  [   84/  183]
# loss: 0.194704  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 85.7%, Avg loss: 0.404117
#
# Epoch 130
# -------------------------------
# loss: 0.108325  [    4/  183]
# loss: 0.017739  [   84/  183]
# loss: 0.021868  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 81.0%, Avg loss: 0.331588
#
# Epoch 131
# -------------------------------
# loss: 0.169629  [    4/  183]
# loss: 0.151232  [   84/  183]
# loss: 0.006066  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.214962
#
# Epoch 132
# -------------------------------
# loss: 0.023403  [    4/  183]
# loss: 0.044499  [   84/  183]
# loss: 0.151000  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 88.1%, Avg loss: 0.203155
#
# Epoch 133
# -------------------------------
# loss: 0.083552  [    4/  183]
# loss: 0.008688  [   84/  183]
# loss: 0.366470  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.209899
#
# Epoch 134
# -------------------------------
# loss: 0.037134  [    4/  183]
# loss: 0.061358  [   84/  183]
# loss: 0.029247  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.217608
#
# Epoch 135
# -------------------------------
# loss: 0.090013  [    4/  183]
# loss: 0.033143  [   84/  183]
# loss: 0.040542  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.245930
#
# Epoch 136
# -------------------------------
# loss: 0.050414  [    4/  183]
# loss: 0.022763  [   84/  183]
# loss: 0.117994  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.203224
#
# Epoch 137
# -------------------------------
# loss: 0.073255  [    4/  183]
# loss: 0.049377  [   84/  183]
# loss: 0.026726  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.220046
#
# Epoch 138
# -------------------------------
# loss: 0.115721  [    4/  183]
# loss: 0.005572  [   84/  183]
# loss: 0.013319  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.197869
#
# Epoch 139
# -------------------------------
# loss: 0.098725  [    4/  183]
# loss: 0.014356  [   84/  183]
# loss: 0.106017  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.218110
#
# Epoch 140
# -------------------------------
# loss: 0.002059  [    4/  183]
# loss: 0.063635  [   84/  183]
# loss: 0.000826  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 83.3%, Avg loss: 0.303073
#
# Epoch 141
# -------------------------------
# loss: 0.107812  [    4/  183]
# loss: 0.007458  [   84/  183]
# loss: 0.009973  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.253623
#
# Epoch 142
# -------------------------------
# loss: 0.063580  [    4/  183]
# loss: 0.015868  [   84/  183]
# loss: 0.105982  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.238492
#
# Epoch 143
# -------------------------------
# loss: 0.101643  [    4/  183]
# loss: 0.006843  [   84/  183]
# loss: 0.006761  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.192079
#
# Epoch 144
# -------------------------------
# loss: 0.002719  [    4/  183]
# loss: 0.057547  [   84/  183]
# loss: 0.000185  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.223320
#
# Epoch 145
# -------------------------------
# loss: 0.023129  [    4/  183]
# loss: 0.017572  [   84/  183]
# loss: 0.007613  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.191569
#
# Epoch 146
# -------------------------------
# loss: 0.005164  [    4/  183]
# loss: 0.206514  [   84/  183]
# loss: 0.014688  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.199246
#
# Epoch 147
# -------------------------------
# loss: 0.016122  [    4/  183]
# loss: 0.010206  [   84/  183]
# loss: 0.025934  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.231262
#
# Epoch 148
# -------------------------------
# loss: 0.018418  [    4/  183]
# loss: 0.016078  [   84/  183]
# loss: 0.090757  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.195856
#
# Epoch 149
# -------------------------------
# loss: 0.128268  [    4/  183]
# loss: 0.021146  [   84/  183]
# loss: 0.099228  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.242239
#
# Epoch 150
# -------------------------------
# loss: 0.028663  [    4/  183]
# loss: 0.004128  [   84/  183]
# loss: 0.169178  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 83.3%, Avg loss: 0.259045
#
# Epoch 151
# -------------------------------
# loss: 0.014906  [    4/  183]
# loss: 0.027770  [   84/  183]
# loss: 0.018837  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.209771
#
# Epoch 152
# -------------------------------
# loss: 0.026716  [    4/  183]
# loss: 0.242059  [   84/  183]
# loss: 0.071332  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.206847
#
# Epoch 153
# -------------------------------
# loss: 0.004285  [    4/  183]
# loss: 0.062634  [   84/  183]
# loss: 0.048456  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.203466
#
# Epoch 154
# -------------------------------
# loss: 0.004727  [    4/  183]
# loss: 0.013695  [   84/  183]
# loss: 0.000510  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.186834
#
# Epoch 155
# -------------------------------
# loss: 0.023839  [    4/  183]
# loss: 0.159518  [   84/  183]
# loss: 0.027101  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.218999
#
# Epoch 156
# -------------------------------
# loss: 0.258590  [    4/  183]
# loss: 0.105062  [   84/  183]
# loss: 0.031390  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.193241
#
# Epoch 157
# -------------------------------
# loss: 0.007448  [    4/  183]
# loss: 0.164198  [   84/  183]
# loss: 0.088731  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.186809
#
# Epoch 158
# -------------------------------
# loss: 0.002117  [    4/  183]
# loss: 0.089689  [   84/  183]
# loss: 0.057504  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.214884
#
# Epoch 159
# -------------------------------
# loss: 0.009404  [    4/  183]
# loss: 0.115888  [   84/  183]
# loss: 0.006596  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.191786
#
# Epoch 160
# -------------------------------
# loss: 0.007360  [    4/  183]
# loss: 0.014966  [   84/  183]
# loss: 0.002826  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.187709
#
# Epoch 161
# -------------------------------
# loss: 0.007201  [    4/  183]
# loss: 0.000159  [   84/  183]
# loss: 0.022669  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.191014
#
# Epoch 162
# -------------------------------
# loss: 0.014096  [    4/  183]
# loss: 0.180145  [   84/  183]
# loss: 0.091308  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.198135
#
# Epoch 163
# -------------------------------
# loss: 0.007534  [    4/  183]
# loss: 0.022381  [   84/  183]
# loss: 0.002585  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.183744
#
# Epoch 164
# -------------------------------
# loss: 0.221881  [    4/  183]
# loss: 0.000480  [   84/  183]
# loss: 0.002551  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.196175
#
# Epoch 165
# -------------------------------
# loss: 0.019514  [    4/  183]
# loss: 0.003325  [   84/  183]
# loss: 0.005232  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 88.1%, Avg loss: 0.247555
#
# Epoch 166
# -------------------------------
# loss: 0.018212  [    4/  183]
# loss: 0.017596  [   84/  183]
# loss: 0.011125  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.190756
#
# Epoch 167
# -------------------------------
# loss: 0.007301  [    4/  183]
# loss: 0.103591  [   84/  183]
# loss: 0.087059  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.190355
#
# Epoch 168
# -------------------------------
# loss: 0.013736  [    4/  183]
# loss: 0.019579  [   84/  183]
# loss: 0.167517  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.230208
#
# Epoch 169
# -------------------------------
# loss: 0.001636  [    4/  183]
# loss: 0.000323  [   84/  183]
# loss: 0.022172  [  164/  183]
# Test Error:
#  Recall: 81.0%, Accuracy: 85.7%, Avg loss: 0.255167
#
# Epoch 170
# -------------------------------
# loss: 0.225146  [    4/  183]
# loss: 0.000879  [   84/  183]
# loss: 0.251582  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.236325
#
# Epoch 171
# -------------------------------
# loss: 0.007650  [    4/  183]
# loss: 0.049933  [   84/  183]
# loss: 0.023985  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.193546
#
# Epoch 172
# -------------------------------
# loss: 0.001520  [    4/  183]
# loss: 0.030785  [   84/  183]
# loss: 0.011879  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.235719
#
# Epoch 173
# -------------------------------
# loss: 0.145313  [    4/  183]
# loss: 0.028333  [   84/  183]
# loss: 0.016272  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.229758
#
# Epoch 174
# -------------------------------
# loss: 0.074916  [    4/  183]
# loss: 0.024802  [   84/  183]
# loss: 0.000087  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.230024
#
# Epoch 175
# -------------------------------
# loss: 0.011132  [    4/  183]
# loss: 0.156541  [   84/  183]
# loss: 0.032492  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.180623
#
# Epoch 176
# -------------------------------
# loss: 0.032900  [    4/  183]
# loss: 0.039428  [   84/  183]
# loss: 0.028797  [  164/  183]
# Test Error:
#  Recall: 76.2%, Accuracy: 83.3%, Avg loss: 0.239230
#
# Epoch 177
# -------------------------------
# loss: 0.057516  [    4/  183]
# loss: 0.000521  [   84/  183]
# loss: 0.000945  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.195632
#
# Epoch 178
# -------------------------------
# loss: 0.007814  [    4/  183]
# loss: 0.007173  [   84/  183]
# loss: 0.039055  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.186552
#
# Epoch 179
# -------------------------------
# loss: 0.000838  [    4/  183]
# loss: 0.047103  [   84/  183]
# loss: 0.048532  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.184575
#
# Epoch 180
# -------------------------------
# loss: 0.060729  [    4/  183]
# loss: 0.065175  [   84/  183]
# loss: 0.066386  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.229428
#
# Epoch 181
# -------------------------------
# loss: 0.014134  [    4/  183]
# loss: 0.009997  [   84/  183]
# loss: 0.062169  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.179692
#
# Epoch 182
# -------------------------------
# loss: 0.032029  [    4/  183]
# loss: 0.002777  [   84/  183]
# loss: 0.021220  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.186715
#
# Epoch 183
# -------------------------------
# loss: 0.035045  [    4/  183]
# loss: 0.002260  [   84/  183]
# loss: 0.002364  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.178264
#
# Epoch 184
# -------------------------------
# loss: 0.008637  [    4/  183]
# loss: 0.000724  [   84/  183]
# loss: 0.000833  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.207903
#
# Epoch 185
# -------------------------------
# loss: 0.009096  [    4/  183]
# loss: 0.009475  [   84/  183]
# loss: 0.024012  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.183345
#
# Epoch 186
# -------------------------------
# loss: 0.033295  [    4/  183]
# loss: 0.018922  [   84/  183]
# loss: 0.128342  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.171494
#
# Epoch 187
# -------------------------------
# loss: 0.014126  [    4/  183]
# loss: 0.010703  [   84/  183]
# loss: 0.000287  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.214366
#
# Epoch 188
# -------------------------------
# loss: 0.007354  [    4/  183]
# loss: 0.000748  [   84/  183]
# loss: 0.140472  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.185832
#
# Epoch 189
# -------------------------------
# loss: 0.013303  [    4/  183]
# loss: 0.001144  [   84/  183]
# loss: 0.009494  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 88.1%, Avg loss: 0.219443
#
# Epoch 190
# -------------------------------
# loss: 0.022003  [    4/  183]
# loss: 0.014406  [   84/  183]
# loss: 0.013398  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.175783
#
# Epoch 191
# -------------------------------
# loss: 0.002618  [    4/  183]
# loss: 0.032402  [   84/  183]
# loss: 0.006081  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.184341
#
# Epoch 192
# -------------------------------
# loss: 0.112276  [    4/  183]
# loss: 0.000158  [   84/  183]
# loss: 0.019188  [  164/  183]
# Test Error:
#  Recall: 85.7%, Accuracy: 85.7%, Avg loss: 0.216575
#
# Epoch 193
# -------------------------------
# loss: 0.033331  [    4/  183]
# loss: 0.018140  [   84/  183]
# loss: 0.008997  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.224718
#
# Epoch 194
# -------------------------------
# loss: 0.013984  [    4/  183]
# loss: 0.049644  [   84/  183]
# loss: 0.029368  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.188683
#
# Epoch 195
# -------------------------------
# loss: 0.002312  [    4/  183]
# loss: 0.004529  [   84/  183]
# loss: 0.095791  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.182413
#
# Epoch 196
# -------------------------------
# loss: 0.048923  [    4/  183]
# loss: 0.011592  [   84/  183]
# loss: 0.000147  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.191023
#
# Epoch 197
# -------------------------------
# loss: 0.008761  [    4/  183]
# loss: 0.012573  [   84/  183]
# loss: 0.053613  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.208277
#
# Epoch 198
# -------------------------------
# loss: 0.007588  [    4/  183]
# loss: 0.112439  [   84/  183]
# loss: 0.000104  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.176683
#
# Epoch 199
# -------------------------------
# loss: 0.105381  [    4/  183]
# loss: 0.005660  [   84/  183]
# loss: 0.019000  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.173361
#
# Epoch 200
# -------------------------------
# loss: 0.012629  [    4/  183]
# loss: 0.008603  [   84/  183]
# loss: 0.000999  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.221657
#
# Epoch 201
# -------------------------------
# loss: 0.008528  [    4/  183]
# loss: 0.005942  [   84/  183]
# loss: 0.017871  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.177956
#
# Epoch 202
# -------------------------------
# loss: 0.018793  [    4/  183]
# loss: 0.024595  [   84/  183]
# loss: 0.001852  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.185330
#
# Epoch 203
# -------------------------------
# loss: 0.009450  [    4/  183]
# loss: 0.004927  [   84/  183]
# loss: 0.008710  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.202976
#
# Epoch 204
# -------------------------------
# loss: 0.000424  [    4/  183]
# loss: 0.000279  [   84/  183]
# loss: 0.011045  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.226484
#
# Epoch 205
# -------------------------------
# loss: 0.052975  [    4/  183]
# loss: 0.005562  [   84/  183]
# loss: 0.041592  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 90.5%, Avg loss: 0.204387
#
# Epoch 206
# -------------------------------
# loss: 0.052388  [    4/  183]
# loss: 0.005023  [   84/  183]
# loss: 0.076777  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.173066
#
# Epoch 207
# -------------------------------
# loss: 0.005888  [    4/  183]
# loss: 0.000698  [   84/  183]
# loss: 0.001061  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.177825
#
# Epoch 208
# -------------------------------
# loss: 0.000574  [    4/  183]
# loss: 0.026034  [   84/  183]
# loss: 0.001341  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.169126
#
# Epoch 209
# -------------------------------
# loss: 0.000157  [    4/  183]
# loss: 0.014027  [   84/  183]
# loss: 0.063959  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.169278
#
# Epoch 210
# -------------------------------
# loss: 0.002853  [    4/  183]
# loss: 0.031344  [   84/  183]
# loss: 0.042972  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.189624
#
# Epoch 211
# -------------------------------
# loss: 0.000085  [    4/  183]
# loss: 0.008203  [   84/  183]
# loss: 0.025656  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.173463
#
# Epoch 212
# -------------------------------
# loss: 0.007380  [    4/  183]
# loss: 0.031168  [   84/  183]
# loss: 0.012676  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.176330
#
# Epoch 213
# -------------------------------
# loss: 0.014570  [    4/  183]
# loss: 0.009888  [   84/  183]
# loss: 0.023586  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.171171
#
# Epoch 214
# -------------------------------
# loss: 0.033233  [    4/  183]
# loss: 0.009464  [   84/  183]
# loss: 0.013096  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.174084
#
# Epoch 215
# -------------------------------
# loss: 0.010023  [    4/  183]
# loss: 0.000964  [   84/  183]
# loss: 0.018638  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.172608
#
# Epoch 216
# -------------------------------
# loss: 0.014931  [    4/  183]
# loss: 0.006487  [   84/  183]
# loss: 0.019982  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.170531
#
# Epoch 217
# -------------------------------
# loss: 0.004985  [    4/  183]
# loss: 0.046804  [   84/  183]
# loss: 0.000148  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.172316
#
# Epoch 218
# -------------------------------
# loss: 0.003344  [    4/  183]
# loss: 0.008450  [   84/  183]
# loss: 0.000162  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.193798
#
# Epoch 219
# -------------------------------
# loss: 0.004564  [    4/  183]
# loss: 0.021974  [   84/  183]
# loss: 0.001669  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.199561
#
# Epoch 220
# -------------------------------
# loss: 0.013931  [    4/  183]
# loss: 0.001451  [   84/  183]
# loss: 0.002308  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.174150
#
# Epoch 221
# -------------------------------
# loss: 0.002500  [    4/  183]
# loss: 0.007611  [   84/  183]
# loss: 0.127578  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.171433
#
# Epoch 222
# -------------------------------
# loss: 0.063222  [    4/  183]
# loss: 0.008722  [   84/  183]
# loss: 0.007562  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.192116
#
# Epoch 223
# -------------------------------
# loss: 0.000098  [    4/  183]
# loss: 0.010310  [   84/  183]
# loss: 0.003445  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.167720
#
# Epoch 224
# -------------------------------
# loss: 0.000209  [    4/  183]
# loss: 0.025142  [   84/  183]
# loss: 0.003650  [  164/  183]
# Test Error:
#  Recall: 90.5%, Accuracy: 88.1%, Avg loss: 0.184091
#
# Epoch 225
# -------------------------------
# loss: 0.001500  [    4/  183]
# loss: 0.001283  [   84/  183]
# loss: 0.010377  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.167714
#
# Epoch 226
# -------------------------------
# loss: 0.015157  [    4/  183]
# loss: 0.002906  [   84/  183]
# loss: 0.058763  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.161183
#
# Epoch 227
# -------------------------------
# loss: 0.000195  [    4/  183]
# loss: 0.000809  [   84/  183]
# loss: 0.000107  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.163255
#
# Epoch 228
# -------------------------------
# loss: 0.001690  [    4/  183]
# loss: 0.002436  [   84/  183]
# loss: 0.000585  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.177280
#
# Epoch 229
# -------------------------------
# loss: 0.002108  [    4/  183]
# loss: 0.093160  [   84/  183]
# loss: 0.014479  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.173842
#
# Epoch 230
# -------------------------------
# loss: 0.004273  [    4/  183]
# loss: 0.000022  [   84/  183]
# loss: 0.024777  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.182407
#
# Epoch 231
# -------------------------------
# loss: 0.002638  [    4/  183]
# loss: 0.014967  [   84/  183]
# loss: 0.011028  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.201592
#
# Epoch 232
# -------------------------------
# loss: 0.003038  [    4/  183]
# loss: 0.006143  [   84/  183]
# loss: 0.029828  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.173754
#
# Epoch 233
# -------------------------------
# loss: 0.006197  [    4/  183]
# loss: 0.014630  [   84/  183]
# loss: 0.002860  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.174207
#
# Epoch 234
# -------------------------------
# loss: 0.001897  [    4/  183]
# loss: 0.002109  [   84/  183]
# loss: 0.014318  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.167569
#
# Epoch 235
# -------------------------------
# loss: 0.026940  [    4/  183]
# loss: 0.007411  [   84/  183]
# loss: 0.001943  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.203897
#
# Epoch 236
# -------------------------------
# loss: 0.000023  [    4/  183]
# loss: 0.015515  [   84/  183]
# loss: 0.002388  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.173975
#
# Epoch 237
# -------------------------------
# loss: 0.003149  [    4/  183]
# loss: 0.014896  [   84/  183]
# loss: 0.006268  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.168323
#
# Epoch 238
# -------------------------------
# loss: 0.005834  [    4/  183]
# loss: 0.000307  [   84/  183]
# loss: 0.014651  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.183117
#
# Epoch 239
# -------------------------------
# loss: 0.000236  [    4/  183]
# loss: 0.012312  [   84/  183]
# loss: 0.003348  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.162692
#
# Epoch 240
# -------------------------------
# loss: 0.013603  [    4/  183]
# loss: 0.012955  [   84/  183]
# loss: 0.007792  [  164/  183]
# Test Error:
#  Recall: 95.2%, Accuracy: 90.5%, Avg loss: 0.163534
#
# Epoch 241
# ...
# loss: 0.005382  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.080243
#
# Epoch 206
# -------------------------------
# loss: 0.001176  [    4/  103]
# loss: 0.002620  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.071379
#
# Epoch 207
# -------------------------------
# loss: 0.008383  [    4/  103]
# loss: 0.012681  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.070905
#
# Epoch 208
# -------------------------------
# loss: 0.292535  [    4/  103]
# loss: 0.032828  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.087597
#
# Epoch 209
# -------------------------------
# loss: 0.022194  [    4/  103]
# loss: 0.009264  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.075401
#
# Epoch 210
# -------------------------------
# loss: 0.007306  [    4/  103]
# loss: 0.120878  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.072144
#
# Epoch 211
# -------------------------------
# loss: 0.006132  [    4/  103]
# loss: 0.011047  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.095889
#
# Epoch 212
# -------------------------------
# loss: 0.062130  [    4/  103]
# loss: 0.042987  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.065888
#
# Epoch 213
# -------------------------------
# loss: 0.014328  [    4/  103]
# loss: 0.009810  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.089110
#
# Epoch 214
# -------------------------------
# loss: 0.032588  [    4/  103]
# loss: 0.010831  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.068359
#
# Epoch 215
# -------------------------------
# loss: 0.006522  [    4/  103]
# loss: 0.263866  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.087421
#
# Epoch 216
# -------------------------------
# loss: 0.000813  [    4/  103]
# loss: 0.006218  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.090586
#
# Epoch 217
# -------------------------------
# loss: 0.014450  [    4/  103]
# loss: 0.063649  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.106368
#
# Epoch 218
# -------------------------------
# loss: 0.055419  [    4/  103]
# loss: 0.003294  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.063456
#
# Epoch 219
# -------------------------------
# loss: 0.008605  [    4/  103]
# loss: 0.022616  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.069105
#
# Epoch 220
# -------------------------------
# loss: 0.010668  [    4/  103]
# loss: 0.199645  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.066243
#
# Epoch 221
# -------------------------------
# loss: 0.022353  [    4/  103]
# loss: 0.084691  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.102170
#
# Epoch 222
# -------------------------------
# loss: 0.061295  [    4/  103]
# loss: 0.001442  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.061767
#
# Epoch 223
# -------------------------------
# loss: 0.006153  [    4/  103]
# loss: 0.013209  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.061722
#
# Epoch 224
# -------------------------------
# loss: 0.062464  [    4/  103]
# loss: 0.006349  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.071482
#
# Epoch 225
# -------------------------------
# loss: 0.061682  [    4/  103]
# loss: 0.022054  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.061231
#
# Epoch 226
# -------------------------------
# loss: 0.036779  [    4/  103]
# loss: 0.004910  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.066058
#
# Epoch 227
# -------------------------------
# loss: 0.007510  [    4/  103]
# loss: 0.000596  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.063383
#
# Epoch 228
# -------------------------------
# loss: 0.161505  [    4/  103]
# loss: 0.001061  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.069413
#
# Epoch 229
# -------------------------------
# loss: 0.005049  [    4/  103]
# loss: 0.013811  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.059408
#
# Epoch 230
# -------------------------------
# loss: 0.017604  [    4/  103]
# loss: 0.181551  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.077025
#
# Epoch 231
# -------------------------------
# loss: 0.001361  [    4/  103]
# loss: 0.029549  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.065688
#
# Epoch 232
# -------------------------------
# loss: 0.028966  [    4/  103]
# loss: 0.060464  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.084705
#
# Epoch 233
# -------------------------------
# loss: 0.001600  [    4/  103]
# loss: 0.000574  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.060119
#
# Epoch 234
# -------------------------------
# loss: 0.112350  [    4/  103]
# loss: 0.000414  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.059584
#
# Epoch 235
# -------------------------------
# loss: 0.087754  [    4/  103]
# loss: 0.017414  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.057065
#
# Epoch 236
# -------------------------------
# loss: 0.002287  [    4/  103]
# loss: 0.000711  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.058560
#
# Epoch 237
# -------------------------------
# loss: 0.009889  [    4/  103]
# loss: 0.065559  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.054575
#
# Epoch 238
# -------------------------------
# loss: 0.076789  [    4/  103]
# loss: 0.010294  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.062966
#
# Epoch 239
# -------------------------------
# loss: 0.002285  [    4/  103]
# loss: 0.001209  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.077706
#
# Epoch 240
# -------------------------------
# loss: 0.016946  [    4/  103]
# loss: 0.082871  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.064808
#
# Epoch 241
# -------------------------------
# loss: 0.028604  [    4/  103]
# loss: 0.080792  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.057100
#
# Epoch 242
# -------------------------------
# loss: 0.134876  [    4/  103]
# loss: 0.133411  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.065706
#
# Epoch 243
# -------------------------------
# loss: 0.037725  [    4/  103]
# loss: 0.002135  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.055307
#
# Epoch 244
# -------------------------------
# loss: 0.011803  [    4/  103]
# loss: 0.037653  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.058433
#
# Epoch 245
# -------------------------------
# loss: 0.175125  [    4/  103]
# loss: 0.035923  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.062151
#
# Epoch 246
# -------------------------------
# loss: 0.324658  [    4/  103]
# loss: 0.002165  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.059996
#
# Epoch 247
# -------------------------------
# loss: 0.134957  [    4/  103]
# loss: 0.001371  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.056412
#
# Epoch 248
# -------------------------------
# loss: 0.083903  [    4/  103]
# loss: 0.011942  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.067358
#
# Epoch 249
# -------------------------------
# loss: 0.024430  [    4/  103]
# loss: 0.003646  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.063163
#
# Epoch 250
# -------------------------------
# loss: 0.029851  [    4/  103]
# loss: 0.004371  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.058463
#
# Epoch 251
# -------------------------------
# loss: 0.002599  [    4/  103]
# loss: 0.165008  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.055579
#
# Epoch 252
# -------------------------------
# loss: 0.007576  [    4/  103]
# loss: 0.127624  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.055000
#
# Epoch 253
# -------------------------------
# loss: 0.001998  [    4/  103]
# loss: 0.002556  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.056749
#
# Epoch 254
# -------------------------------
# loss: 0.017779  [    4/  103]
# loss: 0.007433  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.065904
#
# Epoch 255
# -------------------------------
# loss: 0.316860  [    4/  103]
# loss: 0.037591  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.055320
#
# Epoch 256
# -------------------------------
# loss: 0.002587  [    4/  103]
# loss: 0.001388  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.057277
#
# Epoch 257
# -------------------------------
# loss: 0.100818  [    4/  103]
# loss: 0.025887  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.059810
#
# Epoch 258
# -------------------------------
# loss: 0.011607  [    4/  103]
# loss: 0.051103  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.060185
#
# Epoch 259
# -------------------------------
# loss: 0.001317  [    4/  103]
# loss: 0.031136  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.056741
#
# Epoch 260
# -------------------------------
# loss: 0.008320  [    4/  103]
# loss: 0.000393  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.063416
#
# Epoch 261
# -------------------------------
# loss: 0.324122  [    4/  103]
# loss: 0.000274  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.065824
#
# Epoch 262
# -------------------------------
# loss: 0.035061  [    4/  103]
# loss: 0.010412  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.066990
#
# Epoch 263
# -------------------------------
# loss: 0.130240  [    4/  103]
# loss: 0.006432  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.052855
#
# Epoch 264
# -------------------------------
# loss: 0.078060  [    4/  103]
# loss: 0.000306  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.051087
#
# Epoch 265
# -------------------------------
# loss: 0.015002  [    4/  103]
# loss: 0.065208  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.054777
#
# Epoch 266
# -------------------------------
# loss: 0.000573  [    4/  103]
# loss: 0.016915  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.058185
#
# Epoch 267
# -------------------------------
# loss: 0.013687  [    4/  103]
# loss: 0.000401  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.058316
#
# Epoch 268
# -------------------------------
# loss: 0.000249  [    4/  103]
# loss: 0.127693  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.053349
#
# Epoch 269
# -------------------------------
# loss: 0.025714  [    4/  103]
# loss: 0.000560  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.052967
#
# Epoch 270
# -------------------------------
# loss: 0.008164  [    4/  103]
# loss: 0.003198  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.052140
#
# Epoch 271
# -------------------------------
# loss: 0.010660  [    4/  103]
# loss: 0.004016  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.067603
#
# Epoch 272
# -------------------------------
# loss: 0.037787  [    4/  103]
# loss: 0.004456  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.050278
#
# Epoch 273
# -------------------------------
# loss: 0.002835  [    4/  103]
# loss: 0.002305  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.075522
#
# Epoch 274
# -------------------------------
# loss: 0.027471  [    4/  103]
# loss: 0.000739  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.051332
#
# Epoch 275
# -------------------------------
# loss: 0.008036  [    4/  103]
# loss: 0.000361  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.064966
#
# Epoch 276
# -------------------------------
# loss: 0.004957  [    4/  103]
# loss: 0.017149  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.054082
#
# Epoch 277
# -------------------------------
# loss: 0.005427  [    4/  103]
# loss: 0.034344  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.054261
#
# Epoch 278
# -------------------------------
# loss: 0.006394  [    4/  103]
# loss: 0.019474  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.052636
#
# Epoch 279
# -------------------------------
# loss: 0.157961  [    4/  103]
# loss: 0.001546  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.061352
#
# Epoch 280
# -------------------------------
# loss: 0.002201  [    4/  103]
# loss: 0.043948  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.056696
#
# Epoch 281
# -------------------------------
# loss: 0.000106  [    4/  103]
# loss: 0.031133  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.048435
#
# Epoch 282
# -------------------------------
# loss: 0.152431  [    4/  103]
# loss: 0.008880  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.057861
#
# Epoch 283
# -------------------------------
# loss: 0.070620  [    4/  103]
# loss: 0.002474  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.052883
#
# Epoch 284
# -------------------------------
# loss: 0.004033  [    4/  103]
# loss: 0.002607  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.045784
#
# Epoch 285
# -------------------------------
# loss: 0.000663  [    4/  103]
# loss: 0.011129  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.057985
#
# Epoch 286
# -------------------------------
# loss: 0.007640  [    4/  103]
# loss: 0.000756  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.051335
#
# Epoch 287
# -------------------------------
# loss: 0.000419  [    4/  103]
# loss: 0.007869  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.049769
#
# Epoch 288
# -------------------------------
# loss: 0.000863  [    4/  103]
# loss: 0.000739  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.044060
#
# Epoch 289
# -------------------------------
# loss: 0.001712  [    4/  103]
# loss: 0.002166  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.046425
#
# Epoch 290
# -------------------------------
# loss: 0.038687  [    4/  103]
# loss: 0.022140  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.044358
#
# Epoch 291
# -------------------------------
# loss: 0.169483  [    4/  103]
# loss: 0.002733  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.050667
#
# Epoch 292
# -------------------------------
# loss: 0.000496  [    4/  103]
# loss: 0.002836  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.044514
#
# Epoch 293
# -------------------------------
# loss: 0.000540  [    4/  103]
# loss: 0.004250  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.061357
#
# Epoch 294
# -------------------------------
# loss: 0.023274  [    4/  103]
# loss: 0.031012  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.060826
#
# Epoch 295
# -------------------------------
# loss: 0.002104  [    4/  103]
# loss: 0.000467  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.059582
#
# Epoch 296
# -------------------------------
# loss: 0.004732  [    4/  103]
# loss: 0.024443  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.061867
#
# Epoch 297
# -------------------------------
# loss: 0.014619  [    4/  103]
# loss: 0.016444  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.062382
#
# Epoch 298
# -------------------------------
# loss: 0.004436  [    4/  103]
# loss: 0.001037  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.059588
#
# Epoch 299
# -------------------------------
# loss: 0.000791  [    4/  103]
# loss: 0.000130  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.051750
#
# Done!

# %% [markdown]
# This looks promising: the model seems to learn the positive cases even when the proportion in the dataset is as low as 10%, it just takes longer. The number of epochs $ e $ until the model reaches nonzero recall seems to be roughly $ O(p) $, where $ p $ is the proportion of positive examples in the dataset. This fits with intuition, because the number of positive examples seen by the model (with repeats) is the product $ e p $, and if $ e = O(p) $ then this product is roughly constant.

# %% [markdown]
# # Focal loss
#
# We could put different weights on the classes, but let's assume that we can't do this. This is because the block landing model architecture is intended to be part of a larger Tetris emulator model, and I'd rather avoid injecting knowledge about landed/not landed class weights into the middle of the model because that is essentially giving it domain knowledge.
#
# Let's try using focal loss instead to see if it improves the training.

# %%
from torchvision.ops import sigmoid_focal_loss

loss_fns = {
    "focal_0p2": lambda inputs, targets: sigmoid_focal_loss(inputs, targets, reduction="mean", alpha=-1, gamma=0.2),
    "focal_0p4": lambda inputs, targets: sigmoid_focal_loss(inputs, targets, reduction="mean", alpha=-1, gamma=0.4),
    "focal_0p6": lambda inputs, targets: sigmoid_focal_loss(inputs, targets, reduction="mean", alpha=-1, gamma=0.6),
    "focal_0p8": lambda inputs, targets: sigmoid_focal_loss(inputs, targets, reduction="mean", alpha=-1, gamma=0.8),
    "bce": nn.BCEWithLogitsLoss(),
}
pos_frac = 0.1
learning_rate = 1e-2
batch_size = 4
epochs = 300

log_dir = os.path.join("runs", "experiment_008")
shutil.rmtree(log_dir, ignore_errors=True)

for name, loss_fn in loss_fns.items():
    train_dataset = ImbalancedDataset(BlockLandingDataset(os.path.join("data", "block_landing", "train")), pos_frac)
    test_dataset = ImbalancedDataset(BlockLandingDataset(os.path.join("data", "block_landing", "test")), pos_frac)
    train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)
    test_dataloader = DataLoader(test_dataset, batch_size=4, shuffle=True)
    
    model = BlockLandingModel().to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    log_subdir = os.path.join(log_dir, name + "_" + datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S"))
    tb = SummaryWriter(log_subdir)

    for t in range(epochs):
        print(f"Epoch {t}\n-------------------------------")
        train_metrics = train_loop(train_dataloader, model, loss_fn, optimizer)
        test_metrics = test_loop(test_dataloader, model, loss_fn)
        tb.add_scalar("Loss/train", train_metrics["loss"], t)
        tb.add_scalar("Accuracy/train", train_metrics["acc"], t)
        tb.add_scalar("Recall/train", train_metrics["rec"], t)
        tb.add_scalar("Loss/test", test_metrics["loss"], t)
        tb.add_scalar("Accuracy/test", test_metrics["acc"], t)
        tb.add_scalar("Recall/test", test_metrics["rec"], t)
        for name, weight in model.named_parameters():
            tb.add_histogram(f"Weights/{name}", weight, t)
            tb.add_histogram(f"Gradients/{name}", weight.grad, t)

    tb.close()
    print("Done!")
# Out:
# pos_fraction: requested 0.100, got 0.097
# Total positive examples: 10
# pos_fraction: requested 0.100, got 0.087
# Total positive examples: 2
# Epoch 0
# -------------------------------
# loss: 0.694552  [    4/  103]
# loss: 0.609268  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 82.6%, Avg loss: 0.596175
#
# Epoch 1
# -------------------------------
# loss: 0.592577  [    4/  103]
# loss: 0.569939  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.546273
#
# Epoch 2
# -------------------------------
# loss: 0.570934  [    4/  103]
# loss: 0.497831  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.509351
#
# Epoch 3
# -------------------------------
# loss: 0.543609  [    4/  103]
# loss: 0.448894  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.472476
#
# Epoch 4
# -------------------------------
# loss: 0.439945  [    4/  103]
# loss: 0.415236  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.442535
#
# Epoch 5
# -------------------------------
# loss: 0.514714  [    4/  103]
# loss: 0.500522  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.414840
#
# Epoch 6
# -------------------------------
# loss: 0.506523  [    4/  103]
# loss: 0.339983  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.387572
#
# Epoch 7
# -------------------------------
# loss: 0.324431  [    4/  103]
# loss: 0.301598  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.361518
#
# Epoch 8
# -------------------------------
# loss: 0.287657  [    4/  103]
# loss: 0.270192  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.333748
#
# Epoch 9
# -------------------------------
# loss: 0.246960  [    4/  103]
# loss: 0.229809  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.306916
#
# Epoch 10
# -------------------------------
# loss: 0.471725  [    4/  103]
# loss: 0.185980  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.303226
#
# Epoch 11
# -------------------------------
# loss: 0.172915  [    4/  103]
# loss: 0.495122  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.292481
#
# Epoch 12
# -------------------------------
# loss: 0.147205  [    4/  103]
# loss: 0.117786  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.261348
#
# Epoch 13
# -------------------------------
# loss: 0.113215  [    4/  103]
# loss: 0.529706  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.257208
#
# Epoch 14
# -------------------------------
# loss: 0.109470  [    4/  103]
# loss: 0.100542  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.254171
#
# Epoch 15
# -------------------------------
# loss: 0.097429  [    4/  103]
# loss: 0.088317  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.252862
#
# Epoch 16
# -------------------------------
# loss: 0.094894  [    4/  103]
# loss: 1.054933  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.252466
#
# Epoch 17
# -------------------------------
# loss: 0.093520  [    4/  103]
# loss: 0.089886  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.251244
#
# Epoch 18
# -------------------------------
# loss: 0.087591  [    4/  103]
# loss: 0.093358  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.250215
#
# Epoch 19
# -------------------------------
# loss: 0.084595  [    4/  103]
# loss: 0.102466  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.249364
#
# Epoch 20
# -------------------------------
# loss: 1.040441  [    4/  103]
# loss: 0.604816  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.249351
#
# Epoch 21
# -------------------------------
# loss: 0.085857  [    4/  103]
# loss: 1.079324  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.249358
#
# Epoch 22
# -------------------------------
# loss: 1.032359  [    4/  103]
# loss: 0.548535  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.248691
#
# Epoch 23
# -------------------------------
# loss: 0.584843  [    4/  103]
# loss: 0.090239  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.248453
#
# Epoch 24
# -------------------------------
# loss: 0.079233  [    4/  103]
# loss: 0.084977  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.248086
#
# Epoch 25
# -------------------------------
# loss: 0.081728  [    4/  103]
# loss: 0.560404  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.247655
#
# Epoch 26
# -------------------------------
# loss: 0.082652  [    4/  103]
# loss: 0.559783  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.275538
#
# Epoch 27
# -------------------------------
# loss: 0.075559  [    4/  103]
# loss: 0.564013  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.274602
#
# Epoch 28
# -------------------------------
# loss: 0.083149  [    4/  103]
# loss: 0.083222  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.247738
#
# Epoch 29
# -------------------------------
# loss: 0.084069  [    4/  103]
# loss: 0.552301  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.274731
#
# Epoch 30
# -------------------------------
# loss: 0.562602  [    4/  103]
# loss: 0.086274  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.247132
#
# Epoch 31
# -------------------------------
# loss: 0.084639  [    4/  103]
# loss: 0.085020  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.246793
#
# Epoch 32
# -------------------------------
# loss: 0.082121  [    4/  103]
# loss: 0.083255  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.246648
#
# Epoch 33
# -------------------------------
# loss: 0.089041  [    4/  103]
# loss: 0.102641  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.246554
#
# Epoch 34
# -------------------------------
# loss: 0.572173  [    4/  103]
# loss: 0.088097  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.273936
#
# Epoch 35
# -------------------------------
# loss: 0.081193  [    4/  103]
# loss: 0.073824  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.246685
#
# Epoch 36
# -------------------------------
# loss: 0.087697  [    4/  103]
# loss: 0.085435  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.246205
#
# Epoch 37
# -------------------------------
# loss: 0.082795  [    4/  103]
# loss: 0.079357  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.247116
#
# Epoch 38
# -------------------------------
# loss: 0.087441  [    4/  103]
# loss: 0.080632  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.273677
#
# Epoch 39
# -------------------------------
# loss: 0.085414  [    4/  103]
# loss: 0.079491  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.299619
#
# Epoch 40
# -------------------------------
# loss: 0.088996  [    4/  103]
# loss: 0.096751  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.273209
#
# Epoch 41
# -------------------------------
# loss: 0.085063  [    4/  103]
# loss: 0.096658  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.273041
#
# Epoch 42
# -------------------------------
# loss: 0.082372  [    4/  103]
# loss: 0.092476  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.245295
#
# Epoch 43
# -------------------------------
# loss: 0.081534  [    4/  103]
# loss: 0.553855  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.245372
#
# Epoch 44
# -------------------------------
# loss: 0.080407  [    4/  103]
# loss: 0.557181  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.245910
#
# Epoch 45
# -------------------------------
# loss: 0.087664  [    4/  103]
# loss: 0.094426  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.271846
#
# Epoch 46
# -------------------------------
# loss: 0.083412  [    4/  103]
# loss: 0.069395  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.271939
#
# Epoch 47
# -------------------------------
# loss: 0.088304  [    4/  103]
# loss: 0.096442  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.272293
#
# Epoch 48
# -------------------------------
# loss: 0.081993  [    4/  103]
# loss: 0.083682  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.245009
#
# Epoch 49
# -------------------------------
# loss: 0.081919  [    4/  103]
# loss: 0.076676  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.244664
#
# Epoch 50
# -------------------------------
# loss: 0.565057  [    4/  103]
# loss: 0.552043  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.271852
#
# Epoch 51
# -------------------------------
# loss: 0.560717  [    4/  103]
# loss: 0.561600  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.271769
#
# Epoch 52
# -------------------------------
# loss: 0.089407  [    4/  103]
# loss: 0.097346  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.271661
#
# Epoch 53
# -------------------------------
# loss: 0.078372  [    4/  103]
# loss: 0.092095  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.243739
#
# Epoch 54
# -------------------------------
# loss: 0.080269  [    4/  103]
# loss: 1.065247  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.244464
#
# Epoch 55
# -------------------------------
# loss: 0.083549  [    4/  103]
# loss: 0.080317  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.243926
#
# Epoch 56
# -------------------------------
# loss: 0.077700  [    4/  103]
# loss: 0.574882  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.243842
#
# Epoch 57
# -------------------------------
# loss: 0.569483  [    4/  103]
# loss: 0.078016  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.244109
#
# Epoch 58
# -------------------------------
# loss: 0.082354  [    4/  103]
# loss: 0.079796  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.271391
#
# Epoch 59
# -------------------------------
# loss: 0.086663  [    4/  103]
# loss: 0.089105  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.244585
#
# Epoch 60
# -------------------------------
# loss: 0.545775  [    4/  103]
# loss: 0.076318  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.270443
#
# Epoch 61
# -------------------------------
# loss: 0.084481  [    4/  103]
# loss: 0.083963  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.243774
#
# Epoch 62
# -------------------------------
# loss: 0.084766  [    4/  103]
# loss: 0.085126  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.244138
#
# Epoch 63
# -------------------------------
# loss: 0.085732  [    4/  103]
# loss: 0.089699  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.243109
#
# Epoch 64
# -------------------------------
# loss: 0.549505  [    4/  103]
# loss: 0.089332  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.242924
#
# Epoch 65
# -------------------------------
# loss: 0.079368  [    4/  103]
# loss: 0.088233  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.243627
#
# Epoch 66
# -------------------------------
# loss: 0.085683  [    4/  103]
# loss: 0.556207  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.243430
#
# Epoch 67
# -------------------------------
# loss: 1.004388  [    4/  103]
# loss: 0.084516  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.242840
#
# Epoch 68
# -------------------------------
# loss: 0.553744  [    4/  103]
# loss: 0.088218  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.242322
#
# Epoch 69
# -------------------------------
# loss: 0.083444  [    4/  103]
# loss: 0.552912  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.242916
#
# Epoch 70
# -------------------------------
# loss: 0.079713  [    4/  103]
# loss: 0.081905  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.242087
#
# Epoch 71
# -------------------------------
# loss: 0.547347  [    4/  103]
# loss: 0.089825  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.268663
#
# Epoch 72
# -------------------------------
# loss: 0.549726  [    4/  103]
# loss: 0.083182  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.241354
#
# Epoch 73
# -------------------------------
# loss: 0.075022  [    4/  103]
# loss: 0.083862  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.241116
#
# Epoch 74
# -------------------------------
# loss: 0.562813  [    4/  103]
# loss: 0.084254  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.240985
#
# Epoch 75
# -------------------------------
# loss: 0.075669  [    4/  103]
# loss: 0.555157  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.241605
#
# Epoch 76
# -------------------------------
# loss: 1.013576  [    4/  103]
# loss: 0.553612  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.241846
#
# Epoch 77
# -------------------------------
# loss: 0.079924  [    4/  103]
# loss: 0.085187  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.241777
#
# Epoch 78
# -------------------------------
# loss: 0.077959  [    4/  103]
# loss: 0.084722  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.267305
#
# Epoch 79
# -------------------------------
# loss: 0.079988  [    4/  103]
# loss: 0.544470  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.241547
#
# Epoch 80
# -------------------------------
# loss: 0.080760  [    4/  103]
# loss: 0.080263  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.240199
#
# Epoch 81
# -------------------------------
# loss: 0.546093  [    4/  103]
# loss: 0.066893  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.241262
#
# Epoch 82
# -------------------------------
# loss: 0.083640  [    4/  103]
# loss: 0.539920  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.267487
#
# Epoch 83
# -------------------------------
# loss: 0.546228  [    4/  103]
# loss: 0.087821  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.239836
#
# Epoch 84
# -------------------------------
# loss: 0.077353  [    4/  103]
# loss: 0.555205  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.239980
#
# Epoch 85
# -------------------------------
# loss: 0.544984  [    4/  103]
# loss: 0.077409  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.240052
#
# Epoch 86
# -------------------------------
# loss: 0.079633  [    4/  103]
# loss: 0.083484  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.240080
#
# Epoch 87
# -------------------------------
# loss: 0.085273  [    4/  103]
# loss: 0.547798  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.239909
#
# Epoch 88
# -------------------------------
# loss: 1.007182  [    4/  103]
# loss: 0.069744  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.239481
#
# Epoch 89
# -------------------------------
# loss: 0.075347  [    4/  103]
# loss: 0.085943  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.238465
#
# Epoch 90
# -------------------------------
# loss: 0.082040  [    4/  103]
# loss: 0.079775  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.238808
#
# Epoch 91
# -------------------------------
# loss: 0.072043  [    4/  103]
# loss: 0.078888  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.239265
#
# Epoch 92
# -------------------------------
# loss: 0.080621  [    4/  103]
# loss: 0.072230  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.239390
#
# Epoch 93
# -------------------------------
# loss: 0.082469  [    4/  103]
# loss: 0.083334  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.239513
#
# Epoch 94
# -------------------------------
# loss: 0.084160  [    4/  103]
# loss: 0.087153  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.237806
#
# Epoch 95
# -------------------------------
# loss: 0.534974  [    4/  103]
# loss: 0.525418  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.237487
#
# Epoch 96
# -------------------------------
# loss: 0.086489  [    4/  103]
# loss: 0.533540  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.237850
#
# Epoch 97
# -------------------------------
# loss: 0.075851  [    4/  103]
# loss: 0.544432  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.265539
#
# Epoch 98
# -------------------------------
# loss: 0.087779  [    4/  103]
# loss: 0.083713  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.240103
#
# Epoch 99
# -------------------------------
# loss: 0.091205  [    4/  103]
# loss: 0.088702  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.263339
#
# Epoch 100
# -------------------------------
# loss: 0.083396  [    4/  103]
# loss: 0.082485  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.237164
#
# Epoch 101
# -------------------------------
# loss: 0.082045  [    4/  103]
# loss: 0.085210  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.236899
#
# Epoch 102
# -------------------------------
# loss: 0.083373  [    4/  103]
# loss: 0.072932  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.236043
#
# Epoch 103
# -------------------------------
# loss: 0.072237  [    4/  103]
# loss: 0.084110  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.235685
#
# Epoch 104
# -------------------------------
# loss: 0.065600  [    4/  103]
# loss: 0.548490  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.236787
#
# Epoch 105
# -------------------------------
# loss: 0.082017  [    4/  103]
# loss: 0.537847  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.235985
#
# Epoch 106
# -------------------------------
# loss: 0.518190  [    4/  103]
# loss: 0.072490  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.235747
#
# Epoch 107
# -------------------------------
# loss: 0.077361  [    4/  103]
# loss: 0.088201  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.235535
#
# Epoch 108
# -------------------------------
# loss: 0.081008  [    4/  103]
# loss: 0.091969  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.235875
#
# Epoch 109
# -------------------------------
# loss: 0.517997  [    4/  103]
# loss: 0.068580  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.234763
#
# Epoch 110
# -------------------------------
# loss: 0.091350  [    4/  103]
# loss: 0.516931  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.260863
#
# Epoch 111
# -------------------------------
# loss: 0.080448  [    4/  103]
# loss: 0.507891  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.234354
#
# Epoch 112
# -------------------------------
# loss: 0.082974  [    4/  103]
# loss: 0.070985  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.259069
#
# Epoch 113
# -------------------------------
# loss: 0.522445  [    4/  103]
# loss: 0.082198  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.233229
#
# Epoch 114
# -------------------------------
# loss: 0.508720  [    4/  103]
# loss: 0.099801  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.233137
#
# Epoch 115
# -------------------------------
# loss: 0.081108  [    4/  103]
# loss: 0.075244  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.233419
#
# Epoch 116
# -------------------------------
# loss: 0.091179  [    4/  103]
# loss: 0.070426  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.232560
#
# Epoch 117
# -------------------------------
# loss: 0.074519  [    4/  103]
# loss: 0.560701  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.257708
#
# Epoch 118
# -------------------------------
# loss: 0.087526  [    4/  103]
# loss: 0.509642  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.232227
#
# Epoch 119
# -------------------------------
# loss: 0.076880  [    4/  103]
# loss: 0.077094  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.229877
#
# Epoch 120
# -------------------------------
# loss: 0.079341  [    4/  103]
# loss: 0.089601  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.254678
#
# Epoch 121
# -------------------------------
# loss: 0.498458  [    4/  103]
# loss: 0.505523  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.230812
#
# Epoch 122
# -------------------------------
# loss: 0.084964  [    4/  103]
# loss: 0.540378  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.230527
#
# Epoch 123
# -------------------------------
# loss: 0.076737  [    4/  103]
# loss: 0.090103  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.252843
#
# Epoch 124
# -------------------------------
# loss: 0.080716  [    4/  103]
# loss: 0.493877  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.228639
#
# Epoch 125
# -------------------------------
# loss: 0.071588  [    4/  103]
# loss: 0.081336  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.254537
#
# Epoch 126
# -------------------------------
# loss: 0.489652  [    4/  103]
# loss: 0.491702  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.253177
#
# Epoch 127
# -------------------------------
# loss: 0.061333  [    4/  103]
# loss: 0.070281  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.251053
#
# Epoch 128
# -------------------------------
# loss: 0.512117  [    4/  103]
# loss: 0.085440  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.224983
#
# Epoch 129
# -------------------------------
# loss: 0.482810  [    4/  103]
# loss: 0.487177  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.224003
#
# Epoch 130
# -------------------------------
# loss: 0.495448  [    4/  103]
# loss: 0.067518  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.223704
#
# Epoch 131
# -------------------------------
# loss: 0.481438  [    4/  103]
# loss: 0.963964  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.223849
#
# Epoch 132
# -------------------------------
# loss: 0.492616  [    4/  103]
# loss: 0.090140  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.222205
#
# Epoch 133
# -------------------------------
# loss: 0.074796  [    4/  103]
# loss: 0.079083  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.219806
#
# Epoch 134
# -------------------------------
# loss: 0.067763  [    4/  103]
# loss: 0.059208  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.219349
#
# Epoch 135
# -------------------------------
# loss: 0.055453  [    4/  103]
# loss: 0.079060  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.218247
#
# Epoch 136
# -------------------------------
# loss: 0.069704  [    4/  103]
# loss: 0.446318  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.217426
#
# Epoch 137
# -------------------------------
# loss: 0.071892  [    4/  103]
# loss: 0.478177  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.217313
#
# Epoch 138
# -------------------------------
# loss: 0.501119  [    4/  103]
# loss: 0.471367  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.241262
#
# Epoch 139
# -------------------------------
# loss: 0.069361  [    4/  103]
# loss: 0.119263  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.214962
#
# Epoch 140
# -------------------------------
# loss: 0.054713  [    4/  103]
# loss: 0.471290  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.239235
#
# Epoch 141
# -------------------------------
# loss: 0.465139  [    4/  103]
# loss: 0.082631  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.239548
#
# Epoch 142
# -------------------------------
# loss: 0.071762  [    4/  103]
# loss: 0.116837  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.211030
#
# Epoch 143
# -------------------------------
# loss: 0.069939  [    4/  103]
# loss: 0.421084  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.213955
#
# Epoch 144
# -------------------------------
# loss: 0.090672  [    4/  103]
# loss: 0.481893  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.209077
#
# Epoch 145
# -------------------------------
# loss: 0.064932  [    4/  103]
# loss: 0.061647  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.208511
#
# Epoch 146
# -------------------------------
# loss: 0.054891  [    4/  103]
# loss: 0.415380  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.210661
#
# Epoch 147
# -------------------------------
# loss: 0.121881  [    4/  103]
# loss: 0.421062  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.226721
#
# Epoch 148
# -------------------------------
# loss: 0.083571  [    4/  103]
# loss: 0.058085  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.205768
#
# Epoch 149
# -------------------------------
# loss: 0.042855  [    4/  103]
# loss: 0.069574  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.204694
#
# Epoch 150
# -------------------------------
# loss: 0.062077  [    4/  103]
# loss: 0.086307  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.200804
#
# Epoch 151
# -------------------------------
# loss: 0.048538  [    4/  103]
# loss: 0.080266  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.200204
#
# Epoch 152
# -------------------------------
# loss: 0.069235  [    4/  103]
# loss: 0.054089  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.201619
#
# Epoch 153
# -------------------------------
# loss: 0.061435  [    4/  103]
# loss: 0.052606  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.198931
#
# Epoch 154
# -------------------------------
# loss: 0.107972  [    4/  103]
# loss: 0.086462  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.219320
#
# Epoch 155
# -------------------------------
# loss: 0.054462  [    4/  103]
# loss: 0.054912  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.195921
#
# Epoch 156
# -------------------------------
# loss: 0.053610  [    4/  103]
# loss: 0.048796  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.194381
#
# Epoch 157
# -------------------------------
# loss: 0.058193  [    4/  103]
# loss: 0.400961  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.195589
#
# Epoch 158
# -------------------------------
# loss: 0.421207  [    4/  103]
# loss: 0.379471  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.191993
#
# Epoch 159
# -------------------------------
# loss: 0.036866  [    4/  103]
# loss: 0.319474  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.192099
#
# Epoch 160
# -------------------------------
# loss: 0.407946  [    4/  103]
# loss: 0.392863  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.191581
#
# Epoch 161
# -------------------------------
# loss: 0.065887  [    4/  103]
# loss: 0.048465  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.188226
#
# Epoch 162
# -------------------------------
# loss: 0.056172  [    4/  103]
# loss: 0.064184  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.190686
#
# Epoch 163
# -------------------------------
# loss: 0.034846  [    4/  103]
# loss: 0.410209  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.186787
#
# Epoch 164
# -------------------------------
# loss: 0.332844  [    4/  103]
# loss: 0.372995  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.209178
#
# Epoch 165
# -------------------------------
# loss: 0.032744  [    4/  103]
# loss: 0.027299  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.179880
#
# Epoch 166
# -------------------------------
# loss: 0.080978  [    4/  103]
# loss: 0.638931  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.180909
#
# Epoch 167
# -------------------------------
# loss: 0.091163  [    4/  103]
# loss: 0.041513  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.179638
#
# Epoch 168
# -------------------------------
# loss: 0.046432  [    4/  103]
# loss: 0.082251  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.183149
#
# Epoch 169
# -------------------------------
# loss: 0.032471  [    4/  103]
# loss: 0.056868  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.176533
#
# Epoch 170
# -------------------------------
# loss: 0.040663  [    4/  103]
# loss: 0.083134  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.202975
#
# Epoch 171
# -------------------------------
# loss: 0.067737  [    4/  103]
# loss: 0.075641  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.175477
#
# Epoch 172
# -------------------------------
# loss: 0.077882  [    4/  103]
# loss: 0.330296  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.176783
#
# Epoch 173
# -------------------------------
# loss: 0.077813  [    4/  103]
# loss: 0.044445  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.172115
#
# Epoch 174
# -------------------------------
# loss: 0.323239  [    4/  103]
# loss: 0.140866  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.174953
#
# Epoch 175
# -------------------------------
# loss: 0.045839  [    4/  103]
# loss: 0.057589  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.171206
#
# Epoch 176
# -------------------------------
# loss: 0.407486  [    4/  103]
# loss: 0.366895  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.183544
#
# Epoch 177
# -------------------------------
# loss: 0.109858  [    4/  103]
# loss: 0.459563  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.163768
#
# Epoch 178
# -------------------------------
# loss: 0.295870  [    4/  103]
# loss: 0.323999  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.162740
#
# Epoch 179
# -------------------------------
# loss: 0.030659  [    4/  103]
# loss: 0.023094  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.171491
#
# Epoch 180
# -------------------------------
# loss: 0.013371  [    4/  103]
# loss: 0.313947  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.166210
#
# Epoch 181
# -------------------------------
# loss: 0.309907  [    4/  103]
# loss: 0.569070  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.179218
#
# Epoch 182
# -------------------------------
# loss: 0.030254  [    4/  103]
# loss: 0.067522  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.162002
#
# Epoch 183
# -------------------------------
# loss: 0.353866  [    4/  103]
# loss: 0.043303  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.156193
#
# Epoch 184
# -------------------------------
# loss: 0.063711  [    4/  103]
# loss: 0.026256  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.153106
#
# Epoch 185
# -------------------------------
# loss: 0.094761  [    4/  103]
# loss: 0.292646  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.155182
#
# Epoch 186
# -------------------------------
# loss: 0.070015  [    4/  103]
# loss: 0.063703  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.170491
#
# Epoch 187
# -------------------------------
# loss: 0.028611  [    4/  103]
# loss: 0.058588  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.148748
#
# Epoch 188
# -------------------------------
# loss: 0.021340  [    4/  103]
# loss: 0.268362  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.154667
#
# Epoch 189
# -------------------------------
# loss: 0.072531  [    4/  103]
# loss: 0.011789  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.161004
#
# Epoch 190
# -------------------------------
# loss: 0.310102  [    4/  103]
# loss: 0.086265  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.151503
#
# Epoch 191
# -------------------------------
# loss: 0.285602  [    4/  103]
# loss: 0.820729  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.141266
#
# Epoch 192
# -------------------------------
# loss: 0.022323  [    4/  103]
# loss: 0.111944  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.158089
#
# Epoch 193
# -------------------------------
# loss: 0.583073  [    4/  103]
# loss: 0.072349  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.142907
#
# Epoch 194
# -------------------------------
# loss: 0.324045  [    4/  103]
# loss: 0.065626  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.136536
#
# Epoch 195
# -------------------------------
# loss: 0.318950  [    4/  103]
# loss: 0.080277  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.140706
#
# Epoch 196
# -------------------------------
# loss: 0.020302  [    4/  103]
# loss: 0.070101  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.137022
#
# Epoch 197
# -------------------------------
# loss: 0.120997  [    4/  103]
# loss: 0.261802  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.129336
#
# Epoch 198
# -------------------------------
# loss: 0.038757  [    4/  103]
# loss: 0.309015  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.129595
#
# Epoch 199
# -------------------------------
# loss: 0.015981  [    4/  103]
# loss: 0.022527  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.123989
#
# Epoch 200
# -------------------------------
# loss: 0.234119  [    4/  103]
# loss: 0.054724  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.121643
#
# Epoch 201
# -------------------------------
# loss: 0.325821  [    4/  103]
# loss: 0.017876  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.125836
#
# Epoch 202
# -------------------------------
# loss: 0.061472  [    4/  103]
# loss: 0.031462  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.122138
#
# Epoch 203
# -------------------------------
# loss: 0.137410  [    4/  103]
# loss: 0.208812  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.118815
#
# Epoch 204
# -------------------------------
# loss: 0.254941  [    4/  103]
# loss: 0.052308  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.117814
#
# Epoch 205
# -------------------------------
# loss: 0.011664  [    4/  103]
# loss: 0.031752  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.121388
#
# Epoch 206
# -------------------------------
# loss: 0.097696  [    4/  103]
# loss: 0.202666  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.112524
#
# Epoch 207
# -------------------------------
# loss: 0.178434  [    4/  103]
# loss: 0.082306  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.112494
#
# Epoch 208
# -------------------------------
# loss: 0.010040  [    4/  103]
# loss: 0.196409  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.133594
#
# Epoch 209
# -------------------------------
# loss: 0.034191  [    4/  103]
# loss: 0.074657  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.109561
#
# Epoch 210
# -------------------------------
# loss: 0.195967  [    4/  103]
# loss: 0.195597  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.105173
#
# Epoch 211
# -------------------------------
# loss: 0.030098  [    4/  103]
# loss: 0.261189  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.101313
#
# Epoch 212
# -------------------------------
# loss: 0.003461  [    4/  103]
# loss: 0.006939  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.104490
#
# Epoch 213
# -------------------------------
# loss: 0.046881  [    4/  103]
# loss: 0.440742  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.096595
#
# Epoch 214
# -------------------------------
# loss: 0.117562  [    4/  103]
# loss: 0.056871  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.099093
#
# Epoch 215
# -------------------------------
# loss: 0.197296  [    4/  103]
# loss: 0.006349  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.103072
#
# Epoch 216
# -------------------------------
# loss: 0.103648  [    4/  103]
# loss: 0.201038  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.093333
#
# Epoch 217
# -------------------------------
# loss: 0.021515  [    4/  103]
# loss: 0.169838  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.080583
#
# Epoch 218
# -------------------------------
# loss: 0.163352  [    4/  103]
# loss: 0.003059  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.081814
#
# Epoch 219
# -------------------------------
# loss: 0.013688  [    4/  103]
# loss: 0.199239  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.089299
#
# Epoch 220
# -------------------------------
# loss: 0.071079  [    4/  103]
# loss: 0.004736  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.091424
#
# Epoch 221
# -------------------------------
# loss: 0.272769  [    4/  103]
# loss: 0.052622  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.088848
#
# Epoch 222
# -------------------------------
# loss: 0.018325  [    4/  103]
# loss: 0.054401  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.097162
#
# Epoch 223
# -------------------------------
# loss: 0.027699  [    4/  103]
# loss: 0.058663  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.088453
#
# Epoch 224
# -------------------------------
# loss: 0.220858  [    4/  103]
# loss: 0.123468  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.099766
#
# Epoch 225
# -------------------------------
# loss: 0.013408  [    4/  103]
# loss: 0.085951  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.070802
#
# Epoch 226
# -------------------------------
# loss: 0.127089  [    4/  103]
# loss: 0.011781  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.092753
#
# Epoch 227
# -------------------------------
# loss: 0.027074  [    4/  103]
# loss: 0.268255  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.073995
#
# Epoch 228
# -------------------------------
# loss: 0.087124  [    4/  103]
# loss: 0.151589  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.078211
#
# Epoch 229
# -------------------------------
# loss: 0.002921  [    4/  103]
# loss: 0.025027  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.105488
#
# Epoch 230
# -------------------------------
# loss: 0.035063  [    4/  103]
# loss: 0.145711  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.079723
#
# Epoch 231
# -------------------------------
# loss: 0.047846  [    4/  103]
# loss: 0.016725  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.075758
#
# Epoch 232
# -------------------------------
# loss: 0.110777  [    4/  103]
# loss: 0.053768  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.082556
#
# Epoch 233
# -------------------------------
# loss: 0.022121  [    4/  103]
# loss: 0.001696  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.071823
#
# Epoch 234
# -------------------------------
# loss: 0.005040  [    4/  103]
# loss: 0.195421  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.079769
#
# Epoch 235
# -------------------------------
# loss: 0.110009  [    4/  103]
# loss: 0.051737  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.082202
#
# Epoch 236
# -------------------------------
# loss: 0.226472  [    4/  103]
# loss: 0.049294  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.079236
#
# Epoch 237
# -------------------------------
# loss: 0.249589  [    4/  103]
# loss: 0.125774  [   84/  103]
# Test Error:
#  Recall: 100.0%, Accuracy: 100.0%, Avg loss: 0.061921
#
# Epoch 238
# -------------------------------
# loss: 0.026731  [    4/  103]
# loss: 0.081713  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.061349
#
# Epoch 239
# -------------------------------
# loss: 0.040010  [    4/  103]
# loss: 0.000765  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.085390
#
# Epoch 240
# -------------------------------
# loss: 0.038042  [    4/  103]
# loss: 0.080115  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.062926
#
# Epoch 241
# -------------------------------
# loss: 0.021596  [    4/  103]
# loss: 0.022757  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.065092
#
# Epoch 242
# -------------------------------
# loss: 0.058432  [    4/  103]
# loss: 0.011475  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.069547
#
# Epoch 243
# -------------------------------
# loss: 0.004721  [    4/  103]
# loss: 0.008514  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.056440
#
# Epoch 244
# -------------------------------
# loss: 0.049494  [    4/  103]
# loss: 0.001246  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.071085
#
# Epoch 245
# -------------------------------
# loss: 0.002550  [    4/  103]
# loss: 0.003605  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.058591
#
# Epoch 246
# -------------------------------
# loss: 0.004106  [    4/  103]
# loss: 0.064202  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.065473
#
# Epoch 247
# -------------------------------
# loss: 0.003339  [    4/  103]
# loss: 0.040365  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.079636
#
# Epoch 248
# -------------------------------
# loss: 0.005184  [    4/  103]
# loss: 0.052565  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.066918
#
# Epoch 249
# -------------------------------
# loss: 0.033498  [    4/  103]
# loss: 0.036071  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.061225
#
# Epoch 250
# -------------------------------
# loss: 0.123862  [    4/  103]
# loss: 0.042895  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.061224
#
# Epoch 251
# -------------------------------
# loss: 0.047160  [    4/  103]
# loss: 0.076167  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.081302
#
# Epoch 252
# -------------------------------
# loss: 0.006861  [    4/  103]
# loss: 0.225511  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.062746
#
# Epoch 253
# -------------------------------
# loss: 0.008198  [    4/  103]
# loss: 0.137192  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.069316
#
# Epoch 254
# -------------------------------
# loss: 0.001284  [    4/  103]
# loss: 0.031345  [   84/  103]
# Test Error:
#  Recall: 100.0%, Accuracy: 100.0%, Avg loss: 0.053065
#
# Epoch 255
# -------------------------------
# loss: 0.055142  [    4/  103]
# loss: 0.151426  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.050786
#
# Epoch 256
# -------------------------------
# loss: 0.002665  [    4/  103]
# loss: 0.036761  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.078008
#
# Epoch 257
# -------------------------------
# loss: 0.040421  [    4/  103]
# loss: 0.023895  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.051484
#
# Epoch 258
# -------------------------------
# loss: 0.027372  [    4/  103]
# loss: 0.044907  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.063046
#
# Epoch 259
# -------------------------------
# loss: 0.001172  [    4/  103]
# loss: 0.006417  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.077991
#
# Epoch 260
# -------------------------------
# loss: 0.036201  [    4/  103]
# loss: 0.002691  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.052384
#
# Epoch 261
# -------------------------------
# loss: 0.038211  [    4/  103]
# loss: 0.026828  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.056983
#
# Epoch 262
# -------------------------------
# loss: 0.033396  [    4/  103]
# loss: 0.000874  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.051904
#
# Epoch 263
# -------------------------------
# loss: 0.061771  [    4/  103]
# loss: 0.012528  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.067246
#
# Epoch 264
# -------------------------------
# loss: 0.004007  [    4/  103]
# loss: 0.001251  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.063471
#
# Epoch 265
# -------------------------------
# loss: 0.002327  [    4/  103]
# loss: 0.022327  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.067286
#
# Epoch 266
# -------------------------------
# loss: 0.078284  [    4/  103]
# loss: 0.137220  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.062479
#
# Epoch 267
# -------------------------------
# loss: 0.122843  [    4/  103]
# loss: 0.035003  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.080981
#
# Epoch 268
# -------------------------------
# loss: 0.142158  [    4/  103]
# loss: 0.026262  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.055263
#
# Epoch 269
# -------------------------------
# loss: 0.017446  [    4/  103]
# loss: 0.000646  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.052465
#
# Epoch 270
# -------------------------------
# loss: 0.026506  [    4/  103]
# loss: 0.001116  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.056737
#
# Epoch 271
# -------------------------------
# loss: 0.013069  [    4/  103]
# loss: 0.009771  [   84/  103]
# Test Error:
#  Recall: 100.0%, Accuracy: 100.0%, Avg loss: 0.045596
#
# Epoch 272
# -------------------------------
# loss: 0.076582  [    4/  103]
# loss: 0.094215  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.048939
#
# Epoch 273
# -------------------------------
# loss: 0.000270  [    4/  103]
# loss: 0.003341  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.060599
#
# Epoch 274
# -------------------------------
# loss: 0.007972  [    4/  103]
# loss: 0.047049  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.062689
#
# Epoch 275
# -------------------------------
# loss: 0.001312  [    4/  103]
# loss: 0.008750  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.060983
#
# Epoch 276
# -------------------------------
# loss: 0.040712  [    4/  103]
# loss: 0.112982  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.058093
#
# Epoch 277
# -------------------------------
# loss: 0.029048  [    4/  103]
# loss: 0.000934  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.060943
#
# Epoch 278
# -------------------------------
# loss: 0.112820  [    4/  103]
# loss: 0.050129  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.064911
#
# Epoch 279
# -------------------------------
# loss: 0.026138  [    4/  103]
# loss: 0.000970  [   84/  103]
# Test Error:
#  Recall: 100.0%, Accuracy: 100.0%, Avg loss: 0.043751
#
# Epoch 280
# -------------------------------
# loss: 0.016706  [    4/  103]
# loss: 0.013914  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.063133
#
# Epoch 281
# -------------------------------
# loss: 0.012731  [    4/  103]
# loss: 0.057544  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.049596
#
# Epoch 282
# -------------------------------
# loss: 0.028870  [    4/  103]
# loss: 0.117488  [   84/  103]
# Test Error:
#  Recall: 100.0%, Accuracy: 100.0%, Avg loss: 0.041466
#
# Epoch 283
# -------------------------------
# loss: 0.000830  [    4/  103]
# loss: 0.003360  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.046249
#
# Epoch 284
# -------------------------------
# loss: 0.003844  [    4/  103]
# loss: 0.005272  [   84/  103]
# Test Error:
#  Recall: 100.0%, Accuracy: 100.0%, Avg loss: 0.041204
#
# Epoch 285
# ...
# loss: 0.087368  [    4/  103]
# loss: 0.366111  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.105829
#
# Epoch 206
# -------------------------------
# loss: 0.137481  [    4/  103]
# loss: 0.071751  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.104972
#
# Epoch 207
# -------------------------------
# loss: 0.034724  [    4/  103]
# loss: 0.075914  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.105349
#
# Epoch 208
# -------------------------------
# loss: 0.004114  [    4/  103]
# loss: 0.002938  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.107171
#
# Epoch 209
# -------------------------------
# loss: 0.152318  [    4/  103]
# loss: 0.215499  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.117917
#
# Epoch 210
# -------------------------------
# loss: 0.149094  [    4/  103]
# loss: 0.018631  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.111962
#
# Epoch 211
# -------------------------------
# loss: 0.157278  [    4/  103]
# loss: 0.134388  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.104856
#
# Epoch 212
# -------------------------------
# loss: 0.161992  [    4/  103]
# loss: 0.002183  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.112340
#
# Epoch 213
# -------------------------------
# loss: 0.013140  [    4/  103]
# loss: 0.171533  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.107756
#
# Epoch 214
# -------------------------------
# loss: 0.013491  [    4/  103]
# loss: 0.170145  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.133639
#
# Epoch 215
# -------------------------------
# loss: 0.020797  [    4/  103]
# loss: 0.128342  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.132266
#
# Epoch 216
# -------------------------------
# loss: 0.003871  [    4/  103]
# loss: 0.028237  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.108881
#
# Epoch 217
# -------------------------------
# loss: 0.017203  [    4/  103]
# loss: 0.101436  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.105470
#
# Epoch 218
# -------------------------------
# loss: 0.029484  [    4/  103]
# loss: 0.052753  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.118318
#
# Epoch 219
# -------------------------------
# loss: 0.061084  [    4/  103]
# loss: 0.002804  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.112614
#
# Epoch 220
# -------------------------------
# loss: 0.081952  [    4/  103]
# loss: 0.000477  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.107116
#
# Epoch 221
# -------------------------------
# loss: 0.052865  [    4/  103]
# loss: 0.324639  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.126503
#
# Epoch 222
# -------------------------------
# loss: 0.098416  [    4/  103]
# loss: 0.028460  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.101922
#
# Epoch 223
# -------------------------------
# loss: 0.003512  [    4/  103]
# loss: 0.011214  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.115306
#
# Epoch 224
# -------------------------------
# loss: 0.061748  [    4/  103]
# loss: 0.002409  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.114969
#
# Epoch 225
# -------------------------------
# loss: 0.161834  [    4/  103]
# loss: 0.125239  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.150030
#
# Epoch 226
# -------------------------------
# loss: 0.044586  [    4/  103]
# loss: 0.066113  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.101253
#
# Epoch 227
# -------------------------------
# loss: 0.008354  [    4/  103]
# loss: 0.220941  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.104646
#
# Epoch 228
# -------------------------------
# loss: 0.200514  [    4/  103]
# loss: 0.049561  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.118224
#
# Epoch 229
# -------------------------------
# loss: 0.066006  [    4/  103]
# loss: 0.000134  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.108236
#
# Epoch 230
# -------------------------------
# loss: 0.033676  [    4/  103]
# loss: 0.082834  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.138038
#
# Epoch 231
# -------------------------------
# loss: 0.054464  [    4/  103]
# loss: 0.036559  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.110345
#
# Epoch 232
# -------------------------------
# loss: 0.112549  [    4/  103]
# loss: 0.005176  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.124806
#
# Epoch 233
# -------------------------------
# loss: 0.127907  [    4/  103]
# loss: 0.203720  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.112410
#
# Epoch 234
# -------------------------------
# loss: 0.071785  [    4/  103]
# loss: 0.049786  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.114381
#
# Epoch 235
# -------------------------------
# loss: 0.230672  [    4/  103]
# loss: 0.145578  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.126793
#
# Epoch 236
# -------------------------------
# loss: 0.000625  [    4/  103]
# loss: 0.327995  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.103929
#
# Epoch 237
# -------------------------------
# loss: 0.012900  [    4/  103]
# loss: 0.007908  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.100675
#
# Epoch 238
# -------------------------------
# loss: 0.061818  [    4/  103]
# loss: 0.079248  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.109847
#
# Epoch 239
# -------------------------------
# loss: 0.010904  [    4/  103]
# loss: 0.006847  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.114112
#
# Epoch 240
# -------------------------------
# loss: 0.006565  [    4/  103]
# loss: 0.019382  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.100061
#
# Epoch 241
# -------------------------------
# loss: 0.002292  [    4/  103]
# loss: 0.007259  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.103497
#
# Epoch 242
# -------------------------------
# loss: 0.061311  [    4/  103]
# loss: 0.001695  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.097523
#
# Epoch 243
# -------------------------------
# loss: 0.023895  [    4/  103]
# loss: 0.192708  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.112639
#
# Epoch 244
# -------------------------------
# loss: 0.001780  [    4/  103]
# loss: 0.152474  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.095555
#
# Epoch 245
# -------------------------------
# loss: 0.009914  [    4/  103]
# loss: 0.000161  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.104003
#
# Epoch 246
# -------------------------------
# loss: 0.002696  [    4/  103]
# loss: 0.032596  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.128497
#
# Epoch 247
# -------------------------------
# loss: 0.019504  [    4/  103]
# loss: 0.001348  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.108609
#
# Epoch 248
# -------------------------------
# loss: 0.019785  [    4/  103]
# loss: 0.105713  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.098753
#
# Epoch 249
# -------------------------------
# loss: 0.003530  [    4/  103]
# loss: 0.001890  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.100167
#
# Epoch 250
# -------------------------------
# loss: 0.038178  [    4/  103]
# loss: 0.000925  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.107507
#
# Epoch 251
# -------------------------------
# loss: 0.070609  [    4/  103]
# loss: 0.025827  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.105462
#
# Epoch 252
# -------------------------------
# loss: 0.053087  [    4/  103]
# loss: 0.038837  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.125353
#
# Epoch 253
# -------------------------------
# loss: 0.036930  [    4/  103]
# loss: 0.000290  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.098344
#
# Epoch 254
# -------------------------------
# loss: 0.024197  [    4/  103]
# loss: 0.029479  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.089874
#
# Epoch 255
# -------------------------------
# loss: 0.013867  [    4/  103]
# loss: 0.000794  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.101265
#
# Epoch 256
# -------------------------------
# loss: 0.002027  [    4/  103]
# loss: 0.026033  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.095245
#
# Epoch 257
# -------------------------------
# loss: 0.017542  [    4/  103]
# loss: 0.197095  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.106935
#
# Epoch 258
# -------------------------------
# loss: 0.002081  [    4/  103]
# loss: 0.013918  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.087755
#
# Epoch 259
# -------------------------------
# loss: 0.004173  [    4/  103]
# loss: 0.022887  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.096550
#
# Epoch 260
# -------------------------------
# loss: 0.073491  [    4/  103]
# loss: 0.066404  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.097217
#
# Epoch 261
# -------------------------------
# loss: 0.002443  [    4/  103]
# loss: 0.013446  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.123562
#
# Epoch 262
# -------------------------------
# loss: 0.003424  [    4/  103]
# loss: 0.028153  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.112272
#
# Epoch 263
# -------------------------------
# loss: 0.042046  [    4/  103]
# loss: 0.024802  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.107868
#
# Epoch 264
# -------------------------------
# loss: 0.001779  [    4/  103]
# loss: 0.131134  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.091337
#
# Epoch 265
# -------------------------------
# loss: 0.009376  [    4/  103]
# loss: 0.040383  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.126123
#
# Epoch 266
# -------------------------------
# loss: 0.040000  [    4/  103]
# loss: 0.019921  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.093062
#
# Epoch 267
# -------------------------------
# loss: 0.149818  [    4/  103]
# loss: 0.100107  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.100707
#
# Epoch 268
# -------------------------------
# loss: 0.016074  [    4/  103]
# loss: 0.000124  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.106630
#
# Epoch 269
# -------------------------------
# loss: 0.056919  [    4/  103]
# loss: 0.000708  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.123645
#
# Epoch 270
# -------------------------------
# loss: 0.134198  [    4/  103]
# loss: 0.000890  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.100845
#
# Epoch 271
# -------------------------------
# loss: 0.014762  [    4/  103]
# loss: 0.000090  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.104434
#
# Epoch 272
# -------------------------------
# loss: 0.005663  [    4/  103]
# loss: 0.009512  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.103669
#
# Epoch 273
# -------------------------------
# loss: 0.003991  [    4/  103]
# loss: 0.000241  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.140202
#
# Epoch 274
# -------------------------------
# loss: 0.117149  [    4/  103]
# loss: 0.003244  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.120213
#
# Epoch 275
# -------------------------------
# loss: 0.000204  [    4/  103]
# loss: 0.000305  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.108793
#
# Epoch 276
# -------------------------------
# loss: 0.009456  [    4/  103]
# loss: 0.175485  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.093171
#
# Epoch 277
# -------------------------------
# loss: 0.029671  [    4/  103]
# loss: 0.000079  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.121672
#
# Epoch 278
# -------------------------------
# loss: 0.007658  [    4/  103]
# loss: 0.000509  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.101187
#
# Epoch 279
# -------------------------------
# loss: 0.117416  [    4/  103]
# loss: 0.035826  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.105164
#
# Epoch 280
# -------------------------------
# loss: 0.000070  [    4/  103]
# loss: 0.065577  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.104321
#
# Epoch 281
# -------------------------------
# loss: 0.000285  [    4/  103]
# loss: 0.011505  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.111867
#
# Epoch 282
# -------------------------------
# loss: 0.000583  [    4/  103]
# loss: 0.137227  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.108592
#
# Epoch 283
# -------------------------------
# loss: 0.000705  [    4/  103]
# loss: 0.036142  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.095161
#
# Epoch 284
# -------------------------------
# loss: 0.001061  [    4/  103]
# loss: 0.016747  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.100193
#
# Epoch 285
# -------------------------------
# loss: 0.103403  [    4/  103]
# loss: 0.037068  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.105509
#
# Epoch 286
# -------------------------------
# loss: 0.001508  [    4/  103]
# loss: 0.036151  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.102485
#
# Epoch 287
# -------------------------------
# loss: 0.000286  [    4/  103]
# loss: 0.123836  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.110100
#
# Epoch 288
# -------------------------------
# loss: 0.005863  [    4/  103]
# loss: 0.002558  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.095488
#
# Epoch 289
# -------------------------------
# loss: 0.005820  [    4/  103]
# loss: 0.000388  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.096042
#
# Epoch 290
# -------------------------------
# loss: 0.029195  [    4/  103]
# loss: 0.000189  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.097936
#
# Epoch 291
# -------------------------------
# loss: 0.000791  [    4/  103]
# loss: 0.095976  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.100193
#
# Epoch 292
# -------------------------------
# loss: 0.036968  [    4/  103]
# loss: 0.034991  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.100165
#
# Epoch 293
# -------------------------------
# loss: 0.101291  [    4/  103]
# loss: 0.049457  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.088980
#
# Epoch 294
# -------------------------------
# loss: 0.024769  [    4/  103]
# loss: 0.102860  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.092132
#
# Epoch 295
# -------------------------------
# loss: 0.056211  [    4/  103]
# loss: 0.099915  [   84/  103]
# Test Error:
#  Recall: 0.0%, Accuracy: 91.3%, Avg loss: 0.108974
#
# Epoch 296
# -------------------------------
# loss: 0.000256  [    4/  103]
# loss: 0.002078  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.100105
#
# Epoch 297
# -------------------------------
# loss: 0.025540  [    4/  103]
# loss: 0.024111  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.092428
#
# Epoch 298
# -------------------------------
# loss: 0.067044  [    4/  103]
# loss: 0.000136  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.100205
#
# Epoch 299
# -------------------------------
# loss: 0.000067  [    4/  103]
# loss: 0.001837  [   84/  103]
# Test Error:
#  Recall: 50.0%, Accuracy: 95.7%, Avg loss: 0.099183
#
# Done!

# %% [markdown]
# When the positive examples make up 10% of the dataset, focal loss seems to do somewhat better in terms of recall than binary crossentropy, but only when gamma &lt; 0.5. Over 5 runs, focal loss with gamma = 0.2 beat binary cross entropy within 300 epochs on all runs except one where they both scored 100%. This was measure in terms of training recall. We didn't use test recall because the test set was too small to be useful (only 2 examples).

# %%
from torchvision.ops import sigmoid_focal_loss

loss_fns = {
    "focal_0p2": lambda inputs, targets: sigmoid_focal_loss(inputs, targets, reduction="mean", alpha=-1, gamma=0.2),
    "focal_0p4": lambda inputs, targets: sigmoid_focal_loss(inputs, targets, reduction="mean", alpha=-1, gamma=0.4),
    "focal_0p6": lambda inputs, targets: sigmoid_focal_loss(inputs, targets, reduction="mean", alpha=-1, gamma=0.6),
    "focal_0p8": lambda inputs, targets: sigmoid_focal_loss(inputs, targets, reduction="mean", alpha=-1, gamma=0.8),
    "bce": nn.BCEWithLogitsLoss(),
}
pos_frac = 0.04
learning_rate = 1e-2
batch_size = 4
epochs = 300

log_dir = os.path.join("runs", "experiment_008")
shutil.rmtree(log_dir, ignore_errors=True)

for name, loss_fn in loss_fns.items():
    train_dataset = ImbalancedDataset(BlockLandingDataset(os.path.join("data", "block_landing", "train")), pos_frac)
    test_dataset = ImbalancedDataset(BlockLandingDataset(os.path.join("data", "block_landing", "test")), pos_frac)
    train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)
    test_dataloader = DataLoader(test_dataset, batch_size=4, shuffle=True)
    
    model = BlockLandingModel().to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    log_subdir = os.path.join(log_dir, name + "_" + datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S"))
    tb = SummaryWriter(log_subdir)

    for t in range(epochs):
        print(f"Epoch {t}\n-------------------------------")
        train_metrics = train_loop(train_dataloader, model, loss_fn, optimizer)
        test_metrics = test_loop(test_dataloader, model, loss_fn)
        tb.add_scalar("Loss/train", train_metrics["loss"], t)
        tb.add_scalar("Accuracy/train", train_metrics["acc"], t)
        tb.add_scalar("Recall/train", train_metrics["rec"], t)
        tb.add_scalar("Loss/test", test_metrics["loss"], t)
        tb.add_scalar("Accuracy/test", test_metrics["acc"], t)
        tb.add_scalar("Recall/test", test_metrics["rec"], t)
        for name, weight in model.named_parameters():
            tb.add_histogram(f"Weights/{name}", weight, t)
            tb.add_histogram(f"Gradients/{name}", weight.grad, t)

    tb.close()
    print("Done!")
# Out:
# pos_fraction: requested 0.040, got 0.031
# Total positive examples: 3
# pos_fraction: requested 0.040, got 0.000
# Total positive examples: 0
# Epoch 0
# -------------------------------
# loss: 0.513625  [    4/   96]
# loss: 0.389289  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.367554
#
# Epoch 1
# -------------------------------
# loss: 0.375347  [    4/   96]
# loss: 0.249398  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.226268
#
# Epoch 2
# -------------------------------
# loss: 0.224879  [    4/   96]
# loss: 0.136499  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.124297
#
# Epoch 3
# -------------------------------
# loss: 0.538450  [    4/   96]
# loss: 0.080805  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.072123
#
# Epoch 4
# -------------------------------
# loss: 0.072382  [    4/   96]
# loss: 0.053943  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.047557
#
# Epoch 5
# -------------------------------
# loss: 0.047429  [    4/   96]
# loss: 0.042274  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.037967
#
# Epoch 6
# -------------------------------
# loss: 0.037152  [    4/   96]
# loss: 0.032521  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.034482
#
# Epoch 7
# -------------------------------
# loss: 0.035224  [    4/   96]
# loss: 0.768001  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030774
#
# Epoch 8
# -------------------------------
# loss: 0.030583  [    4/   96]
# loss: 0.032527  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.029407
#
# Epoch 9
# -------------------------------
# loss: 0.030126  [    4/   96]
# loss: 0.032171  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028051
#
# Epoch 10
# -------------------------------
# loss: 0.028736  [    4/   96]
# loss: 0.030404  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027241
#
# Epoch 11
# -------------------------------
# loss: 0.027039  [    4/   96]
# loss: 0.028659  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026070
#
# Epoch 12
# -------------------------------
# loss: 0.778669  [    4/   96]
# loss: 0.026344  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024749
#
# Epoch 13
# -------------------------------
# loss: 1.531176  [    4/   96]
# loss: 0.807185  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024806
#
# Epoch 14
# -------------------------------
# loss: 0.024321  [    4/   96]
# loss: 0.028388  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025761
#
# Epoch 15
# -------------------------------
# loss: 0.026827  [    4/   96]
# loss: 0.027071  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024891
#
# Epoch 16
# -------------------------------
# loss: 0.024959  [    4/   96]
# loss: 0.026777  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024250
#
# Epoch 17
# -------------------------------
# loss: 0.023923  [    4/   96]
# loss: 0.023163  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025533
#
# Epoch 18
# -------------------------------
# loss: 0.025688  [    4/   96]
# loss: 0.026849  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025041
#
# Epoch 19
# -------------------------------
# loss: 0.025075  [    4/   96]
# loss: 0.023303  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024993
#
# Epoch 20
# -------------------------------
# loss: 0.025220  [    4/   96]
# loss: 0.027415  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025683
#
# Epoch 21
# -------------------------------
# loss: 0.026137  [    4/   96]
# loss: 0.023862  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025507
#
# Epoch 22
# -------------------------------
# loss: 0.025764  [    4/   96]
# loss: 0.024010  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026884
#
# Epoch 23
# -------------------------------
# loss: 0.026530  [    4/   96]
# loss: 0.028906  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026327
#
# Epoch 24
# -------------------------------
# loss: 0.765665  [    4/   96]
# loss: 0.027307  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024947
#
# Epoch 25
# -------------------------------
# loss: 0.775870  [    4/   96]
# loss: 0.025875  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024126
#
# Epoch 26
# -------------------------------
# loss: 0.024212  [    4/   96]
# loss: 0.027689  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024972
#
# Epoch 27
# -------------------------------
# loss: 0.025086  [    4/   96]
# loss: 0.028766  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026443
#
# Epoch 28
# -------------------------------
# loss: 0.026963  [    4/   96]
# loss: 0.028275  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026618
#
# Epoch 29
# -------------------------------
# loss: 0.026557  [    4/   96]
# loss: 0.024973  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026964
#
# Epoch 30
# -------------------------------
# loss: 0.026232  [    4/   96]
# loss: 0.029269  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026371
#
# Epoch 31
# -------------------------------
# loss: 0.026477  [    4/   96]
# loss: 0.024161  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025977
#
# Epoch 32
# -------------------------------
# loss: 0.759135  [    4/   96]
# loss: 0.026415  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024429
#
# Epoch 33
# -------------------------------
# loss: 0.024144  [    4/   96]
# loss: 0.022947  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024913
#
# Epoch 34
# -------------------------------
# loss: 0.025902  [    4/   96]
# loss: 0.026223  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024544
#
# Epoch 35
# -------------------------------
# loss: 0.025159  [    4/   96]
# loss: 0.020639  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027020
#
# Epoch 36
# -------------------------------
# loss: 0.027647  [    4/   96]
# loss: 0.025912  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028083
#
# Epoch 37
# -------------------------------
# loss: 0.028527  [    4/   96]
# loss: 0.031288  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028060
#
# Epoch 38
# -------------------------------
# loss: 0.028604  [    4/   96]
# loss: 0.028535  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025555
#
# Epoch 39
# -------------------------------
# loss: 0.025147  [    4/   96]
# loss: 0.728041  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026289
#
# Epoch 40
# -------------------------------
# loss: 0.026065  [    4/   96]
# loss: 0.029007  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026269
#
# Epoch 41
# -------------------------------
# loss: 0.026569  [    4/   96]
# loss: 0.025259  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027348
#
# Epoch 42
# -------------------------------
# loss: 0.027582  [    4/   96]
# loss: 0.030042  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027840
#
# Epoch 43
# -------------------------------
# loss: 0.027826  [    4/   96]
# loss: 0.028527  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026324
#
# Epoch 44
# -------------------------------
# loss: 0.026815  [    4/   96]
# loss: 0.028122  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026414
#
# Epoch 45
# -------------------------------
# loss: 0.026382  [    4/   96]
# loss: 0.744842  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027360
#
# Epoch 46
# -------------------------------
# loss: 0.028745  [    4/   96]
# loss: 0.023849  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026629
#
# Epoch 47
# -------------------------------
# loss: 0.027057  [    4/   96]
# loss: 0.029241  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026237
#
# Epoch 48
# -------------------------------
# loss: 0.025485  [    4/   96]
# loss: 0.029985  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025992
#
# Epoch 49
# -------------------------------
# loss: 0.026859  [    4/   96]
# loss: 0.027581  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025960
#
# Epoch 50
# -------------------------------
# loss: 0.703223  [    4/   96]
# loss: 0.028203  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024830
#
# Epoch 51
# -------------------------------
# loss: 0.025691  [    4/   96]
# loss: 0.716974  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025477
#
# Epoch 52
# -------------------------------
# loss: 0.025401  [    4/   96]
# loss: 0.027179  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024706
#
# Epoch 53
# -------------------------------
# loss: 0.025031  [    4/   96]
# loss: 0.023842  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025840
#
# Epoch 54
# -------------------------------
# loss: 0.024913  [    4/   96]
# loss: 0.027673  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026291
#
# Epoch 55
# -------------------------------
# loss: 0.735311  [    4/   96]
# loss: 0.027513  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025226
#
# Epoch 56
# -------------------------------
# loss: 0.025885  [    4/   96]
# loss: 0.027086  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024935
#
# Epoch 57
# -------------------------------
# loss: 0.024266  [    4/   96]
# loss: 0.024853  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026524
#
# Epoch 58
# -------------------------------
# loss: 0.026941  [    4/   96]
# loss: 0.027512  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025522
#
# Epoch 59
# -------------------------------
# loss: 0.026380  [    4/   96]
# loss: 0.025945  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024395
#
# Epoch 60
# -------------------------------
# loss: 0.023568  [    4/   96]
# loss: 0.024395  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025412
#
# Epoch 61
# -------------------------------
# loss: 0.026254  [    4/   96]
# loss: 0.025079  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027456
#
# Epoch 62
# -------------------------------
# loss: 0.029764  [    4/   96]
# loss: 0.029930  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027136
#
# Epoch 63
# -------------------------------
# loss: 0.027842  [    4/   96]
# loss: 0.028555  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025292
#
# Epoch 64
# -------------------------------
# loss: 0.024572  [    4/   96]
# loss: 0.023318  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025458
#
# Epoch 65
# -------------------------------
# loss: 0.025746  [    4/   96]
# loss: 0.024305  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026911
#
# Epoch 66
# -------------------------------
# loss: 0.027191  [    4/   96]
# loss: 0.028045  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026308
#
# Epoch 67
# -------------------------------
# loss: 0.679934  [    4/   96]
# loss: 0.028458  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025932
#
# Epoch 68
# -------------------------------
# loss: 0.026493  [    4/   96]
# loss: 0.028517  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025132
#
# Epoch 69
# -------------------------------
# loss: 0.026507  [    4/   96]
# loss: 1.603567  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027806
#
# Epoch 70
# -------------------------------
# loss: 0.028774  [    4/   96]
# loss: 0.030522  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028354
#
# Epoch 71
# -------------------------------
# loss: 0.028359  [    4/   96]
# loss: 0.025326  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026787
#
# Epoch 72
# -------------------------------
# loss: 0.027625  [    4/   96]
# loss: 0.028908  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026454
#
# Epoch 73
# -------------------------------
# loss: 0.027288  [    4/   96]
# loss: 0.029872  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026382
#
# Epoch 74
# -------------------------------
# loss: 0.026563  [    4/   96]
# loss: 0.028467  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026064
#
# Epoch 75
# -------------------------------
# loss: 0.026601  [    4/   96]
# loss: 0.028826  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026177
#
# Epoch 76
# -------------------------------
# loss: 0.025668  [    4/   96]
# loss: 0.733231  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026257
#
# Epoch 77
# -------------------------------
# loss: 0.026963  [    4/   96]
# loss: 0.025979  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026555
#
# Epoch 78
# -------------------------------
# loss: 0.028250  [    4/   96]
# loss: 0.028935  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027005
#
# Epoch 79
# -------------------------------
# loss: 0.028572  [    4/   96]
# loss: 0.023954  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026546
#
# Epoch 80
# -------------------------------
# loss: 0.027577  [    4/   96]
# loss: 0.030656  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026785
#
# Epoch 81
# -------------------------------
# loss: 0.781859  [    4/   96]
# loss: 0.025666  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024148
#
# Epoch 82
# -------------------------------
# loss: 0.024135  [    4/   96]
# loss: 0.028547  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023247
#
# Epoch 83
# -------------------------------
# loss: 0.023051  [    4/   96]
# loss: 0.024009  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025105
#
# Epoch 84
# -------------------------------
# loss: 0.024220  [    4/   96]
# loss: 0.027397  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025392
#
# Epoch 85
# -------------------------------
# loss: 0.026191  [    4/   96]
# loss: 0.022858  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025990
#
# Epoch 86
# -------------------------------
# loss: 0.026674  [    4/   96]
# loss: 0.026292  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024331
#
# Epoch 87
# -------------------------------
# loss: 0.023887  [    4/   96]
# loss: 0.028959  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024206
#
# Epoch 88
# -------------------------------
# loss: 0.023784  [    4/   96]
# loss: 0.024830  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023780
#
# Epoch 89
# -------------------------------
# loss: 0.023284  [    4/   96]
# loss: 0.027129  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024137
#
# Epoch 90
# -------------------------------
# loss: 0.027907  [    4/   96]
# loss: 0.025827  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023953
#
# Epoch 91
# -------------------------------
# loss: 0.023531  [    4/   96]
# loss: 0.024874  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023259
#
# Epoch 92
# -------------------------------
# loss: 0.022927  [    4/   96]
# loss: 0.723788  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024989
#
# Epoch 93
# -------------------------------
# loss: 0.025481  [    4/   96]
# loss: 0.027571  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025263
#
# Epoch 94
# -------------------------------
# loss: 0.028960  [    4/   96]
# loss: 0.021753  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025065
#
# Epoch 95
# -------------------------------
# loss: 0.026207  [    4/   96]
# loss: 0.024029  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025249
#
# Epoch 96
# -------------------------------
# loss: 0.025179  [    4/   96]
# loss: 0.022563  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025975
#
# Epoch 97
# -------------------------------
# loss: 0.024074  [    4/   96]
# loss: 0.022767  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025760
#
# Epoch 98
# -------------------------------
# loss: 0.024161  [    4/   96]
# loss: 0.702027  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026855
#
# Epoch 99
# -------------------------------
# loss: 0.025465  [    4/   96]
# loss: 0.023885  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027490
#
# Epoch 100
# -------------------------------
# loss: 0.026545  [    4/   96]
# loss: 0.033188  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025783
#
# Epoch 101
# -------------------------------
# loss: 0.028843  [    4/   96]
# loss: 0.022817  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026068
#
# Epoch 102
# -------------------------------
# loss: 0.026944  [    4/   96]
# loss: 0.026622  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024376
#
# Epoch 103
# -------------------------------
# loss: 0.025704  [    4/   96]
# loss: 0.027481  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025584
#
# Epoch 104
# -------------------------------
# loss: 0.025304  [    4/   96]
# loss: 0.025407  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026042
#
# Epoch 105
# -------------------------------
# loss: 0.025308  [    4/   96]
# loss: 0.822421  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025403
#
# Epoch 106
# -------------------------------
# loss: 0.023394  [    4/   96]
# loss: 0.030228  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024995
#
# Epoch 107
# -------------------------------
# loss: 0.025320  [    4/   96]
# loss: 0.021268  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024697
#
# Epoch 108
# -------------------------------
# loss: 0.026558  [    4/   96]
# loss: 0.024259  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023934
#
# Epoch 109
# -------------------------------
# loss: 0.689372  [    4/   96]
# loss: 0.030629  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024105
#
# Epoch 110
# -------------------------------
# loss: 0.023689  [    4/   96]
# loss: 0.020621  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024484
#
# Epoch 111
# -------------------------------
# loss: 0.811455  [    4/   96]
# loss: 0.026814  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023017
#
# Epoch 112
# -------------------------------
# loss: 0.691028  [    4/   96]
# loss: 0.024881  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022864
#
# Epoch 113
# -------------------------------
# loss: 0.021667  [    4/   96]
# loss: 0.024657  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023736
#
# Epoch 114
# -------------------------------
# loss: 0.025518  [    4/   96]
# loss: 0.030799  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023192
#
# Epoch 115
# -------------------------------
# loss: 0.022481  [    4/   96]
# loss: 0.025464  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023616
#
# Epoch 116
# -------------------------------
# loss: 0.022441  [    4/   96]
# loss: 0.020974  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024606
#
# Epoch 117
# -------------------------------
# loss: 0.023495  [    4/   96]
# loss: 0.028966  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025370
#
# Epoch 118
# -------------------------------
# loss: 0.027487  [    4/   96]
# loss: 0.025900  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024285
#
# Epoch 119
# -------------------------------
# loss: 0.023552  [    4/   96]
# loss: 0.026031  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025118
#
# Epoch 120
# -------------------------------
# loss: 0.024389  [    4/   96]
# loss: 0.030395  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025502
#
# Epoch 121
# -------------------------------
# loss: 0.027709  [    4/   96]
# loss: 0.023732  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023164
#
# Epoch 122
# -------------------------------
# loss: 0.822066  [    4/   96]
# loss: 0.022324  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021893
#
# Epoch 123
# -------------------------------
# loss: 0.019573  [    4/   96]
# loss: 0.024213  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023872
#
# Epoch 124
# -------------------------------
# loss: 0.664985  [    4/   96]
# loss: 0.851999  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022974
#
# Epoch 125
# -------------------------------
# loss: 0.020152  [    4/   96]
# loss: 0.026670  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022551
#
# Epoch 126
# -------------------------------
# loss: 0.024167  [    4/   96]
# loss: 0.020279  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023635
#
# Epoch 127
# -------------------------------
# loss: 0.022189  [    4/   96]
# loss: 0.037924  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023033
#
# Epoch 128
# -------------------------------
# loss: 0.027504  [    4/   96]
# loss: 0.020665  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023325
#
# Epoch 129
# -------------------------------
# loss: 0.026626  [    4/   96]
# loss: 0.021803  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021923
#
# Epoch 130
# -------------------------------
# loss: 0.024185  [    4/   96]
# loss: 0.020208  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024486
#
# Epoch 131
# -------------------------------
# loss: 0.818771  [    4/   96]
# loss: 0.024959  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022672
#
# Epoch 132
# -------------------------------
# loss: 0.028900  [    4/   96]
# loss: 0.019988  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023643
#
# Epoch 133
# -------------------------------
# loss: 0.650964  [    4/   96]
# loss: 0.030490  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022911
#
# Epoch 134
# -------------------------------
# loss: 0.830823  [    4/   96]
# loss: 0.018879  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022651
#
# Epoch 135
# -------------------------------
# loss: 0.021319  [    4/   96]
# loss: 0.020756  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025057
#
# Epoch 136
# -------------------------------
# loss: 0.022476  [    4/   96]
# loss: 0.017062  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025887
#
# Epoch 137
# -------------------------------
# loss: 0.022240  [    4/   96]
# loss: 0.835469  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025284
#
# Epoch 138
# -------------------------------
# loss: 0.023573  [    4/   96]
# loss: 0.025820  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023721
#
# Epoch 139
# -------------------------------
# loss: 0.025396  [    4/   96]
# loss: 0.021437  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021890
#
# Epoch 140
# -------------------------------
# loss: 0.022085  [    4/   96]
# loss: 0.019809  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023704
#
# Epoch 141
# -------------------------------
# loss: 0.022375  [    4/   96]
# loss: 0.027082  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025859
#
# Epoch 142
# -------------------------------
# loss: 0.021852  [    4/   96]
# loss: 0.622732  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025290
#
# Epoch 143
# -------------------------------
# loss: 0.028891  [    4/   96]
# loss: 0.028861  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024730
#
# Epoch 144
# -------------------------------
# loss: 0.820115  [    4/   96]
# loss: 0.036894  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023844
#
# Epoch 145
# -------------------------------
# loss: 0.020997  [    4/   96]
# loss: 0.021927  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022350
#
# Epoch 146
# -------------------------------
# loss: 0.032193  [    4/   96]
# loss: 0.023415  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023460
#
# Epoch 147
# -------------------------------
# loss: 0.022008  [    4/   96]
# loss: 0.025808  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023470
#
# Epoch 148
# -------------------------------
# loss: 0.021230  [    4/   96]
# loss: 0.019007  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024747
#
# Epoch 149
# -------------------------------
# loss: 0.031002  [    4/   96]
# loss: 0.019025  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023473
#
# Epoch 150
# -------------------------------
# loss: 0.031148  [    4/   96]
# loss: 0.023901  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023203
#
# Epoch 151
# -------------------------------
# loss: 0.020360  [    4/   96]
# loss: 0.032194  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023264
#
# Epoch 152
# -------------------------------
# loss: 0.503039  [    4/   96]
# loss: 0.021668  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023207
#
# Epoch 153
# -------------------------------
# loss: 0.026276  [    4/   96]
# loss: 0.020705  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023834
#
# Epoch 154
# -------------------------------
# loss: 0.025437  [    4/   96]
# loss: 0.032660  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022374
#
# Epoch 155
# -------------------------------
# loss: 0.019287  [    4/   96]
# loss: 0.021577  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023009
#
# Epoch 156
# -------------------------------
# loss: 0.029112  [    4/   96]
# loss: 0.040572  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022433
#
# Epoch 157
# -------------------------------
# loss: 0.021686  [    4/   96]
# loss: 0.587447  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025920
#
# Epoch 158
# -------------------------------
# loss: 0.025691  [    4/   96]
# loss: 0.023751  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025363
#
# Epoch 159
# -------------------------------
# loss: 0.026689  [    4/   96]
# loss: 0.021400  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022306
#
# Epoch 160
# -------------------------------
# loss: 0.018596  [    4/   96]
# loss: 0.019996  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022263
#
# Epoch 161
# -------------------------------
# loss: 0.019664  [    4/   96]
# loss: 0.018998  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.020736
#
# Epoch 162
# -------------------------------
# loss: 0.022473  [    4/   96]
# loss: 0.021161  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021929
#
# Epoch 163
# -------------------------------
# loss: 0.017912  [    4/   96]
# loss: 0.026200  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023312
#
# Epoch 164
# -------------------------------
# loss: 0.029343  [    4/   96]
# loss: 0.027724  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023020
#
# Epoch 165
# -------------------------------
# loss: 0.874603  [    4/   96]
# loss: 0.016452  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021458
#
# Epoch 166
# -------------------------------
# loss: 0.018544  [    4/   96]
# loss: 0.020602  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024614
#
# Epoch 167
# -------------------------------
# loss: 0.023029  [    4/   96]
# loss: 0.019475  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025710
#
# Epoch 168
# -------------------------------
# loss: 0.024251  [    4/   96]
# loss: 0.020609  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021524
#
# Epoch 169
# -------------------------------
# loss: 0.033255  [    4/   96]
# loss: 0.453169  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022124
#
# Epoch 170
# -------------------------------
# loss: 0.026228  [    4/   96]
# loss: 0.026369  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022499
#
# Epoch 171
# -------------------------------
# loss: 0.431612  [    4/   96]
# loss: 0.029842  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022337
#
# Epoch 172
# -------------------------------
# loss: 0.016728  [    4/   96]
# loss: 0.032209  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021244
#
# Epoch 173
# -------------------------------
# loss: 0.015384  [    4/   96]
# loss: 0.022313  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021052
#
# Epoch 174
# -------------------------------
# loss: 0.020583  [    4/   96]
# loss: 0.028815  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019744
#
# Epoch 175
# -------------------------------
# loss: 0.020456  [    4/   96]
# loss: 0.026044  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021353
#
# Epoch 176
# -------------------------------
# loss: 0.439859  [    4/   96]
# loss: 0.021744  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022781
#
# Epoch 177
# -------------------------------
# loss: 0.017986  [    4/   96]
# loss: 0.512911  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023382
#
# Epoch 178
# -------------------------------
# loss: 0.020303  [    4/   96]
# loss: 0.022627  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021170
#
# Epoch 179
# -------------------------------
# loss: 0.398606  [    4/   96]
# loss: 0.016629  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019372
#
# Epoch 180
# -------------------------------
# loss: 0.019191  [    4/   96]
# loss: 0.018545  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.020479
#
# Epoch 181
# -------------------------------
# loss: 0.022853  [    4/   96]
# loss: 0.017721  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.020862
#
# Epoch 182
# -------------------------------
# loss: 0.022900  [    4/   96]
# loss: 0.914790  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026811
#
# Epoch 183
# -------------------------------
# loss: 0.030114  [    4/   96]
# loss: 0.027969  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022694
#
# Epoch 184
# -------------------------------
# loss: 0.026259  [    4/   96]
# loss: 0.033371  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022643
#
# Epoch 185
# -------------------------------
# loss: 0.020179  [    4/   96]
# loss: 0.033787  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024142
#
# Epoch 186
# -------------------------------
# loss: 0.021114  [    4/   96]
# loss: 0.017647  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024336
#
# Epoch 187
# -------------------------------
# loss: 0.051138  [    4/   96]
# loss: 0.025615  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022261
#
# Epoch 188
# -------------------------------
# loss: 0.019207  [    4/   96]
# loss: 0.044847  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021445
#
# Epoch 189
# -------------------------------
# loss: 0.041226  [    4/   96]
# loss: 0.018782  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023786
#
# Epoch 190
# -------------------------------
# loss: 0.021549  [    4/   96]
# loss: 0.477018  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023223
#
# Epoch 191
# -------------------------------
# loss: 0.021227  [    4/   96]
# loss: 0.021276  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.020305
#
# Epoch 192
# -------------------------------
# loss: 0.015785  [    4/   96]
# loss: 0.013875  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018126
#
# Epoch 193
# -------------------------------
# loss: 0.030579  [    4/   96]
# loss: 0.927090  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022215
#
# Epoch 194
# -------------------------------
# loss: 0.044527  [    4/   96]
# loss: 0.040982  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.020643
#
# Epoch 195
# -------------------------------
# loss: 0.018640  [    4/   96]
# loss: 0.019195  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022813
#
# Epoch 196
# -------------------------------
# loss: 0.014416  [    4/   96]
# loss: 0.023148  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018147
#
# Epoch 197
# -------------------------------
# loss: 0.039450  [    4/   96]
# loss: 0.014063  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019376
#
# Epoch 198
# -------------------------------
# loss: 0.025964  [    4/   96]
# loss: 0.024268  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.020708
#
# Epoch 199
# -------------------------------
# loss: 0.022320  [    4/   96]
# loss: 0.046945  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.017456
#
# Epoch 200
# -------------------------------
# loss: 0.011300  [    4/   96]
# loss: 0.014856  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019804
#
# Epoch 201
# -------------------------------
# loss: 0.309155  [    4/   96]
# loss: 0.014177  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018714
#
# Epoch 202
# -------------------------------
# loss: 0.013997  [    4/   96]
# loss: 0.014968  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018044
#
# Epoch 203
# -------------------------------
# loss: 0.012285  [    4/   96]
# loss: 0.978526  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019004
#
# Epoch 204
# -------------------------------
# loss: 0.710665  [    4/   96]
# loss: 0.031885  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019013
#
# Epoch 205
# -------------------------------
# loss: 0.028501  [    4/   96]
# loss: 0.011648  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018803
#
# Epoch 206
# -------------------------------
# loss: 0.011011  [    4/   96]
# loss: 0.022160  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019621
#
# Epoch 207
# -------------------------------
# loss: 0.014139  [    4/   96]
# loss: 0.011922  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019606
#
# Epoch 208
# -------------------------------
# loss: 0.011032  [    4/   96]
# loss: 0.015118  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018729
#
# Epoch 209
# -------------------------------
# loss: 0.017264  [    4/   96]
# loss: 0.010893  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018968
#
# Epoch 210
# -------------------------------
# loss: 0.012615  [    4/   96]
# loss: 0.959000  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.020064
#
# Epoch 211
# -------------------------------
# loss: 0.013951  [    4/   96]
# loss: 0.011625  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019188
#
# Epoch 212
# -------------------------------
# loss: 0.301378  [    4/   96]
# loss: 0.017544  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015498
#
# Epoch 213
# -------------------------------
# loss: 0.022326  [    4/   96]
# loss: 0.006853  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.017859
#
# Epoch 214
# -------------------------------
# loss: 0.010912  [    4/   96]
# loss: 0.041699  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019569
#
# Epoch 215
# -------------------------------
# loss: 0.011712  [    4/   96]
# loss: 0.038015  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019535
#
# Epoch 216
# -------------------------------
# loss: 0.017868  [    4/   96]
# loss: 0.072336  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018731
#
# Epoch 217
# -------------------------------
# loss: 0.015401  [    4/   96]
# loss: 0.388845  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019794
#
# Epoch 218
# -------------------------------
# loss: 0.015751  [    4/   96]
# loss: 0.047803  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018788
#
# Epoch 219
# -------------------------------
# loss: 0.012495  [    4/   96]
# loss: 0.015036  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.019475
#
# Epoch 220
# -------------------------------
# loss: 0.035867  [    4/   96]
# loss: 0.045369  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018705
#
# Epoch 221
# -------------------------------
# loss: 0.036145  [    4/   96]
# loss: 0.018939  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024821
#
# Epoch 222
# -------------------------------
# loss: 1.313048  [    4/   96]
# loss: 0.012589  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015442
#
# Epoch 223
# -------------------------------
# loss: 0.012805  [    4/   96]
# loss: 0.013801  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.017699
#
# Epoch 224
# -------------------------------
# loss: 0.023817  [    4/   96]
# loss: 0.020428  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.020703
#
# Epoch 225
# -------------------------------
# loss: 0.011300  [    4/   96]
# loss: 0.010053  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015456
#
# Epoch 226
# -------------------------------
# loss: 0.010287  [    4/   96]
# loss: 0.225435  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.016698
#
# Epoch 227
# -------------------------------
# loss: 0.011039  [    4/   96]
# loss: 0.012127  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018290
#
# Epoch 228
# -------------------------------
# loss: 0.220354  [    4/   96]
# loss: 0.028220  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.022041
#
# Epoch 229
# -------------------------------
# loss: 0.009638  [    4/   96]
# loss: 0.014065  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.014242
#
# Epoch 230
# -------------------------------
# loss: 0.033769  [    4/   96]
# loss: 0.010848  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015018
#
# Epoch 231
# -------------------------------
# loss: 0.057900  [    4/   96]
# loss: 0.011948  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015870
#
# Epoch 232
# -------------------------------
# loss: 0.211364  [    4/   96]
# loss: 0.025408  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015273
#
# Epoch 233
# -------------------------------
# loss: 0.021771  [    4/   96]
# loss: 0.020850  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018153
#
# Epoch 234
# -------------------------------
# loss: 0.009770  [    4/   96]
# loss: 0.015780  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.014739
#
# Epoch 235
# -------------------------------
# loss: 0.009654  [    4/   96]
# loss: 0.009495  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.013776
#
# Epoch 236
# -------------------------------
# loss: 0.009813  [    4/   96]
# loss: 0.006739  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.016024
#
# Epoch 237
# -------------------------------
# loss: 0.009402  [    4/   96]
# loss: 0.012088  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.017061
#
# Epoch 238
# -------------------------------
# loss: 0.030146  [    4/   96]
# loss: 0.007776  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.017787
#
# Epoch 239
# -------------------------------
# loss: 0.020878  [    4/   96]
# loss: 0.363869  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.017869
#
# Epoch 240
# -------------------------------
# loss: 0.019162  [    4/   96]
# loss: 0.025493  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.017091
#
# Epoch 241
# -------------------------------
# loss: 0.024472  [    4/   96]
# loss: 0.039703  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.016361
#
# Epoch 242
# -------------------------------
# loss: 0.009270  [    4/   96]
# loss: 0.024786  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.016702
#
# Epoch 243
# -------------------------------
# loss: 0.308388  [    4/   96]
# loss: 0.016049  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.014880
#
# Epoch 244
# -------------------------------
# loss: 0.009746  [    4/   96]
# loss: 0.009775  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.017865
#
# Epoch 245
# -------------------------------
# loss: 0.015844  [    4/   96]
# loss: 0.008841  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.018694
#
# Epoch 246
# -------------------------------
# loss: 1.194585  [    4/   96]
# loss: 0.174174  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015129
#
# Epoch 247
# -------------------------------
# loss: 1.261281  [    4/   96]
# loss: 0.010798  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.012645
#
# Epoch 248
# -------------------------------
# loss: 0.006093  [    4/   96]
# loss: 0.038706  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015085
#
# Epoch 249
# -------------------------------
# loss: 0.027082  [    4/   96]
# loss: 1.005256  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015782
#
# Epoch 250
# -------------------------------
# loss: 0.160808  [    4/   96]
# loss: 0.976677  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.016779
#
# Epoch 251
# -------------------------------
# loss: 0.028817  [    4/   96]
# loss: 0.033127  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.016043
#
# Epoch 252
# -------------------------------
# loss: 0.941144  [    4/   96]
# loss: 0.007833  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015352
#
# Epoch 253
# -------------------------------
# loss: 0.010215  [    4/   96]
# loss: 0.009163  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015261
#
# Epoch 254
# -------------------------------
# loss: 0.045109  [    4/   96]
# loss: 0.997141  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.017874
#
# Epoch 255
# -------------------------------
# loss: 0.055895  [    4/   96]
# loss: 0.020648  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.017160
#
# Epoch 256
# -------------------------------
# loss: 0.009678  [    4/   96]
# loss: 0.015212  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015507
#
# Epoch 257
# -------------------------------
# loss: 0.008571  [    4/   96]
# loss: 0.295986  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015800
#
# Epoch 258
# -------------------------------
# loss: 0.043256  [    4/   96]
# loss: 0.010324  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015084
#
# Epoch 259
# -------------------------------
# loss: 0.048078  [    4/   96]
# loss: 0.018282  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015498
#
# Epoch 260
# -------------------------------
# loss: 0.026418  [    4/   96]
# loss: 0.047701  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.014771
#
# Epoch 261
# -------------------------------
# loss: 0.017859  [    4/   96]
# loss: 0.045706  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.013650
#
# Epoch 262
# -------------------------------
# loss: 0.007825  [    4/   96]
# loss: 0.031265  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024350
#
# Epoch 263
# -------------------------------
# loss: 0.010293  [    4/   96]
# loss: 0.105094  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015086
#
# Epoch 264
# -------------------------------
# loss: 0.976777  [    4/   96]
# loss: 0.007206  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.013136
#
# Epoch 265
# -------------------------------
# loss: 0.017405  [    4/   96]
# loss: 0.331317  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015161
#
# Epoch 266
# -------------------------------
# loss: 0.051521  [    4/   96]
# loss: 0.094355  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.012706
#
# Epoch 267
# -------------------------------
# loss: 0.015855  [    4/   96]
# loss: 0.008118  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015612
#
# Epoch 268
# -------------------------------
# loss: 0.009904  [    4/   96]
# loss: 0.297528  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.014053
#
# Epoch 269
# -------------------------------
# loss: 1.089345  [    4/   96]
# loss: 0.009387  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.012141
#
# Epoch 270
# -------------------------------
# loss: 0.015934  [    4/   96]
# loss: 0.143690  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.013079
#
# Epoch 271
# -------------------------------
# loss: 0.016333  [    4/   96]
# loss: 0.009284  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.017311
#
# Epoch 272
# -------------------------------
# loss: 0.011156  [    4/   96]
# loss: 0.019023  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.016489
#
# Epoch 273
# -------------------------------
# loss: 0.036342  [    4/   96]
# loss: 0.012626  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.016464
#
# Epoch 274
# -------------------------------
# loss: 0.044341  [    4/   96]
# loss: 0.010890  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.014100
#
# Epoch 275
# -------------------------------
# loss: 0.006996  [    4/   96]
# loss: 0.022355  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.015178
#
# Epoch 276
# -------------------------------
# loss: 0.008535  [    4/   96]
# loss: 0.008801  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.013905
#
# Epoch 277
# -------------------------------
# loss: 0.007949  [    4/   96]
# loss: 0.016950  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.011930
#
# Epoch 278
# -------------------------------
# loss: 0.151311  [    4/   96]
# loss: 0.008345  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.013052
#
# Epoch 279
# -------------------------------
# loss: 0.992880  [    4/   96]
# loss: 0.009437  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.012752
#
# Epoch 280
# -------------------------------
# loss: 1.005395  [    4/   96]
# loss: 0.007725  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.012663
#
# Epoch 281
# -------------------------------
# loss: 0.012860  [    4/   96]
# loss: 0.007218  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.011569
#
# Epoch 282
# -------------------------------
# loss: 0.007718  [    4/   96]
# loss: 0.009072  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.012601
#
# Epoch 283
# -------------------------------
# loss: 0.056225  [    4/   96]
# loss: 0.008756  [   84/   96]
# Test Error:
# ...
# loss: 0.027703  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.031715
#
# Epoch 206
# -------------------------------
# loss: 0.878275  [    4/   96]
# loss: 0.028819  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028266
#
# Epoch 207
# -------------------------------
# loss: 0.758575  [    4/   96]
# loss: 0.030730  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025445
#
# Epoch 208
# -------------------------------
# loss: 0.786313  [    4/   96]
# loss: 0.034789  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027339
#
# Epoch 209
# -------------------------------
# loss: 0.039118  [    4/   96]
# loss: 0.029276  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028503
#
# Epoch 210
# -------------------------------
# loss: 0.034895  [    4/   96]
# loss: 0.029676  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026952
#
# Epoch 211
# -------------------------------
# loss: 0.023440  [    4/   96]
# loss: 0.032939  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027301
#
# Epoch 212
# -------------------------------
# loss: 0.028220  [    4/   96]
# loss: 0.023842  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030454
#
# Epoch 213
# -------------------------------
# loss: 0.029519  [    4/   96]
# loss: 0.027718  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.029281
#
# Epoch 214
# -------------------------------
# loss: 0.601794  [    4/   96]
# loss: 0.036736  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026567
#
# Epoch 215
# -------------------------------
# loss: 0.030384  [    4/   96]
# loss: 0.027060  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023367
#
# Epoch 216
# -------------------------------
# loss: 0.025374  [    4/   96]
# loss: 0.026677  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026878
#
# Epoch 217
# -------------------------------
# loss: 0.614546  [    4/   96]
# loss: 0.028636  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026734
#
# Epoch 218
# -------------------------------
# loss: 0.022192  [    4/   96]
# loss: 0.022244  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027900
#
# Epoch 219
# -------------------------------
# loss: 0.031699  [    4/   96]
# loss: 0.026533  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028437
#
# Epoch 220
# -------------------------------
# loss: 0.029404  [    4/   96]
# loss: 0.038039  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027731
#
# Epoch 221
# -------------------------------
# loss: 0.025112  [    4/   96]
# loss: 0.029321  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023950
#
# Epoch 222
# -------------------------------
# loss: 0.024096  [    4/   96]
# loss: 0.030719  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030183
#
# Epoch 223
# -------------------------------
# loss: 0.034908  [    4/   96]
# loss: 0.030678  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028945
#
# Epoch 224
# -------------------------------
# loss: 0.732037  [    4/   96]
# loss: 0.024057  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028988
#
# Epoch 225
# -------------------------------
# loss: 0.875076  [    4/   96]
# loss: 0.030594  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028554
#
# Epoch 226
# -------------------------------
# loss: 0.026519  [    4/   96]
# loss: 0.032251  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.032979
#
# Epoch 227
# -------------------------------
# loss: 0.028471  [    4/   96]
# loss: 0.776937  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.033875
#
# Epoch 228
# -------------------------------
# loss: 0.026049  [    4/   96]
# loss: 0.027107  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030654
#
# Epoch 229
# -------------------------------
# loss: 0.029189  [    4/   96]
# loss: 0.039136  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030940
#
# Epoch 230
# -------------------------------
# loss: 0.718249  [    4/   96]
# loss: 0.032463  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027821
#
# Epoch 231
# -------------------------------
# loss: 0.024623  [    4/   96]
# loss: 0.027494  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.029589
#
# Epoch 232
# -------------------------------
# loss: 0.036455  [    4/   96]
# loss: 0.027720  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030346
#
# Epoch 233
# -------------------------------
# loss: 0.027510  [    4/   96]
# loss: 0.031037  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025994
#
# Epoch 234
# -------------------------------
# loss: 0.028087  [    4/   96]
# loss: 0.028815  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028359
#
# Epoch 235
# -------------------------------
# loss: 0.028775  [    4/   96]
# loss: 0.019592  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030211
#
# Epoch 236
# -------------------------------
# loss: 0.026902  [    4/   96]
# loss: 0.034062  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026478
#
# Epoch 237
# -------------------------------
# loss: 0.033941  [    4/   96]
# loss: 0.799734  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.029618
#
# Epoch 238
# -------------------------------
# loss: 0.033233  [    4/   96]
# loss: 0.036278  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.029140
#
# Epoch 239
# -------------------------------
# loss: 0.884677  [    4/   96]
# loss: 0.020811  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.029373
#
# Epoch 240
# -------------------------------
# loss: 0.030349  [    4/   96]
# loss: 0.028207  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.031245
#
# Epoch 241
# -------------------------------
# loss: 0.879432  [    4/   96]
# loss: 0.027399  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024285
#
# Epoch 242
# -------------------------------
# loss: 0.021015  [    4/   96]
# loss: 0.027655  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026708
#
# Epoch 243
# -------------------------------
# loss: 0.026965  [    4/   96]
# loss: 0.755126  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027537
#
# Epoch 244
# -------------------------------
# loss: 0.022415  [    4/   96]
# loss: 0.024083  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026505
#
# Epoch 245
# -------------------------------
# loss: 0.023398  [    4/   96]
# loss: 0.023928  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025223
#
# Epoch 246
# -------------------------------
# loss: 0.025029  [    4/   96]
# loss: 0.025870  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027199
#
# Epoch 247
# -------------------------------
# loss: 0.026233  [    4/   96]
# loss: 0.036412  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027411
#
# Epoch 248
# -------------------------------
# loss: 0.026620  [    4/   96]
# loss: 0.030148  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028383
#
# Epoch 249
# -------------------------------
# loss: 0.028883  [    4/   96]
# loss: 0.027248  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030283
#
# Epoch 250
# -------------------------------
# loss: 0.027936  [    4/   96]
# loss: 0.027694  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.029065
#
# Epoch 251
# -------------------------------
# loss: 0.028863  [    4/   96]
# loss: 0.026443  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.029761
#
# Epoch 252
# -------------------------------
# loss: 0.025852  [    4/   96]
# loss: 0.030398  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.032335
#
# Epoch 253
# -------------------------------
# loss: 0.031175  [    4/   96]
# loss: 0.032139  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027170
#
# Epoch 254
# -------------------------------
# loss: 0.034441  [    4/   96]
# loss: 0.025240  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.029067
#
# Epoch 255
# -------------------------------
# loss: 0.027702  [    4/   96]
# loss: 0.025335  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024892
#
# Epoch 256
# -------------------------------
# loss: 0.020547  [    4/   96]
# loss: 0.043755  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026014
#
# Epoch 257
# -------------------------------
# loss: 0.878265  [    4/   96]
# loss: 0.030275  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024136
#
# Epoch 258
# -------------------------------
# loss: 0.032974  [    4/   96]
# loss: 0.036035  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026752
#
# Epoch 259
# -------------------------------
# loss: 0.033973  [    4/   96]
# loss: 0.023649  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028582
#
# Epoch 260
# -------------------------------
# loss: 0.028788  [    4/   96]
# loss: 0.033941  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027450
#
# Epoch 261
# -------------------------------
# loss: 0.025285  [    4/   96]
# loss: 0.030473  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028443
#
# Epoch 262
# -------------------------------
# loss: 0.029323  [    4/   96]
# loss: 0.020231  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030094
#
# Epoch 263
# -------------------------------
# loss: 0.028750  [    4/   96]
# loss: 0.035523  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026437
#
# Epoch 264
# -------------------------------
# loss: 0.028663  [    4/   96]
# loss: 0.022979  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025856
#
# Epoch 265
# -------------------------------
# loss: 0.700620  [    4/   96]
# loss: 0.028088  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025863
#
# Epoch 266
# -------------------------------
# loss: 0.030711  [    4/   96]
# loss: 0.029906  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026142
#
# Epoch 267
# -------------------------------
# loss: 0.030576  [    4/   96]
# loss: 0.033612  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023464
#
# Epoch 268
# -------------------------------
# loss: 0.021622  [    4/   96]
# loss: 0.025494  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023385
#
# Epoch 269
# -------------------------------
# loss: 0.020137  [    4/   96]
# loss: 0.029039  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021808
#
# Epoch 270
# -------------------------------
# loss: 0.018689  [    4/   96]
# loss: 0.025290  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025044
#
# Epoch 271
# -------------------------------
# loss: 0.034908  [    4/   96]
# loss: 0.022880  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026898
#
# Epoch 272
# -------------------------------
# loss: 0.024100  [    4/   96]
# loss: 0.026924  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026821
#
# Epoch 273
# -------------------------------
# loss: 0.028869  [    4/   96]
# loss: 0.750440  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030180
#
# Epoch 274
# -------------------------------
# loss: 0.027576  [    4/   96]
# loss: 0.897263  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030791
#
# Epoch 275
# -------------------------------
# loss: 0.019600  [    4/   96]
# loss: 0.550660  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030305
#
# Epoch 276
# -------------------------------
# loss: 0.485768  [    4/   96]
# loss: 0.030905  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024797
#
# Epoch 277
# -------------------------------
# loss: 0.030223  [    4/   96]
# loss: 0.018516  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026809
#
# Epoch 278
# -------------------------------
# loss: 0.032616  [    4/   96]
# loss: 0.026228  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027075
#
# Epoch 279
# -------------------------------
# loss: 0.022627  [    4/   96]
# loss: 0.029006  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.029512
#
# Epoch 280
# -------------------------------
# loss: 0.027140  [    4/   96]
# loss: 0.020709  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027736
#
# Epoch 281
# -------------------------------
# loss: 0.023723  [    4/   96]
# loss: 0.028336  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025010
#
# Epoch 282
# -------------------------------
# loss: 0.029399  [    4/   96]
# loss: 0.513650  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030493
#
# Epoch 283
# -------------------------------
# loss: 0.030810  [    4/   96]
# loss: 0.024451  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024889
#
# Epoch 284
# -------------------------------
# loss: 0.021511  [    4/   96]
# loss: 0.021265  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023634
#
# Epoch 285
# -------------------------------
# loss: 0.023590  [    4/   96]
# loss: 0.020420  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.023458
#
# Epoch 286
# -------------------------------
# loss: 0.029715  [    4/   96]
# loss: 0.027433  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024915
#
# Epoch 287
# -------------------------------
# loss: 0.031149  [    4/   96]
# loss: 0.032040  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.028480
#
# Epoch 288
# -------------------------------
# loss: 0.028431  [    4/   96]
# loss: 0.034214  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027486
#
# Epoch 289
# -------------------------------
# loss: 0.021332  [    4/   96]
# loss: 0.869620  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.030243
#
# Epoch 290
# -------------------------------
# loss: 0.036440  [    4/   96]
# loss: 0.044811  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.026760
#
# Epoch 291
# -------------------------------
# loss: 0.031465  [    4/   96]
# loss: 0.030374  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024615
#
# Epoch 292
# -------------------------------
# loss: 0.024988  [    4/   96]
# loss: 0.028628  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.021559
#
# Epoch 293
# -------------------------------
# loss: 0.018157  [    4/   96]
# loss: 0.034240  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.025751
#
# Epoch 294
# -------------------------------
# loss: 0.039364  [    4/   96]
# loss: 0.026211  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.029977
#
# Epoch 295
# -------------------------------
# loss: 0.039444  [    4/   96]
# loss: 0.482780  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.024654
#
# Epoch 296
# -------------------------------
# loss: 0.021303  [    4/   96]
# loss: 0.023324  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027061
#
# Epoch 297
# -------------------------------
# loss: 0.025160  [    4/   96]
# loss: 0.029707  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.034453
#
# Epoch 298
# -------------------------------
# loss: 0.038788  [    4/   96]
# loss: 0.032118  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.031743
#
# Epoch 299
# -------------------------------
# loss: 0.031426  [    4/   96]
# loss: 0.023383  [   84/   96]
# Test Error:
#  Recall: nan%, Accuracy: 100.0%, Avg loss: 0.027060
#
# Done!

# %% [markdown]
# When the positive examples make up 4% of the dataset, which is roughly the true proportion when we record all game data, it is a bit hit-and-miss as to whether the model progresses much with recall in 300 epochs. The ordering of which loss functions were better or worse was different in all runs. gamma = 0.4 was the best on three of the runs, but failed to make any progress with recall in the other two runs (out of 5 runs). BCE made progress (and beat some of the focal loss functions) on two of the runs, so it is not clear that focal loss makes a huge difference.

# %% [markdown]
# # Conclusion
#
# The model struggles with recall when the positive examples make up less than 10% of the dataset, but even when they are as low as 4%, it is possible for the model to learn eventually, even without modifying the loss function. This suggests that we can proceed with integrating the block landing model architecture into the Tetris emulator and expect some improvement in performance. If we fail to see an improvement, we can try gathering a larger dataset so the model has enough examples of uncommon events to learn from.
