# %% [markdown]
# # Experiment 012
#
# In this experiment, we build on the findings of Experiment 011 and instead of incorporating a pretrained block landing model into the Tetris emulator, we merge the two architectures and train end to end.

# %%
import os
from pathlib import Path
import shutil
import datetime

import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.utils.data import Dataset
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt

# %%
class RecordingDataset(Dataset):
    def __init__(self, path: str):
        self.path = path
        if not os.path.exists(path):
            raise FileNotFoundError()
        with os.scandir(self.path) as it:
            entry: os.DirEntry = next(iter(it))
            _, self.ext = os.path.splitext(entry.name)
            self.highest_index = max((int(Path(file.path).stem) for file in it), default=-1)

    def __len__(self):
        return self.highest_index + 1

    def __getitem__(self, idx):
        file = os.path.join(self.path, f"{idx}{self.ext}")
        if not os.path.exists(file):
            raise IndexError()
        boards = np.load(file)
        x = torch.tensor(boards[-2]) # Ignore all boards except the last two
        y = torch.tensor(boards[-1], dtype=torch.long)
        return x, y

# %%
train_dataset = RecordingDataset(os.path.join("data", "tetris_emulator", "train"))
test_dataset = RecordingDataset(os.path.join("data", "tetris_emulator", "test"))
train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=4, shuffle=True)

x, y = next(iter(train_dataloader))
print(x.shape, x.dtype)
print(y.shape, y.dtype)
# Out:
# torch.Size([4, 22, 10]) torch.int32
# torch.Size([4, 22, 10]) torch.int64

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
class TetrisModel(nn.Module):
    """Predicts the next state of the cells.

    Inputs:
        x: Tensor of int32 of shape (batch_size, height, width). height = 22 and width = 10 are the dimensions of the game
           board. The entries should be 0 for empty cells and 1 for blocks.
    
    Returns: Tensor of float32 of shape (batch_size, height, width), logits for the new cells. Probabilities close to 0 (negative logits)
             correspond to empty cells, and probabilities close to 1 (positive logits) correspond to blocks.
    """

    def __init__(self):
        super().__init__()
        self.conv0 = nn.Conv2d(2, 16, 3, padding=1)
        self.norm0 = nn.BatchNorm2d(16)
        self.conv1 = nn.Conv2d(16, 16, 3, padding=1)
        self.norm1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(16, 16, 3, padding=1)
        self.norm2 = nn.BatchNorm2d(16)
        self.conv3 = nn.Conv2d(16, 2, 1)

    def forward(self, x):
        x = F.one_hot(x.long(), 2) # One-hot encode the two cell classes
        x = x.type(torch.float) # Convert to floating-point
        x = x.permute((0, 3, 1, 2)) # Move channels/classes to dimension 1
        x = F.relu(self.norm0(self.conv0(x)))
        x = F.relu(self.norm1(self.conv1(x)))
        x = F.relu(self.norm2(self.conv2(x)))
        logits = F.log_softmax(self.conv3(x), dim=1)
        return logits

# %%
class ModelWithGlobalAtStart(nn.Module):
    def __init__(self):
        super().__init__()
        self.glob = nn.Sequential(
            nn.Conv2d(2, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Flatten(),
            nn.Linear(160, 10)
        )
        self.loc = nn.Sequential(
            nn.Conv2d(12, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 2, 1),
            nn.LogSoftmax()
        )

    def forward(self, x):
        batch_size, height, width = x.shape

        x = F.one_hot(x.long(), 2) # One-hot encode the two cell classes
        x = x.type(torch.float) # Convert to floating-point
        x = x.permute((0, 3, 1, 2)) # Move channels/classes to dimension 1

        x_glob = self.glob(x)
        x_glob = x_glob[:, :, None, None] # Expand dims
        x_glob = x_glob.repeat(1, 1, height, width) # Upscale to image size
        x = torch.cat((x, x_glob), dim=1)

        logits = self.loc(x)
        return logits

# %%
class ModelWithGlobalAtEnd(nn.Module):
    def __init__(self):
        super().__init__()
        self.loc = nn.Sequential(
            nn.Conv2d(2, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
        )
        self.glob = nn.Sequential(
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Flatten(),
            nn.Linear(160, 10)
        )
        self.head = nn.Sequential(
            nn.Conv2d(26, 2, 1),
            nn.LogSoftmax()
        )

    def forward(self, x):
        batch_size, height, width = x.shape
        
        x = F.one_hot(x.long(), 2) # One-hot encode the two cell classes
        x = x.type(torch.float) # Convert to floating-point
        x = x.permute((0, 3, 1, 2)) # Move channels/classes to dimension 1

        x = self.loc(x)

        x_glob = self.glob(x)
        x_glob = x_glob[:, :, None, None] # Expand dims
        x_glob = x_glob.repeat(1, 1, height, width) # Upscale to image size
        x = torch.cat((x, x_glob), dim=1)

        logits = self.head(x)
        return logits

# %%
class ModelWithGlobalInMiddle(nn.Module):
    def __init__(self):
        super().__init__()
        self.loc = nn.Sequential(
            nn.Conv2d(2, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
        )
        self.glob = nn.Sequential(
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(16, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),
            nn.Flatten(),
            nn.Linear(160, 10)
        )
        self.head = nn.Sequential(
            nn.Conv2d(26, 16, 3, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 2, 1),
            nn.LogSoftmax()
        )

    def forward(self, x):
        batch_size, height, width = x.shape
        
        x = F.one_hot(x.long(), 2) # One-hot encode the two cell classes
        x = x.type(torch.float) # Convert to floating-point
        x = x.permute((0, 3, 1, 2)) # Move channels/classes to dimension 1

        x = self.loc(x)

        x_glob = self.glob(x)
        x_glob = x_glob[:, :, None, None] # Expand dims
        x_glob = x_glob.repeat(1, 1, height, width) # Upscale to image size
        x = torch.cat((x, x_glob), dim=1)

        logits = self.head(x)
        return logits

# %%
model = ModelWithGlobalInMiddle().to(device)
print(model)

with torch.no_grad():
    X, y = next(iter(train_dataloader))
    logits = model(X)[0]
    preds = torch.exp(logits)
    print(f"Predicted states: {preds}")
# Out:
# ModelWithGlobalInMiddle(
#   (loc): Sequential(
#     (0): Conv2d(2, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (glob): Sequential(
#     (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Flatten(start_dim=1, end_dim=-1)
#     (9): Linear(in_features=160, out_features=10, bias=True)
#   )
#   (head): Sequential(
#     (0): Conv2d(26, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 2, kernel_size=(1, 1), stride=(1, 1))
#     (4): LogSoftmax(dim=None)
#   )
# )
# Predicted states: tensor([[[0.4624, 0.4207, 0.4371, 0.4353, 0.4353, 0.4353, 0.4353, 0.4889,
#           0.3487, 0.3712],
#          [0.4742, 0.4141, 0.4128, 0.4728, 0.4728, 0.4728, 0.4728, 0.4702,
#           0.3608, 0.3180],
#          [0.4731, 0.3200, 0.3340, 0.3993, 0.3993, 0.3993, 0.3993, 0.4093,
#           0.3466, 0.3345],
#          [0.4669, 0.3465, 0.3455, 0.4110, 0.4110, 0.4110, 0.4110, 0.4174,
#           0.3525, 0.3566],
#          [0.4669, 0.3465, 0.3455, 0.4110, 0.4110, 0.4110, 0.4110, 0.4174,
#           0.3525, 0.3566],
#          [0.4690, 0.3566, 0.3441, 0.4671, 0.4723, 0.4828, 0.4726, 0.4443,
#           0.3855, 0.3413],
#          [0.4584, 0.3725, 0.3937, 0.4463, 0.4370, 0.4221, 0.3429, 0.2805,
#           0.2972, 0.3392],
#          [0.4567, 0.3711, 0.4127, 0.5282, 0.5418, 0.5045, 0.5910, 0.4241,
#           0.3626, 0.3696],
#          [0.4641, 0.3918, 0.3095, 0.4550, 0.4982, 0.3859, 0.3228, 0.3464,
#           0.3171, 0.3497],
#          [0.4612, 0.2865, 0.3528, 0.3154, 0.3269, 0.4462, 0.2302, 0.2866,
#           0.2810, 0.3480],
#          [0.4659, 0.3504, 0.3893, 0.4492, 0.4084, 0.3752, 0.3655, 0.4140,
#           0.3609, 0.3679],
#          [0.4620, 0.3222, 0.3817, 0.4138, 0.3688, 0.4144, 0.4188, 0.4291,
#           0.3593, 0.3511],
#          [0.4669, 0.3465, 0.3455, 0.4110, 0.4110, 0.4110, 0.4110, 0.4174,
#           0.3525, 0.3566],
#          [0.4669, 0.3465, 0.3549, 0.4136, 0.3782, 0.4369, 0.4164, 0.4358,
#           0.3415, 0.3566],
#          [0.4690, 0.3566, 0.3654, 0.4538, 0.4679, 0.4595, 0.4685, 0.4107,
#           0.3387, 0.3566],
#          [0.4584, 0.3733, 0.3425, 0.4562, 0.2630, 0.3689, 0.3519, 0.3584,
#           0.4128, 0.3566],
#          [0.4614, 0.3734, 0.4777, 0.5527, 0.3586, 0.5550, 0.5125, 0.3239,
#           0.3092, 0.3566],
#          [0.4505, 0.4190, 0.2661, 0.4789, 0.4439, 0.2000, 0.4188, 0.2470,
#           0.2625, 0.3566],
#          [0.4551, 0.3282, 0.3337, 0.3658, 0.7753, 0.1704, 0.4662, 0.2272,
#           0.2427, 0.3413],
#          [0.4516, 0.3583, 0.3774, 0.5957, 0.7900, 0.0759, 0.2106, 0.3525,
#           0.3352, 0.4200],
#          [0.4258, 0.1604, 0.1203, 0.3908, 0.7755, 0.0879, 0.0810, 0.1325,
#           0.1564, 0.2500],
#          [0.4599, 0.3510, 0.4151, 0.4870, 0.5960, 0.2963, 0.2686, 0.3678,
#           0.4029, 0.2691]],
#
#         [[0.5376, 0.5793, 0.5629, 0.5647, 0.5647, 0.5647, 0.5647, 0.5111,
#           0.6513, 0.6288],
#          [0.5258, 0.5859, 0.5872, 0.5272, 0.5272, 0.5272, 0.5272, 0.5298,
#           0.6392, 0.6820],
#          [0.5269, 0.6800, 0.6660, 0.6007, 0.6007, 0.6007, 0.6007, 0.5907,
#           0.6534, 0.6655],
#          [0.5331, 0.6535, 0.6545, 0.5890, 0.5890, 0.5890, 0.5890, 0.5826,
#           0.6475, 0.6434],
#          [0.5331, 0.6535, 0.6545, 0.5890, 0.5890, 0.5890, 0.5890, 0.5826,
#           0.6475, 0.6434],
#          [0.5310, 0.6434, 0.6559, 0.5329, 0.5277, 0.5172, 0.5274, 0.5557,
#           0.6145, 0.6587],
#          [0.5416, 0.6275, 0.6063, 0.5537, 0.5630, 0.5779, 0.6571, 0.7195,
#           0.7028, 0.6608],
#          [0.5433, 0.6289, 0.5873, 0.4718, 0.4582, 0.4955, 0.4090, 0.5759,
#           0.6374, 0.6304],
#          [0.5359, 0.6082, 0.6905, 0.5450, 0.5018, 0.6141, 0.6772, 0.6536,
#           0.6829, 0.6503],
#          [0.5388, 0.7135, 0.6472, 0.6846, 0.6731, 0.5538, 0.7698, 0.7134,
#           0.7190, 0.6520],
#          [0.5341, 0.6496, 0.6107, 0.5508, 0.5916, 0.6248, 0.6345, 0.5860,
#           0.6391, 0.6321],
#          [0.5380, 0.6778, 0.6183, 0.5862, 0.6312, 0.5856, 0.5812, 0.5709,
#           0.6407, 0.6489],
#          [0.5331, 0.6535, 0.6545, 0.5890, 0.5890, 0.5890, 0.5890, 0.5826,
#           0.6475, 0.6434],
#          [0.5331, 0.6535, 0.6451, 0.5864, 0.6218, 0.5631, 0.5836, 0.5642,
#           0.6585, 0.6434],
#          [0.5310, 0.6434, 0.6346, 0.5462, 0.5321, 0.5405, 0.5315, 0.5893,
#           0.6613, 0.6434],
#          [0.5416, 0.6267, 0.6575, 0.5438, 0.7370, 0.6311, 0.6481, 0.6416,
#           0.5872, 0.6434],
#          [0.5386, 0.6266, 0.5223, 0.4473, 0.6414, 0.4450, 0.4875, 0.6761,
#           0.6908, 0.6434],
#          [0.5495, 0.5810, 0.7339, 0.5211, 0.5561, 0.8000, 0.5812, 0.7530,
#           0.7375, 0.6434],
#          [0.5449, 0.6718, 0.6663, 0.6342, 0.2247, 0.8296, 0.5338, 0.7728,
#           0.7573, 0.6587],
#          [0.5484, 0.6417, 0.6226, 0.4043, 0.2100, 0.9241, 0.7894, 0.6475,
#           0.6648, 0.5800],
#          [0.5742, 0.8396, 0.8797, 0.6092, 0.2245, 0.9121, 0.9190, 0.8675,
#           0.8436, 0.7500],
#          [0.5401, 0.6490, 0.5849, 0.5130, 0.4040, 0.7037, 0.7314, 0.6322,
#           0.5971, 0.7309]]])
# c:\Projects\game_emulation\venv\lib\site-packages\torch\nn\modules\container.py:217: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()

    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):

        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


def test_loop(split_name, dataloader, model, loss_fn):
    model.eval()

    epoch_loss = 0.0
    cell_accuracy = 0.0
    board_accuracy = 0.0
    spawn_recall = 0.0
    num_spawns = 0.0

    num_batches = len(dataloader)
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            epoch_loss += loss_fn(pred, y).item()
            classes = torch.argmax(pred, dim=1)
            cell_accuracy += (classes == y).type(torch.float).mean().item()
            board_accuracy += (classes == y).all(-1).all(-1).type(torch.float).mean().item()

            actual_spawns = (X[:, 0, :] == 0).all(-1) & (y[:, 0, :] == 1).any(-1)
            predicted_spawns = (classes[:, 0, :] == 1).any(-1)
            spawn_recall += (actual_spawns & predicted_spawns).type(torch.float).sum().item()
            num_spawns += actual_spawns.type(torch.float).sum().item()

    epoch_loss /= num_batches
    cell_accuracy /= num_batches
    board_accuracy /= num_batches
    spawn_recall /= num_spawns
    return {
        "loss": epoch_loss,
        "acc": cell_accuracy,
        "acc_board": board_accuracy,
        "Spawn recall": spawn_recall
    }

# %%
def train(model, learning_rate=1e-1, batch_size=4, epochs=100):
    loss_fn = nn.NLLLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    log_dir = os.path.join("runs", "experiment_012")
    log_subdir = os.path.join(log_dir, f'{model.__class__.__name__}_lr_{str(learning_rate).replace(".", "_")}_bs_{batch_size}_ep_{epochs}_{datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")}')
    tb = SummaryWriter(log_subdir)

    print(f"Training model {model.__class__.__name__}...")
    for t in range(epochs):
        train_loop(train_dataloader, model, loss_fn, optimizer)
        train_metrics = test_loop("Train", train_dataloader, model, loss_fn)
        test_metrics = test_loop("Test", test_dataloader, model, loss_fn)
        tb.add_scalar("Loss/train", train_metrics["loss"], t)
        tb.add_scalar("Cell accuracy/train", train_metrics["acc"], t)
        tb.add_scalar("Board accuracy/train", train_metrics["acc_board"], t)
        tb.add_scalar("Spawn recall/train", train_metrics["Spawn recall"], t)
        tb.add_scalar("Loss/test", test_metrics["loss"], t)
        tb.add_scalar("Cell accuracy/test", test_metrics["acc"], t)
        tb.add_scalar("Board accuracy/test", test_metrics["acc_board"], t)
        tb.add_scalar("Spawn recall/test", test_metrics["Spawn recall"], t)
        for name, weight in model.named_parameters():
            tb.add_histogram(f"Weights/{name}", weight, t)
            tb.add_histogram(f"Gradients/{name}", weight.grad, t)

    tb.close()
    print("Done!")

    return {
        "train_accuracy": train_metrics["acc_board"],
        "train_spawn_recall": train_metrics["Spawn recall"],
        "test_accuracy": test_metrics["acc_board"],
        "test_spawn_recall": test_metrics["Spawn recall"]
    }

# %%
from scipy.stats import ttest_ind

repeats = 6

architectures = [
    {
        "class": TetrisModel
    },
    {
        "class": ModelWithGlobalAtStart
    },
    {
        "class": ModelWithGlobalAtEnd
    },
    {
        "class": ModelWithGlobalInMiddle
    }
]

for a in architectures:
    a["train_accuracy"] = np.zeros(repeats)
    a["train_spawn_recall"] = np.zeros(repeats)
    a["test_accuracy"] = np.zeros(repeats)
    a["test_spawn_recall"] = np.zeros(repeats)

for repeat in range(repeats):
    for architecture in architectures:
        model = architecture["class"]().to(device)
        repeat_results = train(model)
        architecture["train_accuracy"][repeat] = repeat_results["train_accuracy"]
        architecture["train_spawn_recall"][repeat] = repeat_results["train_spawn_recall"]
        architecture["test_accuracy"][repeat] = repeat_results["test_accuracy"]
        architecture["test_spawn_recall"][repeat] = repeat_results["test_spawn_recall"]
    
print(f"Results:")
for architecture in architectures:
    print(f"Class: {architecture['class'].__name__}")
    print(f"  Train accuracy mean {architecture['train_accuracy'].mean():.5f}, std {architecture['train_accuracy'].std():.5f}")
    print(f"  Test accuracy mean {architecture['test_accuracy'].mean():.5f}, std {architecture['test_accuracy'].std():.5f}")
    print(f"  Train spawn recall mean {architecture['train_spawn_recall'].mean():.5f}, std {architecture['train_spawn_recall'].std():.5f}")
    print(f"  Test spawn recall mean {architecture['test_spawn_recall'].mean():.5f}, std {architecture['test_spawn_recall'].std():.5f}")
    print()

for architecture in architectures[1:]:
    baseline = architectures[0]
    print(f"Performing t-tests of {architecture['class'].__name__} against {baseline['class'].__name__}")
    accuracy_ttest = ttest_ind(baseline["test_accuracy"], architecture["test_accuracy"], equal_var=False)
    spawn_recall_ttest = ttest_ind(baseline["test_spawn_recall"], architecture["test_spawn_recall"], equal_var=False)
    print("Accuracy t-test results:")
    print(accuracy_ttest)
    print("Spawn recall t-test results:")
    print(spawn_recall_ttest)
    print()
# Out:
# Training model TetrisModel...
# Train Error:
#  Accuracy: 99.4%, Board accuracy: 45.8%, Avg loss: 0.046508
#
# Test Error:
#  Accuracy: 99.6%, Board accuracy: 55.0%, Avg loss: 0.046407
#
# Train Error:
#  Accuracy: 98.8%, Board accuracy: 21.2%, Avg loss: 0.036883
#
# Test Error:
#  Accuracy: 98.9%, Board accuracy: 25.6%, Avg loss: 0.037931
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 85.4%, Avg loss: 0.014346
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 85.6%, Avg loss: 0.016331
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 89.6%, Avg loss: 0.011588
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 89.4%, Avg loss: 0.014397
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 90.8%, Avg loss: 0.009927
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.012917
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 91.2%, Avg loss: 0.008414
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 86.7%, Avg loss: 0.011444
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 90.0%, Avg loss: 0.007674
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.010040
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 90.4%, Avg loss: 0.006908
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.009672
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.2%, Avg loss: 0.006079
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.009435
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 90.0%, Avg loss: 0.006329
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.009265
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.6%, Avg loss: 0.005312
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.008958
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.6%, Avg loss: 0.005089
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.008872
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.4%, Avg loss: 0.004878
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.008621
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005326
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.008136
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.2%, Avg loss: 0.004595
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007876
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.6%, Avg loss: 0.004306
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007992
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.004161
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007897
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 89.6%, Avg loss: 0.005661
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.008066
#
# Train Error:
#  Accuracy: 99.5%, Board accuracy: 53.3%, Avg loss: 0.014646
#
# Test Error:
#  Accuracy: 99.4%, Board accuracy: 50.0%, Avg loss: 0.019175
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.0%, Avg loss: 0.003987
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007110
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003930
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007852
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.4%, Avg loss: 0.004288
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.008295
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.4%, Avg loss: 0.003870
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.008247
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 79.2%, Avg loss: 0.011188
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 84.4%, Avg loss: 0.009758
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.0%, Avg loss: 0.003561
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007081
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003437
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007201
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003397
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006734
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.6%, Avg loss: 0.004603
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.006730
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003310
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006475
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.003328
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006607
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003244
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007060
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003255
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007580
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.004736
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006476
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003314
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007421
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003038
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006699
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003025
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006945
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003042
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.007439
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003462
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005949
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003039
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.007728
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002962
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006368
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003005
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007167
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003106
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006203
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002933
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006872
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002975
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.006712
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003113
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007734
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002854
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006811
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.003093
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006717
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002983
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006222
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 91.2%, Avg loss: 0.004798
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.006319
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.4%, Avg loss: 0.002894
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007326
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002851
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007165
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002835
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.6%, Avg loss: 0.008007
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002747
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.006896
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002798
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007396
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002808
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007093
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002821
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007370
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002758
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006309
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.0%, Avg loss: 0.003749
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007096
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002690
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006751
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002693
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.006544
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002696
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007014
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002667
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.007104
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002657
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006379
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002697
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.007347
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002635
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006724
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002650
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006871
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.003007
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006033
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002604
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006708
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002679
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006309
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002680
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006565
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002613
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007040
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002751
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006134
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002633
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.006557
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.4%, Avg loss: 0.006043
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.008062
#
# Train Error:
#  Accuracy: 99.3%, Board accuracy: 37.9%, Avg loss: 0.023058
#
# Test Error:
#  Accuracy: 99.2%, Board accuracy: 33.3%, Avg loss: 0.021369
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002708
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006945
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002596
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006919
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002623
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.007528
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002646
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007113
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 92.9%, Avg loss: 0.003209
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006489
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002575
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006503
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002549
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006489
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.003378
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005728
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002598
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.006903
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002654
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007426
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002768
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007333
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002644
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.6%, Avg loss: 0.007983
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002502
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006787
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002606
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007114
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.4%, Avg loss: 0.003129
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006686
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.4%, Avg loss: 0.003497
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006078
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002740
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007562
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002562
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007205
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002525
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006368
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.002483
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.006808
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002499
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006755
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002481
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006559
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002478
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006588
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002484
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006819
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.0%, Avg loss: 0.003592
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.6%, Avg loss: 0.007106
#
# Done!
# Training model ModelWithGlobalAtStart...
# Train Error:
#  Accuracy: 97.4%, Board accuracy: 2.1%, Avg loss: 0.078539
#
# Test Error:
#  Accuracy: 97.4%, Board accuracy: 5.0%, Avg loss: 0.080346
#
# Train Error:
#  Accuracy: 99.7%, Board accuracy: 77.5%, Avg loss: 0.025591
#
# Test Error:
#  Accuracy: 99.7%, Board accuracy: 77.8%, Avg loss: 0.027788
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 84.6%, Avg loss: 0.014891
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 89.4%, Avg loss: 0.017939
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 87.1%, Avg loss: 0.014534
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 81.1%, Avg loss: 0.018798
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 86.7%, Avg loss: 0.009832
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.012605
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 90.4%, Avg loss: 0.007063
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 86.1%, Avg loss: 0.010278
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.2%, Avg loss: 0.005865
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 89.4%, Avg loss: 0.009670
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 91.2%, Avg loss: 0.006103
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 86.7%, Avg loss: 0.009059
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.004380
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.007606
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.6%, Avg loss: 0.003965
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 87.8%, Avg loss: 0.007236
#
# Train Error:
#  Accuracy: 99.6%, Board accuracy: 73.3%, Avg loss: 0.015144
#
# Test Error:
#  Accuracy: 99.6%, Board accuracy: 80.0%, Avg loss: 0.016715
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.6%, Avg loss: 0.003413
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.006570
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 93.8%, Avg loss: 0.003810
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 86.7%, Avg loss: 0.006937
#
# Train Error:
#  Accuracy: 99.6%, Board accuracy: 55.4%, Avg loss: 0.011600
#
# Test Error:
#  Accuracy: 99.6%, Board accuracy: 59.4%, Avg loss: 0.011595
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.6%, Avg loss: 0.002915
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.007153
#
# Train Error:
#  Accuracy: 99.4%, Board accuracy: 55.4%, Avg loss: 0.025568
#
# Test Error:
#  Accuracy: 99.2%, Board accuracy: 55.0%, Avg loss: 0.026803
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002313
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 86.7%, Avg loss: 0.006241
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002084
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.005804
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.001971
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.006546
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.004991
#
# Test Error:
#  Accuracy: 99.7%, Board accuracy: 85.0%, Avg loss: 0.009166
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.001952
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 89.4%, Avg loss: 0.004967
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.001758
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.005224
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002204
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 89.4%, Avg loss: 0.005057
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.0%, Avg loss: 0.002038
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 89.4%, Avg loss: 0.005435
#
# Train Error:
#  Accuracy: 92.2%, Board accuracy: 0.4%, Avg loss: 0.418535
#
# Test Error:
#  Accuracy: 91.7%, Board accuracy: 0.0%, Avg loss: 0.421225
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 89.6%, Avg loss: 0.005408
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 86.7%, Avg loss: 0.007061
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.6%, Avg loss: 0.002707
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 87.8%, Avg loss: 0.005581
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002389
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005466
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002169
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 89.4%, Avg loss: 0.004619
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.001790
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006317
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.001635
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003868
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 79.6%, Avg loss: 0.003893
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 85.0%, Avg loss: 0.005293
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.001333
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004638
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.001238
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005433
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.001205
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004605
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.001182
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005833
#
# Train Error:
#  Accuracy: 99.3%, Board accuracy: 27.5%, Avg loss: 0.021900
#
# Test Error:
#  Accuracy: 99.5%, Board accuracy: 42.2%, Avg loss: 0.015047
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.001175
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004246
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.001123
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003449
#
# Train Error:
#  Accuracy: 99.0%, Board accuracy: 26.7%, Avg loss: 0.023745
#
# Test Error:
#  Accuracy: 98.9%, Board accuracy: 20.6%, Avg loss: 0.029371
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.001358
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.004335
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000984
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004560
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.001077
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004216
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.001014
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.003697
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000886
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 92.8%, Avg loss: 0.004244
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000878
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.004167
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000824
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004391
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000820
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004511
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000793
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003828
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000786
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 92.8%, Avg loss: 0.004478
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000769
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.1%, Avg loss: 0.004066
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000732
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004723
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000798
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003691
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000751
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004475
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000707
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005325
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000900
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.1%, Avg loss: 0.003232
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000749
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.004456
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000699
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.005196
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000672
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004745
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000690
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.1%, Avg loss: 0.004622
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000704
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005075
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000666
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.004618
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000720
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005147
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000642
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004474
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000757
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004516
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000651
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.1%, Avg loss: 0.004472
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000618
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005378
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000665
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003850
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000617
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004253
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000611
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.005525
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000651
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.005058
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000602
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005049
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000656
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.005583
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000656
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004823
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000813
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004983
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000673
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.1%, Avg loss: 0.004815
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000582
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005696
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000604
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005204
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000606
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004548
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.001559
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004515
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000635
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005685
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000592
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004997
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000550
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005378
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000565
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005811
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000576
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005013
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000585
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005365
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000547
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005590
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000531
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005500
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000593
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005159
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000516
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.005698
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000566
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005328
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000582
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.005392
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000656
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005346
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000615
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 89.4%, Avg loss: 0.005290
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000662
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005273
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000535
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005313
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000717
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004718
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000612
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.006093
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000540
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005971
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000543
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005734
#
# Done!
# Training model ModelWithGlobalAtEnd...
# Train Error:
#  Accuracy: 99.4%, Board accuracy: 38.8%, Avg loss: 0.032467
#
# Test Error:
#  Accuracy: 99.5%, Board accuracy: 43.3%, Avg loss: 0.033772
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 82.5%, Avg loss: 0.014156
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 81.1%, Avg loss: 0.016115
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 85.0%, Avg loss: 0.010008
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 86.1%, Avg loss: 0.012818
#
# Train Error:
#  Accuracy: 96.2%, Board accuracy: 12.1%, Avg loss: 0.131371
#
# Test Error:
#  Accuracy: 96.2%, Board accuracy: 10.0%, Avg loss: 0.136882
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 89.2%, Avg loss: 0.006040
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 86.1%, Avg loss: 0.010408
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005202
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.008330
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 91.2%, Avg loss: 0.004839
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.007773
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 87.1%, Avg loss: 0.006360
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.008199
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 93.8%, Avg loss: 0.003735
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006731
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.003307
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.007116
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 93.8%, Avg loss: 0.003324
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005780
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.0%, Avg loss: 0.002746
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005670
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.003005
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005716
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.0%, Avg loss: 0.002513
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.6%, Avg loss: 0.005520
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 86.7%, Avg loss: 0.004225
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 84.4%, Avg loss: 0.006676
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002296
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005282
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.0%, Avg loss: 0.002487
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004841
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002301
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005175
#
# Train Error:
#  Accuracy: 99.7%, Board accuracy: 82.9%, Avg loss: 0.010594
#
# Test Error:
#  Accuracy: 99.6%, Board accuracy: 79.4%, Avg loss: 0.011964
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002016
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004872
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.001805
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004435
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.4%, Avg loss: 0.005748
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.007285
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.001728
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005815
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.001649
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004830
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.001543
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003887
#
# Train Error:
#  Accuracy: 99.4%, Board accuracy: 49.2%, Avg loss: 0.013921
#
# Test Error:
#  Accuracy: 99.3%, Board accuracy: 48.9%, Avg loss: 0.017239
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.001701
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003846
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.001468
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004454
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.6%, Avg loss: 0.001981
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.005006
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.001401
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004751
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.001303
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004261
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.001324
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003899
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.001224
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004232
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.001254
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003910
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.2%, Avg loss: 0.001381
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003337
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.001226
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004276
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.001219
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003520
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.001295
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003306
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.001291
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.003426
#
# Train Error:
#  Accuracy: 98.4%, Board accuracy: 19.2%, Avg loss: 0.040783
#
# Test Error:
#  Accuracy: 98.5%, Board accuracy: 28.9%, Avg loss: 0.040599
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.7%, Avg loss: 0.001329
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004650
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.001241
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004203
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.001152
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.1%, Avg loss: 0.003682
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.001131
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004395
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.001279
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003131
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.001004
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003869
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000996
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003361
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.001160
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.002833
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.001061
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003519
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.001165
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.1%, Avg loss: 0.003244
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000970
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.003645
#
# Train Error:
#  Accuracy: 99.6%, Board accuracy: 77.1%, Avg loss: 0.010372
#
# Test Error:
#  Accuracy: 99.6%, Board accuracy: 70.0%, Avg loss: 0.012418
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.001014
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003995
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.001061
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004265
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.000951
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.003613
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.000958
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004474
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000933
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.002953
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000971
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004268
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000927
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003412
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.000917
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003688
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.001021
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.003132
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000878
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003068
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000852
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003338
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.2%, Avg loss: 0.000926
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003620
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000829
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003666
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000873
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004057
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.0%, Avg loss: 0.001262
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004000
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000770
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003824
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000868
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003490
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000807
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.002999
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000817
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003179
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000839
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.003360
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000797
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003510
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000975
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004004
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.000812
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003340
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000816
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003580
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000779
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003798
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000732
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003336
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000806
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003033
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.001347
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.003218
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000864
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.003195
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000748
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.002967
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000743
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003181
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000713
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.003471
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000754
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003423
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000810
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.003379
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000773
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.003380
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000732
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003362
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.000931
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003390
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000781
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.002916
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000727
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.1%, Avg loss: 0.003187
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000762
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003390
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002327
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.005306
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000728
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.003464
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000697
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.002873
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000700
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.002937
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000783
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003341
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000704
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003564
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000673
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.003521
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.000767
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003564
#
# Done!
# Training model ModelWithGlobalInMiddle...
# Train Error:
#  Accuracy: 99.5%, Board accuracy: 52.9%, Avg loss: 0.047624
#
# Test Error:
#  Accuracy: 99.5%, Board accuracy: 55.6%, Avg loss: 0.048629
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 85.4%, Avg loss: 0.021031
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.021983
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 86.7%, Avg loss: 0.013857
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.015269
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 85.8%, Avg loss: 0.011542
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.013311
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.008229
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.009851
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 90.4%, Avg loss: 0.007793
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.010000
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 91.2%, Avg loss: 0.005871
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.008076
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 93.8%, Avg loss: 0.005187
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.007184
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004954
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.007259
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 93.8%, Avg loss: 0.003860
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006049
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.2%, Avg loss: 0.003634
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005677
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.003511
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005382
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.2%, Avg loss: 0.002828
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005995
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.002674
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004961
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.002388
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.004542
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.002224
#
# Test Error:
# ...
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.008566
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 94.6%, Avg loss: 0.005207
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 89.4%, Avg loss: 0.008417
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.0%, Avg loss: 0.004795
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.007400
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 93.8%, Avg loss: 0.004166
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.007573
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.4%, Avg loss: 0.003876
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.006871
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.0%, Avg loss: 0.003245
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006677
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.8%, Avg loss: 0.002883
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006528
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.4%, Avg loss: 0.002996
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.006723
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 95.4%, Avg loss: 0.002761
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006184
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.002383
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005778
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.002196
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.005580
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.002032
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005577
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.002036
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004990
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.001751
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004504
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.001731
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005961
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.001634
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004648
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.001601
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.006511
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.002449
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 88.3%, Avg loss: 0.005389
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.001387
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005652
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.001413
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004724
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.001196
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005300
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.001591
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004496
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.001643
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004499
#
# Train Error:
#  Accuracy: 99.8%, Board accuracy: 70.0%, Avg loss: 0.005234
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 71.7%, Avg loss: 0.006855
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.001196
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006584
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.001132
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.005493
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.001101
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006115
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.001047
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.1%, Avg loss: 0.005752
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.001016
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004348
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000929
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005947
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000982
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004770
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000938
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005666
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000921
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005276
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.001088
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004191
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000877
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004905
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.001192
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 93.3%, Avg loss: 0.003732
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.001352
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004140
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.001223
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.003882
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000790
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004895
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000803
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005418
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000848
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004481
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000861
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004463
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000849
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004280
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000747
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005445
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000725
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005537
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000929
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004378
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000707
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004855
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000799
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004744
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000779
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004591
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.1%, Avg loss: 0.000930
#
# Test Error:
#  Accuracy: 99.9%, Board accuracy: 91.7%, Avg loss: 0.004200
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000697
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005527
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 88.8%, Avg loss: 0.003817
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 85.0%, Avg loss: 0.005120
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000699
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005024
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000752
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006072
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000715
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004966
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000999
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004175
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000871
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004218
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000649
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005441
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000677
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004310
#
# Train Error:
#  Accuracy: 97.2%, Board accuracy: 3.8%, Avg loss: 0.076551
#
# Test Error:
#  Accuracy: 97.2%, Board accuracy: 6.7%, Avg loss: 0.077060
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000831
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.006878
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000682
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006511
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000631
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005690
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000618
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005166
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000692
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004590
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000622
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004828
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000597
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006507
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000633
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004916
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000613
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005068
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000649
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005705
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000549
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005633
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000622
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005616
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000586
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005572
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000596
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005494
#
# Train Error:
#  Accuracy: 99.9%, Board accuracy: 96.2%, Avg loss: 0.002014
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 90.0%, Avg loss: 0.005393
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000628
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.007264
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000594
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005282
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000563
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.005931
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.9%, Avg loss: 0.000656
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.006130
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 96.7%, Avg loss: 0.001007
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005074
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000542
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006363
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000525
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005794
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000526
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005619
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 97.5%, Avg loss: 0.000702
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004353
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000570
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004827
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000492
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.006059
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000561
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004680
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000611
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.1%, Avg loss: 0.004534
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000583
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004513
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000540
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005012
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000590
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005442
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000529
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005166
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000535
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.005661
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000513
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.006177
#
# Train Error:
#  Accuracy: 100.0%, Board accuracy: 98.3%, Avg loss: 0.000628
#
# Test Error:
#  Accuracy: 99.8%, Board accuracy: 91.7%, Avg loss: 0.004290
#
# Done!
# Results:
# Class: TetrisModel
#   Train accuracy mean 0.96250, std 0.00589
#   Test accuracy mean 0.91389, std 0.00424
#   Train spawn recall mean 0.05556, std 0.05556
#   Test spawn recall mean 0.00000, std 0.00000
#
# Class: ModelWithGlobalAtStart
#   Train accuracy mean 0.98194, std 0.00196
#   Test accuracy mean 0.91296, std 0.01270
#   Train spawn recall mean 0.81481, std 0.12284
#   Test spawn recall mean 0.43333, std 0.13744
#
# Class: ModelWithGlobalAtEnd
#   Train accuracy mean 0.97917, std 0.00636
#   Test accuracy mean 0.91574, std 0.00207
#   Train spawn recall mean 0.70370, std 0.25391
#   Test spawn recall mean 0.03333, std 0.07454
#
# Class: ModelWithGlobalInMiddle
#   Train accuracy mean 0.97847, std 0.00698
#   Test accuracy mean 0.92130, std 0.00674
#   Train spawn recall mean 0.75926, std 0.14930
#   Test spawn recall mean 0.40000, std 0.23094
#
# Performing t-tests of ModelWithGlobalAtStart against TetrisModel
# Accuracy t-test results:
# Ttest_indResult(statistic=0.15467207951296527, pvalue=0.8820683242059348)
# Spawn recall t-test results:
# Ttest_indResult(statistic=-7.050239879106327, pvalue=0.0008870513737432898)
# Performing t-tests of ModelWithGlobalAtEnd against TetrisModel
# Accuracy t-test results:
# Ttest_indResult(statistic=-0.8770580675625129, pvalue=0.4085634946772868)
# Spawn recall t-test results:
# Ttest_indResult(statistic=-0.9999999999999998, pvalue=0.36321746764912244)
# Performing t-tests of ModelWithGlobalInMiddle against TetrisModel
# Accuracy t-test results:
# Ttest_indResult(statistic=-2.0795009520031145, pvalue=0.06942166372366157)
# Spawn recall t-test results:
# Ttest_indResult(statistic=-3.8729833462074166, pvalue=0.011724811003954635)

# %% [markdown]
# From these results, we see that in terms of spawn recall, `ModelWithGlobalAtStart` and `ModelWithGlobalInMiddle` did significantly better than the baseline, whereas `ModelWithGlobalAtEnd` does not. It does well in terms of spawn recall on the training set, but worse on the test set, likely a sign of overfitting.
#
# In terms of board accuracy, no model does significantly better than the baseline, but the baseline already has quite a high accuracy. `ModelWithGlobalInMiddle` has the lowest p-value here by far.
#
# The curves are all quite spiky, but especially those of spawn recall and of `ModelWithGlobalAtStart`. The spawn recall curve is probably spiky due to the fact that the dataset contains very few block spawns and is a sign that we need more data, and perhaps we need to rebalance the data to include more spawns and less of other events. The `ModelWithGlobalAtStart` curves may be spiky due to the 10 global features overwhelming the 2 local features when they're combined, or it may be because the global information has a long way to travel before it influences the prediction so gets lost inside the network.
#
# The loss and spawn accuracy are significantly lower on the test set, which implies that we are overfitting somewhat and could do with more data.
#
# `ModelWithGlobalInMiddle` seems the most appealing architecture. Having a local module at the start means that in theory, some spatial information can be shared by both the local and global parts of the network. Having a nontrivial head at the end means that the global features can have a more complex effect on the predictions of each cell. The network also gives a significant amount of customisability.
#
# In conclusion, `ModelWithGlobalInMiddle` looks like the best architecture, but to perform well it needs to be trained on more data. If the training instability persists, we can try lowering the learning rate.
