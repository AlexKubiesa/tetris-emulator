# %% [markdown]
# # Experiment 030
#
# In this notebook, we validate the GameGAN generator architecture on the Tetris problem by training the convolutional encoder and the rendering engine as an autoencoder (excluding the dynamics engine, events and random inputs). This should show whether the GameGAN generator architecture is suitable for the Tetris problem and the current dataset.

# %%
import os
from pathlib import Path
import shutil
import datetime

import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.utils.data import Dataset
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt


from models import TetrisModel, TetrisDiscriminator
import metrics
from recording import FileBasedDatabaseWithEvents
from engines import EVENT_NAMES

# %%
NUM_CELL_TYPES = 8
NUM_EVENT_TYPES = 5

class RecordingDataset(Dataset):
    def __init__(self, path: str):
        self._db = FileBasedDatabaseWithEvents(path)

    def __len__(self):
        return len(self._db)

    def __getitem__(self, idx):
        boards, events = self._db[idx]
        b = self._transform_board(boards[0]) # Just take one board
        return b
    
    def _transform_board(self, board):
        board = torch.tensor(board, dtype=torch.long)
        board = F.one_hot(board, NUM_CELL_TYPES) # One-hot encode the cell types
        board = board.type(torch.float) # Convert to floating-point
        board = board.permute((2, 0, 1)) # Move channels/classes to dimension 0
        return board

# %%
# Put datasets in memory for faster training
train_dataset = list(RecordingDataset(os.path.join("data", "tetris_emulator", "train")))
test_dataset = list(RecordingDataset(os.path.join("data", "tetris_emulator", "test")))
batch_size = 12 # Was 4
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

b = next(iter(train_dataloader))
print(f"b: shape {b.shape}, dtype {b.dtype}")
# Out:
# b: shape torch.Size([12, 8, 22, 10]), dtype torch.float32

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Using device {device}")
# Out:
# Using device cuda

# %%
real_label = 1.0
fake_label = 0.0

def train_loop(dataloader, gen, loss_fn, optimizer_gen):
    gen.train()

    size = len(dataloader.dataset)
    for batch, b in enumerate(dataloader):
        b = b.to(device)

        gen.zero_grad()
        # Reconstruct some examples
        b_pred = gen(b)
        # Calculate the generator's loss based on this output
        err_gen = loss_fn(b_pred, b)
        # Calculate gradients for generator
        err_gen.backward()
        # Update generator
        optimizer_gen.step()

        # Output training stats
        if batch % 30 == 0:
            current = batch * dataloader.batch_size + batch_size
            print(f"[{current}/{size}] G loss: {err_gen.item():.4f}")


def test_loop(split_name, dataloader, gen, loss_fn, tb_writer, epoch):
    gen.eval()

    loss_gen = 0.0
    cell_accuracy = metrics.CellAccuracy()
    board_accuracy = metrics.BoardAccuracy()

    num_batches = len(dataloader)
    with torch.no_grad():        
        for batch, b in enumerate(dataloader):
            b = b.to(device)

            b_pred = gen(b)
            
            loss_gen += loss_fn(b_pred, b).item()

            classes_b = torch.argmax(b, dim=1)
            classes_b_pred = torch.argmax(b_pred, dim=1)
            cell_accuracy.update_state(classes_b_pred, classes_b)
            board_accuracy.update_state(classes_b_pred, classes_b)


    loss_gen /= len(dataloader.dataset)

    print(f"{split_name} error: \n G loss: {loss_gen:>8f}, cell accuracy: {(cell_accuracy.result()):>0.1%}, board accuracy: {(board_accuracy.result()):>0.1%} \n")

    tb_writer.add_scalar(f"Loss/{split_name}", loss_gen, epoch)
    tb_writer.add_scalar(f"Cell accuracy/{split_name}", cell_accuracy.result(), epoch)
    tb_writer.add_scalar(f"Board accuracy/{split_name}", board_accuracy.result(), epoch)

# %%
def train(gen_factory, epochs, learning_rate):

    gen = gen_factory()

    loss_fn = nn.MSELoss() # BCE loss causes instability when the loss gets too small
    optimizer_gen = torch.optim.Adam(gen.parameters(), lr=learning_rate)

    log_dir = os.path.join("runs", "experiment_030")
    log_subdir = os.path.join(log_dir, datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S"))
    tb_writer = SummaryWriter(log_subdir)

    try:
        for epoch in range(epochs):
            print(f"Epoch {epoch}\n-------------------------------")
            train_loop(train_dataloader, gen, loss_fn, optimizer_gen)
            test_loop("train", train_dataloader, gen, loss_fn, tb_writer, epoch)
            test_loop("test", test_dataloader, gen, loss_fn, tb_writer, epoch)
            gen_zero_grads = 0
            for name, weight in gen.named_parameters():
                tb_writer.add_histogram(f"Weights/{name}", weight, epoch)
                if weight.grad is not None:
                    tb_writer.add_histogram(f"Gradients/{name}", weight.grad, epoch)
                    gen_zero_grads += weight.grad.numel() - weight.grad.count_nonzero().item()
            tb_writer.add_scalar(f"Zero gradients", gen_zero_grads, epoch)
    finally:
        tb_writer.close()
        
    print("Done!")
    return gen

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
NUM_RANDOM_INPUTS = 4


class Conv2dLeakyReLU(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, padding=0, use_batch_norm=False, negative_slope=0.0):
        super().__init__()

        self.use_batch_norm = use_batch_norm

        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding, bias=(not use_batch_norm))
        nn.init.kaiming_uniform_(self.conv.weight, a=negative_slope)
        if not use_batch_norm:
            nn.init.constant_(self.conv.bias, 0.01)

        if use_batch_norm:
            self.norm = nn.BatchNorm2d(out_channels)

        self.relu = nn.LeakyReLU(negative_slope)
    
    def forward(self, x):
        x = self.conv(x)
        if self.use_batch_norm:
            x = self.norm(x)
        x = self.relu(x)
        return x


class ConvTranspose2dLeakyReLU(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, padding=0, output_padding=0, use_batch_norm=False, negative_slope=0.0):
        super().__init__()

        self.use_batch_norm = use_batch_norm

        self.conv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding, output_padding=output_padding, bias=(not use_batch_norm))
        nn.init.kaiming_uniform_(self.conv.weight, a=negative_slope)
        if not use_batch_norm:
            nn.init.constant_(self.conv.bias, 0.01)

        if use_batch_norm:
            self.norm = nn.BatchNorm2d(out_channels)
            
        self.relu = nn.LeakyReLU(negative_slope)
    
    def forward(self, x):
        x = self.conv(x)
        if self.use_batch_norm:
            x = self.norm(x)
        x = self.relu(x)
        return x


class LinearLeakyReLU(nn.Module):
    def __init__(self, in_features, out_features, negative_slope=0.0):
        super().__init__()

        self.linear = nn.Linear(in_features, out_features)
        nn.init.kaiming_uniform_(self.linear.weight, a=negative_slope)
        nn.init.constant_(self.linear.bias, 0.01)

        self.relu = nn.LeakyReLU(negative_slope)

    def forward(self, x):
        x = self.linear(x)
        x = self.relu(x)
        return x


class GameganGenerator(nn.Module):
    def __init__(self, use_batch_norm=False, leak=0.0):
        super().__init__()

        self.use_batch_norm = use_batch_norm
        self.leak = leak

        self.board_encoder = nn.Sequential(
            Conv2dLeakyReLU(NUM_CELL_TYPES, 64, kernel_size=2, stride=2, use_batch_norm=use_batch_norm, negative_slope=leak),
            Conv2dLeakyReLU(64, 64, kernel_size=3, use_batch_norm=use_batch_norm, negative_slope=leak),
            Conv2dLeakyReLU(64, 64, kernel_size=3, use_batch_norm=use_batch_norm, negative_slope=leak),
            nn.Flatten(start_dim=1),
            LinearLeakyReLU(448, 256, negative_slope=leak)
        )

        self.renderer = nn.Sequential(
            LinearLeakyReLU(256, 448, negative_slope=leak),
            nn.Unflatten(dim=1, unflattened_size=(64, 7, 1)),
            ConvTranspose2dLeakyReLU(64, 64, kernel_size=3, use_batch_norm=use_batch_norm, negative_slope=leak),
            ConvTranspose2dLeakyReLU(64, 64, kernel_size=3, use_batch_norm=use_batch_norm, negative_slope=leak),
            nn.ConvTranspose2d(64, NUM_CELL_TYPES, kernel_size=2, stride=2),
            nn.Softmax(dim=1),
        )

    def forward(self, b):
        # Encode board state
        s = self.board_encoder(b)

        # Render new board
        y = self.renderer(s)
        return y


print(f"Parameters: {count_parameters(GameganGenerator())}")
# Out:
# Parameters: 381960

# %%
del gen

gen = train(
    gen_factory=lambda: GameganGenerator(use_batch_norm=True, leak=0.2).to(device),
    epochs=1000,
    learning_rate=1e-4
)
# Out:
# Epoch 0
# -------------------------------
# [12/2000] G loss: 0.1178
# [372/2000] G loss: 0.1086
# [732/2000] G loss: 0.1002
# [1092/2000] G loss: 0.0943
# [1452/2000] G loss: 0.0814
# [1812/2000] G loss: 0.0747
# train error:
#  G loss: 0.006062, cell accuracy: 60.3%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.006105, cell accuracy: 60.1%, board accuracy: 0.0%
#
# Epoch 1
# -------------------------------
# [12/2000] G loss: 0.0733
# [372/2000] G loss: 0.0715
# [732/2000] G loss: 0.0647
# [1092/2000] G loss: 0.0595
# [1452/2000] G loss: 0.0534
# [1812/2000] G loss: 0.0522
# train error:
#  G loss: 0.004227, cell accuracy: 72.2%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.004274, cell accuracy: 71.9%, board accuracy: 0.0%
#
# Epoch 2
# -------------------------------
# [12/2000] G loss: 0.0504
# [372/2000] G loss: 0.0475
# [732/2000] G loss: 0.0436
# [1092/2000] G loss: 0.0428
# [1452/2000] G loss: 0.0438
# [1812/2000] G loss: 0.0352
# train error:
#  G loss: 0.003000, cell accuracy: 81.0%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.003052, cell accuracy: 80.7%, board accuracy: 0.0%
#
# Epoch 3
# -------------------------------
# [12/2000] G loss: 0.0381
# [372/2000] G loss: 0.0346
# [732/2000] G loss: 0.0315
# [1092/2000] G loss: 0.0299
# [1452/2000] G loss: 0.0277
# [1812/2000] G loss: 0.0265
# train error:
#  G loss: 0.002209, cell accuracy: 86.3%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.002270, cell accuracy: 85.9%, board accuracy: 0.0%
#
# Epoch 4
# -------------------------------
# [12/2000] G loss: 0.0274
# [372/2000] G loss: 0.0257
# [732/2000] G loss: 0.0247
# [1092/2000] G loss: 0.0222
# [1452/2000] G loss: 0.0223
# [1812/2000] G loss: 0.0201
# train error:
#  G loss: 0.001674, cell accuracy: 90.2%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.001735, cell accuracy: 89.9%, board accuracy: 0.0%
#
# Epoch 5
# -------------------------------
# [12/2000] G loss: 0.0212
# [372/2000] G loss: 0.0184
# [732/2000] G loss: 0.0207
# [1092/2000] G loss: 0.0181
# [1452/2000] G loss: 0.0185
# [1812/2000] G loss: 0.0184
# train error:
#  G loss: 0.001383, cell accuracy: 92.2%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.001439, cell accuracy: 91.8%, board accuracy: 0.0%
#
# Epoch 6
# -------------------------------
# [12/2000] G loss: 0.0188
# [372/2000] G loss: 0.0191
# [732/2000] G loss: 0.0167
# [1092/2000] G loss: 0.0157
# [1452/2000] G loss: 0.0150
# [1812/2000] G loss: 0.0135
# train error:
#  G loss: 0.001160, cell accuracy: 93.8%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.001209, cell accuracy: 93.5%, board accuracy: 0.2%
#
# Epoch 7
# -------------------------------
# [12/2000] G loss: 0.0137
# [372/2000] G loss: 0.0126
# [732/2000] G loss: 0.0145
# [1092/2000] G loss: 0.0138
# [1452/2000] G loss: 0.0141
# [1812/2000] G loss: 0.0131
# train error:
#  G loss: 0.000970, cell accuracy: 94.9%, board accuracy: 0.5%
#
# test error:
#  G loss: 0.001012, cell accuracy: 94.6%, board accuracy: 0.6%
#
# Epoch 8
# -------------------------------
# [12/2000] G loss: 0.0140
# [372/2000] G loss: 0.0120
# [732/2000] G loss: 0.0111
# [1092/2000] G loss: 0.0108
# [1452/2000] G loss: 0.0110
# [1812/2000] G loss: 0.0119
# train error:
#  G loss: 0.000841, cell accuracy: 95.5%, board accuracy: 0.8%
#
# test error:
#  G loss: 0.000878, cell accuracy: 95.4%, board accuracy: 0.8%
#
# Epoch 9
# -------------------------------
# [12/2000] G loss: 0.0123
# [372/2000] G loss: 0.0105
# [732/2000] G loss: 0.0113
# [1092/2000] G loss: 0.0097
# [1452/2000] G loss: 0.0106
# [1812/2000] G loss: 0.0092
# train error:
#  G loss: 0.000741, cell accuracy: 96.1%, board accuracy: 1.4%
#
# test error:
#  G loss: 0.000774, cell accuracy: 96.0%, board accuracy: 1.0%
#
# Epoch 10
# -------------------------------
# [12/2000] G loss: 0.0080
# [372/2000] G loss: 0.0077
# [732/2000] G loss: 0.0083
# [1092/2000] G loss: 0.0096
# [1452/2000] G loss: 0.0085
# [1812/2000] G loss: 0.0066
# train error:
#  G loss: 0.000660, cell accuracy: 96.5%, board accuracy: 1.6%
#
# test error:
#  G loss: 0.000691, cell accuracy: 96.4%, board accuracy: 1.6%
#
# Epoch 11
# -------------------------------
# [12/2000] G loss: 0.0101
# [372/2000] G loss: 0.0071
# [732/2000] G loss: 0.0082
# [1092/2000] G loss: 0.0076
# [1452/2000] G loss: 0.0083
# [1812/2000] G loss: 0.0074
# train error:
#  G loss: 0.000590, cell accuracy: 96.9%, board accuracy: 2.0%
#
# test error:
#  G loss: 0.000618, cell accuracy: 96.8%, board accuracy: 1.6%
#
# Epoch 12
# -------------------------------
# [12/2000] G loss: 0.0064
# [372/2000] G loss: 0.0064
# [732/2000] G loss: 0.0072
# [1092/2000] G loss: 0.0082
# [1452/2000] G loss: 0.0065
# [1812/2000] G loss: 0.0075
# train error:
#  G loss: 0.000530, cell accuracy: 97.2%, board accuracy: 2.6%
#
# test error:
#  G loss: 0.000558, cell accuracy: 97.1%, board accuracy: 1.8%
#
# Epoch 13
# -------------------------------
# [12/2000] G loss: 0.0069
# [372/2000] G loss: 0.0069
# [732/2000] G loss: 0.0090
# [1092/2000] G loss: 0.0052
# [1452/2000] G loss: 0.0064
# [1812/2000] G loss: 0.0062
# train error:
#  G loss: 0.000475, cell accuracy: 97.4%, board accuracy: 2.9%
#
# test error:
#  G loss: 0.000503, cell accuracy: 97.3%, board accuracy: 1.8%
#
# Epoch 14
# -------------------------------
# [12/2000] G loss: 0.0063
# [372/2000] G loss: 0.0052
# [732/2000] G loss: 0.0060
# [1092/2000] G loss: 0.0052
# [1452/2000] G loss: 0.0055
# [1812/2000] G loss: 0.0067
# train error:
#  G loss: 0.000433, cell accuracy: 97.7%, board accuracy: 4.1%
#
# test error:
#  G loss: 0.000462, cell accuracy: 97.5%, board accuracy: 3.0%
#
# Epoch 15
# -------------------------------
# [12/2000] G loss: 0.0056
# [372/2000] G loss: 0.0049
# [732/2000] G loss: 0.0055
# [1092/2000] G loss: 0.0043
# [1452/2000] G loss: 0.0055
# [1812/2000] G loss: 0.0045
# train error:
#  G loss: 0.000400, cell accuracy: 97.9%, board accuracy: 4.8%
#
# test error:
#  G loss: 0.000429, cell accuracy: 97.7%, board accuracy: 3.2%
#
# Epoch 16
# -------------------------------
# [12/2000] G loss: 0.0045
# [372/2000] G loss: 0.0055
# [732/2000] G loss: 0.0041
# [1092/2000] G loss: 0.0053
# [1452/2000] G loss: 0.0047
# [1812/2000] G loss: 0.0048
# train error:
#  G loss: 0.000363, cell accuracy: 98.0%, board accuracy: 5.1%
#
# test error:
#  G loss: 0.000392, cell accuracy: 97.9%, board accuracy: 3.8%
#
# Epoch 17
# -------------------------------
# [12/2000] G loss: 0.0049
# [372/2000] G loss: 0.0044
# [732/2000] G loss: 0.0043
# [1092/2000] G loss: 0.0039
# [1452/2000] G loss: 0.0056
# [1812/2000] G loss: 0.0042
# train error:
#  G loss: 0.000337, cell accuracy: 98.2%, board accuracy: 6.0%
#
# test error:
#  G loss: 0.000366, cell accuracy: 98.1%, board accuracy: 4.2%
#
# Epoch 18
# -------------------------------
# [12/2000] G loss: 0.0036
# [372/2000] G loss: 0.0041
# [732/2000] G loss: 0.0043
# [1092/2000] G loss: 0.0032
# [1452/2000] G loss: 0.0043
# [1812/2000] G loss: 0.0043
# train error:
#  G loss: 0.000309, cell accuracy: 98.3%, board accuracy: 6.9%
#
# test error:
#  G loss: 0.000338, cell accuracy: 98.2%, board accuracy: 4.8%
#
# Epoch 19
# -------------------------------
# [12/2000] G loss: 0.0038
# [372/2000] G loss: 0.0042
# [732/2000] G loss: 0.0033
# [1092/2000] G loss: 0.0039
# [1452/2000] G loss: 0.0042
# [1812/2000] G loss: 0.0042
# train error:
#  G loss: 0.000287, cell accuracy: 98.4%, board accuracy: 9.2%
#
# test error:
#  G loss: 0.000316, cell accuracy: 98.3%, board accuracy: 5.8%
#
# Epoch 20
# -------------------------------
# [12/2000] G loss: 0.0032
# [372/2000] G loss: 0.0040
# [732/2000] G loss: 0.0031
# [1092/2000] G loss: 0.0039
# [1452/2000] G loss: 0.0036
# [1812/2000] G loss: 0.0035
# train error:
#  G loss: 0.000263, cell accuracy: 98.6%, board accuracy: 10.8%
#
# test error:
#  G loss: 0.000293, cell accuracy: 98.4%, board accuracy: 7.2%
#
# Epoch 21
# -------------------------------
# [12/2000] G loss: 0.0033
# [372/2000] G loss: 0.0035
# [732/2000] G loss: 0.0032
# [1092/2000] G loss: 0.0032
# [1452/2000] G loss: 0.0033
# [1812/2000] G loss: 0.0028
# train error:
#  G loss: 0.000241, cell accuracy: 98.7%, board accuracy: 14.4%
#
# test error:
#  G loss: 0.000273, cell accuracy: 98.5%, board accuracy: 10.8%
#
# Epoch 22
# -------------------------------
# [12/2000] G loss: 0.0033
# [372/2000] G loss: 0.0025
# [732/2000] G loss: 0.0036
# [1092/2000] G loss: 0.0027
# [1452/2000] G loss: 0.0034
# [1812/2000] G loss: 0.0025
# train error:
#  G loss: 0.000224, cell accuracy: 98.8%, board accuracy: 16.0%
#
# test error:
#  G loss: 0.000256, cell accuracy: 98.6%, board accuracy: 12.6%
#
# Epoch 23
# -------------------------------
# [12/2000] G loss: 0.0027
# [372/2000] G loss: 0.0024
# [732/2000] G loss: 0.0032
# [1092/2000] G loss: 0.0026
# [1452/2000] G loss: 0.0025
# [1812/2000] G loss: 0.0030
# train error:
#  G loss: 0.000205, cell accuracy: 98.9%, board accuracy: 19.2%
#
# test error:
#  G loss: 0.000238, cell accuracy: 98.7%, board accuracy: 14.4%
#
# Epoch 24
# -------------------------------
# [12/2000] G loss: 0.0030
# [372/2000] G loss: 0.0026
# [732/2000] G loss: 0.0024
# [1092/2000] G loss: 0.0027
# [1452/2000] G loss: 0.0020
# [1812/2000] G loss: 0.0028
# train error:
#  G loss: 0.000191, cell accuracy: 99.0%, board accuracy: 22.9%
#
# test error:
#  G loss: 0.000225, cell accuracy: 98.8%, board accuracy: 17.6%
#
# Epoch 25
# -------------------------------
# [12/2000] G loss: 0.0025
# [372/2000] G loss: 0.0025
# [732/2000] G loss: 0.0025
# [1092/2000] G loss: 0.0019
# [1452/2000] G loss: 0.0028
# [1812/2000] G loss: 0.0024
# train error:
#  G loss: 0.000175, cell accuracy: 99.0%, board accuracy: 26.8%
#
# test error:
#  G loss: 0.000211, cell accuracy: 98.8%, board accuracy: 19.6%
#
# Epoch 26
# -------------------------------
# [12/2000] G loss: 0.0026
# [372/2000] G loss: 0.0026
# [732/2000] G loss: 0.0022
# [1092/2000] G loss: 0.0021
# [1452/2000] G loss: 0.0023
# [1812/2000] G loss: 0.0026
# train error:
#  G loss: 0.000164, cell accuracy: 99.1%, board accuracy: 29.9%
#
# test error:
#  G loss: 0.000200, cell accuracy: 98.9%, board accuracy: 21.6%
#
# Epoch 27
# -------------------------------
# [12/2000] G loss: 0.0021
# [372/2000] G loss: 0.0022
# [732/2000] G loss: 0.0022
# [1092/2000] G loss: 0.0025
# [1452/2000] G loss: 0.0019
# [1812/2000] G loss: 0.0026
# train error:
#  G loss: 0.000148, cell accuracy: 99.2%, board accuracy: 33.5%
#
# test error:
#  G loss: 0.000185, cell accuracy: 99.0%, board accuracy: 25.4%
#
# Epoch 28
# -------------------------------
# [12/2000] G loss: 0.0024
# [372/2000] G loss: 0.0016
# [732/2000] G loss: 0.0019
# [1092/2000] G loss: 0.0019
# [1452/2000] G loss: 0.0015
# [1812/2000] G loss: 0.0017
# train error:
#  G loss: 0.000138, cell accuracy: 99.3%, board accuracy: 37.2%
#
# test error:
#  G loss: 0.000177, cell accuracy: 99.1%, board accuracy: 26.0%
#
# Epoch 29
# -------------------------------
# [12/2000] G loss: 0.0019
# [372/2000] G loss: 0.0019
# [732/2000] G loss: 0.0019
# [1092/2000] G loss: 0.0018
# [1452/2000] G loss: 0.0023
# [1812/2000] G loss: 0.0016
# train error:
#  G loss: 0.000126, cell accuracy: 99.3%, board accuracy: 41.1%
#
# test error:
#  G loss: 0.000165, cell accuracy: 99.1%, board accuracy: 31.2%
#
# Epoch 30
# -------------------------------
# [12/2000] G loss: 0.0018
# [372/2000] G loss: 0.0025
# [732/2000] G loss: 0.0020
# [1092/2000] G loss: 0.0011
# [1452/2000] G loss: 0.0018
# [1812/2000] G loss: 0.0019
# train error:
#  G loss: 0.000114, cell accuracy: 99.4%, board accuracy: 46.9%
#
# test error:
#  G loss: 0.000154, cell accuracy: 99.2%, board accuracy: 32.4%
#
# Epoch 31
# -------------------------------
# [12/2000] G loss: 0.0012
# [372/2000] G loss: 0.0016
# [732/2000] G loss: 0.0020
# [1092/2000] G loss: 0.0016
# [1452/2000] G loss: 0.0012
# [1812/2000] G loss: 0.0021
# train error:
#  G loss: 0.000103, cell accuracy: 99.5%, board accuracy: 50.1%
#
# test error:
#  G loss: 0.000145, cell accuracy: 99.2%, board accuracy: 37.2%
#
# Epoch 32
# -------------------------------
# [12/2000] G loss: 0.0014
# [372/2000] G loss: 0.0010
# [732/2000] G loss: 0.0020
# [1092/2000] G loss: 0.0014
# [1452/2000] G loss: 0.0007
# [1812/2000] G loss: 0.0011
# train error:
#  G loss: 0.000095, cell accuracy: 99.5%, board accuracy: 53.3%
#
# test error:
#  G loss: 0.000137, cell accuracy: 99.3%, board accuracy: 41.2%
#
# Epoch 33
# -------------------------------
# [12/2000] G loss: 0.0013
# [372/2000] G loss: 0.0011
# [732/2000] G loss: 0.0011
# [1092/2000] G loss: 0.0010
# [1452/2000] G loss: 0.0016
# [1812/2000] G loss: 0.0018
# train error:
#  G loss: 0.000086, cell accuracy: 99.6%, board accuracy: 55.5%
#
# test error:
#  G loss: 0.000128, cell accuracy: 99.3%, board accuracy: 43.2%
#
# Epoch 34
# -------------------------------
# [12/2000] G loss: 0.0010
# [372/2000] G loss: 0.0009
# [732/2000] G loss: 0.0010
# [1092/2000] G loss: 0.0010
# [1452/2000] G loss: 0.0010
# [1812/2000] G loss: 0.0014
# train error:
#  G loss: 0.000079, cell accuracy: 99.6%, board accuracy: 59.9%
#
# test error:
#  G loss: 0.000121, cell accuracy: 99.4%, board accuracy: 44.4%
#
# Epoch 35
# -------------------------------
# [12/2000] G loss: 0.0008
# [372/2000] G loss: 0.0012
# [732/2000] G loss: 0.0011
# [1092/2000] G loss: 0.0009
# [1452/2000] G loss: 0.0010
# [1812/2000] G loss: 0.0015
# train error:
#  G loss: 0.000072, cell accuracy: 99.7%, board accuracy: 61.3%
#
# test error:
#  G loss: 0.000116, cell accuracy: 99.4%, board accuracy: 45.6%
#
# Epoch 36
# -------------------------------
# [12/2000] G loss: 0.0007
# [372/2000] G loss: 0.0008
# [732/2000] G loss: 0.0008
# [1092/2000] G loss: 0.0010
# [1452/2000] G loss: 0.0008
# [1812/2000] G loss: 0.0013
# train error:
#  G loss: 0.000065, cell accuracy: 99.7%, board accuracy: 65.6%
#
# test error:
#  G loss: 0.000109, cell accuracy: 99.4%, board accuracy: 47.8%
#
# Epoch 37
# -------------------------------
# [12/2000] G loss: 0.0008
# [372/2000] G loss: 0.0013
# [732/2000] G loss: 0.0006
# [1092/2000] G loss: 0.0005
# [1452/2000] G loss: 0.0014
# [1812/2000] G loss: 0.0007
# train error:
#  G loss: 0.000058, cell accuracy: 99.7%, board accuracy: 68.6%
#
# test error:
#  G loss: 0.000103, cell accuracy: 99.5%, board accuracy: 50.0%
#
# Epoch 38
# -------------------------------
# [12/2000] G loss: 0.0007
# [372/2000] G loss: 0.0008
# [732/2000] G loss: 0.0010
# [1092/2000] G loss: 0.0003
# [1452/2000] G loss: 0.0005
# [1812/2000] G loss: 0.0012
# train error:
#  G loss: 0.000052, cell accuracy: 99.8%, board accuracy: 71.2%
#
# test error:
#  G loss: 0.000097, cell accuracy: 99.5%, board accuracy: 54.4%
#
# Epoch 39
# -------------------------------
# [12/2000] G loss: 0.0005
# [372/2000] G loss: 0.0009
# [732/2000] G loss: 0.0007
# [1092/2000] G loss: 0.0012
# [1452/2000] G loss: 0.0006
# [1812/2000] G loss: 0.0006
# train error:
#  G loss: 0.000048, cell accuracy: 99.8%, board accuracy: 72.9%
#
# test error:
#  G loss: 0.000092, cell accuracy: 99.5%, board accuracy: 54.2%
#
# Epoch 40
# -------------------------------
# [12/2000] G loss: 0.0005
# [372/2000] G loss: 0.0004
# [732/2000] G loss: 0.0003
# [1092/2000] G loss: 0.0003
# [1452/2000] G loss: 0.0010
# [1812/2000] G loss: 0.0005
# train error:
#  G loss: 0.000044, cell accuracy: 99.8%, board accuracy: 74.5%
#
# test error:
#  G loss: 0.000090, cell accuracy: 99.5%, board accuracy: 54.4%
#
# Epoch 41
# -------------------------------
# [12/2000] G loss: 0.0011
# [372/2000] G loss: 0.0004
# [732/2000] G loss: 0.0004
# [1092/2000] G loss: 0.0005
# [1452/2000] G loss: 0.0004
# [1812/2000] G loss: 0.0005
# train error:
#  G loss: 0.000039, cell accuracy: 99.8%, board accuracy: 77.4%
#
# test error:
#  G loss: 0.000085, cell accuracy: 99.6%, board accuracy: 57.4%
#
# Epoch 42
# -------------------------------
# [12/2000] G loss: 0.0006
# [372/2000] G loss: 0.0007
# [732/2000] G loss: 0.0005
# [1092/2000] G loss: 0.0004
# [1452/2000] G loss: 0.0007
# [1812/2000] G loss: 0.0006
# train error:
#  G loss: 0.000035, cell accuracy: 99.9%, board accuracy: 81.8%
#
# test error:
#  G loss: 0.000080, cell accuracy: 99.6%, board accuracy: 60.6%
#
# Epoch 43
# -------------------------------
# [12/2000] G loss: 0.0006
# [372/2000] G loss: 0.0002
# [732/2000] G loss: 0.0004
# [1092/2000] G loss: 0.0003
# [1452/2000] G loss: 0.0006
# [1812/2000] G loss: 0.0006
# train error:
#  G loss: 0.000032, cell accuracy: 99.9%, board accuracy: 83.0%
#
# test error:
#  G loss: 0.000077, cell accuracy: 99.6%, board accuracy: 60.6%
#
# Epoch 44
# -------------------------------
# [12/2000] G loss: 0.0003
# [372/2000] G loss: 0.0003
# [732/2000] G loss: 0.0003
# [1092/2000] G loss: 0.0005
# [1452/2000] G loss: 0.0002
# [1812/2000] G loss: 0.0004
# train error:
#  G loss: 0.000029, cell accuracy: 99.9%, board accuracy: 84.2%
#
# test error:
#  G loss: 0.000075, cell accuracy: 99.6%, board accuracy: 63.2%
#
# Epoch 45
# -------------------------------
# [12/2000] G loss: 0.0007
# [372/2000] G loss: 0.0007
# [732/2000] G loss: 0.0004
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0002
# [1812/2000] G loss: 0.0006
# train error:
#  G loss: 0.000026, cell accuracy: 99.9%, board accuracy: 85.5%
#
# test error:
#  G loss: 0.000072, cell accuracy: 99.6%, board accuracy: 64.2%
#
# Epoch 46
# -------------------------------
# [12/2000] G loss: 0.0006
# [372/2000] G loss: 0.0006
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0005
# [1452/2000] G loss: 0.0003
# [1812/2000] G loss: 0.0003
# train error:
#  G loss: 0.000023, cell accuracy: 99.9%, board accuracy: 87.2%
#
# test error:
#  G loss: 0.000069, cell accuracy: 99.6%, board accuracy: 64.2%
#
# Epoch 47
# -------------------------------
# [12/2000] G loss: 0.0004
# [372/2000] G loss: 0.0003
# [732/2000] G loss: 0.0004
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0003
# [1812/2000] G loss: 0.0005
# train error:
#  G loss: 0.000022, cell accuracy: 99.9%, board accuracy: 87.6%
#
# test error:
#  G loss: 0.000068, cell accuracy: 99.6%, board accuracy: 64.6%
#
# Epoch 48
# -------------------------------
# [12/2000] G loss: 0.0002
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0003
# [1092/2000] G loss: 0.0008
# [1452/2000] G loss: 0.0003
# [1812/2000] G loss: 0.0005
# train error:
#  G loss: 0.000019, cell accuracy: 99.9%, board accuracy: 88.7%
#
# test error:
#  G loss: 0.000064, cell accuracy: 99.7%, board accuracy: 66.6%
#
# Epoch 49
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0004
# [732/2000] G loss: 0.0002
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0003
# [1812/2000] G loss: 0.0005
# train error:
#  G loss: 0.000019, cell accuracy: 99.9%, board accuracy: 89.6%
#
# test error:
#  G loss: 0.000064, cell accuracy: 99.7%, board accuracy: 66.8%
#
# Epoch 50
# -------------------------------
# [12/2000] G loss: 0.0004
# [372/2000] G loss: 0.0003
# [732/2000] G loss: 0.0004
# [1092/2000] G loss: 0.0003
# [1452/2000] G loss: 0.0006
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000017, cell accuracy: 99.9%, board accuracy: 89.6%
#
# test error:
#  G loss: 0.000062, cell accuracy: 99.7%, board accuracy: 67.8%
#
# Epoch 51
# -------------------------------
# [12/2000] G loss: 0.0003
# [372/2000] G loss: 0.0003
# [732/2000] G loss: 0.0004
# [1092/2000] G loss: 0.0005
# [1452/2000] G loss: 0.0002
# [1812/2000] G loss: 0.0002
# train error:
#  G loss: 0.000016, cell accuracy: 99.9%, board accuracy: 90.5%
#
# test error:
#  G loss: 0.000060, cell accuracy: 99.7%, board accuracy: 68.8%
#
# Epoch 52
# -------------------------------
# [12/2000] G loss: 0.0003
# [372/2000] G loss: 0.0007
# [732/2000] G loss: 0.0002
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0003
# [1812/2000] G loss: 0.0004
# train error:
#  G loss: 0.000014, cell accuracy: 99.9%, board accuracy: 91.0%
#
# test error:
#  G loss: 0.000059, cell accuracy: 99.7%, board accuracy: 68.0%
#
# Epoch 53
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0002
# [732/2000] G loss: 0.0005
# [1092/2000] G loss: 0.0003
# [1452/2000] G loss: 0.0002
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000014, cell accuracy: 99.9%, board accuracy: 91.3%
#
# test error:
#  G loss: 0.000058, cell accuracy: 99.7%, board accuracy: 69.2%
#
# Epoch 54
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0003
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0003
# [1812/2000] G loss: 0.0002
# train error:
#  G loss: 0.000013, cell accuracy: 99.9%, board accuracy: 91.9%
#
# test error:
#  G loss: 0.000057, cell accuracy: 99.7%, board accuracy: 69.8%
#
# Epoch 55
# -------------------------------
# [12/2000] G loss: 0.0002
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0003
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0003
# [1812/2000] G loss: 0.0003
# train error:
#  G loss: 0.000012, cell accuracy: 100.0%, board accuracy: 92.3%
#
# test error:
#  G loss: 0.000055, cell accuracy: 99.7%, board accuracy: 69.2%
#
# Epoch 56
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0003
# [1452/2000] G loss: 0.0005
# [1812/2000] G loss: 0.0004
# train error:
#  G loss: 0.000012, cell accuracy: 100.0%, board accuracy: 92.3%
#
# test error:
#  G loss: 0.000057, cell accuracy: 99.7%, board accuracy: 67.4%
#
# Epoch 57
# -------------------------------
# [12/2000] G loss: 0.0003
# [372/2000] G loss: 0.0004
# [732/2000] G loss: 0.0002
# [1092/2000] G loss: 0.0003
# [1452/2000] G loss: 0.0003
# [1812/2000] G loss: 0.0004
# train error:
#  G loss: 0.000010, cell accuracy: 100.0%, board accuracy: 93.2%
#
# test error:
#  G loss: 0.000055, cell accuracy: 99.7%, board accuracy: 68.6%
#
# Epoch 58
# -------------------------------
# [12/2000] G loss: 0.0004
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0002
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0003
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000010, cell accuracy: 100.0%, board accuracy: 93.5%
#
# test error:
#  G loss: 0.000053, cell accuracy: 99.7%, board accuracy: 70.4%
#
# Epoch 59
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0003
# [732/2000] G loss: 0.0002
# [1092/2000] G loss: 0.0005
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000010, cell accuracy: 100.0%, board accuracy: 94.2%
#
# test error:
#  G loss: 0.000054, cell accuracy: 99.7%, board accuracy: 69.2%
#
# Epoch 60
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0003
# [732/2000] G loss: 0.0002
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0002
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000008, cell accuracy: 100.0%, board accuracy: 94.8%
#
# test error:
#  G loss: 0.000052, cell accuracy: 99.7%, board accuracy: 71.4%
#
# Epoch 61
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0002
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0002
# train error:
#  G loss: 0.000008, cell accuracy: 100.0%, board accuracy: 94.8%
#
# test error:
#  G loss: 0.000051, cell accuracy: 99.7%, board accuracy: 71.8%
#
# Epoch 62
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0003
# [732/2000] G loss: 0.0002
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0002
# train error:
#  G loss: 0.000007, cell accuracy: 100.0%, board accuracy: 95.3%
#
# test error:
#  G loss: 0.000051, cell accuracy: 99.7%, board accuracy: 71.2%
#
# Epoch 63
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0003
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000007, cell accuracy: 100.0%, board accuracy: 95.7%
#
# test error:
#  G loss: 0.000049, cell accuracy: 99.7%, board accuracy: 72.4%
#
# Epoch 64
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0004
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000006, cell accuracy: 100.0%, board accuracy: 96.4%
#
# test error:
#  G loss: 0.000049, cell accuracy: 99.7%, board accuracy: 70.6%
#
# Epoch 65
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0002
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0003
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000006, cell accuracy: 100.0%, board accuracy: 96.2%
#
# test error:
#  G loss: 0.000048, cell accuracy: 99.7%, board accuracy: 72.2%
#
# Epoch 66
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000006, cell accuracy: 100.0%, board accuracy: 96.2%
#
# test error:
#  G loss: 0.000049, cell accuracy: 99.7%, board accuracy: 71.8%
#
# Epoch 67
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000006, cell accuracy: 100.0%, board accuracy: 96.0%
#
# test error:
#  G loss: 0.000051, cell accuracy: 99.7%, board accuracy: 70.2%
#
# Epoch 68
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0002
# [1812/2000] G loss: 0.0002
# train error:
#  G loss: 0.000006, cell accuracy: 100.0%, board accuracy: 96.2%
#
# test error:
#  G loss: 0.000047, cell accuracy: 99.7%, board accuracy: 71.8%
#
# Epoch 69
# -------------------------------
# [12/2000] G loss: 0.0002
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0002
# [1812/2000] G loss: 0.0002
# train error:
#  G loss: 0.000007, cell accuracy: 100.0%, board accuracy: 95.3%
#
# test error:
#  G loss: 0.000048, cell accuracy: 99.7%, board accuracy: 71.2%
#
# Epoch 70
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0005
# [1452/2000] G loss: 0.0002
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000005, cell accuracy: 100.0%, board accuracy: 97.0%
#
# test error:
#  G loss: 0.000048, cell accuracy: 99.7%, board accuracy: 72.8%
#
# Epoch 71
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0002
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000005, cell accuracy: 100.0%, board accuracy: 97.0%
#
# test error:
#  G loss: 0.000048, cell accuracy: 99.7%, board accuracy: 72.0%
#
# Epoch 72
# -------------------------------
# [12/2000] G loss: 0.0003
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0003
# train error:
#  G loss: 0.000005, cell accuracy: 100.0%, board accuracy: 96.9%
#
# test error:
#  G loss: 0.000046, cell accuracy: 99.7%, board accuracy: 73.0%
#
# Epoch 73
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 96.8%
#
# test error:
#  G loss: 0.000046, cell accuracy: 99.7%, board accuracy: 72.2%
#
# Epoch 74
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0003
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 97.0%
#
# test error:
#  G loss: 0.000045, cell accuracy: 99.7%, board accuracy: 72.8%
#
# Epoch 75
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 97.6%
#
# test error:
#  G loss: 0.000044, cell accuracy: 99.7%, board accuracy: 74.2%
#
# Epoch 76
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0002
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 97.5%
#
# test error:
#  G loss: 0.000044, cell accuracy: 99.7%, board accuracy: 74.2%
#
# Epoch 77
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 97.5%
#
# test error:
#  G loss: 0.000045, cell accuracy: 99.7%, board accuracy: 73.4%
#
# Epoch 78
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0002
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 97.4%
#
# test error:
#  G loss: 0.000046, cell accuracy: 99.7%, board accuracy: 73.8%
#
# Epoch 79
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 98.2%
#
# test error:
#  G loss: 0.000045, cell accuracy: 99.7%, board accuracy: 72.6%
#
# Epoch 80
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 98.2%
#
# test error:
#  G loss: 0.000043, cell accuracy: 99.8%, board accuracy: 74.6%
#
# Epoch 81
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 97.4%
#
# test error:
#  G loss: 0.000045, cell accuracy: 99.7%, board accuracy: 73.2%
#
# Epoch 82
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 98.1%
#
# test error:
#  G loss: 0.000044, cell accuracy: 99.7%, board accuracy: 74.0%
#
# Epoch 83
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 98.3%
#
# test error:
#  G loss: 0.000041, cell accuracy: 99.8%, board accuracy: 74.6%
#
# Epoch 84
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 98.1%
#
# test error:
#  G loss: 0.000043, cell accuracy: 99.7%, board accuracy: 74.6%
#
# Epoch 85
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.6%
#
# test error:
#  G loss: 0.000042, cell accuracy: 99.8%, board accuracy: 76.0%
#
# Epoch 86
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.5%
#
# test error:
#  G loss: 0.000041, cell accuracy: 99.8%, board accuracy: 76.0%
#
# Epoch 87
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.3%
#
# test error:
#  G loss: 0.000042, cell accuracy: 99.8%, board accuracy: 76.0%
#
# Epoch 88
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 97.8%
#
# test error:
#  G loss: 0.000043, cell accuracy: 99.8%, board accuracy: 74.8%
#
# Epoch 89
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 97.5%
#
# test error:
#  G loss: 0.000047, cell accuracy: 99.7%, board accuracy: 71.2%
#
# Epoch 90
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0002
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 97.5%
#
# test error:
#  G loss: 0.000045, cell accuracy: 99.7%, board accuracy: 72.0%
#
# Epoch 91
# -------------------------------
# [12/2000] G loss: 0.0002
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000005, cell accuracy: 100.0%, board accuracy: 96.1%
#
# test error:
#  G loss: 0.000047, cell accuracy: 99.7%, board accuracy: 72.0%
#
# Epoch 92
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0002
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 98.3%
#
# test error:
#  G loss: 0.000042, cell accuracy: 99.8%, board accuracy: 75.0%
#
# Epoch 93
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.5%
#
# test error:
#  G loss: 0.000041, cell accuracy: 99.8%, board accuracy: 75.8%
#
# Epoch 94
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 98.0%
#
# test error:
#  G loss: 0.000044, cell accuracy: 99.7%, board accuracy: 72.6%
#
# Epoch 95
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.3%
#
# test error:
#  G loss: 0.000042, cell accuracy: 99.8%, board accuracy: 74.4%
#
# Epoch 96
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.7%
#
# test error:
#  G loss: 0.000039, cell accuracy: 99.8%, board accuracy: 75.4%
#
# Epoch 97
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.7%
#
# test error:
#  G loss: 0.000040, cell accuracy: 99.8%, board accuracy: 76.0%
#
# Epoch 98
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.2%
#
# test error:
#  G loss: 0.000041, cell accuracy: 99.8%, board accuracy: 75.2%
#
# Epoch 99
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.6%
#
# test error:
#  G loss: 0.000042, cell accuracy: 99.8%, board accuracy: 76.0%
#
# Epoch 100
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000010, cell accuracy: 99.9%, board accuracy: 94.7%
#
# test error:
#  G loss: 0.000055, cell accuracy: 99.7%, board accuracy: 71.2%
#
# Epoch 101
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 96.8%
#
# test error:
#  G loss: 0.000050, cell accuracy: 99.7%, board accuracy: 69.4%
#
# Epoch 102
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.4%
#
# test error:
#  G loss: 0.000044, cell accuracy: 99.7%, board accuracy: 72.2%
#
# Epoch 103
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.2%
#
# test error:
#  G loss: 0.000042, cell accuracy: 99.8%, board accuracy: 74.0%
#
# Epoch 104
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0003
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.4%
#
# test error:
#  G loss: 0.000042, cell accuracy: 99.7%, board accuracy: 73.8%
#
# Epoch 105
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.8%
#
# test error:
#  G loss: 0.000041, cell accuracy: 99.8%, board accuracy: 74.8%
#
# Epoch 106
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.8%
#
# test error:
#  G loss: 0.000040, cell accuracy: 99.8%, board accuracy: 76.0%
#
# Epoch 107
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 98.9%
#
# test error:
#  G loss: 0.000039, cell accuracy: 99.8%, board accuracy: 76.4%
#
# Epoch 108
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 98.9%
#
# test error:
#  G loss: 0.000038, cell accuracy: 99.8%, board accuracy: 77.6%
#
# Epoch 109
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 99.0%
#
# test error:
#  G loss: 0.000038, cell accuracy: 99.8%, board accuracy: 77.0%
#
# Epoch 110
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 99.0%
#
# test error:
#  G loss: 0.000039, cell accuracy: 99.8%, board accuracy: 76.4%
#
# Epoch 111
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 96.9%
#
# test error:
#  G loss: 0.000045, cell accuracy: 99.7%, board accuracy: 71.4%
#
# Epoch 112
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0003
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 97.8%
#
# test error:
#  G loss: 0.000043, cell accuracy: 99.7%, board accuracy: 73.4%
#
# Epoch 113
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0002
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.0%
#
# test error:
#  G loss: 0.000042, cell accuracy: 99.8%, board accuracy: 73.4%
#
# Epoch 114
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.9%
#
# test error:
#  G loss: 0.000040, cell accuracy: 99.8%, board accuracy: 75.8%
#
# Epoch 115
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 98.9%
#
# test error:
#  G loss: 0.000041, cell accuracy: 99.8%, board accuracy: 75.4%
#
# Epoch 116
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.5%
#
# test error:
#  G loss: 0.000042, cell accuracy: 99.8%, board accuracy: 76.4%
#
# Epoch 117
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 98.8%
#
# test error:
#  G loss: 0.000039, cell accuracy: 99.8%, board accuracy: 76.2%
#
# Epoch 118
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 98.8%
#
# test error:
#  G loss: 0.000039, cell accuracy: 99.8%, board accuracy: 76.2%
#
# Epoch 119
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 98.0%
#
# test error:
#  G loss: 0.000045, cell accuracy: 99.7%, board accuracy: 73.0%
#
# Epoch 120
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0003
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.1%
#
# test error:
#  G loss: 0.000045, cell accuracy: 99.7%, board accuracy: 72.0%
#
# Epoch 121
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0002
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 97.5%
#
# test error:
#  G loss: 0.000045, cell accuracy: 99.7%, board accuracy: 73.0%
#
# Epoch 122
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0001
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000003, cell accuracy: 100.0%, board accuracy: 97.8%
#
# test error:
#  G loss: 0.000044, cell accuracy: 99.8%, board accuracy: 74.6%
#
# Epoch 123
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0002
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.7%
#
# test error:
#  G loss: 0.000043, cell accuracy: 99.7%, board accuracy: 73.6%
#
# Epoch 124
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.8%
#
# test error:
#  G loss: 0.000041, cell accuracy: 99.8%, board accuracy: 74.8%
#
# Epoch 125
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 99.1%
#
# test error:
#  G loss: 0.000039, cell accuracy: 99.8%, board accuracy: 74.4%
#
# Epoch 126
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 98.9%
#
# test error:
#  G loss: 0.000038, cell accuracy: 99.8%, board accuracy: 76.6%
#
# Epoch 127
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.7%
#
# test error:
#  G loss: 0.000040, cell accuracy: 99.8%, board accuracy: 75.2%
#
# Epoch 128
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 99.0%
#
# test error:
#  G loss: 0.000039, cell accuracy: 99.8%, board accuracy: 76.6%
#
# Epoch 129
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 98.8%
#
# test error:
#  G loss: 0.000039, cell accuracy: 99.8%, board accuracy: 75.8%
#
# Epoch 130
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 99.1%
#
# test error:
#  G loss: 0.000038, cell accuracy: 99.8%, board accuracy: 77.0%
#
# Epoch 131
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0002
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 99.0%
#
# test error:
#  G loss: 0.000038, cell accuracy: 99.8%, board accuracy: 77.4%
#
# Epoch 132
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000005, cell accuracy: 100.0%, board accuracy: 95.0%
#
# test error:
#  G loss: 0.000045, cell accuracy: 99.7%, board accuracy: 71.0%
#
# Epoch 133
# -------------------------------
# [12/2000] G loss: 0.0002
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0001
# [1092/2000] G loss: 0.0002
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 96.9%
#
# test error:
#  G loss: 0.000048, cell accuracy: 99.7%, board accuracy: 69.4%
#
# Epoch 134
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
# ...
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.4%
#
# Epoch 956
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.8%
#
# Epoch 957
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.6%
#
# Epoch 958
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 82.0%
#
# Epoch 959
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.6%
#
# Epoch 960
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.6%
#
# Epoch 961
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 82.2%
#
# Epoch 962
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.8%
#
# Epoch 963
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.8%
#
# Epoch 964
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.8%
#
# Epoch 965
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 82.0%
#
# Epoch 966
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.8%
#
# Epoch 967
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.6%
#
# Epoch 968
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.2%
#
# Epoch 969
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 81.4%
#
# Epoch 970
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000031, cell accuracy: 99.8%, board accuracy: 82.6%
#
# Epoch 971
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 96.0%
#
# test error:
#  G loss: 0.000043, cell accuracy: 99.8%, board accuracy: 73.2%
#
# Epoch 972
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0004
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0004
# [1452/2000] G loss: 0.0001
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.0%
#
# test error:
#  G loss: 0.000039, cell accuracy: 99.8%, board accuracy: 76.0%
#
# Epoch 973
# -------------------------------
# [12/2000] G loss: 0.0001
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 99.5%
#
# test error:
#  G loss: 0.000036, cell accuracy: 99.8%, board accuracy: 79.0%
#
# Epoch 974
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000034, cell accuracy: 99.8%, board accuracy: 78.0%
#
# Epoch 975
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 99.3%
#
# test error:
#  G loss: 0.000035, cell accuracy: 99.8%, board accuracy: 79.0%
#
# Epoch 976
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000033, cell accuracy: 99.8%, board accuracy: 80.6%
#
# Epoch 977
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000033, cell accuracy: 99.8%, board accuracy: 80.2%
#
# Epoch 978
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.8%
#
# test error:
#  G loss: 0.000034, cell accuracy: 99.8%, board accuracy: 79.8%
#
# Epoch 979
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.8%
#
# test error:
#  G loss: 0.000034, cell accuracy: 99.8%, board accuracy: 79.6%
#
# Epoch 980
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.8%
#
# test error:
#  G loss: 0.000033, cell accuracy: 99.8%, board accuracy: 80.4%
#
# Epoch 981
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0001
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000033, cell accuracy: 99.8%, board accuracy: 80.2%
#
# Epoch 982
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000033, cell accuracy: 99.8%, board accuracy: 80.0%
#
# Epoch 983
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000033, cell accuracy: 99.8%, board accuracy: 80.0%
#
# Epoch 984
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 81.4%
#
# Epoch 985
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 81.4%
#
# Epoch 986
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.8%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 81.6%
#
# Epoch 987
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 81.6%
#
# Epoch 988
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 81.6%
#
# Epoch 989
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 81.6%
#
# Epoch 990
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 81.2%
#
# Epoch 991
# -------------------------------
# [12/2000] G loss: 0.0002
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 81.2%
#
# Epoch 992
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 81.8%
#
# Epoch 993
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000002, cell accuracy: 100.0%, board accuracy: 98.2%
#
# test error:
#  G loss: 0.000036, cell accuracy: 99.8%, board accuracy: 78.2%
#
# Epoch 994
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0001
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0002
# train error:
#  G loss: 0.000004, cell accuracy: 100.0%, board accuracy: 97.8%
#
# test error:
#  G loss: 0.000041, cell accuracy: 99.8%, board accuracy: 75.4%
#
# Epoch 995
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 99.0%
#
# test error:
#  G loss: 0.000035, cell accuracy: 99.8%, board accuracy: 79.2%
#
# Epoch 996
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000001, cell accuracy: 100.0%, board accuracy: 99.3%
#
# test error:
#  G loss: 0.000034, cell accuracy: 99.8%, board accuracy: 78.8%
#
# Epoch 997
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 79.6%
#
# Epoch 998
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 80.2%
#
# Epoch 999
# -------------------------------
# [12/2000] G loss: 0.0000
# [372/2000] G loss: 0.0000
# [732/2000] G loss: 0.0000
# [1092/2000] G loss: 0.0000
# [1452/2000] G loss: 0.0000
# [1812/2000] G loss: 0.0000
# train error:
#  G loss: 0.000000, cell accuracy: 100.0%, board accuracy: 99.9%
#
# test error:
#  G loss: 0.000032, cell accuracy: 99.8%, board accuracy: 81.0%
#
# Done!

# %% [markdown]
# Having run a number of training sessions, I found the following:
# * MSE loss is better than BCE for the autoencoder. BCE loss becomes very unstable when the loss gets too low and shoots back up, close to the original value. The normal advice is to use a `LogSigmoid` layer and `BCEFromLogitsLoss`, but we won't be able to do that when the encoder is part of a the full GameGAN generator.
# * A shallower convolutional network with kernel size 3 is better than a deeper one with kernel size 2. The latter took many more epochs to learn, and still did not quite reach the same board accuracy.
# * Increasing the channels in the hidden convolutional layers from 32 to 64 helped a lot.
# * Keeping batch norm in is better than removing it. Without batch norm, the model learns a lot more slowly.
# * Changing the "leak" (Leaky ReLU negative slope) from 0.2 to 0.1 makes the model learn more slowly.
# * Reducing the stride in the x-direction to make the intermediate boards more square and increase the number of spatial features at the `Flatten` layer increases the number of model parameters from 380K to over 1M, but doesn't improve performance, even after trying out variations of this.
# * Learning rate 1e-5 has no significant advantage over 1e-4. With 1e-5, the loss and accuracy curves are smoother, but the final values attained are not quite as good.
# * Changing the batch size from 4 to 12 sped up the training (with in-memory data) from 50 mins to 20 mins, improved training board accuracy, and test board accuracy stayed comparable.
#
# The final board accuracy of the last model was 99.85% on the training set and 81.00% on the test set.

# %% [markdown]
# # Conclusion
#
# I've found an autoencoder architecture that works quite well with about 380K parameters. The model overfits significantly, so to get the best performance, we need more data.
