# %% [markdown]
# # Train generator with reconstruction loss
#
# In this notebook, we train the generator without a discriminator. We just take the MSE loss between the predicted next frame and actual next frame.

# %%
import os
from pathlib import Path
import shutil
import datetime

import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.utils.data import Dataset
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt


import models
import metrics
from recording import FileBasedDatabase
from engines import EVENT_NAMES

# %%
NUM_CELL_TYPES = 8
NUM_EVENT_TYPES = 5

class RecordingDataset(Dataset):
    def __init__(self, path: str):
        self._db = FileBasedDatabase(path)

    def __len__(self):
        return len(self._db)

    def __getitem__(self, idx):
        boards, events = self._db[idx]
        b = self._transform_board(boards[-2]) # Ignore all boards except the last two
        e = self._transform_event(events[-1])
        x = (b, e)
        y = self._transform_board(boards[-1])
        return x, y
    
    def _transform_board(self, board):
        board = torch.tensor(board, dtype=torch.long)
        board = F.one_hot(board, NUM_CELL_TYPES) # One-hot encode the cell types
        board = board.type(torch.float) # Convert to floating-point
        board = board.permute((2, 0, 1)) # Move channels/classes to dimension 0
        return board
    
    def _transform_event(self, event):
        event = torch.tensor(event, dtype=torch.long)
        event = F.one_hot(event, NUM_EVENT_TYPES) # One-hot encode the event
        event = event.type(torch.float) # Convert to floating-point
        return event

# %%
# Put datasets in memory for faster training
train_dataset = list(RecordingDataset(os.path.join("data", "more_independent", "train")))
test_dataset = list(RecordingDataset(os.path.join("data", "more_independent", "test")))
batch_size = 12
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

(b, e), y = next(iter(train_dataloader))
print(f"x: shape {b.shape}, dtype {b.dtype}")
print(f"e: shape {e.shape}, dtype {e.dtype}")
print(f"y: shape {y.shape}, dtype {y.dtype}")
# Out:
# x: shape torch.Size([12, 8, 22, 10]), dtype torch.float32
# e: shape torch.Size([12, 5]), dtype torch.float32
# y: shape torch.Size([12, 8, 22, 10]), dtype torch.float32

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Using device {device}")
# Out:
# Using device cuda

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def compute_metric_by_event(metric_cls, dataloader):
    metrics = [metric_cls() for _ in range(NUM_EVENT_TYPES)]

    with torch.no_grad():        
        for ((b, e), y) in dataloader:
            b = b.to(device)
            e = e.to(device)
            y = y.to(device)

            batch_size = b.size(0)

            y_fake = gen(b, e)
            
            classes_b = torch.argmax(b, dim=1)
            classes_e = torch.argmax(e, dim=1)
            classes_y = torch.argmax(y, dim=1)
            classes_y_fake = torch.argmax(y_fake, dim=1)

            for idx in range(batch_size):
                class_e = classes_e[idx]
                metric = metrics[class_e]
                metric.update_state(classes_x=classes_b[idx:idx+1], classes_y_pred=classes_y_fake[idx:idx+1], classes_y=classes_y[idx:idx+1])

    return [metric.result() for metric in metrics]

# %%
import itertools

from engines import EventTypes
from tetris import CELL_COLORS

def render_board(board):
    height, width = board.shape
    img = np.zeros((3, height, width))
    for row in range(height):
        for col in range(width):
            img[:, row, col] = CELL_COLORS[board[row, col]]
    img /= 255.0
    return img

real_label = 1.0
fake_label = 0.0

def train_loop(dataloader, gen, loss_fn, optimizer_gen):
    gen.train()

    size = len(dataloader.dataset)
    for batch, ((b, e), y) in enumerate(dataloader):
        batch_size = b.size(0)

        b = b.to(device)
        e = e.to(device)
        y = y.to(device)

        gen.zero_grad()

        y_fake = gen(b, e)
        err_dyn = loss_fn(y_fake, y)
        err_dyn.backward()

        optimizer_gen.step()


def test_loop(split_name, dataloader, gen, loss_fn, tb_writer, epoch):
    gen.eval()

    loss_gen = 0.0
    cell_accuracy = metrics.CellAccuracy()
    board_accuracy = metrics.BoardAccuracy()
    spawn_recall = metrics.SpawnRecall()

    num_batches = len(dataloader)
    with torch.no_grad():        
        for batch, ((b, e), y) in enumerate(dataloader):
            batch_size = b.size(0)

            b = b.to(device)
            e = e.to(device)
            y = y.to(device)

            y_fake = gen(b, e)
        
            loss_gen += loss_fn(y_fake, y).item()

            classes_b = torch.argmax(b, dim=1)
            classes_e = torch.argmax(e, dim=1)
            classes_y = torch.argmax(y, dim=1)
            classes_y_fake = torch.argmax(y_fake, dim=1)
            cell_accuracy.update_state(classes_y_fake, classes_y)
            board_accuracy.update_state(classes_y_fake, classes_y)

            spawn_recall.update_state(classes_b, classes_y_fake, classes_y)

    loss_gen /= num_batches

    print(f"{split_name} error: \n G loss: {loss_gen:>8f}, cell accuracy: {(cell_accuracy.result()):>0.1%}, board accuracy: {(board_accuracy.result()):>0.1%} \n")

    tb_writer.add_scalar(f"Loss/{split_name}", loss_gen, epoch)
    tb_writer.add_scalar(f"Cell accuracy/{split_name}", cell_accuracy.result(), epoch)
    tb_writer.add_scalar(f"Board accuracy/{split_name}", board_accuracy.result(), epoch)
    tb_writer.add_scalar(f"Spawn recall/{split_name}", spawn_recall.result(), epoch)
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.10.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def train(run_name, gen_factory, epochs):

    learning_rate = 1e-4

    gen = gen_factory()

    loss_fn = nn.MSELoss()
    optimizer_gen = torch.optim.Adam(gen.parameters(), lr=learning_rate)

    log_dir = os.path.join("runs", "gen_with_rec_loss")
    log_subdir = os.path.join(log_dir, run_name + "_" + datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S"))
    tb_writer = SummaryWriter(log_subdir)

    try:
        for epoch in range(epochs):
            print(f"Epoch {epoch}\n-------------------------------")
            train_loop(train_dataloader, gen, loss_fn, optimizer_gen)
            test_loop("train", train_dataloader, gen, loss_fn, tb_writer, epoch)
            test_loop("test", test_dataloader, gen, loss_fn, tb_writer, epoch)
            gen_zero_grads = 0
            for name, weight in gen.named_parameters():
                tb_writer.add_histogram(f"Weights/{name}", weight, epoch)
                if weight.grad is not None:
                    tb_writer.add_histogram(f"Gradients/{name}", weight.grad, epoch)
                    gen_zero_grads += weight.grad.numel() - weight.grad.count_nonzero().item()
            tb_writer.add_scalar(f"Zero gradients", gen_zero_grads, epoch)
    finally:
        tb_writer.close()
        
    print("Done!")
    return gen

# %%
NUM_RANDOM_INPUTS = 4


from models import Conv2dLeakyReLU, ConvTranspose2dLeakyReLU, LinearLeakyReLU


class GameganGenerator(nn.Module):
    def __init__(self, leak=0.0):
        super().__init__()

        self.leak = leak

        self.board_encoder = models.GameganBoardEncoder()

        self.event_embedding = LinearLeakyReLU(NUM_EVENT_TYPES, 256, negative_slope=leak)
        self.random_embedding = LinearLeakyReLU(NUM_RANDOM_INPUTS, 256, negative_slope=leak)

        self.random_event_encoder = nn.Sequential(
            LinearLeakyReLU(512, 256, negative_slope=leak),
            nn.Linear(256, 256)
        )

        self.dynamics = nn.Sequential(
            LinearLeakyReLU(512, 256, negative_slope=leak),
            LinearLeakyReLU(256, 256, negative_slope=leak),
        )

        self.renderer = models.GameganRenderer()

    def forward(self, b, e):
        batch_size, cell_channels, height, width = b.shape

        # Encode board state
        s = self.board_encoder(b)

        # Embed events
        e = self.event_embedding(e)

        # Generate and embed random inputs
        z = torch.rand(batch_size, NUM_RANDOM_INPUTS, device=device)
        z = self.random_embedding(z)

        # Encode events and random inputs
        v = self.random_event_encoder(torch.cat((e, z), dim=1))

        # Apply game dynamics
        h = torch.cat((s, v), dim=1)
        h = self.dynamics(h)

        # Render new board
        y = self.renderer(h)
        return y


print(f"Parameters: {count_parameters(GameganGenerator())}")
# Out:
# Parameters: 779336

# %%
gen = train(
    run_name="more_indep_data",
    gen_factory=lambda: GameganGenerator(leak=0.2).to(device),
    epochs=1500
)
# Out:
# Epoch 0
# -------------------------------
# train error:
#  G loss: 0.037781, cell accuracy: 75.8%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.037943, cell accuracy: 75.7%, board accuracy: 0.0%
#
# Epoch 1
# -------------------------------
# train error:
#  G loss: 0.030361, cell accuracy: 81.6%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.030594, cell accuracy: 81.4%, board accuracy: 0.0%
#
# Epoch 2
# -------------------------------
# train error:
#  G loss: 0.025210, cell accuracy: 85.4%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.025535, cell accuracy: 85.2%, board accuracy: 0.0%
#
# Epoch 3
# -------------------------------
# train error:
#  G loss: 0.021622, cell accuracy: 87.8%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.022029, cell accuracy: 87.5%, board accuracy: 0.0%
#
# Epoch 4
# -------------------------------
# train error:
#  G loss: 0.019417, cell accuracy: 89.2%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.019917, cell accuracy: 88.9%, board accuracy: 0.0%
#
# Epoch 5
# -------------------------------
# train error:
#  G loss: 0.017666, cell accuracy: 90.4%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.018226, cell accuracy: 90.0%, board accuracy: 0.0%
#
# Epoch 6
# -------------------------------
# train error:
#  G loss: 0.016157, cell accuracy: 91.2%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.016864, cell accuracy: 90.8%, board accuracy: 0.0%
#
# Epoch 7
# -------------------------------
# train error:
#  G loss: 0.015180, cell accuracy: 91.8%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.015941, cell accuracy: 91.4%, board accuracy: 0.0%
#
# Epoch 8
# -------------------------------
# train error:
#  G loss: 0.014351, cell accuracy: 92.3%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.015148, cell accuracy: 91.9%, board accuracy: 0.0%
#
# Epoch 9
# -------------------------------
# train error:
#  G loss: 0.013544, cell accuracy: 92.8%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.014430, cell accuracy: 92.3%, board accuracy: 0.0%
#
# Epoch 10
# -------------------------------
# train error:
#  G loss: 0.012780, cell accuracy: 93.2%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.013740, cell accuracy: 92.7%, board accuracy: 0.0%
#
# Epoch 11
# -------------------------------
# train error:
#  G loss: 0.012293, cell accuracy: 93.5%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.013326, cell accuracy: 92.9%, board accuracy: 0.0%
#
# Epoch 12
# -------------------------------
# train error:
#  G loss: 0.011835, cell accuracy: 93.8%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.012898, cell accuracy: 93.2%, board accuracy: 0.0%
#
# Epoch 13
# -------------------------------
# train error:
#  G loss: 0.011366, cell accuracy: 94.0%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.012476, cell accuracy: 93.4%, board accuracy: 0.0%
#
# Epoch 14
# -------------------------------
# train error:
#  G loss: 0.010937, cell accuracy: 94.3%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.012098, cell accuracy: 93.6%, board accuracy: 0.0%
#
# Epoch 15
# -------------------------------
# train error:
#  G loss: 0.010550, cell accuracy: 94.5%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.011780, cell accuracy: 93.8%, board accuracy: 0.0%
#
# Epoch 16
# -------------------------------
# train error:
#  G loss: 0.010258, cell accuracy: 94.7%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.011494, cell accuracy: 94.0%, board accuracy: 0.1%
#
# Epoch 17
# -------------------------------
# train error:
#  G loss: 0.010036, cell accuracy: 94.8%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.011351, cell accuracy: 94.1%, board accuracy: 0.1%
#
# Epoch 18
# -------------------------------
# train error:
#  G loss: 0.009680, cell accuracy: 95.0%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.010992, cell accuracy: 94.3%, board accuracy: 0.1%
#
# Epoch 19
# -------------------------------
# train error:
#  G loss: 0.009531, cell accuracy: 95.1%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.010887, cell accuracy: 94.3%, board accuracy: 0.1%
#
# Epoch 20
# -------------------------------
# train error:
#  G loss: 0.009298, cell accuracy: 95.2%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.010732, cell accuracy: 94.4%, board accuracy: 0.1%
#
# Epoch 21
# -------------------------------
# train error:
#  G loss: 0.008925, cell accuracy: 95.4%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.010376, cell accuracy: 94.6%, board accuracy: 0.1%
#
# Epoch 22
# -------------------------------
# train error:
#  G loss: 0.008811, cell accuracy: 95.5%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.010271, cell accuracy: 94.7%, board accuracy: 0.1%
#
# Epoch 23
# -------------------------------
# train error:
#  G loss: 0.008578, cell accuracy: 95.6%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.010093, cell accuracy: 94.8%, board accuracy: 0.1%
#
# Epoch 24
# -------------------------------
# train error:
#  G loss: 0.008349, cell accuracy: 95.7%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.009881, cell accuracy: 94.9%, board accuracy: 0.1%
#
# Epoch 25
# -------------------------------
# train error:
#  G loss: 0.008179, cell accuracy: 95.8%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.009738, cell accuracy: 95.0%, board accuracy: 0.1%
#
# Epoch 26
# -------------------------------
# train error:
#  G loss: 0.008018, cell accuracy: 95.9%, board accuracy: 0.3%
#
# test error:
#  G loss: 0.009617, cell accuracy: 95.0%, board accuracy: 0.2%
#
# Epoch 27
# -------------------------------
# train error:
#  G loss: 0.007859, cell accuracy: 96.0%, board accuracy: 0.3%
#
# test error:
#  G loss: 0.009476, cell accuracy: 95.1%, board accuracy: 0.2%
#
# Epoch 28
# -------------------------------
# train error:
#  G loss: 0.007730, cell accuracy: 96.0%, board accuracy: 0.3%
#
# test error:
#  G loss: 0.009402, cell accuracy: 95.1%, board accuracy: 0.2%
#
# Epoch 29
# -------------------------------
# train error:
#  G loss: 0.007544, cell accuracy: 96.2%, board accuracy: 0.3%
#
# test error:
#  G loss: 0.009212, cell accuracy: 95.3%, board accuracy: 0.1%
#
# Epoch 30
# -------------------------------
# train error:
#  G loss: 0.007551, cell accuracy: 96.2%, board accuracy: 0.3%
#
# test error:
#  G loss: 0.009242, cell accuracy: 95.2%, board accuracy: 0.1%
#
# Epoch 31
# -------------------------------
# train error:
#  G loss: 0.007369, cell accuracy: 96.3%, board accuracy: 0.4%
#
# test error:
#  G loss: 0.009112, cell accuracy: 95.3%, board accuracy: 0.2%
#
# Epoch 32
# -------------------------------
# train error:
#  G loss: 0.007168, cell accuracy: 96.4%, board accuracy: 0.5%
#
# test error:
#  G loss: 0.008934, cell accuracy: 95.4%, board accuracy: 0.2%
#
# Epoch 33
# -------------------------------
# train error:
#  G loss: 0.007105, cell accuracy: 96.4%, board accuracy: 0.4%
#
# test error:
#  G loss: 0.008899, cell accuracy: 95.4%, board accuracy: 0.2%
#
# Epoch 34
# -------------------------------
# train error:
#  G loss: 0.007064, cell accuracy: 96.4%, board accuracy: 0.5%
#
# test error:
#  G loss: 0.008853, cell accuracy: 95.5%, board accuracy: 0.3%
#
# Epoch 35
# -------------------------------
# train error:
#  G loss: 0.006852, cell accuracy: 96.5%, board accuracy: 0.6%
#
# test error:
#  G loss: 0.008699, cell accuracy: 95.5%, board accuracy: 0.2%
#
# Epoch 36
# -------------------------------
# train error:
#  G loss: 0.006788, cell accuracy: 96.6%, board accuracy: 0.7%
#
# test error:
#  G loss: 0.008618, cell accuracy: 95.6%, board accuracy: 0.2%
#
# Epoch 37
# -------------------------------
# train error:
#  G loss: 0.006641, cell accuracy: 96.6%, board accuracy: 0.7%
#
# test error:
#  G loss: 0.008537, cell accuracy: 95.6%, board accuracy: 0.4%
#
# Epoch 38
# -------------------------------
# train error:
#  G loss: 0.006584, cell accuracy: 96.7%, board accuracy: 0.8%
#
# test error:
#  G loss: 0.008454, cell accuracy: 95.7%, board accuracy: 0.4%
#
# Epoch 39
# -------------------------------
# train error:
#  G loss: 0.006474, cell accuracy: 96.7%, board accuracy: 0.7%
#
# test error:
#  G loss: 0.008388, cell accuracy: 95.7%, board accuracy: 0.4%
#
# Epoch 40
# -------------------------------
# train error:
#  G loss: 0.006431, cell accuracy: 96.8%, board accuracy: 1.0%
#
# test error:
#  G loss: 0.008350, cell accuracy: 95.7%, board accuracy: 0.4%
#
# Epoch 41
# -------------------------------
# train error:
#  G loss: 0.006350, cell accuracy: 96.8%, board accuracy: 0.9%
#
# test error:
#  G loss: 0.008315, cell accuracy: 95.7%, board accuracy: 0.5%
#
# Epoch 42
# -------------------------------
# train error:
#  G loss: 0.006305, cell accuracy: 96.8%, board accuracy: 0.9%
#
# test error:
#  G loss: 0.008233, cell accuracy: 95.8%, board accuracy: 0.4%
#
# Epoch 43
# -------------------------------
# train error:
#  G loss: 0.006137, cell accuracy: 96.9%, board accuracy: 1.1%
#
# test error:
#  G loss: 0.008090, cell accuracy: 95.9%, board accuracy: 0.4%
#
# Epoch 44
# -------------------------------
# train error:
#  G loss: 0.006085, cell accuracy: 96.9%, board accuracy: 1.0%
#
# test error:
#  G loss: 0.008056, cell accuracy: 95.9%, board accuracy: 0.4%
#
# Epoch 45
# -------------------------------
# train error:
#  G loss: 0.006120, cell accuracy: 96.9%, board accuracy: 1.0%
#
# test error:
#  G loss: 0.008112, cell accuracy: 95.9%, board accuracy: 0.3%
#
# Epoch 46
# -------------------------------
# train error:
#  G loss: 0.006023, cell accuracy: 97.0%, board accuracy: 1.2%
#
# test error:
#  G loss: 0.008029, cell accuracy: 95.9%, board accuracy: 0.4%
#
# Epoch 47
# -------------------------------
# train error:
#  G loss: 0.005848, cell accuracy: 97.1%, board accuracy: 1.5%
#
# test error:
#  G loss: 0.007881, cell accuracy: 96.0%, board accuracy: 0.5%
#
# Epoch 48
# -------------------------------
# train error:
#  G loss: 0.005904, cell accuracy: 97.0%, board accuracy: 1.4%
#
# test error:
#  G loss: 0.007950, cell accuracy: 95.9%, board accuracy: 0.6%
#
# Epoch 49
# -------------------------------
# train error:
#  G loss: 0.005699, cell accuracy: 97.1%, board accuracy: 1.7%
#
# test error:
#  G loss: 0.007771, cell accuracy: 96.0%, board accuracy: 0.7%
#
# Epoch 50
# -------------------------------
# train error:
#  G loss: 0.005704, cell accuracy: 97.1%, board accuracy: 1.5%
#
# test error:
#  G loss: 0.007787, cell accuracy: 96.0%, board accuracy: 0.5%
#
# Epoch 51
# -------------------------------
# train error:
#  G loss: 0.005585, cell accuracy: 97.2%, board accuracy: 1.7%
#
# test error:
#  G loss: 0.007688, cell accuracy: 96.1%, board accuracy: 0.6%
#
# Epoch 52
# -------------------------------
# train error:
#  G loss: 0.005551, cell accuracy: 97.2%, board accuracy: 1.8%
#
# test error:
#  G loss: 0.007697, cell accuracy: 96.1%, board accuracy: 0.5%
#
# Epoch 53
# -------------------------------
# train error:
#  G loss: 0.005455, cell accuracy: 97.3%, board accuracy: 1.9%
#
# test error:
#  G loss: 0.007609, cell accuracy: 96.1%, board accuracy: 0.7%
#
# Epoch 54
# -------------------------------
# train error:
#  G loss: 0.005412, cell accuracy: 97.3%, board accuracy: 2.1%
#
# test error:
#  G loss: 0.007557, cell accuracy: 96.2%, board accuracy: 0.8%
#
# Epoch 55
# -------------------------------
# train error:
#  G loss: 0.005296, cell accuracy: 97.4%, board accuracy: 2.1%
#
# test error:
#  G loss: 0.007477, cell accuracy: 96.2%, board accuracy: 0.8%
#
# Epoch 56
# -------------------------------
# train error:
#  G loss: 0.005278, cell accuracy: 97.4%, board accuracy: 2.2%
#
# test error:
#  G loss: 0.007500, cell accuracy: 96.2%, board accuracy: 0.9%
#
# Epoch 57
# -------------------------------
# train error:
#  G loss: 0.005393, cell accuracy: 97.3%, board accuracy: 2.1%
#
# test error:
#  G loss: 0.007633, cell accuracy: 96.1%, board accuracy: 0.8%
#
# Epoch 58
# -------------------------------
# train error:
#  G loss: 0.005236, cell accuracy: 97.4%, board accuracy: 2.3%
#
# test error:
#  G loss: 0.007466, cell accuracy: 96.2%, board accuracy: 0.9%
#
# Epoch 59
# -------------------------------
# train error:
#  G loss: 0.005198, cell accuracy: 97.4%, board accuracy: 2.1%
#
# test error:
#  G loss: 0.007430, cell accuracy: 96.2%, board accuracy: 1.0%
#
# Epoch 60
# -------------------------------
# train error:
#  G loss: 0.005104, cell accuracy: 97.5%, board accuracy: 2.5%
#
# test error:
#  G loss: 0.007369, cell accuracy: 96.3%, board accuracy: 1.2%
#
# Epoch 61
# -------------------------------
# train error:
#  G loss: 0.005050, cell accuracy: 97.5%, board accuracy: 2.6%
#
# test error:
#  G loss: 0.007353, cell accuracy: 96.3%, board accuracy: 1.1%
#
# Epoch 62
# -------------------------------
# train error:
#  G loss: 0.005083, cell accuracy: 97.5%, board accuracy: 2.3%
#
# test error:
#  G loss: 0.007377, cell accuracy: 96.2%, board accuracy: 0.8%
#
# Epoch 63
# -------------------------------
# train error:
#  G loss: 0.004904, cell accuracy: 97.6%, board accuracy: 3.0%
#
# test error:
#  G loss: 0.007196, cell accuracy: 96.4%, board accuracy: 1.0%
#
# Epoch 64
# -------------------------------
# train error:
#  G loss: 0.004946, cell accuracy: 97.6%, board accuracy: 2.6%
#
# test error:
#  G loss: 0.007264, cell accuracy: 96.3%, board accuracy: 0.8%
#
# Epoch 65
# -------------------------------
# train error:
#  G loss: 0.004814, cell accuracy: 97.6%, board accuracy: 3.1%
#
# test error:
#  G loss: 0.007179, cell accuracy: 96.4%, board accuracy: 1.1%
#
# Epoch 66
# -------------------------------
# train error:
#  G loss: 0.004732, cell accuracy: 97.7%, board accuracy: 3.6%
#
# test error:
#  G loss: 0.007079, cell accuracy: 96.4%, board accuracy: 1.3%
#
# Epoch 67
# -------------------------------
# train error:
#  G loss: 0.004687, cell accuracy: 97.7%, board accuracy: 3.6%
#
# test error:
#  G loss: 0.007054, cell accuracy: 96.4%, board accuracy: 1.2%
#
# Epoch 68
# -------------------------------
# train error:
#  G loss: 0.004646, cell accuracy: 97.7%, board accuracy: 3.7%
#
# test error:
#  G loss: 0.007043, cell accuracy: 96.4%, board accuracy: 1.4%
#
# Epoch 69
# -------------------------------
# train error:
#  G loss: 0.004655, cell accuracy: 97.7%, board accuracy: 3.5%
#
# test error:
#  G loss: 0.007096, cell accuracy: 96.4%, board accuracy: 1.2%
#
# Epoch 70
# -------------------------------
# train error:
#  G loss: 0.004611, cell accuracy: 97.7%, board accuracy: 3.8%
#
# test error:
#  G loss: 0.007040, cell accuracy: 96.4%, board accuracy: 1.2%
#
# Epoch 71
# -------------------------------
# train error:
#  G loss: 0.004550, cell accuracy: 97.8%, board accuracy: 4.1%
#
# test error:
#  G loss: 0.006968, cell accuracy: 96.5%, board accuracy: 1.5%
#
# Epoch 72
# -------------------------------
# train error:
#  G loss: 0.004529, cell accuracy: 97.8%, board accuracy: 3.9%
#
# test error:
#  G loss: 0.006990, cell accuracy: 96.5%, board accuracy: 1.2%
#
# Epoch 73
# -------------------------------
# train error:
#  G loss: 0.004578, cell accuracy: 97.7%, board accuracy: 3.5%
#
# test error:
#  G loss: 0.007048, cell accuracy: 96.5%, board accuracy: 1.1%
#
# Epoch 74
# -------------------------------
# train error:
#  G loss: 0.004485, cell accuracy: 97.8%, board accuracy: 3.8%
#
# test error:
#  G loss: 0.006957, cell accuracy: 96.5%, board accuracy: 1.4%
#
# Epoch 75
# -------------------------------
# train error:
#  G loss: 0.004398, cell accuracy: 97.8%, board accuracy: 4.5%
#
# test error:
#  G loss: 0.006897, cell accuracy: 96.5%, board accuracy: 1.5%
#
# Epoch 76
# -------------------------------
# train error:
#  G loss: 0.004470, cell accuracy: 97.8%, board accuracy: 4.1%
#
# test error:
#  G loss: 0.007005, cell accuracy: 96.5%, board accuracy: 1.4%
#
# Epoch 77
# -------------------------------
# train error:
#  G loss: 0.004377, cell accuracy: 97.9%, board accuracy: 4.6%
#
# test error:
#  G loss: 0.006862, cell accuracy: 96.5%, board accuracy: 1.5%
#
# Epoch 78
# -------------------------------
# train error:
#  G loss: 0.004302, cell accuracy: 97.9%, board accuracy: 4.8%
#
# test error:
#  G loss: 0.006835, cell accuracy: 96.6%, board accuracy: 1.7%
#
# Epoch 79
# -------------------------------
# train error:
#  G loss: 0.004351, cell accuracy: 97.9%, board accuracy: 4.6%
#
# test error:
#  G loss: 0.006887, cell accuracy: 96.5%, board accuracy: 1.8%
#
# Epoch 80
# -------------------------------
# train error:
#  G loss: 0.004194, cell accuracy: 98.0%, board accuracy: 5.0%
#
# test error:
#  G loss: 0.006704, cell accuracy: 96.6%, board accuracy: 1.7%
#
# Epoch 81
# -------------------------------
# train error:
#  G loss: 0.004179, cell accuracy: 98.0%, board accuracy: 5.3%
#
# test error:
#  G loss: 0.006739, cell accuracy: 96.6%, board accuracy: 1.8%
#
# Epoch 82
# -------------------------------
# train error:
#  G loss: 0.004186, cell accuracy: 98.0%, board accuracy: 5.2%
#
# test error:
#  G loss: 0.006744, cell accuracy: 96.6%, board accuracy: 2.1%
#
# Epoch 83
# -------------------------------
# train error:
#  G loss: 0.004170, cell accuracy: 98.0%, board accuracy: 5.1%
#
# test error:
#  G loss: 0.006771, cell accuracy: 96.6%, board accuracy: 1.8%
#
# Epoch 84
# -------------------------------
# train error:
#  G loss: 0.004101, cell accuracy: 98.0%, board accuracy: 5.4%
#
# test error:
#  G loss: 0.006716, cell accuracy: 96.6%, board accuracy: 1.8%
#
# Epoch 85
# -------------------------------
# train error:
#  G loss: 0.004088, cell accuracy: 98.0%, board accuracy: 5.6%
#
# test error:
#  G loss: 0.006656, cell accuracy: 96.7%, board accuracy: 2.1%
#
# Epoch 86
# -------------------------------
# train error:
#  G loss: 0.004078, cell accuracy: 98.0%, board accuracy: 5.8%
#
# test error:
#  G loss: 0.006718, cell accuracy: 96.6%, board accuracy: 1.8%
#
# Epoch 87
# -------------------------------
# train error:
#  G loss: 0.004016, cell accuracy: 98.0%, board accuracy: 6.0%
#
# test error:
#  G loss: 0.006622, cell accuracy: 96.7%, board accuracy: 2.0%
#
# Epoch 88
# -------------------------------
# train error:
#  G loss: 0.004043, cell accuracy: 98.0%, board accuracy: 6.0%
#
# test error:
#  G loss: 0.006718, cell accuracy: 96.6%, board accuracy: 1.8%
#
# Epoch 89
# -------------------------------
# train error:
#  G loss: 0.003914, cell accuracy: 98.1%, board accuracy: 6.6%
#
# test error:
#  G loss: 0.006556, cell accuracy: 96.7%, board accuracy: 2.3%
#
# Epoch 90
# -------------------------------
# train error:
#  G loss: 0.003902, cell accuracy: 98.1%, board accuracy: 6.7%
#
# test error:
#  G loss: 0.006546, cell accuracy: 96.7%, board accuracy: 2.3%
#
# Epoch 91
# -------------------------------
# train error:
#  G loss: 0.003835, cell accuracy: 98.1%, board accuracy: 7.2%
#
# test error:
#  G loss: 0.006492, cell accuracy: 96.7%, board accuracy: 2.4%
#
# Epoch 92
# -------------------------------
# train error:
#  G loss: 0.003939, cell accuracy: 98.1%, board accuracy: 6.2%
#
# test error:
#  G loss: 0.006596, cell accuracy: 96.7%, board accuracy: 2.4%
#
# Epoch 93
# -------------------------------
# train error:
#  G loss: 0.003854, cell accuracy: 98.1%, board accuracy: 6.6%
#
# test error:
#  G loss: 0.006541, cell accuracy: 96.7%, board accuracy: 2.1%
#
# Epoch 94
# -------------------------------
# train error:
#  G loss: 0.003832, cell accuracy: 98.1%, board accuracy: 6.9%
#
# test error:
#  G loss: 0.006552, cell accuracy: 96.7%, board accuracy: 2.2%
#
# Epoch 95
# -------------------------------
# train error:
#  G loss: 0.003834, cell accuracy: 98.1%, board accuracy: 6.9%
#
# test error:
#  G loss: 0.006560, cell accuracy: 96.7%, board accuracy: 2.1%
#
# Epoch 96
# -------------------------------
# train error:
#  G loss: 0.003827, cell accuracy: 98.1%, board accuracy: 7.1%
#
# test error:
#  G loss: 0.006596, cell accuracy: 96.7%, board accuracy: 2.2%
#
# Epoch 97
# -------------------------------
# train error:
#  G loss: 0.003746, cell accuracy: 98.2%, board accuracy: 7.7%
#
# test error:
#  G loss: 0.006484, cell accuracy: 96.8%, board accuracy: 2.3%
#
# Epoch 98
# -------------------------------
# train error:
#  G loss: 0.003764, cell accuracy: 98.2%, board accuracy: 7.2%
#
# test error:
#  G loss: 0.006520, cell accuracy: 96.7%, board accuracy: 2.3%
#
# Epoch 99
# -------------------------------
# train error:
#  G loss: 0.003766, cell accuracy: 98.2%, board accuracy: 7.2%
#
# test error:
#  G loss: 0.006543, cell accuracy: 96.7%, board accuracy: 2.1%
#
# Epoch 100
# -------------------------------
# train error:
#  G loss: 0.003658, cell accuracy: 98.2%, board accuracy: 8.1%
#
# test error:
#  G loss: 0.006433, cell accuracy: 96.8%, board accuracy: 2.3%
#
# Epoch 101
# -------------------------------
# train error:
#  G loss: 0.003696, cell accuracy: 98.2%, board accuracy: 7.9%
#
# test error:
#  G loss: 0.006463, cell accuracy: 96.8%, board accuracy: 2.5%
#
# Epoch 102
# -------------------------------
# train error:
#  G loss: 0.003705, cell accuracy: 98.2%, board accuracy: 7.3%
#
# test error:
#  G loss: 0.006439, cell accuracy: 96.8%, board accuracy: 2.5%
#
# Epoch 103
# -------------------------------
# train error:
#  G loss: 0.003558, cell accuracy: 98.3%, board accuracy: 8.8%
#
# test error:
#  G loss: 0.006380, cell accuracy: 96.8%, board accuracy: 2.9%
#
# Epoch 104
# -------------------------------
# train error:
#  G loss: 0.003605, cell accuracy: 98.3%, board accuracy: 8.3%
#
# test error:
#  G loss: 0.006427, cell accuracy: 96.8%, board accuracy: 2.6%
#
# Epoch 105
# -------------------------------
# train error:
#  G loss: 0.003623, cell accuracy: 98.2%, board accuracy: 8.3%
#
# test error:
#  G loss: 0.006459, cell accuracy: 96.8%, board accuracy: 2.2%
#
# Epoch 106
# -------------------------------
# train error:
#  G loss: 0.003598, cell accuracy: 98.3%, board accuracy: 8.6%
#
# test error:
#  G loss: 0.006435, cell accuracy: 96.8%, board accuracy: 2.4%
#
# Epoch 107
# -------------------------------
# train error:
#  G loss: 0.003497, cell accuracy: 98.3%, board accuracy: 9.2%
#
# test error:
#  G loss: 0.006350, cell accuracy: 96.8%, board accuracy: 2.5%
#
# Epoch 108
# -------------------------------
# train error:
#  G loss: 0.003448, cell accuracy: 98.3%, board accuracy: 9.6%
#
# test error:
#  G loss: 0.006329, cell accuracy: 96.8%, board accuracy: 2.5%
#
# Epoch 109
# -------------------------------
# train error:
#  G loss: 0.003491, cell accuracy: 98.3%, board accuracy: 9.3%
#
# test error:
#  G loss: 0.006360, cell accuracy: 96.8%, board accuracy: 2.6%
#
# Epoch 110
# -------------------------------
# train error:
#  G loss: 0.003474, cell accuracy: 98.3%, board accuracy: 9.4%
#
# test error:
#  G loss: 0.006300, cell accuracy: 96.9%, board accuracy: 2.8%
#
# Epoch 111
# -------------------------------
# train error:
#  G loss: 0.003406, cell accuracy: 98.4%, board accuracy: 9.7%
#
# test error:
#  G loss: 0.006290, cell accuracy: 96.9%, board accuracy: 2.9%
#
# Epoch 112
# -------------------------------
# train error:
#  G loss: 0.003499, cell accuracy: 98.3%, board accuracy: 8.8%
#
# test error:
#  G loss: 0.006396, cell accuracy: 96.8%, board accuracy: 2.4%
#
# Epoch 113
# -------------------------------
# train error:
#  G loss: 0.003360, cell accuracy: 98.4%, board accuracy: 10.1%
#
# test error:
#  G loss: 0.006275, cell accuracy: 96.9%, board accuracy: 2.8%
#
# Epoch 114
# -------------------------------
# train error:
#  G loss: 0.003425, cell accuracy: 98.4%, board accuracy: 9.6%
#
# test error:
#  G loss: 0.006323, cell accuracy: 96.8%, board accuracy: 2.9%
#
# Epoch 115
# -------------------------------
# train error:
#  G loss: 0.003313, cell accuracy: 98.4%, board accuracy: 10.7%
#
# test error:
#  G loss: 0.006265, cell accuracy: 96.9%, board accuracy: 2.9%
#
# Epoch 116
# -------------------------------
# train error:
#  G loss: 0.003345, cell accuracy: 98.4%, board accuracy: 9.8%
#
# test error:
#  G loss: 0.006327, cell accuracy: 96.8%, board accuracy: 2.8%
#
# Epoch 117
# -------------------------------
# train error:
#  G loss: 0.003299, cell accuracy: 98.4%, board accuracy: 10.7%
#
# test error:
#  G loss: 0.006284, cell accuracy: 96.9%, board accuracy: 2.8%
#
# Epoch 118
# -------------------------------
# train error:
#  G loss: 0.003260, cell accuracy: 98.4%, board accuracy: 11.1%
#
# test error:
#  G loss: 0.006220, cell accuracy: 96.9%, board accuracy: 3.3%
#
# Epoch 119
# -------------------------------
# train error:
#  G loss: 0.003326, cell accuracy: 98.4%, board accuracy: 10.2%
#
# test error:
#  G loss: 0.006266, cell accuracy: 96.9%, board accuracy: 2.7%
#
# Epoch 120
# -------------------------------
# train error:
#  G loss: 0.003274, cell accuracy: 98.4%, board accuracy: 10.9%
#
# test error:
#  G loss: 0.006257, cell accuracy: 96.9%, board accuracy: 2.6%
#
# Epoch 121
# -------------------------------
# train error:
#  G loss: 0.003272, cell accuracy: 98.4%, board accuracy: 10.8%
#
# test error:
#  G loss: 0.006273, cell accuracy: 96.9%, board accuracy: 2.6%
#
# Epoch 122
# -------------------------------
# train error:
#  G loss: 0.003215, cell accuracy: 98.5%, board accuracy: 11.3%
#
# test error:
#  G loss: 0.006215, cell accuracy: 96.9%, board accuracy: 3.4%
#
# Epoch 123
# -------------------------------
# train error:
#  G loss: 0.003153, cell accuracy: 98.5%, board accuracy: 12.0%
#
# test error:
#  G loss: 0.006130, cell accuracy: 97.0%, board accuracy: 3.0%
#
# Epoch 124
# -------------------------------
# train error:
#  G loss: 0.003182, cell accuracy: 98.5%, board accuracy: 11.4%
#
# test error:
#  G loss: 0.006180, cell accuracy: 96.9%, board accuracy: 3.4%
#
# Epoch 125
# -------------------------------
# train error:
#  G loss: 0.003122, cell accuracy: 98.5%, board accuracy: 12.2%
#
# test error:
#  G loss: 0.006147, cell accuracy: 96.9%, board accuracy: 3.3%
#
# Epoch 126
# -------------------------------
# train error:
#  G loss: 0.003169, cell accuracy: 98.5%, board accuracy: 11.2%
#
# test error:
#  G loss: 0.006184, cell accuracy: 96.9%, board accuracy: 3.1%
#
# Epoch 127
# -------------------------------
# train error:
#  G loss: 0.003163, cell accuracy: 98.5%, board accuracy: 11.6%
#
# test error:
#  G loss: 0.006209, cell accuracy: 96.9%, board accuracy: 3.3%
#
# Epoch 128
# -------------------------------
# train error:
#  G loss: 0.003113, cell accuracy: 98.5%, board accuracy: 12.0%
#
# test error:
#  G loss: 0.006134, cell accuracy: 97.0%, board accuracy: 3.0%
#
# Epoch 129
# -------------------------------
# train error:
#  G loss: 0.003228, cell accuracy: 98.4%, board accuracy: 11.0%
#
# test error:
#  G loss: 0.006301, cell accuracy: 96.9%, board accuracy: 2.9%
#
# Epoch 130
# -------------------------------
# train error:
#  G loss: 0.003055, cell accuracy: 98.5%, board accuracy: 12.9%
#
# test error:
#  G loss: 0.006142, cell accuracy: 96.9%, board accuracy: 3.3%
#
# Epoch 131
# -------------------------------
# train error:
#  G loss: 0.003036, cell accuracy: 98.6%, board accuracy: 12.8%
#
# test error:
#  G loss: 0.006102, cell accuracy: 97.0%, board accuracy: 3.2%
#
# Epoch 132
# -------------------------------
# train error:
#  G loss: 0.003069, cell accuracy: 98.5%, board accuracy: 12.6%
#
# test error:
#  G loss: 0.006171, cell accuracy: 96.9%, board accuracy: 3.2%
#
# Epoch 133
# -------------------------------
# train error:
#  G loss: 0.003083, cell accuracy: 98.5%, board accuracy: 12.0%
#
# test error:
#  G loss: 0.006159, cell accuracy: 96.9%, board accuracy: 3.1%
#
# Epoch 134
# -------------------------------
# train error:
#  G loss: 0.003097, cell accuracy: 98.5%, board accuracy: 12.1%
#
# test error:
#  G loss: 0.006163, cell accuracy: 96.9%, board accuracy: 3.3%
#
# Epoch 135
# -------------------------------
# train error:
#  G loss: 0.003015, cell accuracy: 98.6%, board accuracy: 13.4%
#
# test error:
#  G loss: 0.006110, cell accuracy: 97.0%, board accuracy: 3.5%
#
# Epoch 136
# -------------------------------
# train error:
#  G loss: 0.002948, cell accuracy: 98.6%, board accuracy: 13.8%
#
# test error:
#  G loss: 0.006046, cell accuracy: 97.0%, board accuracy: 3.1%
#
# Epoch 137
# -------------------------------
# train error:
#  G loss: 0.002960, cell accuracy: 98.6%, board accuracy: 13.1%
#
# test error:
#  G loss: 0.006060, cell accuracy: 97.0%, board accuracy: 3.7%
#
# Epoch 138
# -------------------------------
# train error:
#  G loss: 0.002978, cell accuracy: 98.6%, board accuracy: 13.4%
#
# test error:
#  G loss: 0.006137, cell accuracy: 97.0%, board accuracy: 3.6%
#
# Epoch 139
# -------------------------------
# train error:
#  G loss: 0.002958, cell accuracy: 98.6%, board accuracy: 13.8%
#
# test error:
#  G loss: 0.006110, cell accuracy: 97.0%, board accuracy: 3.6%
#
# Epoch 140
# -------------------------------
# train error:
#  G loss: 0.002930, cell accuracy: 98.6%, board accuracy: 14.0%
#
# test error:
#  G loss: 0.006108, cell accuracy: 97.0%, board accuracy: 3.3%
#
# Epoch 141
# -------------------------------
# train error:
#  G loss: 0.002936, cell accuracy: 98.6%, board accuracy: 14.0%
#
# test error:
#  G loss: 0.006112, cell accuracy: 97.0%, board accuracy: 3.5%
#
# Epoch 142
# -------------------------------
# train error:
#  G loss: 0.002935, cell accuracy: 98.6%, board accuracy: 13.6%
#
# test error:
#  G loss: 0.006093, cell accuracy: 97.0%, board accuracy: 3.6%
#
# Epoch 143
# -------------------------------
# train error:
#  G loss: 0.002895, cell accuracy: 98.6%, board accuracy: 14.2%
#
# test error:
#  G loss: 0.006076, cell accuracy: 97.0%, board accuracy: 3.6%
#
# Epoch 144
# -------------------------------
# train error:
#  G loss: 0.002853, cell accuracy: 98.7%, board accuracy: 15.0%
#
# test error:
#  G loss: 0.006024, cell accuracy: 97.0%, board accuracy: 3.8%
#
# Epoch 145
# -------------------------------
# train error:
#  G loss: 0.002913, cell accuracy: 98.6%, board accuracy: 13.5%
#
# test error:
#  G loss: 0.006106, cell accuracy: 97.0%, board accuracy: 3.4%
#
# Epoch 146
# -------------------------------
# train error:
#  G loss: 0.002940, cell accuracy: 98.6%, board accuracy: 13.5%
#
# test error:
#  G loss: 0.006118, cell accuracy: 97.0%, board accuracy: 3.9%
#
# Epoch 147
# -------------------------------
# train error:
#  G loss: 0.002955, cell accuracy: 98.6%, board accuracy: 13.4%
#
# test error:
#  G loss: 0.006201, cell accuracy: 96.9%, board accuracy: 3.4%
#
# Epoch 148
# -------------------------------
# train error:
#  G loss: 0.002862, cell accuracy: 98.6%, board accuracy: 14.4%
#
# test error:
#  G loss: 0.006108, cell accuracy: 97.0%, board accuracy: 3.6%
#
# Epoch 149
# -------------------------------
# train error:
#  G loss: 0.002809, cell accuracy: 98.7%, board accuracy: 15.1%
#
# test error:
#  G loss: 0.006051, cell accuracy: 97.0%, board accuracy: 3.6%
#
# Epoch 150
# -------------------------------
# train error:
#  G loss: 0.002886, cell accuracy: 98.6%, board accuracy: 13.9%
#
# test error:
#  G loss: 0.006115, cell accuracy: 97.0%, board accuracy: 3.3%
#
# Epoch 151
# -------------------------------
# train error:
#  G loss: 0.002873, cell accuracy: 98.6%, board accuracy: 14.0%
#
# test error:
#  G loss: 0.006093, cell accuracy: 97.0%, board accuracy: 3.5%
#
# Epoch 152
# -------------------------------
# train error:
#  G loss: 0.002871, cell accuracy: 98.6%, board accuracy: 14.0%
#
# test error:
#  G loss: 0.006120, cell accuracy: 97.0%, board accuracy: 3.3%
#
# Epoch 153
# -------------------------------
# train error:
#  G loss: 0.002812, cell accuracy: 98.7%, board accuracy: 15.0%
#
# test error:
#  G loss: 0.006057, cell accuracy: 97.0%, board accuracy: 3.6%
#
# Epoch 154
# -------------------------------
# train error:
#  G loss: 0.002747, cell accuracy: 98.7%, board accuracy: 15.6%
#
# test error:
#  G loss: 0.006006, cell accuracy: 97.0%, board accuracy: 3.6%
#
# Epoch 155
# -------------------------------
# train error:
#  G loss: 0.002822, cell accuracy: 98.7%, board accuracy: 14.4%
#
# test error:
#  G loss: 0.006123, cell accuracy: 96.9%, board accuracy: 3.9%
#
# Epoch 156
# -------------------------------
# train error:
#  G loss: 0.002726, cell accuracy: 98.7%, board accuracy: 15.9%
#
# test error:
#  G loss: 0.006018, cell accuracy: 97.0%, board accuracy: 3.5%
#
# Epoch 157
# -------------------------------
# train error:
#  G loss: 0.002751, cell accuracy: 98.7%, board accuracy: 15.3%
#
# test error:
#  G loss: 0.006047, cell accuracy: 97.0%, board accuracy: 3.4%
#
# Epoch 158
# -------------------------------
# train error:
#  G loss: 0.002767, cell accuracy: 98.7%, board accuracy: 15.7%
#
# test error:
#  G loss: 0.006067, cell accuracy: 97.0%, board accuracy: 3.9%
#
# Epoch 159
# -------------------------------
# train error:
#  G loss: 0.002719, cell accuracy: 98.7%, board accuracy: 15.1%
#
# test error:
#  G loss: 0.005982, cell accuracy: 97.0%, board accuracy: 3.7%
#
# Epoch 160
# -------------------------------
# train error:
#  G loss: 0.002649, cell accuracy: 98.8%, board accuracy: 17.1%
#
# test error:
#  G loss: 0.005954, cell accuracy: 97.1%, board accuracy: 4.3%
#
# Epoch 161
# -------------------------------
# train error:
#  G loss: 0.002697, cell accuracy: 98.7%, board accuracy: 16.4%
#
# test error:
#  G loss: 0.006037, cell accuracy: 97.0%, board accuracy: 3.4%
#
# Epoch 162
# -------------------------------
# train error:
#  G loss: 0.002659, cell accuracy: 98.8%, board accuracy: 16.8%
#
# test error:
#  G loss: 0.005990, cell accuracy: 97.0%, board accuracy: 3.8%
#
# Epoch 163
# -------------------------------
# train error:
#  G loss: 0.002622, cell accuracy: 98.8%, board accuracy: 17.3%
#
# test error:
#  G loss: 0.005946, cell accuracy: 97.1%, board accuracy: 3.8%
#
# Epoch 164
# -------------------------------
# train error:
#  G loss: 0.002664, cell accuracy: 98.7%, board accuracy: 16.6%
#
# test error:
#  G loss: 0.006030, cell accuracy: 97.0%, board accuracy: 3.8%
#
# Epoch 165
# -------------------------------
# train error:
#  G loss: 0.002610, cell accuracy: 98.8%, board accuracy: 17.4%
#
# test error:
#  G loss: 0.005964, cell accuracy: 97.1%, board accuracy: 4.2%
#
# Epoch 166
# -------------------------------
# train error:
#  G loss: 0.002622, cell accuracy: 98.8%, board accuracy: 16.6%
#
# test error:
#  G loss: 0.005979, cell accuracy: 97.0%, board accuracy: 3.9%
#
# Epoch 167
# -------------------------------
# train error:
#  G loss: 0.002608, cell accuracy: 98.8%, board accuracy: 17.5%
#
# test error:
#  G loss: 0.005959, cell accuracy: 97.0%, board accuracy: 4.0%
#
# Epoch 168
# -------------------------------
# train error:
#  G loss: 0.002646, cell accuracy: 98.8%, board accuracy: 16.4%
#
# test error:
#  G loss: 0.006051, cell accuracy: 97.0%, board accuracy: 3.7%
#
# Epoch 169
# -------------------------------
# train error:
#  G loss: 0.002682, cell accuracy: 98.7%, board accuracy: 15.8%
#
# test error:
#  G loss: 0.006072, cell accuracy: 97.0%, board accuracy: 3.8%
#
# Epoch 170
# -------------------------------
# train error:
#  G loss: 0.002541, cell accuracy: 98.8%, board accuracy: 18.5%
#
# test error:
#  G loss: 0.005926, cell accuracy: 97.1%, board accuracy: 4.3%
#
# Epoch 171
# -------------------------------
# train error:
#  G loss: 0.002552, cell accuracy: 98.8%, board accuracy: 18.4%
#
# test error:
#  G loss: 0.005947, cell accuracy: 97.0%, board accuracy: 4.3%
#
# Epoch 172
# -------------------------------
# train error:
#  G loss: 0.002583, cell accuracy: 98.8%, board accuracy: 18.0%
#
# test error:
#  G loss: 0.006016, cell accuracy: 97.0%, board accuracy: 3.7%
#
# Epoch 173
# -------------------------------
# train error:
#  G loss: 0.002514, cell accuracy: 98.8%, board accuracy: 18.1%
#
# test error:
#  G loss: 0.005910, cell accuracy: 97.1%, board accuracy: 3.8%
#
# Epoch 174
# -------------------------------
# train error:
#  G loss: 0.002483, cell accuracy: 98.8%, board accuracy: 19.2%
#
# test error:
#  G loss: 0.005920, cell accuracy: 97.1%, board accuracy: 4.2%
#
# Epoch 175
# -------------------------------
# train error:
#  G loss: 0.002574, cell accuracy: 98.8%, board accuracy: 17.6%
#
# test error:
#  G loss: 0.006009, cell accuracy: 97.0%, board accuracy: 3.6%
#
# Epoch 176
# -------------------------------
# train error:
#  G loss: 0.002609, cell accuracy: 98.8%, board accuracy: 17.0%
#
# test error:
#  G loss: 0.006015, cell accuracy: 97.1%, board accuracy: 3.5%
#
# Epoch 177
# -------------------------------
# train error:
#  G loss: 0.002535, cell accuracy: 98.8%, board accuracy: 18.5%
#
# test error:
#  G loss: 0.005960, cell accuracy: 97.1%, board accuracy: 4.1%
#
# Epoch 178
# -------------------------------
# train error:
#  G loss: 0.002461, cell accuracy: 98.9%, board accuracy: 19.6%
#
# test error:
#  G loss: 0.005899, cell accuracy: 97.1%, board accuracy: 4.3%
#
# Epoch 179
# -------------------------------
# train error:
#  G loss: 0.002487, cell accuracy: 98.8%, board accuracy: 18.8%
#
# test error:
#  G loss: 0.005937, cell accuracy: 97.1%, board accuracy: 4.5%
#
# Epoch 180
# -------------------------------
# train error:
#  G loss: 0.002507, cell accuracy: 98.8%, board accuracy: 18.1%
#
# test error:
#  G loss: 0.005940, cell accuracy: 97.1%, board accuracy: 3.9%
#
# Epoch 181
# -------------------------------
# train error:
#  G loss: 0.002496, cell accuracy: 98.8%, board accuracy: 18.4%
#
# test error:
#  G loss: 0.005952, cell accuracy: 97.1%, board accuracy: 4.0%
#
# Epoch 182
# -------------------------------
# train error:
#  G loss: 0.002470, cell accuracy: 98.9%, board accuracy: 19.2%
#
# test error:
#  G loss: 0.005954, cell accuracy: 97.1%, board accuracy: 4.1%
#
# Epoch 183
# -------------------------------
# train error:
#  G loss: 0.002434, cell accuracy: 98.9%, board accuracy: 19.4%
#
# test error:
#  G loss: 0.005907, cell accuracy: 97.1%, board accuracy: 4.3%
#
# Epoch 184
# -------------------------------
# train error:
#  G loss: 0.002428, cell accuracy: 98.9%, board accuracy: 19.6%
#
# test error:
#  G loss: 0.005914, cell accuracy: 97.1%, board accuracy: 4.3%
#
# Epoch 185
# -------------------------------
# train error:
#  G loss: 0.002503, cell accuracy: 98.8%, board accuracy: 18.4%
#
# test error:
#  G loss: 0.006022, cell accuracy: 97.0%, board accuracy: 4.1%
#
# Epoch 186
# -------------------------------
# train error:
#  G loss: 0.002398, cell accuracy: 98.9%, board accuracy: 20.3%
#
# test error:
#  G loss: 0.005915, cell accuracy: 97.1%, board accuracy: 4.5%
#
# Epoch 187
# -------------------------------
# train error:
#  G loss: 0.002465, cell accuracy: 98.9%, board accuracy: 18.7%
#
# test error:
#  G loss: 0.005961, cell accuracy: 97.1%, board accuracy: 4.5%
#
# Epoch 188
# -------------------------------
# train error:
#  G loss: 0.002405, cell accuracy: 98.9%, board accuracy: 19.9%
#
# test error:
#  G loss: 0.005903, cell accuracy: 97.1%, board accuracy: 4.0%
#
# Epoch 189
# -------------------------------
# train error:
#  G loss: 0.002425, cell accuracy: 98.9%, board accuracy: 19.6%
#
# test error:
#  G loss: 0.005947, cell accuracy: 97.1%, board accuracy: 3.9%
#
# Epoch 190
# -------------------------------
# train error:
#  G loss: 0.002433, cell accuracy: 98.9%, board accuracy: 19.5%
#
# test error:
#  G loss: 0.005985, cell accuracy: 97.0%, board accuracy: 3.7%
#
# Epoch 191
# -------------------------------
# train error:
#  G loss: 0.002361, cell accuracy: 98.9%, board accuracy: 20.8%
#
# test error:
#  G loss: 0.005896, cell accuracy: 97.1%, board accuracy: 4.3%
#
# Epoch 192
# -------------------------------
# train error:
#  G loss: 0.002354, cell accuracy: 98.9%, board accuracy: 20.8%
#
# test error:
#  G loss: 0.005918, cell accuracy: 97.1%, board accuracy: 4.5%
#
# Epoch 193
# -------------------------------
# train error:
#  G loss: 0.002429, cell accuracy: 98.9%, board accuracy: 19.6%
#
# test error:
#  G loss: 0.005928, cell accuracy: 97.1%, board accuracy: 4.3%
#
# Epoch 194
# -------------------------------
# train error:
#  G loss: 0.002353, cell accuracy: 98.9%, board accuracy: 20.6%
#
# test error:
#  G loss: 0.005868, cell accuracy: 97.1%, board accuracy: 4.4%
#
# Epoch 195
# -------------------------------
# train error:
#  G loss: 0.002371, cell accuracy: 98.9%, board accuracy: 20.5%
#
# test error:
#  G loss: 0.005900, cell accuracy: 97.1%, board accuracy: 3.8%
#
# Epoch 196
# -------------------------------
# train error:
#  G loss: 0.002364, cell accuracy: 98.9%, board accuracy: 20.9%
#
# test error:
#  G loss: 0.005938, cell accuracy: 97.1%, board accuracy: 3.9%
#
# Epoch 197
# -------------------------------
# train error:
#  G loss: 0.002332, cell accuracy: 98.9%, board accuracy: 21.1%
#
# test error:
#  G loss: 0.005906, cell accuracy: 97.1%, board accuracy: 4.2%
#
# Epoch 198
# -------------------------------
# train error:
#  G loss: 0.002269, cell accuracy: 99.0%, board accuracy: 22.3%
#
# test error:
#  G loss: 0.005851, cell accuracy: 97.1%, board accuracy: 4.7%
#
# Epoch 199
# -------------------------------
# train error:
#  G loss: 0.002314, cell accuracy: 98.9%, board accuracy: 20.8%
#
# test error:
#  G loss: 0.005845, cell accuracy: 97.1%, board accuracy: 4.3%
#
# Epoch 200
# -------------------------------
# train error:
#  G loss: 0.002341, cell accuracy: 98.9%, board accuracy: 20.4%
#
# test error:
#  G loss: 0.005893, cell accuracy: 97.1%, board accuracy: 4.3%
#
# Epoch 201
# -------------------------------
# train error:
#  G loss: 0.002309, cell accuracy: 98.9%, board accuracy: 20.9%
#
# test error:
#  G loss: 0.005930, cell accuracy: 97.1%, board accuracy: 4.3%
#
# Epoch 202
# -------------------------------
# train error:
#  G loss: 0.002282, cell accuracy: 98.9%, board accuracy: 21.8%
#
# test error:
#  G loss: 0.005845, cell accuracy: 97.1%, board accuracy: 4.7%
#
# Epoch 203
# -------------------------------
# train error:
#  G loss: 0.002245, cell accuracy: 99.0%, board accuracy: 22.0%
#
# test error:
#  G loss: 0.005879, cell accuracy: 97.1%, board accuracy: 4.7%
#
# Epoch 204
# -------------------------------
# train error:
#  G loss: 0.002322, cell accuracy: 98.9%, board accuracy: 21.2%
#
# test error:
#  G loss: 0.005928, cell accuracy: 97.1%, board accuracy: 4.8%
#
# Epoch 205
# -------------------------------
# train error:
#  G loss: 0.002277, cell accuracy: 98.9%, board accuracy: 21.6%
#
# test error:
#  G loss: 0.005883, cell accuracy: 97.1%, board accuracy: 4.9%
#
# Epoch 206
# -------------------------------
# train error:
#  G loss: 0.002277, cell accuracy: 98.9%, board accuracy: 21.0%
#
# test error:
#  G loss: 0.005899, cell accuracy: 97.1%, board accuracy: 4.2%
#
# Epoch 207
# -------------------------------
# train error:
#  G loss: 0.002259, cell accuracy: 99.0%, board accuracy: 22.0%
#
# test error:
#  G loss: 0.005853, cell accuracy: 97.1%, board accuracy: 4.6%
#
# Epoch 208
# -------------------------------
# train error:
#  G loss: 0.002200, cell accuracy: 99.0%, board accuracy: 23.2%
#
# test error:
#  G loss: 0.005864, cell accuracy: 97.1%, board accuracy: 4.9%
#
# Epoch 209
# -------------------------------
# train error:
#  G loss: 0.002211, cell accuracy: 99.0%, board accuracy: 23.0%
#
# test error:
#  G loss: 0.005846, cell accuracy: 97.1%, board accuracy: 4.9%
#
# Epoch 210
# -------------------------------
# train error:
#  G loss: 0.002199, cell accuracy: 99.0%, board accuracy: 23.2%
#
# test error:
#  G loss: 0.005841, cell accuracy: 97.1%, board accuracy: 4.9%
#
# Epoch 211
# -------------------------------
# train error:
#  G loss: 0.002226, cell accuracy: 99.0%, board accuracy: 22.2%
#
# test error:
#  G loss: 0.005898, cell accuracy: 97.1%, board accuracy: 4.4%
#
# Epoch 212
# -------------------------------
# train error:
#  G loss: 0.002271, cell accuracy: 98.9%, board accuracy: 21.5%
#
# test error:
#  G loss: 0.005958, cell accuracy: 97.1%, board accuracy: 4.2%
#
# Epoch 213
# -------------------------------
# train error:
#  G loss: 0.002251, cell accuracy: 99.0%, board accuracy: 22.3%
#
# test error:
#  G loss: 0.005908, cell accuracy: 97.1%, board accuracy: 4.9%
#
# Epoch 214
# -------------------------------
# train error:
#  G loss: 0.002191, cell accuracy: 99.0%, board accuracy: 23.1%
#
# test error:
#  G loss: 0.005932, cell accuracy: 97.1%, board accuracy: 5.0%
#
# Epoch 215
# -------------------------------
# train error:
#  G loss: 0.002195, cell accuracy: 99.0%, board accuracy: 22.6%
#
# test error:
#  G loss: 0.005872, cell accuracy: 97.1%, board accuracy: 4.3%
#
# Epoch 216
# -------------------------------
# train error:
#  G loss: 0.002174, cell accuracy: 99.0%, board accuracy: 23.9%
#
# test error:
#  G loss: 0.005908, cell accuracy: 97.1%, board accuracy: 4.7%
#
# Epoch 217
# -------------------------------
# train error:
#  G loss: 0.002165, cell accuracy: 99.0%, board accuracy: 23.7%
#
# test error:
#  G loss: 0.005883, cell accuracy: 97.1%, board accuracy: 4.9%
#
# Epoch 218
# -------------------------------
# train error:
#  G loss: 0.002134, cell accuracy: 99.0%, board accuracy: 24.6%
#
# test error:
#  G loss: 0.005844, cell accuracy: 97.1%, board accuracy: 5.0%
#
# Epoch 219
# -------------------------------
# train error:
#  G loss: 0.002103, cell accuracy: 99.0%, board accuracy: 25.0%
#
# test error:
#  G loss: 0.005794, cell accuracy: 97.2%, board accuracy: 5.1%
#
# Epoch 220
# -------------------------------
# train error:
#  G loss: 0.002077, cell accuracy: 99.1%, board accuracy: 26.1%
#
# test error:
#  G loss: 0.005795, cell accuracy: 97.1%, board accuracy: 4.9%
#
# Epoch 221
# -------------------------------
# train error:
#  G loss: 0.002170, cell accuracy: 99.0%, board accuracy: 23.3%
#
# test error:
#  G loss: 0.005879, cell accuracy: 97.1%, board accuracy: 4.5%
#
# Epoch 222
# -------------------------------
# train error:
#  G loss: 0.002225, cell accuracy: 99.0%, board accuracy: 21.0%
#
# test error:
#  G loss: 0.005928, cell accuracy: 97.1%, board accuracy: 4.0%
#
# Epoch 223
# -------------------------------
# train error:
#  G loss: 0.002187, cell accuracy: 99.0%, board accuracy: 22.8%
#
# test error:
#  G loss: 0.005906, cell accuracy: 97.1%, board accuracy: 4.5%
#
# Epoch 224
# -------------------------------
# train error:
#  G loss: 0.002131, cell accuracy: 99.0%, board accuracy: 23.8%
#
# test error:
#  G loss: 0.005892, cell accuracy: 97.1%, board accuracy: 5.0%
#
# Epoch 225
# -------------------------------
# train error:
#  G loss: 0.002112, cell accuracy: 99.0%, board accuracy: 24.1%
#
# test error:
#  G loss: 0.005911, cell accuracy: 97.1%, board accuracy: 4.2%
#
# Epoch 226
# -------------------------------
# train error:
#  G loss: 0.002143, cell accuracy: 99.0%, board accuracy: 23.3%
#
# test error:
#  G loss: 0.005853, cell accuracy: 97.1%, board accuracy: 5.0%
#
# Epoch 227
# -------------------------------
# train error:
#  G loss: 0.002102, cell accuracy: 99.0%, board accuracy: 24.3%
#
# test error:
#  G loss: 0.005837, cell accuracy: 97.1%, board accuracy: 5.0%
#
# Epoch 228
# -------------------------------
# train error:
#  G loss: 0.002063, cell accuracy: 99.1%, board accuracy: 25.8%
#
# test error:
#  G loss: 0.005860, cell accuracy: 97.1%, board accuracy: 4.7%
#
# Epoch 229
# -------------------------------
# train error:
#  G loss: 0.002063, cell accuracy: 99.1%, board accuracy: 25.5%
#
# test error:
#  G loss: 0.005796, cell accuracy: 97.2%, board accuracy: 4.9%
#
# Epoch 230
# -------------------------------
# train error:
#  G loss: 0.002063, cell accuracy: 99.1%, board accuracy: 25.3%
#
# test error:
#  G loss: 0.005840, cell accuracy: 97.2%, board accuracy: 4.8%
#
# Epoch 231
# -------------------------------
# train error:
#  G loss: 0.002074, cell accuracy: 99.1%, board accuracy: 25.6%
#
# test error:
#  G loss: 0.005828, cell accuracy: 97.1%, board accuracy: 5.4%
#
# Epoch 232
# -------------------------------
# train error:
#  G loss: 0.002114, cell accuracy: 99.0%, board accuracy: 24.1%
#
# test error:
#  G loss: 0.005934, cell accuracy: 97.1%, board accuracy: 4.5%
#
# Epoch 233
# -------------------------------
# train error:
#  G loss: 0.002119, cell accuracy: 99.0%, board accuracy: 24.2%
#
# test error:
#  G loss: 0.005898, cell accuracy: 97.1%, board accuracy: 4.8%
#
# Epoch 234
# -------------------------------
# train error:
#  G loss: 0.002121, cell accuracy: 99.0%, board accuracy: 23.5%
#
# test error:
#  G loss: 0.005853, cell accuracy: 97.1%, board accuracy: 4.9%
#
# Epoch 235
# -------------------------------
# train error:
#  G loss: 0.002017, cell accuracy: 99.1%, board accuracy: 26.6%
#
# test error:
#  G loss: 0.005816, cell accuracy: 97.2%, board accuracy: 5.1%
#
# Epoch 236
# -------------------------------
# train error:
#  G loss: 0.002024, cell accuracy: 99.1%, board accuracy: 25.8%
#
# test error:
#  G loss: 0.005777, cell accuracy: 97.2%, board accuracy: 5.3%
#
# Epoch 237
# -------------------------------
# train error:
#  G loss: 0.002079, cell accuracy: 99.0%, board accuracy: 25.2%
#
# test error:
#  G loss: 0.005888, cell accuracy: 97.1%, board accuracy: 4.4%
#
# Epoch 238
# -------------------------------
# train error:
#  G loss: 0.002042, cell accuracy: 99.1%, board accuracy: 25.9%
#
# test error:
#  G loss: 0.005829, cell accuracy: 97.2%, board accuracy: 5.2%
#
# Epoch 239
# -------------------------------
# train error:
#  G loss: 0.002030, cell accuracy: 99.1%, board accuracy: 25.8%
#
# test error:
#  G loss: 0.005867, cell accuracy: 97.1%, board accuracy: 5.0%
#
# Epoch 240
# -------------------------------
# train error:
#  G loss: 0.001990, cell accuracy: 99.1%, board accuracy: 26.5%
#
# test error:
#  G loss: 0.005792, cell accuracy: 97.2%, board accuracy: 5.0%
#
# Epoch 241
# -------------------------------
# train error:
#  G loss: 0.002028, cell accuracy: 99.1%, board accuracy: 26.0%
#
# test error:
#  G loss: 0.005865, cell accuracy: 97.1%, board accuracy: 5.1%
#
# Epoch 242
# -------------------------------
# train error:
#  G loss: 0.002035, cell accuracy: 99.1%, board accuracy: 25.6%
#
# test error:
#  G loss: 0.005855, cell accuracy: 97.1%, board accuracy: 5.2%
#
# Epoch 243
# -------------------------------
# train error:
# ...
#  G loss: 0.005611, cell accuracy: 97.4%, board accuracy: 9.4%
#
# Epoch 1420
# -------------------------------
# train error:
#  G loss: 0.000808, cell accuracy: 99.6%, board accuracy: 58.3%
#
# test error:
#  G loss: 0.005545, cell accuracy: 97.5%, board accuracy: 9.2%
#
# Epoch 1421
# -------------------------------
# train error:
#  G loss: 0.000814, cell accuracy: 99.6%, board accuracy: 58.0%
#
# test error:
#  G loss: 0.005552, cell accuracy: 97.4%, board accuracy: 9.9%
#
# Epoch 1422
# -------------------------------
# train error:
#  G loss: 0.000801, cell accuracy: 99.6%, board accuracy: 58.4%
#
# test error:
#  G loss: 0.005505, cell accuracy: 97.5%, board accuracy: 9.4%
#
# Epoch 1423
# -------------------------------
# train error:
#  G loss: 0.000810, cell accuracy: 99.6%, board accuracy: 58.2%
#
# test error:
#  G loss: 0.005510, cell accuracy: 97.5%, board accuracy: 9.2%
#
# Epoch 1424
# -------------------------------
# train error:
#  G loss: 0.000799, cell accuracy: 99.6%, board accuracy: 58.5%
#
# test error:
#  G loss: 0.005502, cell accuracy: 97.5%, board accuracy: 9.4%
#
# Epoch 1425
# -------------------------------
# train error:
#  G loss: 0.000809, cell accuracy: 99.6%, board accuracy: 57.9%
#
# test error:
#  G loss: 0.005526, cell accuracy: 97.5%, board accuracy: 8.8%
#
# Epoch 1426
# -------------------------------
# train error:
#  G loss: 0.000807, cell accuracy: 99.6%, board accuracy: 58.3%
#
# test error:
#  G loss: 0.005537, cell accuracy: 97.4%, board accuracy: 9.5%
#
# Epoch 1427
# -------------------------------
# train error:
#  G loss: 0.000801, cell accuracy: 99.6%, board accuracy: 58.5%
#
# test error:
#  G loss: 0.005539, cell accuracy: 97.5%, board accuracy: 9.6%
#
# Epoch 1428
# -------------------------------
# train error:
#  G loss: 0.000821, cell accuracy: 99.6%, board accuracy: 57.5%
#
# test error:
#  G loss: 0.005608, cell accuracy: 97.4%, board accuracy: 9.4%
#
# Epoch 1429
# -------------------------------
# train error:
#  G loss: 0.000800, cell accuracy: 99.6%, board accuracy: 58.5%
#
# test error:
#  G loss: 0.005492, cell accuracy: 97.5%, board accuracy: 10.0%
#
# Epoch 1430
# -------------------------------
# train error:
#  G loss: 0.000801, cell accuracy: 99.6%, board accuracy: 58.4%
#
# test error:
#  G loss: 0.005501, cell accuracy: 97.5%, board accuracy: 9.6%
#
# Epoch 1431
# -------------------------------
# train error:
#  G loss: 0.000804, cell accuracy: 99.6%, board accuracy: 58.3%
#
# test error:
#  G loss: 0.005557, cell accuracy: 97.4%, board accuracy: 9.7%
#
# Epoch 1432
# -------------------------------
# train error:
#  G loss: 0.000810, cell accuracy: 99.6%, board accuracy: 58.3%
#
# test error:
#  G loss: 0.005543, cell accuracy: 97.5%, board accuracy: 8.5%
#
# Epoch 1433
# -------------------------------
# train error:
#  G loss: 0.000806, cell accuracy: 99.6%, board accuracy: 58.2%
#
# test error:
#  G loss: 0.005510, cell accuracy: 97.5%, board accuracy: 9.5%
#
# Epoch 1434
# -------------------------------
# train error:
#  G loss: 0.000805, cell accuracy: 99.6%, board accuracy: 58.3%
#
# test error:
#  G loss: 0.005517, cell accuracy: 97.5%, board accuracy: 9.5%
#
# Epoch 1435
# -------------------------------
# train error:
#  G loss: 0.000798, cell accuracy: 99.6%, board accuracy: 58.6%
#
# test error:
#  G loss: 0.005508, cell accuracy: 97.5%, board accuracy: 9.8%
#
# Epoch 1436
# -------------------------------
# train error:
#  G loss: 0.000815, cell accuracy: 99.6%, board accuracy: 57.7%
#
# test error:
#  G loss: 0.005564, cell accuracy: 97.4%, board accuracy: 9.2%
#
# Epoch 1437
# -------------------------------
# train error:
#  G loss: 0.000801, cell accuracy: 99.6%, board accuracy: 58.5%
#
# test error:
#  G loss: 0.005536, cell accuracy: 97.5%, board accuracy: 9.1%
#
# Epoch 1438
# -------------------------------
# train error:
#  G loss: 0.000815, cell accuracy: 99.6%, board accuracy: 57.7%
#
# test error:
#  G loss: 0.005518, cell accuracy: 97.5%, board accuracy: 9.5%
#
# Epoch 1439
# -------------------------------
# train error:
#  G loss: 0.000804, cell accuracy: 99.6%, board accuracy: 58.4%
#
# test error:
#  G loss: 0.005519, cell accuracy: 97.5%, board accuracy: 9.2%
#
# Epoch 1440
# -------------------------------
# train error:
#  G loss: 0.000789, cell accuracy: 99.6%, board accuracy: 59.0%
#
# test error:
#  G loss: 0.005449, cell accuracy: 97.5%, board accuracy: 9.7%
#
# Epoch 1441
# -------------------------------
# train error:
#  G loss: 0.000821, cell accuracy: 99.6%, board accuracy: 57.3%
#
# test error:
#  G loss: 0.005603, cell accuracy: 97.4%, board accuracy: 9.3%
#
# Epoch 1442
# -------------------------------
# train error:
#  G loss: 0.000810, cell accuracy: 99.6%, board accuracy: 58.0%
#
# test error:
#  G loss: 0.005481, cell accuracy: 97.5%, board accuracy: 9.2%
#
# Epoch 1443
# -------------------------------
# train error:
#  G loss: 0.000803, cell accuracy: 99.6%, board accuracy: 58.4%
#
# test error:
#  G loss: 0.005501, cell accuracy: 97.5%, board accuracy: 9.5%
#
# Epoch 1444
# -------------------------------
# train error:
#  G loss: 0.000817, cell accuracy: 99.6%, board accuracy: 57.5%
#
# test error:
#  G loss: 0.005535, cell accuracy: 97.5%, board accuracy: 9.2%
#
# Epoch 1445
# -------------------------------
# train error:
#  G loss: 0.000805, cell accuracy: 99.6%, board accuracy: 58.1%
#
# test error:
#  G loss: 0.005513, cell accuracy: 97.5%, board accuracy: 9.4%
#
# Epoch 1446
# -------------------------------
# train error:
#  G loss: 0.000799, cell accuracy: 99.6%, board accuracy: 58.6%
#
# test error:
#  G loss: 0.005468, cell accuracy: 97.5%, board accuracy: 9.8%
#
# Epoch 1447
# -------------------------------
# train error:
#  G loss: 0.000812, cell accuracy: 99.6%, board accuracy: 57.6%
#
# test error:
#  G loss: 0.005553, cell accuracy: 97.4%, board accuracy: 8.9%
#
# Epoch 1448
# -------------------------------
# train error:
#  G loss: 0.000795, cell accuracy: 99.6%, board accuracy: 58.4%
#
# test error:
#  G loss: 0.005509, cell accuracy: 97.5%, board accuracy: 9.2%
#
# Epoch 1449
# -------------------------------
# train error:
#  G loss: 0.000797, cell accuracy: 99.6%, board accuracy: 58.8%
#
# test error:
#  G loss: 0.005512, cell accuracy: 97.5%, board accuracy: 9.7%
#
# Epoch 1450
# -------------------------------
# train error:
#  G loss: 0.000806, cell accuracy: 99.6%, board accuracy: 58.2%
#
# test error:
#  G loss: 0.005507, cell accuracy: 97.5%, board accuracy: 9.0%
#
# Epoch 1451
# -------------------------------
# train error:
#  G loss: 0.000819, cell accuracy: 99.6%, board accuracy: 57.3%
#
# test error:
#  G loss: 0.005514, cell accuracy: 97.5%, board accuracy: 8.5%
#
# Epoch 1452
# -------------------------------
# train error:
#  G loss: 0.000805, cell accuracy: 99.6%, board accuracy: 58.1%
#
# test error:
#  G loss: 0.005511, cell accuracy: 97.5%, board accuracy: 9.9%
#
# Epoch 1453
# -------------------------------
# train error:
#  G loss: 0.000795, cell accuracy: 99.6%, board accuracy: 58.7%
#
# test error:
#  G loss: 0.005512, cell accuracy: 97.5%, board accuracy: 9.4%
#
# Epoch 1454
# -------------------------------
# train error:
#  G loss: 0.000808, cell accuracy: 99.6%, board accuracy: 58.2%
#
# test error:
#  G loss: 0.005529, cell accuracy: 97.4%, board accuracy: 9.4%
#
# Epoch 1455
# -------------------------------
# train error:
#  G loss: 0.000786, cell accuracy: 99.6%, board accuracy: 59.1%
#
# test error:
#  G loss: 0.005467, cell accuracy: 97.5%, board accuracy: 9.6%
#
# Epoch 1456
# -------------------------------
# train error:
#  G loss: 0.000801, cell accuracy: 99.6%, board accuracy: 58.4%
#
# test error:
#  G loss: 0.005516, cell accuracy: 97.5%, board accuracy: 9.8%
#
# Epoch 1457
# -------------------------------
# train error:
#  G loss: 0.000790, cell accuracy: 99.6%, board accuracy: 59.1%
#
# test error:
#  G loss: 0.005453, cell accuracy: 97.5%, board accuracy: 10.0%
#
# Epoch 1458
# -------------------------------
# train error:
#  G loss: 0.000815, cell accuracy: 99.6%, board accuracy: 57.9%
#
# test error:
#  G loss: 0.005533, cell accuracy: 97.5%, board accuracy: 9.2%
#
# Epoch 1459
# -------------------------------
# train error:
#  G loss: 0.000796, cell accuracy: 99.6%, board accuracy: 58.8%
#
# test error:
#  G loss: 0.005517, cell accuracy: 97.5%, board accuracy: 9.7%
#
# Epoch 1460
# -------------------------------
# train error:
#  G loss: 0.000827, cell accuracy: 99.6%, board accuracy: 57.1%
#
# test error:
#  G loss: 0.005615, cell accuracy: 97.4%, board accuracy: 9.1%
#
# Epoch 1461
# -------------------------------
# train error:
#  G loss: 0.000794, cell accuracy: 99.6%, board accuracy: 58.7%
#
# test error:
#  G loss: 0.005486, cell accuracy: 97.5%, board accuracy: 9.9%
#
# Epoch 1462
# -------------------------------
# train error:
#  G loss: 0.000800, cell accuracy: 99.6%, board accuracy: 58.6%
#
# test error:
#  G loss: 0.005513, cell accuracy: 97.5%, board accuracy: 9.3%
#
# Epoch 1463
# -------------------------------
# train error:
#  G loss: 0.000793, cell accuracy: 99.6%, board accuracy: 58.7%
#
# test error:
#  G loss: 0.005521, cell accuracy: 97.5%, board accuracy: 9.2%
#
# Epoch 1464
# -------------------------------
# train error:
#  G loss: 0.000792, cell accuracy: 99.6%, board accuracy: 58.9%
#
# test error:
#  G loss: 0.005494, cell accuracy: 97.5%, board accuracy: 10.0%
#
# Epoch 1465
# -------------------------------
# train error:
#  G loss: 0.000795, cell accuracy: 99.6%, board accuracy: 58.6%
#
# test error:
#  G loss: 0.005512, cell accuracy: 97.5%, board accuracy: 10.0%
#
# Epoch 1466
# -------------------------------
# train error:
#  G loss: 0.000813, cell accuracy: 99.6%, board accuracy: 57.7%
#
# test error:
#  G loss: 0.005599, cell accuracy: 97.4%, board accuracy: 9.0%
#
# Epoch 1467
# -------------------------------
# train error:
#  G loss: 0.000801, cell accuracy: 99.6%, board accuracy: 58.3%
#
# test error:
#  G loss: 0.005535, cell accuracy: 97.4%, board accuracy: 9.4%
#
# Epoch 1468
# -------------------------------
# train error:
#  G loss: 0.000795, cell accuracy: 99.6%, board accuracy: 59.0%
#
# test error:
#  G loss: 0.005506, cell accuracy: 97.5%, board accuracy: 9.7%
#
# Epoch 1469
# -------------------------------
# train error:
#  G loss: 0.000792, cell accuracy: 99.6%, board accuracy: 58.8%
#
# test error:
#  G loss: 0.005491, cell accuracy: 97.5%, board accuracy: 9.4%
#
# Epoch 1470
# -------------------------------
# train error:
#  G loss: 0.000791, cell accuracy: 99.6%, board accuracy: 58.9%
#
# test error:
#  G loss: 0.005518, cell accuracy: 97.5%, board accuracy: 9.5%
#
# Epoch 1471
# -------------------------------
# train error:
#  G loss: 0.000787, cell accuracy: 99.6%, board accuracy: 59.1%
#
# test error:
#  G loss: 0.005512, cell accuracy: 97.5%, board accuracy: 9.5%
#
# Epoch 1472
# -------------------------------
# train error:
#  G loss: 0.000803, cell accuracy: 99.6%, board accuracy: 58.2%
#
# test error:
#  G loss: 0.005533, cell accuracy: 97.5%, board accuracy: 9.3%
#
# Epoch 1473
# -------------------------------
# train error:
#  G loss: 0.000793, cell accuracy: 99.6%, board accuracy: 58.7%
#
# test error:
#  G loss: 0.005488, cell accuracy: 97.5%, board accuracy: 9.5%
#
# Epoch 1474
# -------------------------------
# train error:
#  G loss: 0.000806, cell accuracy: 99.6%, board accuracy: 58.1%
#
# test error:
#  G loss: 0.005534, cell accuracy: 97.4%, board accuracy: 8.6%
#
# Epoch 1475
# -------------------------------
# train error:
#  G loss: 0.000795, cell accuracy: 99.6%, board accuracy: 58.6%
#
# test error:
#  G loss: 0.005508, cell accuracy: 97.5%, board accuracy: 9.3%
#
# Epoch 1476
# -------------------------------
# train error:
#  G loss: 0.000809, cell accuracy: 99.6%, board accuracy: 58.0%
#
# test error:
#  G loss: 0.005527, cell accuracy: 97.5%, board accuracy: 9.0%
#
# Epoch 1477
# -------------------------------
# train error:
#  G loss: 0.000798, cell accuracy: 99.6%, board accuracy: 58.3%
#
# test error:
#  G loss: 0.005522, cell accuracy: 97.5%, board accuracy: 9.4%
#
# Epoch 1478
# -------------------------------
# train error:
#  G loss: 0.000800, cell accuracy: 99.6%, board accuracy: 58.4%
#
# test error:
#  G loss: 0.005550, cell accuracy: 97.4%, board accuracy: 9.0%
#
# Epoch 1479
# -------------------------------
# train error:
#  G loss: 0.000809, cell accuracy: 99.6%, board accuracy: 57.9%
#
# test error:
#  G loss: 0.005515, cell accuracy: 97.5%, board accuracy: 9.7%
#
# Epoch 1480
# -------------------------------
# train error:
#  G loss: 0.000795, cell accuracy: 99.6%, board accuracy: 58.4%
#
# test error:
#  G loss: 0.005513, cell accuracy: 97.5%, board accuracy: 9.2%
#
# Epoch 1481
# -------------------------------
# train error:
#  G loss: 0.000797, cell accuracy: 99.6%, board accuracy: 58.6%
#
# test error:
#  G loss: 0.005521, cell accuracy: 97.5%, board accuracy: 9.7%
#
# Epoch 1482
# -------------------------------
# train error:
#  G loss: 0.000787, cell accuracy: 99.6%, board accuracy: 58.9%
#
# test error:
#  G loss: 0.005472, cell accuracy: 97.5%, board accuracy: 9.8%
#
# Epoch 1483
# -------------------------------
# train error:
#  G loss: 0.000806, cell accuracy: 99.6%, board accuracy: 57.8%
#
# test error:
#  G loss: 0.005482, cell accuracy: 97.5%, board accuracy: 9.2%
#
# Epoch 1484
# -------------------------------
# train error:
#  G loss: 0.000784, cell accuracy: 99.6%, board accuracy: 59.1%
#
# test error:
#  G loss: 0.005464, cell accuracy: 97.5%, board accuracy: 9.7%
#
# Epoch 1485
# -------------------------------
# train error:
#  G loss: 0.000790, cell accuracy: 99.6%, board accuracy: 58.9%
#
# test error:
#  G loss: 0.005544, cell accuracy: 97.5%, board accuracy: 9.6%
#
# Epoch 1486
# -------------------------------
# train error:
#  G loss: 0.000805, cell accuracy: 99.6%, board accuracy: 58.0%
#
# test error:
#  G loss: 0.005549, cell accuracy: 97.4%, board accuracy: 9.7%
#
# Epoch 1487
# -------------------------------
# train error:
#  G loss: 0.000797, cell accuracy: 99.6%, board accuracy: 58.6%
#
# test error:
#  G loss: 0.005537, cell accuracy: 97.5%, board accuracy: 9.6%
#
# Epoch 1488
# -------------------------------
# train error:
#  G loss: 0.000785, cell accuracy: 99.6%, board accuracy: 59.0%
#
# test error:
#  G loss: 0.005464, cell accuracy: 97.5%, board accuracy: 10.2%
#
# Epoch 1489
# -------------------------------
# train error:
#  G loss: 0.000786, cell accuracy: 99.6%, board accuracy: 58.8%
#
# test error:
#  G loss: 0.005452, cell accuracy: 97.5%, board accuracy: 9.8%
#
# Epoch 1490
# -------------------------------
# train error:
#  G loss: 0.000814, cell accuracy: 99.6%, board accuracy: 57.6%
#
# test error:
#  G loss: 0.005586, cell accuracy: 97.4%, board accuracy: 9.0%
#
# Epoch 1491
# -------------------------------
# train error:
#  G loss: 0.000807, cell accuracy: 99.6%, board accuracy: 58.0%
#
# test error:
#  G loss: 0.005545, cell accuracy: 97.4%, board accuracy: 9.5%
#
# Epoch 1492
# -------------------------------
# train error:
#  G loss: 0.000786, cell accuracy: 99.6%, board accuracy: 58.9%
#
# test error:
#  G loss: 0.005488, cell accuracy: 97.5%, board accuracy: 9.7%
#
# Epoch 1493
# -------------------------------
# train error:
#  G loss: 0.000796, cell accuracy: 99.6%, board accuracy: 58.6%
#
# test error:
#  G loss: 0.005511, cell accuracy: 97.5%, board accuracy: 9.4%
#
# Epoch 1494
# -------------------------------
# train error:
#  G loss: 0.000793, cell accuracy: 99.6%, board accuracy: 58.4%
#
# test error:
#  G loss: 0.005518, cell accuracy: 97.5%, board accuracy: 9.2%
#
# Epoch 1495
# -------------------------------
# train error:
#  G loss: 0.000794, cell accuracy: 99.6%, board accuracy: 58.4%
#
# test error:
#  G loss: 0.005540, cell accuracy: 97.4%, board accuracy: 8.9%
#
# Epoch 1496
# -------------------------------
# train error:
#  G loss: 0.000795, cell accuracy: 99.6%, board accuracy: 58.7%
#
# test error:
#  G loss: 0.005499, cell accuracy: 97.5%, board accuracy: 9.6%
#
# Epoch 1497
# -------------------------------
# train error:
#  G loss: 0.000799, cell accuracy: 99.6%, board accuracy: 58.1%
#
# test error:
#  G loss: 0.005538, cell accuracy: 97.4%, board accuracy: 9.8%
#
# Epoch 1498
# -------------------------------
# train error:
#  G loss: 0.000796, cell accuracy: 99.6%, board accuracy: 58.4%
#
# test error:
#  G loss: 0.005527, cell accuracy: 97.5%, board accuracy: 9.9%
#
# Epoch 1499
# -------------------------------
# train error:
#  G loss: 0.000781, cell accuracy: 99.6%, board accuracy: 59.1%
#
# test error:
#  G loss: 0.005487, cell accuracy: 97.5%, board accuracy: 9.3%
#
# Done!

# %%
cell_accuracies_train = compute_metric_by_event(metrics.CellAccuracy, train_dataloader)
cell_accuracies_test = compute_metric_by_event(metrics.CellAccuracy, test_dataloader)
board_accuracies_train = compute_metric_by_event(metrics.BoardAccuracy, train_dataloader)
board_accuracies_test = compute_metric_by_event(metrics.BoardAccuracy, test_dataloader)

for event_type in range(NUM_EVENT_TYPES):
    print(f"Stats for event type '{EVENT_NAMES[event_type]}':")
    print(f"  Cell accuracy (train): {cell_accuracies_train[event_type]:.2%}")
    print(f"  Cell accuracy (test): {cell_accuracies_test[event_type]:.2%}")
    print(f"  Board accuracy (train): {board_accuracies_train[event_type]:.2%}")
    print(f"  Board accuracy (test): {board_accuracies_test[event_type]:.2%}")
    print()
# Out:
# Stats for event type 'Drop':
#   Cell accuracy (train): 99.74%
#   Cell accuracy (test): 97.36%
#   Board accuracy (train): 65.98%
#   Board accuracy (test): 8.01%
#
# Stats for event type 'Left':
#   Cell accuracy (train): 99.70%
#   Cell accuracy (test): 97.88%
#   Board accuracy (train): 62.89%
#   Board accuracy (test): 14.37%
#
# Stats for event type 'Right':
#   Cell accuracy (train): 99.71%
#   Cell accuracy (test): 98.03%
#   Board accuracy (train): 63.71%
#   Board accuracy (test): 16.04%
#
# Stats for event type 'Rotate':
#   Cell accuracy (train): 99.48%
#   Cell accuracy (test): 97.50%
#   Board accuracy (train): 40.34%
#   Board accuracy (test): 4.42%
#
# Stats for event type 'Insta-drop':
#   Cell accuracy (train): 99.12%
#   Cell accuracy (test): 96.16%
#   Board accuracy (train): 26.61%
#   Board accuracy (test): 0.00%

# %%
def show_prediction(example):
    (b, e), y = example
    pred = gen(b.to(device).unsqueeze(0), e.to(device).unsqueeze(0)).squeeze(0).cpu()
    b, e, y, pred = b.argmax(0), e.argmax(0), y.argmax(0), pred.argmax(0)

    fig, axs = plt.subplots(1, 3)
    fig.suptitle(f"Prediction vs reality\nEvent = {EVENT_NAMES[e]}")

    for ax in axs:
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

    axs[0].set_title("Input")
    axs[1].set_title("Predicted")
    axs[2].set_title("Reality")

    num_mistakes = (y != pred).type(torch.int).sum().item()
    print(f"Mistakes: {num_mistakes}")
    axs[0].imshow(render_board(b).transpose((1, 2, 0)), vmin=0, vmax=1)
    axs[1].imshow(render_board(pred).transpose((1, 2, 0)), vmin=0, vmax=1)
    axs[2].imshow(render_board(y).transpose((1, 2, 0)), vmin=0, vmax=1)

    plt.show()

# %%
# Show a random training prediction vs reality
import random

idx = random.randrange(len(train_dataset))
print(f"Showing prediction for training example {idx}")
show_prediction(train_dataset[idx])
# Out:
# Showing prediction for training example 5476
# Mistakes: 0

# %%
torch.save(gen.state_dict(), "gamegan_emulator.pth")
