# %% [markdown]
# # Train generator with reconstruction loss
#
# In this notebook, we train the generator without a discriminator. We just take the MSE loss between the predicted next frame and actual next frame.

# %%
import os
from pathlib import Path
import shutil
import datetime

import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.utils.data import Dataset
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt


import models
import metrics
from recording import FileBasedDatabase
from engines import EVENT_NAMES

# %%
NUM_CELL_TYPES = 8
NUM_EVENT_TYPES = 5

class RecordingDataset(Dataset):
    def __init__(self, path: str):
        self._db = FileBasedDatabase(path)

    def __len__(self):
        return len(self._db)

    def __getitem__(self, idx):
        boards, events = self._db[idx]
        b = self._transform_board(boards[-2]) # Ignore all boards except the last two
        e = self._transform_event(events[-1])
        x = (b, e)
        y = self._transform_board(boards[-1])
        return x, y
    
    def _transform_board(self, board):
        board = torch.tensor(board, dtype=torch.long)
        board = F.one_hot(board, NUM_CELL_TYPES) # One-hot encode the cell types
        board = board.type(torch.float) # Convert to floating-point
        board = board.permute((2, 0, 1)) # Move channels/classes to dimension 0
        return board
    
    def _transform_event(self, event):
        event = torch.tensor(event, dtype=torch.long)
        event = F.one_hot(event, NUM_EVENT_TYPES) # One-hot encode the event
        event = event.type(torch.float) # Convert to floating-point
        return event

# %%
# Put datasets in memory for faster training
train_dataset = list(RecordingDataset(os.path.join("data", "tetris_emulator", "train")))
test_dataset = list(RecordingDataset(os.path.join("data", "tetris_emulator", "test")))
batch_size = 12
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

(b, e), y = next(iter(train_dataloader))
print(f"x: shape {b.shape}, dtype {b.dtype}")
print(f"e: shape {e.shape}, dtype {e.dtype}")
print(f"y: shape {y.shape}, dtype {y.dtype}")
# Out:
# x: shape torch.Size([12, 8, 22, 10]), dtype torch.float32
# e: shape torch.Size([12, 5]), dtype torch.float32
# y: shape torch.Size([12, 8, 22, 10]), dtype torch.float32

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Using device {device}")
# Out:
# Using device cuda

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def compute_metric_by_event(metric_cls, dataloader):
    metrics = [metric_cls() for _ in range(NUM_EVENT_TYPES)]

    with torch.no_grad():        
        for ((b, e), y) in dataloader:
            b = b.to(device)
            e = e.to(device)
            y = y.to(device)

            batch_size = b.size(0)

            y_fake = gen(b, e)
            
            classes_b = torch.argmax(b, dim=1)
            classes_e = torch.argmax(e, dim=1)
            classes_y = torch.argmax(y, dim=1)
            classes_y_fake = torch.argmax(y_fake, dim=1)

            for idx in range(batch_size):
                class_e = classes_e[idx]
                metric = metrics[class_e]
                metric.update_state(classes_x=classes_b[idx:idx+1], classes_y_pred=classes_y_fake[idx:idx+1], classes_y=classes_y[idx:idx+1])

    return [metric.result() for metric in metrics]

# %%
import itertools

from engines import EventTypes
from tetris import CELL_COLORS

def render_board(board):
    height, width = board.shape
    img = np.zeros((3, height, width))
    for row in range(height):
        for col in range(width):
            img[:, row, col] = CELL_COLORS[board[row, col]]
    img /= 255.0
    return img

real_label = 1.0
fake_label = 0.0

def train_loop(dataloader, gen, loss_fn, optimizer_gen):
    gen.train()

    size = len(dataloader.dataset)
    for batch, ((b, e), y) in enumerate(dataloader):
        batch_size = b.size(0)

        b = b.to(device)
        e = e.to(device)
        y = y.to(device)

        gen.zero_grad()

        y_fake = gen(b, e)
        err_dyn = loss_fn(y_fake, y)
        err_dyn.backward()

        optimizer_gen.step()


def test_loop(split_name, dataloader, gen, loss_fn, tb_writer, epoch):
    gen.eval()

    loss_gen = 0.0
    cell_accuracy = metrics.CellAccuracy()
    board_accuracy = metrics.BoardAccuracy()
    spawn_recall = metrics.SpawnRecall()

    num_batches = len(dataloader)
    with torch.no_grad():        
        for batch, ((b, e), y) in enumerate(dataloader):
            batch_size = b.size(0)

            b = b.to(device)
            e = e.to(device)
            y = y.to(device)

            y_fake = gen(b, e)
        
            loss_gen += loss_fn(y_fake, y).item()

            classes_b = torch.argmax(b, dim=1)
            classes_e = torch.argmax(e, dim=1)
            classes_y = torch.argmax(y, dim=1)
            classes_y_fake = torch.argmax(y_fake, dim=1)
            cell_accuracy.update_state(classes_y_fake, classes_y)
            board_accuracy.update_state(classes_y_fake, classes_y)

            spawn_recall.update_state(classes_b, classes_y_fake, classes_y)

    loss_gen /= num_batches

    print(f"{split_name} error: \n G loss: {loss_gen:>8f}, cell accuracy: {(cell_accuracy.result()):>0.1%}, board accuracy: {(board_accuracy.result()):>0.1%} \n")

    tb_writer.add_scalar(f"Loss/{split_name}", loss_gen, epoch)
    tb_writer.add_scalar(f"Cell accuracy/{split_name}", cell_accuracy.result(), epoch)
    tb_writer.add_scalar(f"Board accuracy/{split_name}", board_accuracy.result(), epoch)
    tb_writer.add_scalar(f"Spawn recall/{split_name}", spawn_recall.result(), epoch)
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.10.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def train(run_name, gen_factory, epochs):

    learning_rate = 1e-4

    gen = gen_factory()

    loss_fn = nn.MSELoss()
    optimizer_gen = torch.optim.Adam(gen.parameters(), lr=learning_rate)

    log_dir = os.path.join("runs", "gen_with_rec_loss")
    log_subdir = os.path.join(log_dir, run_name + "_" + datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S"))
    tb_writer = SummaryWriter(log_subdir)

    try:
        for epoch in range(epochs):
            print(f"Epoch {epoch}\n-------------------------------")
            train_loop(train_dataloader, gen, loss_fn, optimizer_gen)
            test_loop("train", train_dataloader, gen, loss_fn, tb_writer, epoch)
            test_loop("test", test_dataloader, gen, loss_fn, tb_writer, epoch)
            gen_zero_grads = 0
            for name, weight in gen.named_parameters():
                tb_writer.add_histogram(f"Weights/{name}", weight, epoch)
                if weight.grad is not None:
                    tb_writer.add_histogram(f"Gradients/{name}", weight.grad, epoch)
                    gen_zero_grads += weight.grad.numel() - weight.grad.count_nonzero().item()
            tb_writer.add_scalar(f"Zero gradients", gen_zero_grads, epoch)
    finally:
        tb_writer.close()
        
    print("Done!")
    return gen

# %%
NUM_RANDOM_INPUTS = 4


from models import Conv2dLeakyReLU, ConvTranspose2dLeakyReLU, LinearLeakyReLU


class GameganGenerator(nn.Module):
    def __init__(self, leak=0.0):
        super().__init__()

        self.leak = leak

        self.board_encoder = models.GameganBoardEncoder()

        self.event_embedding = LinearLeakyReLU(NUM_EVENT_TYPES, 256, negative_slope=leak)
        self.random_embedding = LinearLeakyReLU(NUM_RANDOM_INPUTS, 256, negative_slope=leak)

        self.random_event_encoder = nn.Sequential(
            LinearLeakyReLU(512, 256, negative_slope=leak),
            nn.Linear(256, 256)
        )

        self.dynamics = nn.Sequential(
            LinearLeakyReLU(512, 256, negative_slope=leak),
            LinearLeakyReLU(256, 256, negative_slope=leak),
        )

        self.renderer = models.GameganRenderer()

    def forward(self, b, e):
        batch_size, cell_channels, height, width = b.shape

        # Encode board state
        s = self.board_encoder(b)

        # Embed events
        e = self.event_embedding(e)

        # Generate and embed random inputs
        z = torch.rand(batch_size, NUM_RANDOM_INPUTS, device=device)
        z = self.random_embedding(z)

        # Encode events and random inputs
        v = self.random_event_encoder(torch.cat((e, z), dim=1))

        # Apply game dynamics
        h = torch.cat((s, v), dim=1)
        h = self.dynamics(h)

        # Render new board
        y = self.renderer(h)
        return y


print(f"Parameters: {count_parameters(GameganGenerator())}")
# Out:
# Parameters: 779336

# %%
gen = train(
    run_name="run",
    gen_factory=lambda: GameganGenerator(leak=0.2).to(device),
    epochs=1500
)
# Out:
# Epoch 0
# -------------------------------
# train error:
#  G loss: 0.026288, cell accuracy: 85.6%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.026400, cell accuracy: 85.5%, board accuracy: 0.0%
#
# Epoch 1
# -------------------------------
# train error:
#  G loss: 0.016257, cell accuracy: 91.5%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.016472, cell accuracy: 91.4%, board accuracy: 0.0%
#
# Epoch 2
# -------------------------------
# train error:
#  G loss: 0.012636, cell accuracy: 93.6%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.012913, cell accuracy: 93.4%, board accuracy: 0.0%
#
# Epoch 3
# -------------------------------
# train error:
#  G loss: 0.010473, cell accuracy: 94.7%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.010790, cell accuracy: 94.5%, board accuracy: 0.0%
#
# Epoch 4
# -------------------------------
# train error:
#  G loss: 0.008909, cell accuracy: 95.6%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.009261, cell accuracy: 95.4%, board accuracy: 0.0%
#
# Epoch 5
# -------------------------------
# train error:
#  G loss: 0.007878, cell accuracy: 96.1%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.008240, cell accuracy: 96.0%, board accuracy: 0.1%
#
# Epoch 6
# -------------------------------
# train error:
#  G loss: 0.007137, cell accuracy: 96.5%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.007537, cell accuracy: 96.3%, board accuracy: 0.0%
#
# Epoch 7
# -------------------------------
# train error:
#  G loss: 0.006591, cell accuracy: 96.8%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.006994, cell accuracy: 96.6%, board accuracy: 0.0%
#
# Epoch 8
# -------------------------------
# train error:
#  G loss: 0.006050, cell accuracy: 97.0%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.006515, cell accuracy: 96.8%, board accuracy: 0.0%
#
# Epoch 9
# -------------------------------
# train error:
#  G loss: 0.005696, cell accuracy: 97.1%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.006148, cell accuracy: 96.9%, board accuracy: 0.1%
#
# Epoch 10
# -------------------------------
# train error:
#  G loss: 0.005402, cell accuracy: 97.3%, board accuracy: 0.3%
#
# test error:
#  G loss: 0.005869, cell accuracy: 97.1%, board accuracy: 0.1%
#
# Epoch 11
# -------------------------------
# train error:
#  G loss: 0.005162, cell accuracy: 97.4%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.005635, cell accuracy: 97.2%, board accuracy: 0.1%
#
# Epoch 12
# -------------------------------
# train error:
#  G loss: 0.004922, cell accuracy: 97.5%, board accuracy: 0.5%
#
# test error:
#  G loss: 0.005425, cell accuracy: 97.3%, board accuracy: 0.1%
#
# Epoch 13
# -------------------------------
# train error:
#  G loss: 0.004767, cell accuracy: 97.6%, board accuracy: 0.7%
#
# test error:
#  G loss: 0.005280, cell accuracy: 97.3%, board accuracy: 0.2%
#
# Epoch 14
# -------------------------------
# train error:
#  G loss: 0.004544, cell accuracy: 97.7%, board accuracy: 1.2%
#
# test error:
#  G loss: 0.005081, cell accuracy: 97.4%, board accuracy: 0.5%
#
# Epoch 15
# -------------------------------
# train error:
#  G loss: 0.004406, cell accuracy: 97.8%, board accuracy: 1.6%
#
# test error:
#  G loss: 0.004961, cell accuracy: 97.5%, board accuracy: 0.8%
#
# Epoch 16
# -------------------------------
# train error:
#  G loss: 0.004251, cell accuracy: 97.8%, board accuracy: 1.8%
#
# test error:
#  G loss: 0.004832, cell accuracy: 97.6%, board accuracy: 0.8%
#
# Epoch 17
# -------------------------------
# train error:
#  G loss: 0.004109, cell accuracy: 97.9%, board accuracy: 2.1%
#
# test error:
#  G loss: 0.004730, cell accuracy: 97.6%, board accuracy: 0.9%
#
# Epoch 18
# -------------------------------
# train error:
#  G loss: 0.004000, cell accuracy: 98.0%, board accuracy: 2.6%
#
# test error:
#  G loss: 0.004624, cell accuracy: 97.7%, board accuracy: 1.5%
#
# Epoch 19
# -------------------------------
# train error:
#  G loss: 0.003923, cell accuracy: 98.0%, board accuracy: 2.9%
#
# test error:
#  G loss: 0.004589, cell accuracy: 97.7%, board accuracy: 1.7%
#
# Epoch 20
# -------------------------------
# train error:
#  G loss: 0.003828, cell accuracy: 98.1%, board accuracy: 3.2%
#
# test error:
#  G loss: 0.004520, cell accuracy: 97.7%, board accuracy: 1.9%
#
# Epoch 21
# -------------------------------
# train error:
#  G loss: 0.003664, cell accuracy: 98.2%, board accuracy: 4.2%
#
# test error:
#  G loss: 0.004370, cell accuracy: 97.8%, board accuracy: 2.5%
#
# Epoch 22
# -------------------------------
# train error:
#  G loss: 0.003440, cell accuracy: 98.3%, board accuracy: 6.0%
#
# test error:
#  G loss: 0.004172, cell accuracy: 97.9%, board accuracy: 3.4%
#
# Epoch 23
# -------------------------------
# train error:
#  G loss: 0.003405, cell accuracy: 98.3%, board accuracy: 5.6%
#
# test error:
#  G loss: 0.004184, cell accuracy: 97.9%, board accuracy: 3.4%
#
# Epoch 24
# -------------------------------
# train error:
#  G loss: 0.003327, cell accuracy: 98.3%, board accuracy: 7.0%
#
# test error:
#  G loss: 0.004105, cell accuracy: 98.0%, board accuracy: 4.1%
#
# Epoch 25
# -------------------------------
# train error:
#  G loss: 0.003157, cell accuracy: 98.4%, board accuracy: 8.5%
#
# test error:
#  G loss: 0.003965, cell accuracy: 98.0%, board accuracy: 5.0%
#
# Epoch 26
# -------------------------------
# train error:
#  G loss: 0.003115, cell accuracy: 98.4%, board accuracy: 8.7%
#
# test error:
#  G loss: 0.003954, cell accuracy: 98.0%, board accuracy: 5.5%
#
# Epoch 27
# -------------------------------
# train error:
#  G loss: 0.002933, cell accuracy: 98.6%, board accuracy: 10.3%
#
# test error:
#  G loss: 0.003777, cell accuracy: 98.1%, board accuracy: 6.4%
#
# Epoch 28
# -------------------------------
# train error:
#  G loss: 0.002911, cell accuracy: 98.6%, board accuracy: 10.7%
#
# test error:
#  G loss: 0.003766, cell accuracy: 98.1%, board accuracy: 6.6%
#
# Epoch 29
# -------------------------------
# train error:
#  G loss: 0.002786, cell accuracy: 98.6%, board accuracy: 12.3%
#
# test error:
#  G loss: 0.003686, cell accuracy: 98.2%, board accuracy: 7.5%
#
# Epoch 30
# -------------------------------
# train error:
#  G loss: 0.002717, cell accuracy: 98.7%, board accuracy: 13.7%
#
# test error:
#  G loss: 0.003643, cell accuracy: 98.2%, board accuracy: 8.2%
#
# Epoch 31
# -------------------------------
# train error:
#  G loss: 0.002632, cell accuracy: 98.7%, board accuracy: 14.5%
#
# test error:
#  G loss: 0.003576, cell accuracy: 98.2%, board accuracy: 9.0%
#
# Epoch 32
# -------------------------------
# train error:
#  G loss: 0.002588, cell accuracy: 98.7%, board accuracy: 15.3%
#
# test error:
#  G loss: 0.003579, cell accuracy: 98.2%, board accuracy: 9.0%
#
# Epoch 33
# -------------------------------
# train error:
#  G loss: 0.002483, cell accuracy: 98.8%, board accuracy: 17.1%
#
# test error:
#  G loss: 0.003462, cell accuracy: 98.3%, board accuracy: 9.9%
#
# Epoch 34
# -------------------------------
# train error:
#  G loss: 0.002423, cell accuracy: 98.8%, board accuracy: 17.2%
#
# test error:
#  G loss: 0.003407, cell accuracy: 98.3%, board accuracy: 9.8%
#
# Epoch 35
# -------------------------------
# train error:
#  G loss: 0.002362, cell accuracy: 98.8%, board accuracy: 18.1%
#
# test error:
#  G loss: 0.003388, cell accuracy: 98.3%, board accuracy: 10.3%
#
# Epoch 36
# -------------------------------
# train error:
#  G loss: 0.002347, cell accuracy: 98.8%, board accuracy: 17.9%
#
# test error:
#  G loss: 0.003399, cell accuracy: 98.3%, board accuracy: 10.0%
#
# Epoch 37
# -------------------------------
# train error:
#  G loss: 0.002253, cell accuracy: 98.9%, board accuracy: 20.8%
#
# test error:
#  G loss: 0.003310, cell accuracy: 98.3%, board accuracy: 11.9%
#
# Epoch 38
# -------------------------------
# train error:
#  G loss: 0.002232, cell accuracy: 98.9%, board accuracy: 20.5%
#
# test error:
#  G loss: 0.003305, cell accuracy: 98.3%, board accuracy: 11.8%
#
# Epoch 39
# -------------------------------
# train error:
#  G loss: 0.002207, cell accuracy: 98.9%, board accuracy: 20.5%
#
# test error:
#  G loss: 0.003310, cell accuracy: 98.3%, board accuracy: 11.4%
#
# Epoch 40
# -------------------------------
# train error:
#  G loss: 0.002124, cell accuracy: 99.0%, board accuracy: 23.0%
#
# test error:
#  G loss: 0.003261, cell accuracy: 98.4%, board accuracy: 13.0%
#
# Epoch 41
# -------------------------------
# train error:
#  G loss: 0.002044, cell accuracy: 99.0%, board accuracy: 24.7%
#
# test error:
#  G loss: 0.003196, cell accuracy: 98.4%, board accuracy: 12.7%
#
# Epoch 42
# -------------------------------
# train error:
#  G loss: 0.002048, cell accuracy: 99.0%, board accuracy: 24.7%
#
# test error:
#  G loss: 0.003229, cell accuracy: 98.4%, board accuracy: 13.2%
#
# Epoch 43
# -------------------------------
# train error:
#  G loss: 0.002022, cell accuracy: 99.0%, board accuracy: 24.4%
#
# test error:
#  G loss: 0.003179, cell accuracy: 98.4%, board accuracy: 13.5%
#
# Epoch 44
# -------------------------------
# train error:
#  G loss: 0.001996, cell accuracy: 99.0%, board accuracy: 25.6%
#
# test error:
#  G loss: 0.003194, cell accuracy: 98.4%, board accuracy: 13.4%
#
# Epoch 45
# -------------------------------
# train error:
#  G loss: 0.001899, cell accuracy: 99.1%, board accuracy: 28.0%
#
# test error:
#  G loss: 0.003097, cell accuracy: 98.4%, board accuracy: 14.5%
#
# Epoch 46
# -------------------------------
# train error:
#  G loss: 0.001881, cell accuracy: 99.1%, board accuracy: 28.0%
#
# test error:
#  G loss: 0.003092, cell accuracy: 98.4%, board accuracy: 15.0%
#
# Epoch 47
# -------------------------------
# train error:
#  G loss: 0.001816, cell accuracy: 99.1%, board accuracy: 28.9%
#
# test error:
#  G loss: 0.003059, cell accuracy: 98.5%, board accuracy: 15.1%
#
# Epoch 48
# -------------------------------
# train error:
#  G loss: 0.001797, cell accuracy: 99.1%, board accuracy: 30.3%
#
# test error:
#  G loss: 0.003047, cell accuracy: 98.5%, board accuracy: 16.0%
#
# Epoch 49
# -------------------------------
# train error:
#  G loss: 0.001749, cell accuracy: 99.2%, board accuracy: 31.5%
#
# test error:
#  G loss: 0.003000, cell accuracy: 98.5%, board accuracy: 16.6%
#
# Epoch 50
# -------------------------------
# train error:
#  G loss: 0.001747, cell accuracy: 99.2%, board accuracy: 30.7%
#
# test error:
#  G loss: 0.003026, cell accuracy: 98.5%, board accuracy: 15.4%
#
# Epoch 51
# -------------------------------
# train error:
#  G loss: 0.001738, cell accuracy: 99.2%, board accuracy: 31.4%
#
# test error:
#  G loss: 0.003034, cell accuracy: 98.5%, board accuracy: 16.9%
#
# Epoch 52
# -------------------------------
# train error:
#  G loss: 0.001665, cell accuracy: 99.2%, board accuracy: 32.8%
#
# test error:
#  G loss: 0.002991, cell accuracy: 98.5%, board accuracy: 17.0%
#
# Epoch 53
# -------------------------------
# train error:
#  G loss: 0.001636, cell accuracy: 99.2%, board accuracy: 33.0%
#
# test error:
#  G loss: 0.002964, cell accuracy: 98.5%, board accuracy: 17.2%
#
# Epoch 54
# -------------------------------
# train error:
#  G loss: 0.001615, cell accuracy: 99.2%, board accuracy: 34.1%
#
# test error:
#  G loss: 0.002951, cell accuracy: 98.5%, board accuracy: 18.1%
#
# Epoch 55
# -------------------------------
# train error:
#  G loss: 0.001576, cell accuracy: 99.3%, board accuracy: 35.6%
#
# test error:
#  G loss: 0.002925, cell accuracy: 98.5%, board accuracy: 18.1%
#
# Epoch 56
# -------------------------------
# train error:
#  G loss: 0.001535, cell accuracy: 99.3%, board accuracy: 36.4%
#
# test error:
#  G loss: 0.002878, cell accuracy: 98.6%, board accuracy: 18.6%
#
# Epoch 57
# -------------------------------
# train error:
#  G loss: 0.001538, cell accuracy: 99.3%, board accuracy: 35.7%
#
# test error:
#  G loss: 0.002898, cell accuracy: 98.6%, board accuracy: 19.0%
#
# Epoch 58
# -------------------------------
# train error:
#  G loss: 0.001505, cell accuracy: 99.3%, board accuracy: 37.1%
#
# test error:
#  G loss: 0.002886, cell accuracy: 98.6%, board accuracy: 18.3%
#
# Epoch 59
# -------------------------------
# train error:
#  G loss: 0.001494, cell accuracy: 99.3%, board accuracy: 36.9%
#
# test error:
#  G loss: 0.002904, cell accuracy: 98.5%, board accuracy: 19.4%
#
# Epoch 60
# -------------------------------
# train error:
#  G loss: 0.001465, cell accuracy: 99.3%, board accuracy: 38.0%
#
# test error:
#  G loss: 0.002913, cell accuracy: 98.5%, board accuracy: 19.5%
#
# Epoch 61
# -------------------------------
# train error:
#  G loss: 0.001409, cell accuracy: 99.4%, board accuracy: 40.0%
#
# test error:
#  G loss: 0.002850, cell accuracy: 98.6%, board accuracy: 19.4%
#
# Epoch 62
# -------------------------------
# train error:
#  G loss: 0.001388, cell accuracy: 99.4%, board accuracy: 39.6%
#
# test error:
#  G loss: 0.002834, cell accuracy: 98.6%, board accuracy: 19.0%
#
# Epoch 63
# -------------------------------
# train error:
#  G loss: 0.001425, cell accuracy: 99.3%, board accuracy: 38.8%
#
# test error:
#  G loss: 0.002890, cell accuracy: 98.6%, board accuracy: 19.0%
#
# Epoch 64
# -------------------------------
# train error:
#  G loss: 0.001405, cell accuracy: 99.3%, board accuracy: 39.0%
#
# test error:
#  G loss: 0.002867, cell accuracy: 98.6%, board accuracy: 20.1%
#
# Epoch 65
# -------------------------------
# train error:
#  G loss: 0.001328, cell accuracy: 99.4%, board accuracy: 42.6%
#
# test error:
#  G loss: 0.002808, cell accuracy: 98.6%, board accuracy: 20.5%
#
# Epoch 66
# -------------------------------
# train error:
#  G loss: 0.001301, cell accuracy: 99.4%, board accuracy: 42.5%
#
# test error:
#  G loss: 0.002789, cell accuracy: 98.6%, board accuracy: 20.9%
#
# Epoch 67
# -------------------------------
# train error:
#  G loss: 0.001333, cell accuracy: 99.4%, board accuracy: 42.2%
#
# test error:
#  G loss: 0.002813, cell accuracy: 98.6%, board accuracy: 21.0%
#
# Epoch 68
# -------------------------------
# train error:
#  G loss: 0.001261, cell accuracy: 99.4%, board accuracy: 43.6%
#
# test error:
#  G loss: 0.002779, cell accuracy: 98.6%, board accuracy: 21.0%
#
# Epoch 69
# -------------------------------
# train error:
#  G loss: 0.001225, cell accuracy: 99.4%, board accuracy: 45.0%
#
# test error:
#  G loss: 0.002780, cell accuracy: 98.6%, board accuracy: 21.3%
#
# Epoch 70
# -------------------------------
# train error:
#  G loss: 0.001237, cell accuracy: 99.4%, board accuracy: 43.6%
#
# test error:
#  G loss: 0.002776, cell accuracy: 98.6%, board accuracy: 21.2%
#
# Epoch 71
# -------------------------------
# train error:
#  G loss: 0.001169, cell accuracy: 99.5%, board accuracy: 46.7%
#
# test error:
#  G loss: 0.002715, cell accuracy: 98.7%, board accuracy: 22.6%
#
# Epoch 72
# -------------------------------
# train error:
#  G loss: 0.001219, cell accuracy: 99.4%, board accuracy: 44.6%
#
# test error:
#  G loss: 0.002790, cell accuracy: 98.6%, board accuracy: 22.0%
#
# Epoch 73
# -------------------------------
# train error:
#  G loss: 0.001180, cell accuracy: 99.5%, board accuracy: 46.3%
#
# test error:
#  G loss: 0.002759, cell accuracy: 98.6%, board accuracy: 22.9%
#
# Epoch 74
# -------------------------------
# train error:
#  G loss: 0.001144, cell accuracy: 99.5%, board accuracy: 47.3%
#
# test error:
#  G loss: 0.002735, cell accuracy: 98.7%, board accuracy: 22.8%
#
# Epoch 75
# -------------------------------
# train error:
#  G loss: 0.001161, cell accuracy: 99.5%, board accuracy: 45.8%
#
# test error:
#  G loss: 0.002745, cell accuracy: 98.6%, board accuracy: 22.2%
#
# Epoch 76
# -------------------------------
# train error:
#  G loss: 0.001177, cell accuracy: 99.5%, board accuracy: 46.0%
#
# test error:
#  G loss: 0.002773, cell accuracy: 98.6%, board accuracy: 22.0%
#
# Epoch 77
# -------------------------------
# train error:
#  G loss: 0.001142, cell accuracy: 99.5%, board accuracy: 47.4%
#
# test error:
#  G loss: 0.002743, cell accuracy: 98.6%, board accuracy: 22.1%
#
# Epoch 78
# -------------------------------
# train error:
#  G loss: 0.001112, cell accuracy: 99.5%, board accuracy: 47.5%
#
# test error:
#  G loss: 0.002705, cell accuracy: 98.7%, board accuracy: 23.5%
#
# Epoch 79
# -------------------------------
# train error:
#  G loss: 0.001068, cell accuracy: 99.5%, board accuracy: 49.8%
#
# test error:
#  G loss: 0.002712, cell accuracy: 98.7%, board accuracy: 23.3%
#
# Epoch 80
# -------------------------------
# train error:
#  G loss: 0.001049, cell accuracy: 99.5%, board accuracy: 50.2%
#
# test error:
#  G loss: 0.002690, cell accuracy: 98.7%, board accuracy: 23.8%
#
# Epoch 81
# -------------------------------
# train error:
#  G loss: 0.001028, cell accuracy: 99.5%, board accuracy: 51.1%
#
# test error:
#  G loss: 0.002684, cell accuracy: 98.7%, board accuracy: 24.0%
#
# Epoch 82
# -------------------------------
# train error:
#  G loss: 0.001048, cell accuracy: 99.5%, board accuracy: 50.4%
#
# test error:
#  G loss: 0.002702, cell accuracy: 98.7%, board accuracy: 24.1%
#
# Epoch 83
# -------------------------------
# train error:
#  G loss: 0.001046, cell accuracy: 99.5%, board accuracy: 50.3%
#
# test error:
#  G loss: 0.002674, cell accuracy: 98.7%, board accuracy: 24.1%
#
# Epoch 84
# -------------------------------
# train error:
#  G loss: 0.001006, cell accuracy: 99.5%, board accuracy: 51.9%
#
# test error:
#  G loss: 0.002667, cell accuracy: 98.7%, board accuracy: 24.6%
#
# Epoch 85
# -------------------------------
# train error:
#  G loss: 0.001021, cell accuracy: 99.5%, board accuracy: 50.9%
#
# test error:
#  G loss: 0.002687, cell accuracy: 98.7%, board accuracy: 23.4%
#
# Epoch 86
# -------------------------------
# train error:
#  G loss: 0.001002, cell accuracy: 99.5%, board accuracy: 51.6%
#
# test error:
#  G loss: 0.002673, cell accuracy: 98.7%, board accuracy: 23.8%
#
# Epoch 87
# -------------------------------
# train error:
#  G loss: 0.000990, cell accuracy: 99.6%, board accuracy: 52.1%
#
# test error:
#  G loss: 0.002657, cell accuracy: 98.7%, board accuracy: 24.1%
#
# Epoch 88
# -------------------------------
# train error:
#  G loss: 0.001012, cell accuracy: 99.5%, board accuracy: 50.1%
#
# test error:
#  G loss: 0.002730, cell accuracy: 98.7%, board accuracy: 22.8%
#
# Epoch 89
# -------------------------------
# train error:
#  G loss: 0.000954, cell accuracy: 99.6%, board accuracy: 53.1%
#
# test error:
#  G loss: 0.002662, cell accuracy: 98.7%, board accuracy: 25.0%
#
# Epoch 90
# -------------------------------
# train error:
#  G loss: 0.000911, cell accuracy: 99.6%, board accuracy: 55.1%
#
# test error:
#  G loss: 0.002604, cell accuracy: 98.7%, board accuracy: 25.7%
#
# Epoch 91
# -------------------------------
# train error:
#  G loss: 0.000907, cell accuracy: 99.6%, board accuracy: 55.3%
#
# test error:
#  G loss: 0.002643, cell accuracy: 98.7%, board accuracy: 26.1%
#
# Epoch 92
# -------------------------------
# train error:
#  G loss: 0.000973, cell accuracy: 99.6%, board accuracy: 52.1%
#
# test error:
#  G loss: 0.002679, cell accuracy: 98.7%, board accuracy: 24.1%
#
# Epoch 93
# -------------------------------
# train error:
#  G loss: 0.000908, cell accuracy: 99.6%, board accuracy: 54.3%
#
# test error:
#  G loss: 0.002652, cell accuracy: 98.7%, board accuracy: 24.3%
#
# Epoch 94
# -------------------------------
# train error:
#  G loss: 0.000884, cell accuracy: 99.6%, board accuracy: 56.0%
#
# test error:
#  G loss: 0.002595, cell accuracy: 98.7%, board accuracy: 26.3%
#
# Epoch 95
# -------------------------------
# train error:
#  G loss: 0.000952, cell accuracy: 99.6%, board accuracy: 52.9%
#
# test error:
#  G loss: 0.002671, cell accuracy: 98.7%, board accuracy: 24.9%
#
# Epoch 96
# -------------------------------
# train error:
#  G loss: 0.000894, cell accuracy: 99.6%, board accuracy: 54.3%
#
# test error:
#  G loss: 0.002623, cell accuracy: 98.7%, board accuracy: 25.2%
#
# Epoch 97
# -------------------------------
# train error:
#  G loss: 0.000853, cell accuracy: 99.6%, board accuracy: 57.3%
#
# test error:
#  G loss: 0.002591, cell accuracy: 98.7%, board accuracy: 26.2%
#
# Epoch 98
# -------------------------------
# train error:
#  G loss: 0.000832, cell accuracy: 99.6%, board accuracy: 58.1%
#
# test error:
#  G loss: 0.002574, cell accuracy: 98.7%, board accuracy: 27.3%
#
# Epoch 99
# -------------------------------
# train error:
#  G loss: 0.000871, cell accuracy: 99.6%, board accuracy: 56.0%
#
# test error:
#  G loss: 0.002620, cell accuracy: 98.7%, board accuracy: 25.8%
#
# Epoch 100
# -------------------------------
# train error:
#  G loss: 0.000855, cell accuracy: 99.6%, board accuracy: 56.5%
#
# test error:
#  G loss: 0.002605, cell accuracy: 98.7%, board accuracy: 25.2%
#
# Epoch 101
# -------------------------------
# train error:
#  G loss: 0.000833, cell accuracy: 99.6%, board accuracy: 57.3%
#
# test error:
#  G loss: 0.002610, cell accuracy: 98.7%, board accuracy: 25.9%
#
# Epoch 102
# -------------------------------
# train error:
#  G loss: 0.000837, cell accuracy: 99.6%, board accuracy: 56.9%
#
# test error:
#  G loss: 0.002608, cell accuracy: 98.7%, board accuracy: 25.9%
#
# Epoch 103
# -------------------------------
# train error:
#  G loss: 0.000843, cell accuracy: 99.6%, board accuracy: 56.7%
#
# test error:
#  G loss: 0.002621, cell accuracy: 98.7%, board accuracy: 26.0%
#
# Epoch 104
# -------------------------------
# train error:
#  G loss: 0.000808, cell accuracy: 99.6%, board accuracy: 58.3%
#
# test error:
#  G loss: 0.002578, cell accuracy: 98.7%, board accuracy: 26.8%
#
# Epoch 105
# -------------------------------
# train error:
#  G loss: 0.000807, cell accuracy: 99.6%, board accuracy: 57.8%
#
# test error:
#  G loss: 0.002578, cell accuracy: 98.7%, board accuracy: 26.5%
#
# Epoch 106
# -------------------------------
# train error:
#  G loss: 0.000814, cell accuracy: 99.6%, board accuracy: 57.9%
#
# test error:
#  G loss: 0.002640, cell accuracy: 98.7%, board accuracy: 25.9%
#
# Epoch 107
# -------------------------------
# train error:
#  G loss: 0.000780, cell accuracy: 99.7%, board accuracy: 59.3%
#
# test error:
#  G loss: 0.002618, cell accuracy: 98.7%, board accuracy: 26.7%
#
# Epoch 108
# -------------------------------
# train error:
#  G loss: 0.000761, cell accuracy: 99.7%, board accuracy: 60.2%
#
# test error:
#  G loss: 0.002548, cell accuracy: 98.8%, board accuracy: 27.8%
#
# Epoch 109
# -------------------------------
# train error:
#  G loss: 0.000774, cell accuracy: 99.7%, board accuracy: 59.0%
#
# test error:
#  G loss: 0.002562, cell accuracy: 98.7%, board accuracy: 26.8%
#
# Epoch 110
# -------------------------------
# train error:
#  G loss: 0.000786, cell accuracy: 99.6%, board accuracy: 58.5%
#
# test error:
#  G loss: 0.002608, cell accuracy: 98.7%, board accuracy: 25.9%
#
# Epoch 111
# -------------------------------
# train error:
#  G loss: 0.000769, cell accuracy: 99.7%, board accuracy: 59.4%
#
# test error:
#  G loss: 0.002569, cell accuracy: 98.8%, board accuracy: 27.6%
#
# Epoch 112
# -------------------------------
# train error:
#  G loss: 0.000770, cell accuracy: 99.7%, board accuracy: 59.5%
#
# test error:
#  G loss: 0.002613, cell accuracy: 98.7%, board accuracy: 25.9%
#
# Epoch 113
# -------------------------------
# train error:
#  G loss: 0.000736, cell accuracy: 99.7%, board accuracy: 60.8%
#
# test error:
#  G loss: 0.002568, cell accuracy: 98.8%, board accuracy: 27.4%
#
# Epoch 114
# -------------------------------
# train error:
#  G loss: 0.000750, cell accuracy: 99.7%, board accuracy: 60.3%
#
# test error:
#  G loss: 0.002589, cell accuracy: 98.7%, board accuracy: 27.2%
#
# Epoch 115
# -------------------------------
# train error:
#  G loss: 0.000745, cell accuracy: 99.7%, board accuracy: 60.4%
#
# test error:
#  G loss: 0.002562, cell accuracy: 98.8%, board accuracy: 27.3%
#
# Epoch 116
# -------------------------------
# train error:
#  G loss: 0.000733, cell accuracy: 99.7%, board accuracy: 60.9%
#
# test error:
#  G loss: 0.002585, cell accuracy: 98.7%, board accuracy: 27.6%
#
# Epoch 117
# -------------------------------
# train error:
#  G loss: 0.000710, cell accuracy: 99.7%, board accuracy: 61.8%
#
# test error:
#  G loss: 0.002545, cell accuracy: 98.8%, board accuracy: 28.4%
#
# Epoch 118
# -------------------------------
# train error:
#  G loss: 0.000706, cell accuracy: 99.7%, board accuracy: 62.2%
#
# test error:
#  G loss: 0.002550, cell accuracy: 98.8%, board accuracy: 28.1%
#
# Epoch 119
# -------------------------------
# train error:
#  G loss: 0.000691, cell accuracy: 99.7%, board accuracy: 62.9%
#
# test error:
#  G loss: 0.002522, cell accuracy: 98.8%, board accuracy: 28.7%
#
# Epoch 120
# -------------------------------
# train error:
#  G loss: 0.000696, cell accuracy: 99.7%, board accuracy: 62.9%
#
# test error:
#  G loss: 0.002526, cell accuracy: 98.8%, board accuracy: 28.5%
#
# Epoch 121
# -------------------------------
# train error:
#  G loss: 0.000694, cell accuracy: 99.7%, board accuracy: 62.4%
#
# test error:
#  G loss: 0.002539, cell accuracy: 98.8%, board accuracy: 28.9%
#
# Epoch 122
# -------------------------------
# train error:
#  G loss: 0.000682, cell accuracy: 99.7%, board accuracy: 62.9%
#
# test error:
#  G loss: 0.002526, cell accuracy: 98.8%, board accuracy: 28.8%
#
# Epoch 123
# -------------------------------
# train error:
#  G loss: 0.000679, cell accuracy: 99.7%, board accuracy: 63.5%
#
# test error:
#  G loss: 0.002515, cell accuracy: 98.8%, board accuracy: 28.9%
#
# Epoch 124
# -------------------------------
# train error:
#  G loss: 0.000651, cell accuracy: 99.7%, board accuracy: 64.8%
#
# test error:
#  G loss: 0.002490, cell accuracy: 98.8%, board accuracy: 28.9%
#
# Epoch 125
# -------------------------------
# train error:
#  G loss: 0.000701, cell accuracy: 99.7%, board accuracy: 62.0%
#
# test error:
#  G loss: 0.002565, cell accuracy: 98.8%, board accuracy: 27.4%
#
# Epoch 126
# -------------------------------
# train error:
#  G loss: 0.000699, cell accuracy: 99.7%, board accuracy: 62.9%
#
# test error:
#  G loss: 0.002566, cell accuracy: 98.8%, board accuracy: 28.6%
#
# Epoch 127
# -------------------------------
# train error:
#  G loss: 0.000679, cell accuracy: 99.7%, board accuracy: 63.6%
#
# test error:
#  G loss: 0.002568, cell accuracy: 98.8%, board accuracy: 28.2%
#
# Epoch 128
# -------------------------------
# train error:
#  G loss: 0.000645, cell accuracy: 99.7%, board accuracy: 64.9%
#
# test error:
#  G loss: 0.002491, cell accuracy: 98.8%, board accuracy: 28.9%
#
# Epoch 129
# -------------------------------
# train error:
#  G loss: 0.000650, cell accuracy: 99.7%, board accuracy: 64.3%
#
# test error:
#  G loss: 0.002515, cell accuracy: 98.8%, board accuracy: 29.2%
#
# Epoch 130
# -------------------------------
# train error:
#  G loss: 0.000638, cell accuracy: 99.7%, board accuracy: 65.0%
#
# test error:
#  G loss: 0.002521, cell accuracy: 98.8%, board accuracy: 28.3%
#
# Epoch 131
# -------------------------------
# train error:
#  G loss: 0.000646, cell accuracy: 99.7%, board accuracy: 64.4%
#
# test error:
#  G loss: 0.002496, cell accuracy: 98.8%, board accuracy: 30.1%
#
# Epoch 132
# -------------------------------
# train error:
#  G loss: 0.000676, cell accuracy: 99.7%, board accuracy: 62.4%
#
# test error:
#  G loss: 0.002569, cell accuracy: 98.8%, board accuracy: 27.2%
#
# Epoch 133
# -------------------------------
# train error:
#  G loss: 0.000630, cell accuracy: 99.7%, board accuracy: 64.8%
#
# test error:
#  G loss: 0.002510, cell accuracy: 98.8%, board accuracy: 29.5%
#
# Epoch 134
# -------------------------------
# train error:
#  G loss: 0.000661, cell accuracy: 99.7%, board accuracy: 63.3%
#
# test error:
#  G loss: 0.002559, cell accuracy: 98.8%, board accuracy: 28.1%
#
# Epoch 135
# -------------------------------
# train error:
#  G loss: 0.000615, cell accuracy: 99.7%, board accuracy: 65.9%
#
# test error:
#  G loss: 0.002499, cell accuracy: 98.8%, board accuracy: 29.8%
#
# Epoch 136
# -------------------------------
# train error:
#  G loss: 0.000642, cell accuracy: 99.7%, board accuracy: 64.4%
#
# test error:
#  G loss: 0.002526, cell accuracy: 98.8%, board accuracy: 29.7%
#
# Epoch 137
# -------------------------------
# train error:
#  G loss: 0.000630, cell accuracy: 99.7%, board accuracy: 65.2%
#
# test error:
#  G loss: 0.002501, cell accuracy: 98.8%, board accuracy: 28.9%
#
# Epoch 138
# -------------------------------
# train error:
#  G loss: 0.000605, cell accuracy: 99.7%, board accuracy: 66.6%
#
# test error:
#  G loss: 0.002509, cell accuracy: 98.8%, board accuracy: 29.7%
#
# Epoch 139
# -------------------------------
# train error:
#  G loss: 0.000633, cell accuracy: 99.7%, board accuracy: 64.4%
#
# test error:
#  G loss: 0.002495, cell accuracy: 98.8%, board accuracy: 28.9%
#
# Epoch 140
# -------------------------------
# train error:
#  G loss: 0.000635, cell accuracy: 99.7%, board accuracy: 64.2%
#
# test error:
#  G loss: 0.002556, cell accuracy: 98.8%, board accuracy: 28.3%
#
# Epoch 141
# -------------------------------
# train error:
#  G loss: 0.000601, cell accuracy: 99.7%, board accuracy: 66.3%
#
# test error:
#  G loss: 0.002515, cell accuracy: 98.8%, board accuracy: 29.3%
#
# Epoch 142
# -------------------------------
# train error:
#  G loss: 0.000635, cell accuracy: 99.7%, board accuracy: 64.5%
#
# test error:
#  G loss: 0.002545, cell accuracy: 98.8%, board accuracy: 28.8%
#
# Epoch 143
# -------------------------------
# train error:
#  G loss: 0.000587, cell accuracy: 99.7%, board accuracy: 67.0%
#
# test error:
#  G loss: 0.002484, cell accuracy: 98.8%, board accuracy: 30.6%
#
# Epoch 144
# -------------------------------
# train error:
#  G loss: 0.000577, cell accuracy: 99.7%, board accuracy: 67.7%
#
# test error:
#  G loss: 0.002455, cell accuracy: 98.8%, board accuracy: 30.1%
#
# Epoch 145
# -------------------------------
# train error:
#  G loss: 0.000599, cell accuracy: 99.7%, board accuracy: 65.9%
#
# test error:
#  G loss: 0.002477, cell accuracy: 98.8%, board accuracy: 29.7%
#
# Epoch 146
# -------------------------------
# train error:
#  G loss: 0.000600, cell accuracy: 99.7%, board accuracy: 66.2%
#
# test error:
#  G loss: 0.002488, cell accuracy: 98.8%, board accuracy: 30.5%
#
# Epoch 147
# -------------------------------
# train error:
#  G loss: 0.000591, cell accuracy: 99.7%, board accuracy: 66.8%
#
# test error:
#  G loss: 0.002518, cell accuracy: 98.8%, board accuracy: 30.9%
#
# Epoch 148
# -------------------------------
# train error:
#  G loss: 0.000612, cell accuracy: 99.7%, board accuracy: 65.2%
#
# test error:
#  G loss: 0.002542, cell accuracy: 98.8%, board accuracy: 29.8%
#
# Epoch 149
# -------------------------------
# train error:
#  G loss: 0.000610, cell accuracy: 99.7%, board accuracy: 65.5%
#
# test error:
#  G loss: 0.002513, cell accuracy: 98.8%, board accuracy: 29.6%
#
# Epoch 150
# -------------------------------
# train error:
#  G loss: 0.000567, cell accuracy: 99.7%, board accuracy: 67.5%
#
# test error:
#  G loss: 0.002450, cell accuracy: 98.8%, board accuracy: 30.0%
#
# Epoch 151
# -------------------------------
# train error:
#  G loss: 0.000589, cell accuracy: 99.7%, board accuracy: 66.4%
#
# test error:
#  G loss: 0.002478, cell accuracy: 98.8%, board accuracy: 30.4%
#
# Epoch 152
# -------------------------------
# train error:
#  G loss: 0.000578, cell accuracy: 99.7%, board accuracy: 67.5%
#
# test error:
#  G loss: 0.002479, cell accuracy: 98.8%, board accuracy: 29.9%
#
# Epoch 153
# -------------------------------
# train error:
#  G loss: 0.000565, cell accuracy: 99.7%, board accuracy: 68.4%
#
# test error:
#  G loss: 0.002468, cell accuracy: 98.8%, board accuracy: 30.9%
#
# Epoch 154
# -------------------------------
# train error:
#  G loss: 0.000549, cell accuracy: 99.8%, board accuracy: 68.5%
#
# test error:
#  G loss: 0.002449, cell accuracy: 98.8%, board accuracy: 30.5%
#
# Epoch 155
# -------------------------------
# train error:
#  G loss: 0.000546, cell accuracy: 99.8%, board accuracy: 69.2%
#
# test error:
#  G loss: 0.002448, cell accuracy: 98.8%, board accuracy: 30.3%
#
# Epoch 156
# -------------------------------
# train error:
#  G loss: 0.000552, cell accuracy: 99.8%, board accuracy: 68.4%
#
# test error:
#  G loss: 0.002475, cell accuracy: 98.8%, board accuracy: 29.9%
#
# Epoch 157
# -------------------------------
# train error:
#  G loss: 0.000548, cell accuracy: 99.8%, board accuracy: 68.7%
#
# test error:
#  G loss: 0.002439, cell accuracy: 98.8%, board accuracy: 31.0%
#
# Epoch 158
# -------------------------------
# train error:
#  G loss: 0.000564, cell accuracy: 99.7%, board accuracy: 68.1%
#
# test error:
#  G loss: 0.002492, cell accuracy: 98.8%, board accuracy: 30.6%
#
# Epoch 159
# -------------------------------
# train error:
#  G loss: 0.000553, cell accuracy: 99.8%, board accuracy: 68.6%
#
# test error:
#  G loss: 0.002479, cell accuracy: 98.8%, board accuracy: 30.5%
#
# Epoch 160
# -------------------------------
# train error:
#  G loss: 0.000525, cell accuracy: 99.8%, board accuracy: 69.9%
#
# test error:
#  G loss: 0.002433, cell accuracy: 98.8%, board accuracy: 32.2%
#
# Epoch 161
# -------------------------------
# train error:
#  G loss: 0.000532, cell accuracy: 99.8%, board accuracy: 69.5%
#
# test error:
#  G loss: 0.002448, cell accuracy: 98.8%, board accuracy: 31.4%
#
# Epoch 162
# -------------------------------
# train error:
#  G loss: 0.000555, cell accuracy: 99.8%, board accuracy: 68.3%
#
# test error:
#  G loss: 0.002463, cell accuracy: 98.8%, board accuracy: 31.4%
#
# Epoch 163
# -------------------------------
# train error:
#  G loss: 0.000565, cell accuracy: 99.7%, board accuracy: 67.7%
#
# test error:
#  G loss: 0.002492, cell accuracy: 98.8%, board accuracy: 30.6%
#
# Epoch 164
# -------------------------------
# train error:
#  G loss: 0.000516, cell accuracy: 99.8%, board accuracy: 70.6%
#
# test error:
#  G loss: 0.002464, cell accuracy: 98.8%, board accuracy: 31.8%
#
# Epoch 165
# -------------------------------
# train error:
#  G loss: 0.000519, cell accuracy: 99.8%, board accuracy: 70.4%
#
# test error:
#  G loss: 0.002446, cell accuracy: 98.8%, board accuracy: 31.6%
#
# Epoch 166
# -------------------------------
# train error:
#  G loss: 0.000524, cell accuracy: 99.8%, board accuracy: 70.2%
#
# test error:
#  G loss: 0.002445, cell accuracy: 98.8%, board accuracy: 31.8%
#
# Epoch 167
# -------------------------------
# train error:
#  G loss: 0.000526, cell accuracy: 99.8%, board accuracy: 69.6%
#
# test error:
#  G loss: 0.002467, cell accuracy: 98.8%, board accuracy: 30.2%
#
# Epoch 168
# -------------------------------
# train error:
#  G loss: 0.000516, cell accuracy: 99.8%, board accuracy: 70.8%
#
# test error:
#  G loss: 0.002430, cell accuracy: 98.8%, board accuracy: 31.9%
#
# Epoch 169
# -------------------------------
# train error:
#  G loss: 0.000494, cell accuracy: 99.8%, board accuracy: 71.7%
#
# test error:
#  G loss: 0.002422, cell accuracy: 98.8%, board accuracy: 31.5%
#
# Epoch 170
# -------------------------------
# train error:
#  G loss: 0.000535, cell accuracy: 99.8%, board accuracy: 69.3%
#
# test error:
#  G loss: 0.002493, cell accuracy: 98.8%, board accuracy: 30.8%
#
# Epoch 171
# -------------------------------
# train error:
#  G loss: 0.000511, cell accuracy: 99.8%, board accuracy: 70.9%
#
# test error:
#  G loss: 0.002461, cell accuracy: 98.8%, board accuracy: 31.8%
#
# Epoch 172
# -------------------------------
# train error:
#  G loss: 0.000534, cell accuracy: 99.8%, board accuracy: 68.9%
#
# test error:
#  G loss: 0.002482, cell accuracy: 98.8%, board accuracy: 30.9%
#
# Epoch 173
# -------------------------------
# train error:
#  G loss: 0.000496, cell accuracy: 99.8%, board accuracy: 71.1%
#
# test error:
#  G loss: 0.002421, cell accuracy: 98.8%, board accuracy: 31.8%
#
# Epoch 174
# -------------------------------
# train error:
#  G loss: 0.000498, cell accuracy: 99.8%, board accuracy: 71.4%
#
# test error:
#  G loss: 0.002432, cell accuracy: 98.8%, board accuracy: 32.1%
#
# Epoch 175
# -------------------------------
# train error:
#  G loss: 0.000524, cell accuracy: 99.8%, board accuracy: 69.7%
#
# test error:
#  G loss: 0.002452, cell accuracy: 98.8%, board accuracy: 30.9%
#
# Epoch 176
# -------------------------------
# train error:
#  G loss: 0.000520, cell accuracy: 99.8%, board accuracy: 70.7%
#
# test error:
#  G loss: 0.002461, cell accuracy: 98.8%, board accuracy: 32.0%
#
# Epoch 177
# -------------------------------
# train error:
#  G loss: 0.000504, cell accuracy: 99.8%, board accuracy: 70.8%
#
# test error:
#  G loss: 0.002444, cell accuracy: 98.8%, board accuracy: 32.0%
#
# Epoch 178
# -------------------------------
# train error:
#  G loss: 0.000494, cell accuracy: 99.8%, board accuracy: 71.1%
#
# test error:
#  G loss: 0.002420, cell accuracy: 98.8%, board accuracy: 31.8%
#
# Epoch 179
# -------------------------------
# train error:
#  G loss: 0.000511, cell accuracy: 99.8%, board accuracy: 70.6%
#
# test error:
#  G loss: 0.002453, cell accuracy: 98.8%, board accuracy: 31.7%
#
# Epoch 180
# -------------------------------
# train error:
#  G loss: 0.000522, cell accuracy: 99.8%, board accuracy: 69.5%
#
# test error:
#  G loss: 0.002472, cell accuracy: 98.8%, board accuracy: 30.4%
#
# Epoch 181
# -------------------------------
# train error:
#  G loss: 0.000499, cell accuracy: 99.8%, board accuracy: 70.8%
#
# test error:
#  G loss: 0.002437, cell accuracy: 98.8%, board accuracy: 30.9%
#
# Epoch 182
# -------------------------------
# train error:
#  G loss: 0.000506, cell accuracy: 99.8%, board accuracy: 70.0%
#
# test error:
#  G loss: 0.002463, cell accuracy: 98.8%, board accuracy: 30.6%
#
# Epoch 183
# -------------------------------
# train error:
#  G loss: 0.000497, cell accuracy: 99.8%, board accuracy: 70.8%
#
# test error:
#  G loss: 0.002443, cell accuracy: 98.8%, board accuracy: 31.5%
#
# Epoch 184
# -------------------------------
# train error:
#  G loss: 0.000512, cell accuracy: 99.8%, board accuracy: 70.0%
#
# test error:
#  G loss: 0.002452, cell accuracy: 98.8%, board accuracy: 31.3%
#
# Epoch 185
# -------------------------------
# train error:
#  G loss: 0.000478, cell accuracy: 99.8%, board accuracy: 72.0%
#
# test error:
#  G loss: 0.002413, cell accuracy: 98.9%, board accuracy: 32.3%
#
# Epoch 186
# -------------------------------
# train error:
#  G loss: 0.000487, cell accuracy: 99.8%, board accuracy: 71.6%
#
# test error:
#  G loss: 0.002445, cell accuracy: 98.8%, board accuracy: 31.6%
#
# Epoch 187
# -------------------------------
# train error:
#  G loss: 0.000483, cell accuracy: 99.8%, board accuracy: 71.5%
#
# test error:
#  G loss: 0.002452, cell accuracy: 98.8%, board accuracy: 32.1%
#
# Epoch 188
# -------------------------------
# train error:
#  G loss: 0.000483, cell accuracy: 99.8%, board accuracy: 71.9%
#
# test error:
#  G loss: 0.002440, cell accuracy: 98.8%, board accuracy: 33.1%
#
# Epoch 189
# -------------------------------
# train error:
#  G loss: 0.000501, cell accuracy: 99.8%, board accuracy: 70.5%
#
# test error:
#  G loss: 0.002476, cell accuracy: 98.8%, board accuracy: 31.4%
#
# Epoch 190
# -------------------------------
# train error:
#  G loss: 0.000495, cell accuracy: 99.8%, board accuracy: 70.8%
#
# test error:
#  G loss: 0.002447, cell accuracy: 98.8%, board accuracy: 31.4%
#
# Epoch 191
# -------------------------------
# train error:
#  G loss: 0.000466, cell accuracy: 99.8%, board accuracy: 72.5%
#
# test error:
#  G loss: 0.002408, cell accuracy: 98.9%, board accuracy: 33.3%
#
# Epoch 192
# -------------------------------
# train error:
#  G loss: 0.000472, cell accuracy: 99.8%, board accuracy: 72.4%
#
# test error:
#  G loss: 0.002436, cell accuracy: 98.8%, board accuracy: 32.7%
#
# Epoch 193
# -------------------------------
# train error:
#  G loss: 0.000482, cell accuracy: 99.8%, board accuracy: 71.8%
#
# test error:
#  G loss: 0.002441, cell accuracy: 98.8%, board accuracy: 31.4%
#
# Epoch 194
# -------------------------------
# train error:
#  G loss: 0.000470, cell accuracy: 99.8%, board accuracy: 71.9%
#
# test error:
#  G loss: 0.002443, cell accuracy: 98.8%, board accuracy: 31.8%
#
# Epoch 195
# -------------------------------
# train error:
#  G loss: 0.000474, cell accuracy: 99.8%, board accuracy: 72.2%
#
# test error:
#  G loss: 0.002461, cell accuracy: 98.8%, board accuracy: 31.2%
#
# Epoch 196
# -------------------------------
# train error:
#  G loss: 0.000467, cell accuracy: 99.8%, board accuracy: 72.4%
#
# test error:
#  G loss: 0.002440, cell accuracy: 98.8%, board accuracy: 32.0%
#
# Epoch 197
# -------------------------------
# train error:
#  G loss: 0.000468, cell accuracy: 99.8%, board accuracy: 72.4%
#
# test error:
#  G loss: 0.002436, cell accuracy: 98.8%, board accuracy: 32.4%
#
# Epoch 198
# -------------------------------
# train error:
#  G loss: 0.000471, cell accuracy: 99.8%, board accuracy: 72.0%
#
# test error:
#  G loss: 0.002472, cell accuracy: 98.8%, board accuracy: 30.6%
#
# Epoch 199
# -------------------------------
# train error:
#  G loss: 0.000469, cell accuracy: 99.8%, board accuracy: 72.0%
#
# test error:
#  G loss: 0.002446, cell accuracy: 98.8%, board accuracy: 32.1%
#
# Epoch 200
# -------------------------------
# train error:
#  G loss: 0.000467, cell accuracy: 99.8%, board accuracy: 72.4%
#
# test error:
#  G loss: 0.002443, cell accuracy: 98.8%, board accuracy: 32.1%
#
# Epoch 201
# -------------------------------
# train error:
#  G loss: 0.000441, cell accuracy: 99.8%, board accuracy: 73.9%
#
# test error:
#  G loss: 0.002400, cell accuracy: 98.9%, board accuracy: 33.1%
#
# Epoch 202
# -------------------------------
# train error:
#  G loss: 0.000455, cell accuracy: 99.8%, board accuracy: 73.2%
#
# test error:
#  G loss: 0.002443, cell accuracy: 98.8%, board accuracy: 32.5%
#
# Epoch 203
# -------------------------------
# train error:
#  G loss: 0.000443, cell accuracy: 99.8%, board accuracy: 73.8%
#
# test error:
#  G loss: 0.002390, cell accuracy: 98.9%, board accuracy: 33.8%
#
# Epoch 204
# -------------------------------
# train error:
#  G loss: 0.000456, cell accuracy: 99.8%, board accuracy: 72.8%
#
# test error:
#  G loss: 0.002429, cell accuracy: 98.8%, board accuracy: 32.8%
#
# Epoch 205
# -------------------------------
# train error:
#  G loss: 0.000456, cell accuracy: 99.8%, board accuracy: 72.6%
#
# test error:
#  G loss: 0.002437, cell accuracy: 98.8%, board accuracy: 33.2%
#
# Epoch 206
# -------------------------------
# train error:
#  G loss: 0.000443, cell accuracy: 99.8%, board accuracy: 73.5%
#
# test error:
#  G loss: 0.002408, cell accuracy: 98.9%, board accuracy: 33.4%
#
# Epoch 207
# -------------------------------
# train error:
#  G loss: 0.000452, cell accuracy: 99.8%, board accuracy: 73.3%
#
# test error:
#  G loss: 0.002396, cell accuracy: 98.9%, board accuracy: 32.8%
#
# Epoch 208
# -------------------------------
# train error:
#  G loss: 0.000451, cell accuracy: 99.8%, board accuracy: 73.3%
#
# test error:
#  G loss: 0.002445, cell accuracy: 98.8%, board accuracy: 33.2%
#
# Epoch 209
# -------------------------------
# train error:
#  G loss: 0.000468, cell accuracy: 99.8%, board accuracy: 71.8%
#
# test error:
#  G loss: 0.002453, cell accuracy: 98.8%, board accuracy: 31.4%
#
# Epoch 210
# -------------------------------
# train error:
#  G loss: 0.000469, cell accuracy: 99.8%, board accuracy: 72.1%
#
# test error:
#  G loss: 0.002475, cell accuracy: 98.8%, board accuracy: 32.0%
#
# Epoch 211
# -------------------------------
# train error:
#  G loss: 0.000450, cell accuracy: 99.8%, board accuracy: 73.1%
#
# test error:
#  G loss: 0.002443, cell accuracy: 98.8%, board accuracy: 32.9%
#
# Epoch 212
# -------------------------------
# train error:
#  G loss: 0.000440, cell accuracy: 99.8%, board accuracy: 73.9%
#
# test error:
#  G loss: 0.002402, cell accuracy: 98.9%, board accuracy: 33.9%
#
# Epoch 213
# -------------------------------
# train error:
#  G loss: 0.000438, cell accuracy: 99.8%, board accuracy: 73.8%
#
# test error:
#  G loss: 0.002450, cell accuracy: 98.8%, board accuracy: 33.3%
#
# Epoch 214
# -------------------------------
# train error:
#  G loss: 0.000430, cell accuracy: 99.8%, board accuracy: 74.1%
#
# test error:
#  G loss: 0.002431, cell accuracy: 98.8%, board accuracy: 33.8%
#
# Epoch 215
# -------------------------------
# train error:
#  G loss: 0.000435, cell accuracy: 99.8%, board accuracy: 74.1%
#
# test error:
#  G loss: 0.002408, cell accuracy: 98.9%, board accuracy: 32.9%
#
# Epoch 216
# -------------------------------
# train error:
#  G loss: 0.000419, cell accuracy: 99.8%, board accuracy: 74.8%
#
# test error:
#  G loss: 0.002381, cell accuracy: 98.9%, board accuracy: 33.6%
#
# Epoch 217
# -------------------------------
# train error:
#  G loss: 0.000458, cell accuracy: 99.8%, board accuracy: 72.8%
#
# test error:
#  G loss: 0.002436, cell accuracy: 98.8%, board accuracy: 32.9%
#
# Epoch 218
# -------------------------------
# train error:
#  G loss: 0.000427, cell accuracy: 99.8%, board accuracy: 74.4%
#
# test error:
#  G loss: 0.002395, cell accuracy: 98.9%, board accuracy: 33.6%
#
# Epoch 219
# -------------------------------
# train error:
#  G loss: 0.000420, cell accuracy: 99.8%, board accuracy: 74.8%
#
# test error:
#  G loss: 0.002387, cell accuracy: 98.9%, board accuracy: 33.9%
#
# Epoch 220
# -------------------------------
# train error:
#  G loss: 0.000456, cell accuracy: 99.8%, board accuracy: 72.4%
#
# test error:
#  G loss: 0.002454, cell accuracy: 98.8%, board accuracy: 31.9%
#
# Epoch 221
# -------------------------------
# train error:
#  G loss: 0.000416, cell accuracy: 99.8%, board accuracy: 75.2%
#
# test error:
#  G loss: 0.002387, cell accuracy: 98.9%, board accuracy: 34.0%
#
# Epoch 222
# -------------------------------
# train error:
#  G loss: 0.000453, cell accuracy: 99.8%, board accuracy: 73.4%
#
# test error:
#  G loss: 0.002424, cell accuracy: 98.9%, board accuracy: 33.6%
#
# Epoch 223
# -------------------------------
# train error:
#  G loss: 0.000413, cell accuracy: 99.8%, board accuracy: 75.1%
#
# test error:
#  G loss: 0.002379, cell accuracy: 98.9%, board accuracy: 34.2%
#
# Epoch 224
# -------------------------------
# train error:
#  G loss: 0.000425, cell accuracy: 99.8%, board accuracy: 74.2%
#
# test error:
#  G loss: 0.002420, cell accuracy: 98.8%, board accuracy: 33.0%
#
# Epoch 225
# -------------------------------
# train error:
#  G loss: 0.000412, cell accuracy: 99.8%, board accuracy: 75.3%
#
# test error:
#  G loss: 0.002376, cell accuracy: 98.9%, board accuracy: 34.1%
#
# Epoch 226
# -------------------------------
# train error:
#  G loss: 0.000424, cell accuracy: 99.8%, board accuracy: 74.6%
#
# test error:
#  G loss: 0.002394, cell accuracy: 98.9%, board accuracy: 34.4%
#
# Epoch 227
# -------------------------------
# train error:
#  G loss: 0.000426, cell accuracy: 99.8%, board accuracy: 74.2%
#
# test error:
#  G loss: 0.002397, cell accuracy: 98.9%, board accuracy: 34.1%
#
# Epoch 228
# -------------------------------
# train error:
#  G loss: 0.000426, cell accuracy: 99.8%, board accuracy: 74.6%
#
# test error:
#  G loss: 0.002420, cell accuracy: 98.9%, board accuracy: 33.7%
#
# Epoch 229
# -------------------------------
# train error:
#  G loss: 0.000412, cell accuracy: 99.8%, board accuracy: 74.8%
#
# test error:
#  G loss: 0.002391, cell accuracy: 98.9%, board accuracy: 34.1%
#
# Epoch 230
# -------------------------------
# train error:
#  G loss: 0.000425, cell accuracy: 99.8%, board accuracy: 74.2%
#
# test error:
#  G loss: 0.002403, cell accuracy: 98.9%, board accuracy: 33.8%
#
# Epoch 231
# -------------------------------
# train error:
#  G loss: 0.000414, cell accuracy: 99.8%, board accuracy: 75.2%
#
# test error:
#  G loss: 0.002383, cell accuracy: 98.9%, board accuracy: 34.0%
#
# Epoch 232
# -------------------------------
# train error:
#  G loss: 0.000412, cell accuracy: 99.8%, board accuracy: 75.1%
#
# test error:
#  G loss: 0.002388, cell accuracy: 98.9%, board accuracy: 34.2%
#
# Epoch 233
# -------------------------------
# train error:
#  G loss: 0.000410, cell accuracy: 99.8%, board accuracy: 75.2%
#
# test error:
#  G loss: 0.002377, cell accuracy: 98.9%, board accuracy: 34.2%
#
# Epoch 234
# -------------------------------
# train error:
#  G loss: 0.000438, cell accuracy: 99.8%, board accuracy: 73.4%
#
# test error:
#  G loss: 0.002445, cell accuracy: 98.8%, board accuracy: 32.1%
#
# Epoch 235
# -------------------------------
# train error:
#  G loss: 0.000411, cell accuracy: 99.8%, board accuracy: 75.0%
#
# test error:
#  G loss: 0.002384, cell accuracy: 98.9%, board accuracy: 34.6%
#
# Epoch 236
# -------------------------------
# train error:
#  G loss: 0.000423, cell accuracy: 99.8%, board accuracy: 74.5%
#
# test error:
#  G loss: 0.002403, cell accuracy: 98.9%, board accuracy: 33.5%
#
# Epoch 237
# -------------------------------
# train error:
#  G loss: 0.000402, cell accuracy: 99.8%, board accuracy: 75.6%
#
# test error:
#  G loss: 0.002383, cell accuracy: 98.9%, board accuracy: 34.0%
#
# Epoch 238
# -------------------------------
# train error:
#  G loss: 0.000409, cell accuracy: 99.8%, board accuracy: 75.2%
#
# test error:
#  G loss: 0.002395, cell accuracy: 98.9%, board accuracy: 33.9%
#
# Epoch 239
# -------------------------------
# train error:
#  G loss: 0.000395, cell accuracy: 99.8%, board accuracy: 76.0%
#
# test error:
#  G loss: 0.002376, cell accuracy: 98.9%, board accuracy: 35.1%
#
# Epoch 240
# -------------------------------
# train error:
#  G loss: 0.000416, cell accuracy: 99.8%, board accuracy: 74.7%
#
# test error:
#  G loss: 0.002411, cell accuracy: 98.9%, board accuracy: 33.1%
#
# Epoch 241
# -------------------------------
# train error:
#  G loss: 0.000397, cell accuracy: 99.8%, board accuracy: 75.8%
#
# test error:
#  G loss: 0.002368, cell accuracy: 98.9%, board accuracy: 34.1%
#
# Epoch 242
# ...
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002105, cell accuracy: 99.0%, board accuracy: 45.4%
#
# Epoch 1421
# -------------------------------
# train error:
#  G loss: 0.000172, cell accuracy: 99.9%, board accuracy: 87.5%
#
# test error:
#  G loss: 0.002113, cell accuracy: 99.0%, board accuracy: 43.8%
#
# Epoch 1422
# -------------------------------
# train error:
#  G loss: 0.000173, cell accuracy: 99.9%, board accuracy: 87.5%
#
# test error:
#  G loss: 0.002153, cell accuracy: 99.0%, board accuracy: 44.1%
#
# Epoch 1423
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.6%
#
# test error:
#  G loss: 0.002131, cell accuracy: 99.0%, board accuracy: 44.5%
#
# Epoch 1424
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002136, cell accuracy: 99.0%, board accuracy: 44.0%
#
# Epoch 1425
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002106, cell accuracy: 99.0%, board accuracy: 44.4%
#
# Epoch 1426
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.6%
#
# test error:
#  G loss: 0.002120, cell accuracy: 99.0%, board accuracy: 44.6%
#
# Epoch 1427
# -------------------------------
# train error:
#  G loss: 0.000172, cell accuracy: 99.9%, board accuracy: 87.6%
#
# test error:
#  G loss: 0.002126, cell accuracy: 99.0%, board accuracy: 44.8%
#
# Epoch 1428
# -------------------------------
# train error:
#  G loss: 0.000170, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002137, cell accuracy: 99.0%, board accuracy: 44.2%
#
# Epoch 1429
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.5%
#
# test error:
#  G loss: 0.002125, cell accuracy: 99.0%, board accuracy: 43.6%
#
# Epoch 1430
# -------------------------------
# train error:
#  G loss: 0.000173, cell accuracy: 99.9%, board accuracy: 87.5%
#
# test error:
#  G loss: 0.002135, cell accuracy: 99.0%, board accuracy: 44.5%
#
# Epoch 1431
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.5%
#
# test error:
#  G loss: 0.002126, cell accuracy: 99.0%, board accuracy: 43.8%
#
# Epoch 1432
# -------------------------------
# train error:
#  G loss: 0.000172, cell accuracy: 99.9%, board accuracy: 87.6%
#
# test error:
#  G loss: 0.002141, cell accuracy: 99.0%, board accuracy: 44.0%
#
# Epoch 1433
# -------------------------------
# train error:
#  G loss: 0.000180, cell accuracy: 99.9%, board accuracy: 87.0%
#
# test error:
#  G loss: 0.002168, cell accuracy: 99.0%, board accuracy: 42.4%
#
# Epoch 1434
# -------------------------------
# train error:
#  G loss: 0.000172, cell accuracy: 99.9%, board accuracy: 87.5%
#
# test error:
#  G loss: 0.002142, cell accuracy: 99.0%, board accuracy: 42.9%
#
# Epoch 1435
# -------------------------------
# train error:
#  G loss: 0.000167, cell accuracy: 99.9%, board accuracy: 88.0%
#
# test error:
#  G loss: 0.002104, cell accuracy: 99.0%, board accuracy: 44.3%
#
# Epoch 1436
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002147, cell accuracy: 99.0%, board accuracy: 42.9%
#
# Epoch 1437
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002146, cell accuracy: 99.0%, board accuracy: 43.1%
#
# Epoch 1438
# -------------------------------
# train error:
#  G loss: 0.000173, cell accuracy: 99.9%, board accuracy: 87.4%
#
# test error:
#  G loss: 0.002144, cell accuracy: 99.0%, board accuracy: 44.0%
#
# Epoch 1439
# -------------------------------
# train error:
#  G loss: 0.000172, cell accuracy: 99.9%, board accuracy: 87.6%
#
# test error:
#  G loss: 0.002134, cell accuracy: 99.0%, board accuracy: 44.1%
#
# Epoch 1440
# -------------------------------
# train error:
#  G loss: 0.000176, cell accuracy: 99.9%, board accuracy: 87.4%
#
# test error:
#  G loss: 0.002177, cell accuracy: 99.0%, board accuracy: 43.0%
#
# Epoch 1441
# -------------------------------
# train error:
#  G loss: 0.000172, cell accuracy: 99.9%, board accuracy: 87.6%
#
# test error:
#  G loss: 0.002121, cell accuracy: 99.0%, board accuracy: 42.8%
#
# Epoch 1442
# -------------------------------
# train error:
#  G loss: 0.000168, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002134, cell accuracy: 99.0%, board accuracy: 44.0%
#
# Epoch 1443
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002128, cell accuracy: 99.0%, board accuracy: 43.9%
#
# Epoch 1444
# -------------------------------
# train error:
#  G loss: 0.000170, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002114, cell accuracy: 99.0%, board accuracy: 44.8%
#
# Epoch 1445
# -------------------------------
# train error:
#  G loss: 0.000167, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002121, cell accuracy: 99.0%, board accuracy: 44.6%
#
# Epoch 1446
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002128, cell accuracy: 99.0%, board accuracy: 43.6%
#
# Epoch 1447
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002135, cell accuracy: 99.0%, board accuracy: 43.8%
#
# Epoch 1448
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002122, cell accuracy: 99.0%, board accuracy: 44.2%
#
# Epoch 1449
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002121, cell accuracy: 99.0%, board accuracy: 44.4%
#
# Epoch 1450
# -------------------------------
# train error:
#  G loss: 0.000168, cell accuracy: 99.9%, board accuracy: 88.0%
#
# test error:
#  G loss: 0.002110, cell accuracy: 99.0%, board accuracy: 43.8%
#
# Epoch 1451
# -------------------------------
# train error:
#  G loss: 0.000172, cell accuracy: 99.9%, board accuracy: 87.6%
#
# test error:
#  G loss: 0.002131, cell accuracy: 99.0%, board accuracy: 43.8%
#
# Epoch 1452
# -------------------------------
# train error:
#  G loss: 0.000174, cell accuracy: 99.9%, board accuracy: 87.5%
#
# test error:
#  G loss: 0.002150, cell accuracy: 99.0%, board accuracy: 43.5%
#
# Epoch 1453
# -------------------------------
# train error:
#  G loss: 0.000167, cell accuracy: 99.9%, board accuracy: 88.0%
#
# test error:
#  G loss: 0.002126, cell accuracy: 99.0%, board accuracy: 44.3%
#
# Epoch 1454
# -------------------------------
# train error:
#  G loss: 0.000166, cell accuracy: 99.9%, board accuracy: 88.0%
#
# test error:
#  G loss: 0.002128, cell accuracy: 99.0%, board accuracy: 43.5%
#
# Epoch 1455
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002142, cell accuracy: 99.0%, board accuracy: 43.5%
#
# Epoch 1456
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002123, cell accuracy: 99.0%, board accuracy: 44.0%
#
# Epoch 1457
# -------------------------------
# train error:
#  G loss: 0.000168, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002121, cell accuracy: 99.0%, board accuracy: 44.5%
#
# Epoch 1458
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002114, cell accuracy: 99.0%, board accuracy: 45.3%
#
# Epoch 1459
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002138, cell accuracy: 99.0%, board accuracy: 44.4%
#
# Epoch 1460
# -------------------------------
# train error:
#  G loss: 0.000166, cell accuracy: 99.9%, board accuracy: 88.1%
#
# test error:
#  G loss: 0.002098, cell accuracy: 99.0%, board accuracy: 44.9%
#
# Epoch 1461
# -------------------------------
# train error:
#  G loss: 0.000170, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002139, cell accuracy: 99.0%, board accuracy: 44.2%
#
# Epoch 1462
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002126, cell accuracy: 99.0%, board accuracy: 44.3%
#
# Epoch 1463
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002123, cell accuracy: 99.0%, board accuracy: 44.4%
#
# Epoch 1464
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002113, cell accuracy: 99.0%, board accuracy: 44.1%
#
# Epoch 1465
# -------------------------------
# train error:
#  G loss: 0.000170, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002133, cell accuracy: 99.0%, board accuracy: 43.8%
#
# Epoch 1466
# -------------------------------
# train error:
#  G loss: 0.000172, cell accuracy: 99.9%, board accuracy: 87.5%
#
# test error:
#  G loss: 0.002137, cell accuracy: 99.0%, board accuracy: 42.4%
#
# Epoch 1467
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.6%
#
# test error:
#  G loss: 0.002114, cell accuracy: 99.0%, board accuracy: 43.5%
#
# Epoch 1468
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002127, cell accuracy: 99.0%, board accuracy: 43.4%
#
# Epoch 1469
# -------------------------------
# train error:
#  G loss: 0.000170, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002148, cell accuracy: 99.0%, board accuracy: 44.5%
#
# Epoch 1470
# -------------------------------
# train error:
#  G loss: 0.000172, cell accuracy: 99.9%, board accuracy: 87.6%
#
# test error:
#  G loss: 0.002148, cell accuracy: 99.0%, board accuracy: 43.8%
#
# Epoch 1471
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002137, cell accuracy: 99.0%, board accuracy: 43.9%
#
# Epoch 1472
# -------------------------------
# train error:
#  G loss: 0.000170, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002135, cell accuracy: 99.0%, board accuracy: 44.4%
#
# Epoch 1473
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002153, cell accuracy: 99.0%, board accuracy: 43.6%
#
# Epoch 1474
# -------------------------------
# train error:
#  G loss: 0.000170, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002140, cell accuracy: 99.0%, board accuracy: 44.3%
#
# Epoch 1475
# -------------------------------
# train error:
#  G loss: 0.000171, cell accuracy: 99.9%, board accuracy: 87.7%
#
# test error:
#  G loss: 0.002154, cell accuracy: 99.0%, board accuracy: 43.2%
#
# Epoch 1476
# -------------------------------
# train error:
#  G loss: 0.000166, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002122, cell accuracy: 99.0%, board accuracy: 44.4%
#
# Epoch 1477
# -------------------------------
# train error:
#  G loss: 0.000168, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002139, cell accuracy: 99.0%, board accuracy: 44.3%
#
# Epoch 1478
# -------------------------------
# train error:
#  G loss: 0.000170, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002147, cell accuracy: 99.0%, board accuracy: 43.5%
#
# Epoch 1479
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002145, cell accuracy: 99.0%, board accuracy: 43.5%
#
# Epoch 1480
# -------------------------------
# train error:
#  G loss: 0.000165, cell accuracy: 99.9%, board accuracy: 88.1%
#
# test error:
#  G loss: 0.002140, cell accuracy: 99.0%, board accuracy: 43.9%
#
# Epoch 1481
# -------------------------------
# train error:
#  G loss: 0.000174, cell accuracy: 99.9%, board accuracy: 87.6%
#
# test error:
#  G loss: 0.002170, cell accuracy: 99.0%, board accuracy: 42.4%
#
# Epoch 1482
# -------------------------------
# train error:
#  G loss: 0.000165, cell accuracy: 99.9%, board accuracy: 88.2%
#
# test error:
#  G loss: 0.002110, cell accuracy: 99.0%, board accuracy: 44.5%
#
# Epoch 1483
# -------------------------------
# train error:
#  G loss: 0.000173, cell accuracy: 99.9%, board accuracy: 87.5%
#
# test error:
#  G loss: 0.002151, cell accuracy: 99.0%, board accuracy: 43.0%
#
# Epoch 1484
# -------------------------------
# train error:
#  G loss: 0.000166, cell accuracy: 99.9%, board accuracy: 88.1%
#
# test error:
#  G loss: 0.002134, cell accuracy: 99.0%, board accuracy: 44.4%
#
# Epoch 1485
# -------------------------------
# train error:
#  G loss: 0.000167, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002111, cell accuracy: 99.0%, board accuracy: 44.5%
#
# Epoch 1486
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002110, cell accuracy: 99.0%, board accuracy: 44.0%
#
# Epoch 1487
# -------------------------------
# train error:
#  G loss: 0.000165, cell accuracy: 99.9%, board accuracy: 88.1%
#
# test error:
#  G loss: 0.002097, cell accuracy: 99.0%, board accuracy: 44.6%
#
# Epoch 1488
# -------------------------------
# train error:
#  G loss: 0.000165, cell accuracy: 99.9%, board accuracy: 88.2%
#
# test error:
#  G loss: 0.002111, cell accuracy: 99.0%, board accuracy: 44.7%
#
# Epoch 1489
# -------------------------------
# train error:
#  G loss: 0.000167, cell accuracy: 99.9%, board accuracy: 88.0%
#
# test error:
#  G loss: 0.002113, cell accuracy: 99.0%, board accuracy: 44.4%
#
# Epoch 1490
# -------------------------------
# train error:
#  G loss: 0.000167, cell accuracy: 99.9%, board accuracy: 88.1%
#
# test error:
#  G loss: 0.002121, cell accuracy: 99.0%, board accuracy: 43.5%
#
# Epoch 1491
# -------------------------------
# train error:
#  G loss: 0.000166, cell accuracy: 99.9%, board accuracy: 88.1%
#
# test error:
#  G loss: 0.002130, cell accuracy: 99.0%, board accuracy: 44.7%
#
# Epoch 1492
# -------------------------------
# train error:
#  G loss: 0.000164, cell accuracy: 99.9%, board accuracy: 88.2%
#
# test error:
#  G loss: 0.002104, cell accuracy: 99.0%, board accuracy: 44.5%
#
# Epoch 1493
# -------------------------------
# train error:
#  G loss: 0.000168, cell accuracy: 99.9%, board accuracy: 88.0%
#
# test error:
#  G loss: 0.002148, cell accuracy: 99.0%, board accuracy: 43.7%
#
# Epoch 1494
# -------------------------------
# train error:
#  G loss: 0.000166, cell accuracy: 99.9%, board accuracy: 88.1%
#
# test error:
#  G loss: 0.002110, cell accuracy: 99.0%, board accuracy: 44.1%
#
# Epoch 1495
# -------------------------------
# train error:
#  G loss: 0.000168, cell accuracy: 99.9%, board accuracy: 88.0%
#
# test error:
#  G loss: 0.002123, cell accuracy: 99.0%, board accuracy: 44.6%
#
# Epoch 1496
# -------------------------------
# train error:
#  G loss: 0.000167, cell accuracy: 99.9%, board accuracy: 88.0%
#
# test error:
#  G loss: 0.002147, cell accuracy: 99.0%, board accuracy: 43.8%
#
# Epoch 1497
# -------------------------------
# train error:
#  G loss: 0.000165, cell accuracy: 99.9%, board accuracy: 88.1%
#
# test error:
#  G loss: 0.002134, cell accuracy: 99.0%, board accuracy: 43.5%
#
# Epoch 1498
# -------------------------------
# train error:
#  G loss: 0.000168, cell accuracy: 99.9%, board accuracy: 87.9%
#
# test error:
#  G loss: 0.002145, cell accuracy: 99.0%, board accuracy: 43.9%
#
# Epoch 1499
# -------------------------------
# train error:
#  G loss: 0.000169, cell accuracy: 99.9%, board accuracy: 87.8%
#
# test error:
#  G loss: 0.002129, cell accuracy: 99.0%, board accuracy: 43.7%
#
# Done!

# %%
cell_accuracies_train = compute_metric_by_event(metrics.CellAccuracy, train_dataloader)
cell_accuracies_test = compute_metric_by_event(metrics.CellAccuracy, test_dataloader)
board_accuracies_train = compute_metric_by_event(metrics.BoardAccuracy, train_dataloader)
board_accuracies_test = compute_metric_by_event(metrics.BoardAccuracy, test_dataloader)

for event_type in range(NUM_EVENT_TYPES):
    print(f"Stats for event type '{EVENT_NAMES[event_type]}':")
    print(f"  Cell accuracy (train): {cell_accuracies_train[event_type]:.2%}")
    print(f"  Cell accuracy (test): {cell_accuracies_test[event_type]:.2%}")
    print(f"  Board accuracy (train): {board_accuracies_train[event_type]:.2%}")
    print(f"  Board accuracy (test): {board_accuracies_test[event_type]:.2%}")
    print()
# Out:
# Stats for event type 'Drop':
#   Cell accuracy (train): 99.95%
#   Cell accuracy (test): 98.67%
#   Board accuracy (train): 91.43%
#   Board accuracy (test): 40.36%
#
# Stats for event type 'Left':
#   Cell accuracy (train): 99.92%
#   Cell accuracy (test): 99.46%
#   Board accuracy (train): 87.85%
#   Board accuracy (test): 49.48%
#
# Stats for event type 'Right':
#   Cell accuracy (train): 99.94%
#   Cell accuracy (test): 99.64%
#   Board accuracy (train): 90.78%
#   Board accuracy (test): 64.21%
#
# Stats for event type 'Rotate':
#   Cell accuracy (train): 99.86%
#   Cell accuracy (test): 99.28%
#   Board accuracy (train): 76.73%
#   Board accuracy (test): 46.57%
#
# Stats for event type 'Insta-drop':
#   Cell accuracy (train): 99.86%
#   Cell accuracy (test): 98.28%
#   Board accuracy (train): 80.83%
#   Board accuracy (test): 4.10%

# %%
def show_prediction(example):
    (b, e), y = example
    pred = gen(b.to(device).unsqueeze(0), e.to(device).unsqueeze(0)).squeeze(0).cpu()
    b, e, y, pred = b.argmax(0), e.argmax(0), y.argmax(0), pred.argmax(0)

    fig, axs = plt.subplots(1, 3)
    fig.suptitle(f"Prediction vs reality\nEvent = {EVENT_NAMES[e]}")

    for ax in axs:
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

    axs[0].set_title("Input")
    axs[1].set_title("Predicted")
    axs[2].set_title("Reality")

    num_mistakes = (y != pred).type(torch.int).sum().item()
    print(f"Mistakes: {num_mistakes}")
    axs[0].imshow(render_board(b).transpose((1, 2, 0)), vmin=0, vmax=1)
    axs[1].imshow(render_board(pred).transpose((1, 2, 0)), vmin=0, vmax=1)
    axs[2].imshow(render_board(y).transpose((1, 2, 0)), vmin=0, vmax=1)

    plt.show()

# %%
# Show a random training prediction vs reality
import random

idx = random.randrange(len(train_dataset))
print(f"Showing prediction for training example {idx}")
show_prediction(train_dataset[idx])
# Out:
# Showing prediction for training example 12715
# Mistakes: 0

# %%
torch.save(gen.state_dict(), "gamegan_emulator.pth")
