# %% [markdown]
# # Train generator with reconstruction loss
#
# In this notebook, we train the generator without a discriminator. We just take the MSE loss between the predicted next frame and actual next frame.

# %%
import os
from pathlib import Path
import shutil
import datetime

import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.utils.data import Dataset
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt


import models
from models import TetrisModel, TetrisDiscriminator, GameganAutoencoder
import metrics
from recording import FileBasedDatabaseWithEvents
from engines import EVENT_NAMES

# %%
NUM_CELL_TYPES = 8
NUM_EVENT_TYPES = 5

class RecordingDataset(Dataset):
    def __init__(self, path: str):
        self._db = FileBasedDatabaseWithEvents(path)

    def __len__(self):
        return len(self._db)

    def __getitem__(self, idx):
        boards, events = self._db[idx]
        b = self._transform_board(boards[-2]) # Ignore all boards except the last two
        e = self._transform_event(events[-1])
        x = (b, e)
        y = self._transform_board(boards[-1])
        return x, y
    
    def _transform_board(self, board):
        board = torch.tensor(board, dtype=torch.long)
        board = F.one_hot(board, NUM_CELL_TYPES) # One-hot encode the cell types
        board = board.type(torch.float) # Convert to floating-point
        board = board.permute((2, 0, 1)) # Move channels/classes to dimension 0
        return board
    
    def _transform_event(self, event):
        event = torch.tensor(event, dtype=torch.long)
        event = F.one_hot(event, NUM_EVENT_TYPES) # One-hot encode the event
        event = event.type(torch.float) # Convert to floating-point
        return event

# %%
# Put datasets in memory for faster training
train_dataset = list(RecordingDataset(os.path.join("data", "tetris_emulator", "train")))
test_dataset = list(RecordingDataset(os.path.join("data", "tetris_emulator", "test")))
batch_size = 12
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

(b, e), y = next(iter(train_dataloader))
print(f"x: shape {b.shape}, dtype {b.dtype}")
print(f"e: shape {e.shape}, dtype {e.dtype}")
print(f"y: shape {y.shape}, dtype {y.dtype}")
# Out:
# x: shape torch.Size([12, 8, 22, 10]), dtype torch.float32
# e: shape torch.Size([12, 5]), dtype torch.float32
# y: shape torch.Size([12, 8, 22, 10]), dtype torch.float32

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Using device {device}")
# Out:
# Using device cuda

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def compute_metric_by_event(metric_cls, dataloader):
    metrics = [metric_cls() for _ in range(NUM_EVENT_TYPES)]

    with torch.no_grad():        
        for ((b, e), y) in dataloader:
            b = b.to(device)
            e = e.to(device)
            y = y.to(device)

            batch_size = b.size(0)

            y_fake = gen(b, e)
            
            classes_b = torch.argmax(b, dim=1)
            classes_e = torch.argmax(e, dim=1)
            classes_y = torch.argmax(y, dim=1)
            classes_y_fake = torch.argmax(y_fake, dim=1)

            for idx in range(batch_size):
                class_e = classes_e[idx]
                metric = metrics[class_e]
                metric.update_state(classes_x=classes_b[idx:idx+1], classes_y_pred=classes_y_fake[idx:idx+1], classes_y=classes_y[idx:idx+1])

    return [metric.result() for metric in metrics]

# %%
import itertools

from engines import EventTypes
from tetris import CELL_COLORS

def render_board(board):
    height, width = board.shape
    img = np.zeros((3, height, width))
    for row in range(height):
        for col in range(width):
            img[:, row, col] = CELL_COLORS[board[row, col]]
    img /= 255.0
    return img

real_label = 1.0
fake_label = 0.0

def train_loop(dataloader, gen, loss_fn, optimizer_gen):
    gen.train()

    size = len(dataloader.dataset)
    for batch, ((b, e), y) in enumerate(dataloader):
        batch_size = b.size(0)

        b = b.to(device)
        e = e.to(device)
        y = y.to(device)

        gen.zero_grad()

        y_fake = gen(b, e)
        err_dyn = loss_fn(y_fake, y)
        err_dyn.backward()

        optimizer_gen.step()


def test_loop(split_name, dataloader, gen, loss_fn, tb_writer, epoch):
    gen.eval()

    loss_gen = 0.0
    cell_accuracy = metrics.CellAccuracy()
    board_accuracy = metrics.BoardAccuracy()
    spawn_recall = metrics.SpawnRecall()

    num_batches = len(dataloader)
    with torch.no_grad():        
        for batch, ((b, e), y) in enumerate(dataloader):
            batch_size = b.size(0)

            b = b.to(device)
            e = e.to(device)
            y = y.to(device)

            y_fake = gen(b, e)
        
            loss_gen += loss_fn(y_fake, y).item()

            classes_b = torch.argmax(b, dim=1)
            classes_e = torch.argmax(e, dim=1)
            classes_y = torch.argmax(y, dim=1)
            classes_y_fake = torch.argmax(y_fake, dim=1)
            cell_accuracy.update_state(classes_y_fake, classes_y)
            board_accuracy.update_state(classes_y_fake, classes_y)

            spawn_recall.update_state(classes_b, classes_y_fake, classes_y)

    loss_gen /= num_batches

    print(f"{split_name} error: \n G loss: {loss_gen:>8f}, cell accuracy: {(cell_accuracy.result()):>0.1%}, board accuracy: {(board_accuracy.result()):>0.1%} \n")

    tb_writer.add_scalar(f"Loss/{split_name}", loss_gen, epoch)
    tb_writer.add_scalar(f"Cell accuracy/{split_name}", cell_accuracy.result(), epoch)
    tb_writer.add_scalar(f"Board accuracy/{split_name}", board_accuracy.result(), epoch)
    tb_writer.add_scalar(f"Spawn recall/{split_name}", spawn_recall.result(), epoch)
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.10.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def train(run_name, gen_factory, epochs):

    learning_rate = 1e-4

    gen = gen_factory()

    loss_fn = nn.MSELoss()
    optimizer_gen = torch.optim.Adam(gen.parameters(), lr=learning_rate)

    log_dir = os.path.join("runs", "gen_with_rec_loss")
    log_subdir = os.path.join(log_dir, run_name + "_" + datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S"))
    tb_writer = SummaryWriter(log_subdir)

    try:
        for epoch in range(epochs):
            print(f"Epoch {epoch}\n-------------------------------")
            train_loop(train_dataloader, gen, loss_fn, optimizer_gen)
            test_loop("train", train_dataloader, gen, loss_fn, tb_writer, epoch)
            test_loop("test", test_dataloader, gen, loss_fn, tb_writer, epoch)
            gen_zero_grads = 0
            for name, weight in gen.named_parameters():
                tb_writer.add_histogram(f"Weights/{name}", weight, epoch)
                if weight.grad is not None:
                    tb_writer.add_histogram(f"Gradients/{name}", weight.grad, epoch)
                    gen_zero_grads += weight.grad.numel() - weight.grad.count_nonzero().item()
            tb_writer.add_scalar(f"Zero gradients", gen_zero_grads, epoch)
    finally:
        tb_writer.close()
        
    print("Done!")
    return gen

# %%
NUM_RANDOM_INPUTS = 4


from models import Conv2dLeakyReLU, ConvTranspose2dLeakyReLU, LinearLeakyReLU


class GameganGenerator(nn.Module):
    def __init__(self, leak=0.0):
        super().__init__()

        self.leak = leak

        self.board_encoder = models.GameganBoardEncoder()

        self.event_encoder = nn.Sequential(
            LinearLeakyReLU(NUM_EVENT_TYPES + NUM_RANDOM_INPUTS, 32, negative_slope=leak),
            LinearLeakyReLU(32, 32, negative_slope=leak),
            LinearLeakyReLU(32, 32, negative_slope=leak),
        )

        self.dynamics = nn.Sequential(
            LinearLeakyReLU(256 + 32, 256, negative_slope=leak),
            LinearLeakyReLU(256, 256, negative_slope=leak),
            LinearLeakyReLU(256, 256, negative_slope=leak),
        )

        self.renderer = models.GameganRenderer()

    def forward(self, b, e):
        batch_size, cell_channels, height, width = b.shape

        # Encode board state
        s = self.board_encoder(b)

        # Generate random inputs
        z = torch.rand(batch_size, NUM_RANDOM_INPUTS, device=device)

        # Encode events and random inputs
        v = self.event_encoder(torch.cat((e, z), dim=1))

        # Combine encodings
        h = torch.cat((s, v), dim=1)

        # Apply game dynamics
        h = self.dynamics(h)

        # Render new board
        y = self.renderer(h)
        return y


print(f"Parameters: {count_parameters(GameganGenerator())}")
# Out:
# Parameters: 590280

# %%
gen = train(
    run_name="run",
    gen_factory=lambda: GameganGenerator(leak=0.2).to(device),
    epochs=1500
)
# Out:
# Epoch 0
# -------------------------------
# train error:
#  G loss: 0.037001, cell accuracy: 78.5%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.037057, cell accuracy: 78.4%, board accuracy: 0.0%
#
# Epoch 1
# -------------------------------
# train error:
#  G loss: 0.021028, cell accuracy: 89.0%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.021253, cell accuracy: 88.8%, board accuracy: 0.0%
#
# Epoch 2
# -------------------------------
# train error:
#  G loss: 0.015727, cell accuracy: 92.0%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.016055, cell accuracy: 91.8%, board accuracy: 0.0%
#
# Epoch 3
# -------------------------------
# train error:
#  G loss: 0.012758, cell accuracy: 93.8%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.013148, cell accuracy: 93.5%, board accuracy: 0.0%
#
# Epoch 4
# -------------------------------
# train error:
#  G loss: 0.010632, cell accuracy: 94.9%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.011039, cell accuracy: 94.7%, board accuracy: 0.0%
#
# Epoch 5
# -------------------------------
# train error:
#  G loss: 0.009189, cell accuracy: 95.7%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.009624, cell accuracy: 95.5%, board accuracy: 0.1%
#
# Epoch 6
# -------------------------------
# train error:
#  G loss: 0.008081, cell accuracy: 96.2%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.008563, cell accuracy: 96.0%, board accuracy: 0.1%
#
# Epoch 7
# -------------------------------
# train error:
#  G loss: 0.007279, cell accuracy: 96.6%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.007767, cell accuracy: 96.4%, board accuracy: 0.1%
#
# Epoch 8
# -------------------------------
# train error:
#  G loss: 0.006586, cell accuracy: 96.9%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.007100, cell accuracy: 96.7%, board accuracy: 0.1%
#
# Epoch 9
# -------------------------------
# train error:
#  G loss: 0.006130, cell accuracy: 97.1%, board accuracy: 0.3%
#
# test error:
#  G loss: 0.006700, cell accuracy: 96.9%, board accuracy: 0.2%
#
# Epoch 10
# -------------------------------
# train error:
#  G loss: 0.005725, cell accuracy: 97.3%, board accuracy: 0.5%
#
# test error:
#  G loss: 0.006321, cell accuracy: 97.0%, board accuracy: 0.2%
#
# Epoch 11
# -------------------------------
# train error:
#  G loss: 0.005386, cell accuracy: 97.4%, board accuracy: 0.5%
#
# test error:
#  G loss: 0.006013, cell accuracy: 97.1%, board accuracy: 0.3%
#
# Epoch 12
# -------------------------------
# train error:
#  G loss: 0.005138, cell accuracy: 97.5%, board accuracy: 0.8%
#
# test error:
#  G loss: 0.005808, cell accuracy: 97.2%, board accuracy: 0.2%
#
# Epoch 13
# -------------------------------
# train error:
#  G loss: 0.004892, cell accuracy: 97.6%, board accuracy: 1.1%
#
# test error:
#  G loss: 0.005596, cell accuracy: 97.3%, board accuracy: 0.5%
#
# Epoch 14
# -------------------------------
# train error:
#  G loss: 0.004639, cell accuracy: 97.7%, board accuracy: 1.2%
#
# test error:
#  G loss: 0.005368, cell accuracy: 97.4%, board accuracy: 0.4%
#
# Epoch 15
# -------------------------------
# train error:
#  G loss: 0.004463, cell accuracy: 97.8%, board accuracy: 1.5%
#
# test error:
#  G loss: 0.005231, cell accuracy: 97.4%, board accuracy: 0.6%
#
# Epoch 16
# -------------------------------
# train error:
#  G loss: 0.004312, cell accuracy: 97.8%, board accuracy: 1.8%
#
# test error:
#  G loss: 0.005091, cell accuracy: 97.5%, board accuracy: 0.8%
#
# Epoch 17
# -------------------------------
# train error:
#  G loss: 0.004175, cell accuracy: 97.9%, board accuracy: 1.8%
#
# test error:
#  G loss: 0.004985, cell accuracy: 97.5%, board accuracy: 0.4%
#
# Epoch 18
# -------------------------------
# train error:
#  G loss: 0.004075, cell accuracy: 97.9%, board accuracy: 1.9%
#
# test error:
#  G loss: 0.004949, cell accuracy: 97.5%, board accuracy: 0.7%
#
# Epoch 19
# -------------------------------
# train error:
#  G loss: 0.003878, cell accuracy: 98.1%, board accuracy: 2.7%
#
# test error:
#  G loss: 0.004798, cell accuracy: 97.6%, board accuracy: 0.8%
#
# Epoch 20
# -------------------------------
# train error:
#  G loss: 0.003771, cell accuracy: 98.1%, board accuracy: 2.7%
#
# test error:
#  G loss: 0.004699, cell accuracy: 97.6%, board accuracy: 0.7%
#
# Epoch 21
# -------------------------------
# train error:
#  G loss: 0.003680, cell accuracy: 98.1%, board accuracy: 3.3%
#
# test error:
#  G loss: 0.004634, cell accuracy: 97.7%, board accuracy: 0.9%
#
# Epoch 22
# -------------------------------
# train error:
#  G loss: 0.003579, cell accuracy: 98.2%, board accuracy: 3.7%
#
# test error:
#  G loss: 0.004601, cell accuracy: 97.7%, board accuracy: 1.1%
#
# Epoch 23
# -------------------------------
# train error:
#  G loss: 0.003439, cell accuracy: 98.3%, board accuracy: 4.5%
#
# test error:
#  G loss: 0.004470, cell accuracy: 97.8%, board accuracy: 1.4%
#
# Epoch 24
# -------------------------------
# train error:
#  G loss: 0.003385, cell accuracy: 98.3%, board accuracy: 5.3%
#
# test error:
#  G loss: 0.004477, cell accuracy: 97.8%, board accuracy: 2.1%
#
# Epoch 25
# -------------------------------
# train error:
#  G loss: 0.003284, cell accuracy: 98.3%, board accuracy: 6.1%
#
# test error:
#  G loss: 0.004381, cell accuracy: 97.8%, board accuracy: 2.1%
#
# Epoch 26
# -------------------------------
# train error:
#  G loss: 0.003166, cell accuracy: 98.4%, board accuracy: 7.5%
#
# test error:
#  G loss: 0.004278, cell accuracy: 97.9%, board accuracy: 2.7%
#
# Epoch 27
# -------------------------------
# train error:
#  G loss: 0.003031, cell accuracy: 98.5%, board accuracy: 7.9%
#
# test error:
#  G loss: 0.004223, cell accuracy: 97.9%, board accuracy: 3.1%
#
# Epoch 28
# -------------------------------
# train error:
#  G loss: 0.002931, cell accuracy: 98.5%, board accuracy: 9.4%
#
# test error:
#  G loss: 0.004160, cell accuracy: 97.9%, board accuracy: 3.0%
#
# Epoch 29
# -------------------------------
# train error:
#  G loss: 0.002871, cell accuracy: 98.6%, board accuracy: 9.7%
#
# test error:
#  G loss: 0.004100, cell accuracy: 97.9%, board accuracy: 4.2%
#
# Epoch 30
# -------------------------------
# train error:
#  G loss: 0.002756, cell accuracy: 98.6%, board accuracy: 11.0%
#
# test error:
#  G loss: 0.004018, cell accuracy: 98.0%, board accuracy: 4.8%
#
# Epoch 31
# -------------------------------
# train error:
#  G loss: 0.002663, cell accuracy: 98.7%, board accuracy: 12.2%
#
# test error:
#  G loss: 0.003951, cell accuracy: 98.0%, board accuracy: 5.1%
#
# Epoch 32
# -------------------------------
# train error:
#  G loss: 0.002639, cell accuracy: 98.7%, board accuracy: 13.0%
#
# test error:
#  G loss: 0.003962, cell accuracy: 98.0%, board accuracy: 5.1%
#
# Epoch 33
# -------------------------------
# train error:
#  G loss: 0.002538, cell accuracy: 98.7%, board accuracy: 13.3%
#
# test error:
#  G loss: 0.003851, cell accuracy: 98.1%, board accuracy: 5.6%
#
# Epoch 34
# -------------------------------
# train error:
#  G loss: 0.002487, cell accuracy: 98.8%, board accuracy: 15.2%
#
# test error:
#  G loss: 0.003859, cell accuracy: 98.1%, board accuracy: 6.2%
#
# Epoch 35
# -------------------------------
# train error:
#  G loss: 0.002319, cell accuracy: 98.9%, board accuracy: 16.8%
#
# test error:
#  G loss: 0.003733, cell accuracy: 98.1%, board accuracy: 6.6%
#
# Epoch 36
# -------------------------------
# train error:
#  G loss: 0.002278, cell accuracy: 98.9%, board accuracy: 18.4%
#
# test error:
#  G loss: 0.003739, cell accuracy: 98.1%, board accuracy: 6.6%
#
# Epoch 37
# -------------------------------
# train error:
#  G loss: 0.002291, cell accuracy: 98.9%, board accuracy: 17.7%
#
# test error:
#  G loss: 0.003793, cell accuracy: 98.1%, board accuracy: 6.9%
#
# Epoch 38
# -------------------------------
# train error:
#  G loss: 0.002161, cell accuracy: 99.0%, board accuracy: 20.6%
#
# test error:
#  G loss: 0.003660, cell accuracy: 98.2%, board accuracy: 7.5%
#
# Epoch 39
# -------------------------------
# train error:
#  G loss: 0.002133, cell accuracy: 99.0%, board accuracy: 19.7%
#
# test error:
#  G loss: 0.003617, cell accuracy: 98.2%, board accuracy: 7.3%
#
# Epoch 40
# -------------------------------
# train error:
#  G loss: 0.002083, cell accuracy: 99.0%, board accuracy: 20.7%
#
# test error:
#  G loss: 0.003611, cell accuracy: 98.2%, board accuracy: 8.1%
#
# Epoch 41
# -------------------------------
# train error:
#  G loss: 0.001992, cell accuracy: 99.0%, board accuracy: 22.5%
#
# test error:
#  G loss: 0.003563, cell accuracy: 98.2%, board accuracy: 8.3%
#
# Epoch 42
# -------------------------------
# train error:
#  G loss: 0.001933, cell accuracy: 99.1%, board accuracy: 24.6%
#
# test error:
#  G loss: 0.003549, cell accuracy: 98.2%, board accuracy: 9.4%
#
# Epoch 43
# -------------------------------
# train error:
#  G loss: 0.001881, cell accuracy: 99.1%, board accuracy: 24.9%
#
# test error:
#  G loss: 0.003529, cell accuracy: 98.2%, board accuracy: 8.7%
#
# Epoch 44
# -------------------------------
# train error:
#  G loss: 0.001850, cell accuracy: 99.1%, board accuracy: 25.6%
#
# test error:
#  G loss: 0.003534, cell accuracy: 98.2%, board accuracy: 9.9%
#
# Epoch 45
# -------------------------------
# train error:
#  G loss: 0.001735, cell accuracy: 99.2%, board accuracy: 27.8%
#
# test error:
#  G loss: 0.003402, cell accuracy: 98.3%, board accuracy: 10.7%
#
# Epoch 46
# -------------------------------
# train error:
#  G loss: 0.001733, cell accuracy: 99.2%, board accuracy: 28.1%
#
# test error:
#  G loss: 0.003484, cell accuracy: 98.3%, board accuracy: 10.3%
#
# Epoch 47
# -------------------------------
# train error:
#  G loss: 0.001679, cell accuracy: 99.2%, board accuracy: 29.5%
#
# test error:
#  G loss: 0.003425, cell accuracy: 98.3%, board accuracy: 10.9%
#
# Epoch 48
# -------------------------------
# train error:
#  G loss: 0.001630, cell accuracy: 99.2%, board accuracy: 30.9%
#
# test error:
#  G loss: 0.003387, cell accuracy: 98.3%, board accuracy: 11.4%
#
# Epoch 49
# -------------------------------
# train error:
#  G loss: 0.001592, cell accuracy: 99.3%, board accuracy: 31.6%
#
# test error:
#  G loss: 0.003395, cell accuracy: 98.3%, board accuracy: 11.7%
#
# Epoch 50
# -------------------------------
# train error:
#  G loss: 0.001522, cell accuracy: 99.3%, board accuracy: 33.7%
#
# test error:
#  G loss: 0.003350, cell accuracy: 98.3%, board accuracy: 11.3%
#
# Epoch 51
# -------------------------------
# train error:
#  G loss: 0.001485, cell accuracy: 99.3%, board accuracy: 33.2%
#
# test error:
#  G loss: 0.003344, cell accuracy: 98.3%, board accuracy: 11.6%
#
# Epoch 52
# -------------------------------
# train error:
#  G loss: 0.001431, cell accuracy: 99.3%, board accuracy: 35.8%
#
# test error:
#  G loss: 0.003284, cell accuracy: 98.4%, board accuracy: 12.4%
#
# Epoch 53
# -------------------------------
# train error:
#  G loss: 0.001452, cell accuracy: 99.3%, board accuracy: 35.9%
#
# test error:
#  G loss: 0.003325, cell accuracy: 98.3%, board accuracy: 12.2%
#
# Epoch 54
# -------------------------------
# train error:
#  G loss: 0.001392, cell accuracy: 99.4%, board accuracy: 37.2%
#
# test error:
#  G loss: 0.003326, cell accuracy: 98.3%, board accuracy: 13.5%
#
# Epoch 55
# -------------------------------
# train error:
#  G loss: 0.001348, cell accuracy: 99.4%, board accuracy: 37.6%
#
# test error:
#  G loss: 0.003270, cell accuracy: 98.4%, board accuracy: 13.1%
#
# Epoch 56
# -------------------------------
# train error:
#  G loss: 0.001309, cell accuracy: 99.4%, board accuracy: 39.1%
#
# test error:
#  G loss: 0.003207, cell accuracy: 98.4%, board accuracy: 13.8%
#
# Epoch 57
# -------------------------------
# train error:
#  G loss: 0.001334, cell accuracy: 99.4%, board accuracy: 38.9%
#
# test error:
#  G loss: 0.003291, cell accuracy: 98.4%, board accuracy: 13.4%
#
# Epoch 58
# -------------------------------
# train error:
#  G loss: 0.001312, cell accuracy: 99.4%, board accuracy: 38.9%
#
# test error:
#  G loss: 0.003306, cell accuracy: 98.4%, board accuracy: 12.4%
#
# Epoch 59
# -------------------------------
# train error:
#  G loss: 0.001261, cell accuracy: 99.4%, board accuracy: 40.6%
#
# test error:
#  G loss: 0.003227, cell accuracy: 98.4%, board accuracy: 13.3%
#
# Epoch 60
# -------------------------------
# train error:
#  G loss: 0.001213, cell accuracy: 99.4%, board accuracy: 41.9%
#
# test error:
#  G loss: 0.003248, cell accuracy: 98.4%, board accuracy: 12.5%
#
# Epoch 61
# -------------------------------
# train error:
#  G loss: 0.001161, cell accuracy: 99.5%, board accuracy: 45.3%
#
# test error:
#  G loss: 0.003192, cell accuracy: 98.4%, board accuracy: 13.7%
#
# Epoch 62
# -------------------------------
# train error:
#  G loss: 0.001173, cell accuracy: 99.5%, board accuracy: 42.6%
#
# test error:
#  G loss: 0.003200, cell accuracy: 98.4%, board accuracy: 13.7%
#
# Epoch 63
# -------------------------------
# train error:
#  G loss: 0.001121, cell accuracy: 99.5%, board accuracy: 45.6%
#
# test error:
#  G loss: 0.003204, cell accuracy: 98.4%, board accuracy: 14.8%
#
# Epoch 64
# -------------------------------
# train error:
#  G loss: 0.001119, cell accuracy: 99.5%, board accuracy: 45.6%
#
# test error:
#  G loss: 0.003169, cell accuracy: 98.4%, board accuracy: 14.6%
#
# Epoch 65
# -------------------------------
# train error:
#  G loss: 0.001090, cell accuracy: 99.5%, board accuracy: 45.6%
#
# test error:
#  G loss: 0.003196, cell accuracy: 98.4%, board accuracy: 14.0%
#
# Epoch 66
# -------------------------------
# train error:
#  G loss: 0.001035, cell accuracy: 99.5%, board accuracy: 48.9%
#
# test error:
#  G loss: 0.003130, cell accuracy: 98.4%, board accuracy: 15.0%
#
# Epoch 67
# -------------------------------
# train error:
#  G loss: 0.001010, cell accuracy: 99.5%, board accuracy: 49.2%
#
# test error:
#  G loss: 0.003128, cell accuracy: 98.4%, board accuracy: 15.8%
#
# Epoch 68
# -------------------------------
# train error:
#  G loss: 0.001063, cell accuracy: 99.5%, board accuracy: 46.8%
#
# test error:
#  G loss: 0.003172, cell accuracy: 98.4%, board accuracy: 14.8%
#
# Epoch 69
# -------------------------------
# train error:
#  G loss: 0.001013, cell accuracy: 99.5%, board accuracy: 48.8%
#
# test error:
#  G loss: 0.003157, cell accuracy: 98.4%, board accuracy: 15.6%
#
# Epoch 70
# -------------------------------
# train error:
#  G loss: 0.001002, cell accuracy: 99.6%, board accuracy: 49.4%
#
# test error:
#  G loss: 0.003154, cell accuracy: 98.4%, board accuracy: 16.1%
#
# Epoch 71
# -------------------------------
# train error:
#  G loss: 0.000965, cell accuracy: 99.6%, board accuracy: 50.9%
#
# test error:
#  G loss: 0.003112, cell accuracy: 98.5%, board accuracy: 16.6%
#
# Epoch 72
# -------------------------------
# train error:
#  G loss: 0.000952, cell accuracy: 99.6%, board accuracy: 50.7%
#
# test error:
#  G loss: 0.003125, cell accuracy: 98.5%, board accuracy: 16.3%
#
# Epoch 73
# -------------------------------
# train error:
#  G loss: 0.000925, cell accuracy: 99.6%, board accuracy: 52.0%
#
# test error:
#  G loss: 0.003141, cell accuracy: 98.5%, board accuracy: 16.6%
#
# Epoch 74
# -------------------------------
# train error:
#  G loss: 0.000926, cell accuracy: 99.6%, board accuracy: 52.3%
#
# test error:
#  G loss: 0.003115, cell accuracy: 98.5%, board accuracy: 17.1%
#
# Epoch 75
# -------------------------------
# train error:
#  G loss: 0.000909, cell accuracy: 99.6%, board accuracy: 52.7%
#
# test error:
#  G loss: 0.003105, cell accuracy: 98.5%, board accuracy: 16.3%
#
# Epoch 76
# -------------------------------
# train error:
#  G loss: 0.000883, cell accuracy: 99.6%, board accuracy: 54.2%
#
# test error:
#  G loss: 0.003103, cell accuracy: 98.5%, board accuracy: 17.0%
#
# Epoch 77
# -------------------------------
# train error:
#  G loss: 0.000843, cell accuracy: 99.6%, board accuracy: 56.0%
#
# test error:
#  G loss: 0.003070, cell accuracy: 98.5%, board accuracy: 18.1%
#
# Epoch 78
# -------------------------------
# train error:
#  G loss: 0.000847, cell accuracy: 99.6%, board accuracy: 55.8%
#
# test error:
#  G loss: 0.003099, cell accuracy: 98.5%, board accuracy: 16.9%
#
# Epoch 79
# -------------------------------
# train error:
#  G loss: 0.000884, cell accuracy: 99.6%, board accuracy: 53.5%
#
# test error:
#  G loss: 0.003163, cell accuracy: 98.4%, board accuracy: 16.6%
#
# Epoch 80
# -------------------------------
# train error:
#  G loss: 0.000806, cell accuracy: 99.6%, board accuracy: 57.1%
#
# test error:
#  G loss: 0.003073, cell accuracy: 98.5%, board accuracy: 16.9%
#
# Epoch 81
# -------------------------------
# train error:
#  G loss: 0.000795, cell accuracy: 99.6%, board accuracy: 57.8%
#
# test error:
#  G loss: 0.003066, cell accuracy: 98.5%, board accuracy: 17.9%
#
# Epoch 82
# -------------------------------
# train error:
#  G loss: 0.000819, cell accuracy: 99.6%, board accuracy: 56.2%
#
# test error:
#  G loss: 0.003103, cell accuracy: 98.5%, board accuracy: 18.1%
#
# Epoch 83
# -------------------------------
# train error:
#  G loss: 0.000813, cell accuracy: 99.6%, board accuracy: 56.7%
#
# test error:
#  G loss: 0.003072, cell accuracy: 98.5%, board accuracy: 17.5%
#
# Epoch 84
# -------------------------------
# train error:
#  G loss: 0.000804, cell accuracy: 99.6%, board accuracy: 56.6%
#
# test error:
#  G loss: 0.003125, cell accuracy: 98.5%, board accuracy: 16.5%
#
# Epoch 85
# -------------------------------
# train error:
#  G loss: 0.000763, cell accuracy: 99.7%, board accuracy: 58.8%
#
# test error:
#  G loss: 0.003088, cell accuracy: 98.5%, board accuracy: 17.2%
#
# Epoch 86
# -------------------------------
# train error:
#  G loss: 0.000746, cell accuracy: 99.7%, board accuracy: 59.6%
#
# test error:
#  G loss: 0.003054, cell accuracy: 98.5%, board accuracy: 18.2%
#
# Epoch 87
# -------------------------------
# train error:
#  G loss: 0.000736, cell accuracy: 99.7%, board accuracy: 60.0%
#
# test error:
#  G loss: 0.003038, cell accuracy: 98.5%, board accuracy: 18.8%
#
# Epoch 88
# -------------------------------
# train error:
#  G loss: 0.000728, cell accuracy: 99.7%, board accuracy: 60.4%
#
# test error:
#  G loss: 0.003029, cell accuracy: 98.5%, board accuracy: 17.6%
#
# Epoch 89
# -------------------------------
# train error:
#  G loss: 0.000764, cell accuracy: 99.7%, board accuracy: 58.5%
#
# test error:
#  G loss: 0.003071, cell accuracy: 98.5%, board accuracy: 17.6%
#
# Epoch 90
# -------------------------------
# train error:
#  G loss: 0.000700, cell accuracy: 99.7%, board accuracy: 62.3%
#
# test error:
#  G loss: 0.003000, cell accuracy: 98.5%, board accuracy: 20.0%
#
# Epoch 91
# -------------------------------
# train error:
#  G loss: 0.000729, cell accuracy: 99.7%, board accuracy: 60.4%
#
# test error:
#  G loss: 0.003072, cell accuracy: 98.5%, board accuracy: 17.6%
#
# Epoch 92
# -------------------------------
# train error:
#  G loss: 0.000737, cell accuracy: 99.7%, board accuracy: 59.8%
#
# test error:
#  G loss: 0.003024, cell accuracy: 98.5%, board accuracy: 18.6%
#
# Epoch 93
# -------------------------------
# train error:
#  G loss: 0.000660, cell accuracy: 99.7%, board accuracy: 63.6%
#
# test error:
#  G loss: 0.003002, cell accuracy: 98.5%, board accuracy: 19.8%
#
# Epoch 94
# -------------------------------
# train error:
#  G loss: 0.000694, cell accuracy: 99.7%, board accuracy: 61.9%
#
# test error:
#  G loss: 0.003038, cell accuracy: 98.5%, board accuracy: 19.0%
#
# Epoch 95
# -------------------------------
# train error:
#  G loss: 0.000658, cell accuracy: 99.7%, board accuracy: 63.5%
#
# test error:
#  G loss: 0.003017, cell accuracy: 98.5%, board accuracy: 18.9%
#
# Epoch 96
# -------------------------------
# train error:
#  G loss: 0.000688, cell accuracy: 99.7%, board accuracy: 62.5%
#
# test error:
#  G loss: 0.003041, cell accuracy: 98.5%, board accuracy: 20.1%
#
# Epoch 97
# -------------------------------
# train error:
#  G loss: 0.000668, cell accuracy: 99.7%, board accuracy: 62.9%
#
# test error:
#  G loss: 0.003031, cell accuracy: 98.5%, board accuracy: 19.7%
#
# Epoch 98
# -------------------------------
# train error:
#  G loss: 0.000675, cell accuracy: 99.7%, board accuracy: 62.2%
#
# test error:
#  G loss: 0.003026, cell accuracy: 98.5%, board accuracy: 18.6%
#
# Epoch 99
# -------------------------------
# train error:
#  G loss: 0.000665, cell accuracy: 99.7%, board accuracy: 62.6%
#
# test error:
#  G loss: 0.003082, cell accuracy: 98.5%, board accuracy: 18.7%
#
# Epoch 100
# -------------------------------
# train error:
#  G loss: 0.000628, cell accuracy: 99.7%, board accuracy: 64.5%
#
# test error:
#  G loss: 0.002979, cell accuracy: 98.5%, board accuracy: 19.2%
#
# Epoch 101
# -------------------------------
# train error:
#  G loss: 0.000603, cell accuracy: 99.7%, board accuracy: 66.0%
#
# test error:
#  G loss: 0.002974, cell accuracy: 98.6%, board accuracy: 19.5%
#
# Epoch 102
# -------------------------------
# train error:
#  G loss: 0.000602, cell accuracy: 99.7%, board accuracy: 66.2%
#
# test error:
#  G loss: 0.003010, cell accuracy: 98.5%, board accuracy: 19.4%
#
# Epoch 103
# -------------------------------
# train error:
#  G loss: 0.000600, cell accuracy: 99.7%, board accuracy: 65.8%
#
# test error:
#  G loss: 0.002992, cell accuracy: 98.5%, board accuracy: 20.2%
#
# Epoch 104
# -------------------------------
# train error:
#  G loss: 0.000591, cell accuracy: 99.7%, board accuracy: 66.5%
#
# test error:
#  G loss: 0.002998, cell accuracy: 98.5%, board accuracy: 21.1%
#
# Epoch 105
# -------------------------------
# train error:
#  G loss: 0.000582, cell accuracy: 99.7%, board accuracy: 66.9%
#
# test error:
#  G loss: 0.003007, cell accuracy: 98.5%, board accuracy: 20.3%
#
# Epoch 106
# -------------------------------
# train error:
#  G loss: 0.000613, cell accuracy: 99.7%, board accuracy: 64.6%
#
# test error:
#  G loss: 0.003033, cell accuracy: 98.5%, board accuracy: 19.7%
#
# Epoch 107
# -------------------------------
# train error:
#  G loss: 0.000578, cell accuracy: 99.7%, board accuracy: 67.3%
#
# test error:
#  G loss: 0.002972, cell accuracy: 98.6%, board accuracy: 21.1%
#
# Epoch 108
# -------------------------------
# train error:
#  G loss: 0.000547, cell accuracy: 99.8%, board accuracy: 68.4%
#
# test error:
#  G loss: 0.002967, cell accuracy: 98.6%, board accuracy: 21.3%
#
# Epoch 109
# -------------------------------
# train error:
#  G loss: 0.000568, cell accuracy: 99.7%, board accuracy: 66.8%
#
# test error:
#  G loss: 0.002985, cell accuracy: 98.6%, board accuracy: 19.7%
#
# Epoch 110
# -------------------------------
# train error:
#  G loss: 0.000587, cell accuracy: 99.7%, board accuracy: 66.0%
#
# test error:
#  G loss: 0.003001, cell accuracy: 98.5%, board accuracy: 20.4%
#
# Epoch 111
# -------------------------------
# train error:
#  G loss: 0.000580, cell accuracy: 99.7%, board accuracy: 65.9%
#
# test error:
#  G loss: 0.002981, cell accuracy: 98.6%, board accuracy: 20.4%
#
# Epoch 112
# -------------------------------
# train error:
#  G loss: 0.000553, cell accuracy: 99.8%, board accuracy: 67.0%
#
# test error:
#  G loss: 0.003022, cell accuracy: 98.5%, board accuracy: 20.4%
#
# Epoch 113
# -------------------------------
# train error:
#  G loss: 0.000515, cell accuracy: 99.8%, board accuracy: 69.7%
#
# test error:
#  G loss: 0.002925, cell accuracy: 98.6%, board accuracy: 21.9%
#
# Epoch 114
# -------------------------------
# train error:
#  G loss: 0.000540, cell accuracy: 99.8%, board accuracy: 68.3%
#
# test error:
#  G loss: 0.002975, cell accuracy: 98.6%, board accuracy: 22.0%
#
# Epoch 115
# -------------------------------
# train error:
#  G loss: 0.000531, cell accuracy: 99.8%, board accuracy: 68.5%
#
# test error:
#  G loss: 0.002987, cell accuracy: 98.6%, board accuracy: 20.4%
#
# Epoch 116
# -------------------------------
# train error:
#  G loss: 0.000512, cell accuracy: 99.8%, board accuracy: 70.2%
#
# test error:
#  G loss: 0.002948, cell accuracy: 98.6%, board accuracy: 22.7%
#
# Epoch 117
# -------------------------------
# train error:
#  G loss: 0.000534, cell accuracy: 99.8%, board accuracy: 69.1%
#
# test error:
#  G loss: 0.002950, cell accuracy: 98.6%, board accuracy: 21.6%
#
# Epoch 118
# -------------------------------
# train error:
#  G loss: 0.000542, cell accuracy: 99.8%, board accuracy: 68.0%
#
# test error:
#  G loss: 0.003014, cell accuracy: 98.5%, board accuracy: 20.8%
#
# Epoch 119
# -------------------------------
# train error:
#  G loss: 0.000517, cell accuracy: 99.8%, board accuracy: 69.6%
#
# test error:
#  G loss: 0.002982, cell accuracy: 98.6%, board accuracy: 21.0%
#
# Epoch 120
# -------------------------------
# train error:
#  G loss: 0.000496, cell accuracy: 99.8%, board accuracy: 71.2%
#
# test error:
#  G loss: 0.002908, cell accuracy: 98.6%, board accuracy: 22.4%
#
# Epoch 121
# -------------------------------
# train error:
#  G loss: 0.000533, cell accuracy: 99.8%, board accuracy: 68.2%
#
# test error:
#  G loss: 0.003023, cell accuracy: 98.5%, board accuracy: 21.1%
#
# Epoch 122
# -------------------------------
# train error:
#  G loss: 0.000500, cell accuracy: 99.8%, board accuracy: 71.0%
#
# test error:
#  G loss: 0.002946, cell accuracy: 98.6%, board accuracy: 20.5%
#
# Epoch 123
# -------------------------------
# train error:
#  G loss: 0.000501, cell accuracy: 99.8%, board accuracy: 70.2%
#
# test error:
#  G loss: 0.002975, cell accuracy: 98.6%, board accuracy: 20.9%
#
# Epoch 124
# -------------------------------
# train error:
#  G loss: 0.000494, cell accuracy: 99.8%, board accuracy: 71.0%
#
# test error:
#  G loss: 0.002942, cell accuracy: 98.6%, board accuracy: 22.4%
#
# Epoch 125
# -------------------------------
# train error:
#  G loss: 0.000472, cell accuracy: 99.8%, board accuracy: 72.2%
#
# test error:
#  G loss: 0.002927, cell accuracy: 98.6%, board accuracy: 22.1%
#
# Epoch 126
# -------------------------------
# train error:
#  G loss: 0.000491, cell accuracy: 99.8%, board accuracy: 70.8%
#
# test error:
#  G loss: 0.002927, cell accuracy: 98.6%, board accuracy: 22.2%
#
# Epoch 127
# -------------------------------
# train error:
#  G loss: 0.000521, cell accuracy: 99.8%, board accuracy: 68.9%
#
# test error:
#  G loss: 0.003018, cell accuracy: 98.5%, board accuracy: 21.3%
#
# Epoch 128
# -------------------------------
# train error:
#  G loss: 0.000496, cell accuracy: 99.8%, board accuracy: 70.7%
#
# test error:
#  G loss: 0.002982, cell accuracy: 98.6%, board accuracy: 21.6%
#
# Epoch 129
# -------------------------------
# train error:
#  G loss: 0.000480, cell accuracy: 99.8%, board accuracy: 70.9%
#
# test error:
#  G loss: 0.002984, cell accuracy: 98.6%, board accuracy: 21.1%
#
# Epoch 130
# -------------------------------
# train error:
#  G loss: 0.000490, cell accuracy: 99.8%, board accuracy: 70.7%
#
# test error:
#  G loss: 0.002991, cell accuracy: 98.6%, board accuracy: 21.2%
#
# Epoch 131
# -------------------------------
# train error:
#  G loss: 0.000471, cell accuracy: 99.8%, board accuracy: 71.0%
#
# test error:
#  G loss: 0.002957, cell accuracy: 98.6%, board accuracy: 21.2%
#
# Epoch 132
# -------------------------------
# train error:
#  G loss: 0.000463, cell accuracy: 99.8%, board accuracy: 71.8%
#
# test error:
#  G loss: 0.002944, cell accuracy: 98.6%, board accuracy: 21.3%
#
# Epoch 133
# -------------------------------
# train error:
#  G loss: 0.000466, cell accuracy: 99.8%, board accuracy: 71.6%
#
# test error:
#  G loss: 0.002942, cell accuracy: 98.6%, board accuracy: 22.6%
#
# Epoch 134
# -------------------------------
# train error:
#  G loss: 0.000523, cell accuracy: 99.8%, board accuracy: 66.8%
#
# test error:
#  G loss: 0.003046, cell accuracy: 98.5%, board accuracy: 20.1%
#
# Epoch 135
# -------------------------------
# train error:
#  G loss: 0.000462, cell accuracy: 99.8%, board accuracy: 72.3%
#
# test error:
#  G loss: 0.002935, cell accuracy: 98.6%, board accuracy: 22.8%
#
# Epoch 136
# -------------------------------
# train error:
#  G loss: 0.000455, cell accuracy: 99.8%, board accuracy: 72.7%
#
# test error:
#  G loss: 0.002930, cell accuracy: 98.6%, board accuracy: 22.4%
#
# Epoch 137
# -------------------------------
# train error:
#  G loss: 0.000445, cell accuracy: 99.8%, board accuracy: 73.1%
#
# test error:
#  G loss: 0.002925, cell accuracy: 98.6%, board accuracy: 22.9%
#
# Epoch 138
# -------------------------------
# train error:
#  G loss: 0.000458, cell accuracy: 99.8%, board accuracy: 71.8%
#
# test error:
#  G loss: 0.002961, cell accuracy: 98.6%, board accuracy: 22.1%
#
# Epoch 139
# -------------------------------
# train error:
#  G loss: 0.000439, cell accuracy: 99.8%, board accuracy: 73.1%
#
# test error:
#  G loss: 0.002887, cell accuracy: 98.6%, board accuracy: 23.4%
#
# Epoch 140
# -------------------------------
# train error:
#  G loss: 0.000418, cell accuracy: 99.8%, board accuracy: 74.7%
#
# test error:
#  G loss: 0.002886, cell accuracy: 98.6%, board accuracy: 24.6%
#
# Epoch 141
# -------------------------------
# train error:
#  G loss: 0.000424, cell accuracy: 99.8%, board accuracy: 74.1%
#
# test error:
#  G loss: 0.002870, cell accuracy: 98.6%, board accuracy: 23.7%
#
# Epoch 142
# -------------------------------
# train error:
#  G loss: 0.000469, cell accuracy: 99.8%, board accuracy: 71.7%
#
# test error:
#  G loss: 0.002918, cell accuracy: 98.6%, board accuracy: 21.5%
#
# Epoch 143
# -------------------------------
# train error:
#  G loss: 0.000439, cell accuracy: 99.8%, board accuracy: 73.2%
#
# test error:
#  G loss: 0.002860, cell accuracy: 98.6%, board accuracy: 22.9%
#
# Epoch 144
# -------------------------------
# train error:
#  G loss: 0.000423, cell accuracy: 99.8%, board accuracy: 74.3%
#
# test error:
#  G loss: 0.002888, cell accuracy: 98.6%, board accuracy: 22.9%
#
# Epoch 145
# -------------------------------
# train error:
#  G loss: 0.000435, cell accuracy: 99.8%, board accuracy: 73.6%
#
# test error:
#  G loss: 0.002896, cell accuracy: 98.6%, board accuracy: 23.4%
#
# Epoch 146
# -------------------------------
# train error:
#  G loss: 0.000411, cell accuracy: 99.8%, board accuracy: 75.0%
#
# test error:
#  G loss: 0.002885, cell accuracy: 98.6%, board accuracy: 22.9%
#
# Epoch 147
# -------------------------------
# train error:
#  G loss: 0.000409, cell accuracy: 99.8%, board accuracy: 75.5%
#
# test error:
#  G loss: 0.002928, cell accuracy: 98.6%, board accuracy: 23.2%
#
# Epoch 148
# -------------------------------
# train error:
#  G loss: 0.000416, cell accuracy: 99.8%, board accuracy: 74.1%
#
# test error:
#  G loss: 0.002928, cell accuracy: 98.6%, board accuracy: 23.0%
#
# Epoch 149
# -------------------------------
# train error:
#  G loss: 0.000424, cell accuracy: 99.8%, board accuracy: 73.2%
#
# test error:
#  G loss: 0.002956, cell accuracy: 98.6%, board accuracy: 22.8%
#
# Epoch 150
# -------------------------------
# train error:
#  G loss: 0.000407, cell accuracy: 99.8%, board accuracy: 75.0%
#
# test error:
#  G loss: 0.002921, cell accuracy: 98.6%, board accuracy: 23.4%
#
# Epoch 151
# -------------------------------
# train error:
#  G loss: 0.000403, cell accuracy: 99.8%, board accuracy: 75.1%
#
# test error:
#  G loss: 0.002963, cell accuracy: 98.6%, board accuracy: 23.1%
#
# Epoch 152
# -------------------------------
# train error:
#  G loss: 0.000398, cell accuracy: 99.8%, board accuracy: 75.8%
#
# test error:
#  G loss: 0.002878, cell accuracy: 98.6%, board accuracy: 22.4%
#
# Epoch 153
# -------------------------------
# train error:
#  G loss: 0.000402, cell accuracy: 99.8%, board accuracy: 75.5%
#
# test error:
#  G loss: 0.002860, cell accuracy: 98.6%, board accuracy: 23.4%
#
# Epoch 154
# -------------------------------
# train error:
#  G loss: 0.000401, cell accuracy: 99.8%, board accuracy: 75.4%
#
# test error:
#  G loss: 0.002889, cell accuracy: 98.6%, board accuracy: 24.1%
#
# Epoch 155
# -------------------------------
# train error:
#  G loss: 0.000424, cell accuracy: 99.8%, board accuracy: 73.7%
#
# test error:
#  G loss: 0.002960, cell accuracy: 98.6%, board accuracy: 22.9%
#
# Epoch 156
# -------------------------------
# train error:
#  G loss: 0.000440, cell accuracy: 99.8%, board accuracy: 72.7%
#
# test error:
#  G loss: 0.002956, cell accuracy: 98.6%, board accuracy: 21.9%
#
# Epoch 157
# -------------------------------
# train error:
#  G loss: 0.000382, cell accuracy: 99.8%, board accuracy: 76.2%
#
# test error:
#  G loss: 0.002855, cell accuracy: 98.6%, board accuracy: 25.4%
#
# Epoch 158
# -------------------------------
# train error:
#  G loss: 0.000398, cell accuracy: 99.8%, board accuracy: 75.7%
#
# test error:
#  G loss: 0.002886, cell accuracy: 98.6%, board accuracy: 23.9%
#
# Epoch 159
# -------------------------------
# train error:
#  G loss: 0.000404, cell accuracy: 99.8%, board accuracy: 75.2%
#
# test error:
#  G loss: 0.002921, cell accuracy: 98.6%, board accuracy: 23.2%
#
# Epoch 160
# -------------------------------
# train error:
#  G loss: 0.000393, cell accuracy: 99.8%, board accuracy: 75.6%
#
# test error:
#  G loss: 0.002919, cell accuracy: 98.6%, board accuracy: 23.5%
#
# Epoch 161
# -------------------------------
# train error:
#  G loss: 0.000385, cell accuracy: 99.8%, board accuracy: 76.1%
#
# test error:
#  G loss: 0.002925, cell accuracy: 98.6%, board accuracy: 23.3%
#
# Epoch 162
# -------------------------------
# train error:
#  G loss: 0.000372, cell accuracy: 99.8%, board accuracy: 77.1%
#
# test error:
#  G loss: 0.002910, cell accuracy: 98.6%, board accuracy: 23.8%
#
# Epoch 163
# -------------------------------
# train error:
#  G loss: 0.000394, cell accuracy: 99.8%, board accuracy: 76.1%
#
# test error:
#  G loss: 0.002933, cell accuracy: 98.6%, board accuracy: 24.1%
#
# Epoch 164
# -------------------------------
# train error:
#  G loss: 0.000381, cell accuracy: 99.8%, board accuracy: 76.2%
#
# test error:
#  G loss: 0.002920, cell accuracy: 98.6%, board accuracy: 24.3%
#
# Epoch 165
# -------------------------------
# train error:
#  G loss: 0.000377, cell accuracy: 99.8%, board accuracy: 76.8%
#
# test error:
#  G loss: 0.002890, cell accuracy: 98.6%, board accuracy: 24.3%
#
# Epoch 166
# -------------------------------
# train error:
#  G loss: 0.000361, cell accuracy: 99.8%, board accuracy: 77.5%
#
# test error:
#  G loss: 0.002869, cell accuracy: 98.6%, board accuracy: 24.4%
#
# Epoch 167
# -------------------------------
# train error:
#  G loss: 0.000384, cell accuracy: 99.8%, board accuracy: 76.4%
#
# test error:
#  G loss: 0.002906, cell accuracy: 98.6%, board accuracy: 25.1%
#
# Epoch 168
# -------------------------------
# train error:
#  G loss: 0.000373, cell accuracy: 99.8%, board accuracy: 77.0%
#
# test error:
#  G loss: 0.002879, cell accuracy: 98.6%, board accuracy: 24.0%
#
# Epoch 169
# -------------------------------
# train error:
#  G loss: 0.000417, cell accuracy: 99.8%, board accuracy: 73.7%
#
# test error:
#  G loss: 0.002974, cell accuracy: 98.6%, board accuracy: 21.7%
#
# Epoch 170
# -------------------------------
# train error:
#  G loss: 0.000363, cell accuracy: 99.8%, board accuracy: 77.8%
#
# test error:
#  G loss: 0.002901, cell accuracy: 98.6%, board accuracy: 24.8%
#
# Epoch 171
# -------------------------------
# train error:
#  G loss: 0.000355, cell accuracy: 99.8%, board accuracy: 77.6%
#
# test error:
#  G loss: 0.002838, cell accuracy: 98.7%, board accuracy: 24.7%
#
# Epoch 172
# -------------------------------
# train error:
#  G loss: 0.000356, cell accuracy: 99.8%, board accuracy: 77.9%
#
# test error:
#  G loss: 0.002858, cell accuracy: 98.6%, board accuracy: 25.6%
#
# Epoch 173
# -------------------------------
# train error:
#  G loss: 0.000358, cell accuracy: 99.8%, board accuracy: 77.7%
#
# test error:
#  G loss: 0.002885, cell accuracy: 98.6%, board accuracy: 23.6%
#
# Epoch 174
# -------------------------------
# train error:
#  G loss: 0.000365, cell accuracy: 99.8%, board accuracy: 77.5%
#
# test error:
#  G loss: 0.002907, cell accuracy: 98.6%, board accuracy: 24.1%
#
# Epoch 175
# -------------------------------
# train error:
#  G loss: 0.000370, cell accuracy: 99.8%, board accuracy: 77.5%
#
# test error:
#  G loss: 0.002874, cell accuracy: 98.6%, board accuracy: 25.6%
#
# Epoch 176
# -------------------------------
# train error:
#  G loss: 0.000360, cell accuracy: 99.8%, board accuracy: 77.3%
#
# test error:
#  G loss: 0.002855, cell accuracy: 98.6%, board accuracy: 24.4%
#
# Epoch 177
# -------------------------------
# train error:
#  G loss: 0.000370, cell accuracy: 99.8%, board accuracy: 76.6%
#
# test error:
#  G loss: 0.002897, cell accuracy: 98.6%, board accuracy: 24.3%
#
# Epoch 178
# -------------------------------
# train error:
#  G loss: 0.000347, cell accuracy: 99.8%, board accuracy: 78.3%
#
# test error:
#  G loss: 0.002876, cell accuracy: 98.6%, board accuracy: 25.4%
#
# Epoch 179
# -------------------------------
# train error:
#  G loss: 0.000350, cell accuracy: 99.8%, board accuracy: 78.1%
#
# test error:
#  G loss: 0.002849, cell accuracy: 98.7%, board accuracy: 24.9%
#
# Epoch 180
# -------------------------------
# train error:
#  G loss: 0.000351, cell accuracy: 99.8%, board accuracy: 78.0%
#
# test error:
#  G loss: 0.002853, cell accuracy: 98.6%, board accuracy: 25.4%
#
# Epoch 181
# -------------------------------
# train error:
#  G loss: 0.000375, cell accuracy: 99.8%, board accuracy: 76.7%
#
# test error:
#  G loss: 0.002960, cell accuracy: 98.6%, board accuracy: 24.1%
#
# Epoch 182
# -------------------------------
# train error:
#  G loss: 0.000325, cell accuracy: 99.9%, board accuracy: 79.5%
#
# test error:
#  G loss: 0.002827, cell accuracy: 98.7%, board accuracy: 24.8%
#
# Epoch 183
# -------------------------------
# train error:
#  G loss: 0.000346, cell accuracy: 99.8%, board accuracy: 78.5%
#
# test error:
#  G loss: 0.002862, cell accuracy: 98.6%, board accuracy: 24.6%
#
# Epoch 184
# -------------------------------
# train error:
#  G loss: 0.000338, cell accuracy: 99.9%, board accuracy: 79.1%
#
# test error:
#  G loss: 0.002841, cell accuracy: 98.7%, board accuracy: 25.4%
#
# Epoch 185
# -------------------------------
# train error:
#  G loss: 0.000351, cell accuracy: 99.8%, board accuracy: 77.7%
#
# test error:
#  G loss: 0.002902, cell accuracy: 98.6%, board accuracy: 24.6%
#
# Epoch 186
# -------------------------------
# train error:
#  G loss: 0.000339, cell accuracy: 99.8%, board accuracy: 78.7%
#
# test error:
#  G loss: 0.002857, cell accuracy: 98.7%, board accuracy: 26.5%
#
# Epoch 187
# -------------------------------
# train error:
#  G loss: 0.000357, cell accuracy: 99.8%, board accuracy: 77.4%
#
# test error:
#  G loss: 0.002908, cell accuracy: 98.6%, board accuracy: 24.6%
#
# Epoch 188
# -------------------------------
# train error:
#  G loss: 0.000333, cell accuracy: 99.9%, board accuracy: 78.8%
#
# test error:
#  G loss: 0.002876, cell accuracy: 98.6%, board accuracy: 24.6%
#
# Epoch 189
# -------------------------------
# train error:
#  G loss: 0.000334, cell accuracy: 99.8%, board accuracy: 78.6%
#
# test error:
#  G loss: 0.002832, cell accuracy: 98.7%, board accuracy: 26.1%
#
# Epoch 190
# -------------------------------
# train error:
#  G loss: 0.000350, cell accuracy: 99.8%, board accuracy: 77.8%
#
# test error:
#  G loss: 0.002913, cell accuracy: 98.6%, board accuracy: 24.3%
#
# Epoch 191
# -------------------------------
# train error:
#  G loss: 0.000354, cell accuracy: 99.8%, board accuracy: 77.3%
#
# test error:
#  G loss: 0.002942, cell accuracy: 98.6%, board accuracy: 24.3%
#
# Epoch 192
# -------------------------------
# train error:
#  G loss: 0.000352, cell accuracy: 99.8%, board accuracy: 77.9%
#
# test error:
#  G loss: 0.002910, cell accuracy: 98.6%, board accuracy: 24.6%
#
# Epoch 193
# -------------------------------
# train error:
#  G loss: 0.000325, cell accuracy: 99.9%, board accuracy: 79.8%
#
# test error:
#  G loss: 0.002834, cell accuracy: 98.7%, board accuracy: 26.6%
#
# Epoch 194
# -------------------------------
# train error:
#  G loss: 0.000353, cell accuracy: 99.8%, board accuracy: 77.8%
#
# test error:
#  G loss: 0.002891, cell accuracy: 98.6%, board accuracy: 24.3%
#
# Epoch 195
# -------------------------------
# train error:
#  G loss: 0.000330, cell accuracy: 99.9%, board accuracy: 78.8%
#
# test error:
#  G loss: 0.002884, cell accuracy: 98.6%, board accuracy: 25.1%
#
# Epoch 196
# -------------------------------
# train error:
#  G loss: 0.000364, cell accuracy: 99.8%, board accuracy: 77.4%
#
# test error:
#  G loss: 0.002897, cell accuracy: 98.6%, board accuracy: 24.4%
#
# Epoch 197
# -------------------------------
# train error:
#  G loss: 0.000329, cell accuracy: 99.9%, board accuracy: 79.2%
#
# test error:
#  G loss: 0.002822, cell accuracy: 98.7%, board accuracy: 25.9%
#
# Epoch 198
# -------------------------------
# train error:
#  G loss: 0.000330, cell accuracy: 99.9%, board accuracy: 79.5%
#
# test error:
#  G loss: 0.002876, cell accuracy: 98.6%, board accuracy: 24.4%
#
# Epoch 199
# -------------------------------
# train error:
#  G loss: 0.000338, cell accuracy: 99.8%, board accuracy: 78.9%
#
# test error:
#  G loss: 0.002853, cell accuracy: 98.7%, board accuracy: 25.7%
#
# Epoch 200
# -------------------------------
# train error:
#  G loss: 0.000317, cell accuracy: 99.9%, board accuracy: 79.8%
#
# test error:
#  G loss: 0.002875, cell accuracy: 98.7%, board accuracy: 25.4%
#
# Epoch 201
# -------------------------------
# train error:
#  G loss: 0.000315, cell accuracy: 99.9%, board accuracy: 80.1%
#
# test error:
#  G loss: 0.002794, cell accuracy: 98.7%, board accuracy: 26.7%
#
# Epoch 202
# -------------------------------
# train error:
#  G loss: 0.000324, cell accuracy: 99.9%, board accuracy: 79.7%
#
# test error:
#  G loss: 0.002855, cell accuracy: 98.6%, board accuracy: 25.1%
#
# Epoch 203
# -------------------------------
# train error:
#  G loss: 0.000321, cell accuracy: 99.9%, board accuracy: 79.2%
#
# test error:
#  G loss: 0.002921, cell accuracy: 98.6%, board accuracy: 24.9%
#
# Epoch 204
# -------------------------------
# train error:
#  G loss: 0.000325, cell accuracy: 99.9%, board accuracy: 79.1%
#
# test error:
#  G loss: 0.002817, cell accuracy: 98.7%, board accuracy: 25.4%
#
# Epoch 205
# -------------------------------
# train error:
#  G loss: 0.000328, cell accuracy: 99.9%, board accuracy: 79.0%
#
# test error:
#  G loss: 0.002882, cell accuracy: 98.6%, board accuracy: 25.4%
#
# Epoch 206
# -------------------------------
# train error:
#  G loss: 0.000325, cell accuracy: 99.9%, board accuracy: 79.1%
#
# test error:
#  G loss: 0.002902, cell accuracy: 98.6%, board accuracy: 25.1%
#
# Epoch 207
# -------------------------------
# train error:
#  G loss: 0.000321, cell accuracy: 99.9%, board accuracy: 80.1%
#
# test error:
#  G loss: 0.002894, cell accuracy: 98.6%, board accuracy: 25.1%
#
# Epoch 208
# -------------------------------
# train error:
#  G loss: 0.000362, cell accuracy: 99.8%, board accuracy: 77.4%
#
# test error:
#  G loss: 0.002934, cell accuracy: 98.6%, board accuracy: 23.8%
#
# Epoch 209
# -------------------------------
# train error:
#  G loss: 0.000313, cell accuracy: 99.9%, board accuracy: 80.2%
#
# test error:
#  G loss: 0.002844, cell accuracy: 98.7%, board accuracy: 26.2%
#
# Epoch 210
# -------------------------------
# train error:
#  G loss: 0.000325, cell accuracy: 99.9%, board accuracy: 80.0%
#
# test error:
#  G loss: 0.002896, cell accuracy: 98.6%, board accuracy: 25.2%
#
# Epoch 211
# -------------------------------
# train error:
#  G loss: 0.000336, cell accuracy: 99.8%, board accuracy: 79.4%
#
# test error:
#  G loss: 0.002895, cell accuracy: 98.6%, board accuracy: 24.8%
#
# Epoch 212
# -------------------------------
# train error:
#  G loss: 0.000299, cell accuracy: 99.9%, board accuracy: 81.0%
#
# test error:
#  G loss: 0.002811, cell accuracy: 98.7%, board accuracy: 26.7%
#
# Epoch 213
# -------------------------------
# train error:
#  G loss: 0.000317, cell accuracy: 99.9%, board accuracy: 80.1%
#
# test error:
#  G loss: 0.002896, cell accuracy: 98.6%, board accuracy: 25.2%
#
# Epoch 214
# -------------------------------
# train error:
#  G loss: 0.000319, cell accuracy: 99.9%, board accuracy: 79.5%
#
# test error:
#  G loss: 0.002899, cell accuracy: 98.6%, board accuracy: 24.9%
#
# Epoch 215
# -------------------------------
# train error:
#  G loss: 0.000328, cell accuracy: 99.9%, board accuracy: 79.5%
#
# test error:
#  G loss: 0.002900, cell accuracy: 98.6%, board accuracy: 25.4%
#
# Epoch 216
# -------------------------------
# train error:
#  G loss: 0.000312, cell accuracy: 99.9%, board accuracy: 80.5%
#
# test error:
#  G loss: 0.002894, cell accuracy: 98.6%, board accuracy: 25.2%
#
# Epoch 217
# -------------------------------
# train error:
#  G loss: 0.000318, cell accuracy: 99.9%, board accuracy: 80.2%
#
# test error:
#  G loss: 0.002844, cell accuracy: 98.7%, board accuracy: 25.7%
#
# Epoch 218
# -------------------------------
# train error:
#  G loss: 0.000315, cell accuracy: 99.9%, board accuracy: 80.3%
#
# test error:
#  G loss: 0.002860, cell accuracy: 98.6%, board accuracy: 26.2%
#
# Epoch 219
# -------------------------------
# train error:
#  G loss: 0.000318, cell accuracy: 99.9%, board accuracy: 79.8%
#
# test error:
#  G loss: 0.002897, cell accuracy: 98.6%, board accuracy: 25.2%
#
# Epoch 220
# -------------------------------
# train error:
#  G loss: 0.000291, cell accuracy: 99.9%, board accuracy: 81.6%
#
# test error:
#  G loss: 0.002796, cell accuracy: 98.7%, board accuracy: 28.4%
#
# Epoch 221
# -------------------------------
# train error:
#  G loss: 0.000300, cell accuracy: 99.9%, board accuracy: 81.2%
#
# test error:
#  G loss: 0.002836, cell accuracy: 98.7%, board accuracy: 26.9%
#
# Epoch 222
# -------------------------------
# train error:
#  G loss: 0.000303, cell accuracy: 99.9%, board accuracy: 81.1%
#
# test error:
#  G loss: 0.002866, cell accuracy: 98.6%, board accuracy: 25.9%
#
# Epoch 223
# -------------------------------
# train error:
#  G loss: 0.000295, cell accuracy: 99.9%, board accuracy: 81.4%
#
# test error:
#  G loss: 0.002821, cell accuracy: 98.7%, board accuracy: 26.3%
#
# Epoch 224
# -------------------------------
# train error:
#  G loss: 0.000293, cell accuracy: 99.9%, board accuracy: 81.3%
#
# test error:
#  G loss: 0.002819, cell accuracy: 98.7%, board accuracy: 26.2%
#
# Epoch 225
# -------------------------------
# train error:
#  G loss: 0.000316, cell accuracy: 99.9%, board accuracy: 79.7%
#
# test error:
#  G loss: 0.002878, cell accuracy: 98.6%, board accuracy: 25.2%
#
# Epoch 226
# -------------------------------
# train error:
#  G loss: 0.000296, cell accuracy: 99.9%, board accuracy: 80.9%
#
# test error:
#  G loss: 0.002806, cell accuracy: 98.7%, board accuracy: 26.6%
#
# Epoch 227
# -------------------------------
# train error:
#  G loss: 0.000307, cell accuracy: 99.9%, board accuracy: 80.6%
#
# test error:
#  G loss: 0.002830, cell accuracy: 98.7%, board accuracy: 26.4%
#
# Epoch 228
# -------------------------------
# train error:
#  G loss: 0.000305, cell accuracy: 99.9%, board accuracy: 80.9%
#
# test error:
#  G loss: 0.002847, cell accuracy: 98.7%, board accuracy: 25.4%
#
# Epoch 229
# -------------------------------
# train error:
#  G loss: 0.000300, cell accuracy: 99.9%, board accuracy: 81.1%
#
# test error:
#  G loss: 0.002840, cell accuracy: 98.7%, board accuracy: 27.1%
#
# Epoch 230
# -------------------------------
# train error:
#  G loss: 0.000292, cell accuracy: 99.9%, board accuracy: 81.3%
#
# test error:
#  G loss: 0.002844, cell accuracy: 98.7%, board accuracy: 24.9%
#
# Epoch 231
# -------------------------------
# train error:
#  G loss: 0.000288, cell accuracy: 99.9%, board accuracy: 81.9%
#
# test error:
#  G loss: 0.002846, cell accuracy: 98.7%, board accuracy: 27.3%
#
# Epoch 232
# -------------------------------
# train error:
#  G loss: 0.000298, cell accuracy: 99.9%, board accuracy: 81.2%
#
# test error:
#  G loss: 0.002864, cell accuracy: 98.7%, board accuracy: 26.4%
#
# Epoch 233
# -------------------------------
# train error:
#  G loss: 0.000285, cell accuracy: 99.9%, board accuracy: 81.6%
#
# test error:
#  G loss: 0.002829, cell accuracy: 98.7%, board accuracy: 27.1%
#
# Epoch 234
# -------------------------------
# train error:
#  G loss: 0.000321, cell accuracy: 99.9%, board accuracy: 79.3%
#
# test error:
#  G loss: 0.002924, cell accuracy: 98.6%, board accuracy: 25.2%
#
# Epoch 235
# -------------------------------
# train error:
#  G loss: 0.000288, cell accuracy: 99.9%, board accuracy: 81.5%
#
# test error:
#  G loss: 0.002852, cell accuracy: 98.7%, board accuracy: 26.2%
#
# Epoch 236
# -------------------------------
# train error:
#  G loss: 0.000281, cell accuracy: 99.9%, board accuracy: 82.3%
#
# test error:
#  G loss: 0.002812, cell accuracy: 98.7%, board accuracy: 28.3%
#
# Epoch 237
# -------------------------------
# train error:
#  G loss: 0.000293, cell accuracy: 99.9%, board accuracy: 81.3%
#
# test error:
#  G loss: 0.002842, cell accuracy: 98.7%, board accuracy: 26.2%
#
# Epoch 238
# -------------------------------
# train error:
#  G loss: 0.000303, cell accuracy: 99.9%, board accuracy: 80.3%
#
# test error:
#  G loss: 0.002872, cell accuracy: 98.6%, board accuracy: 27.0%
#
# Epoch 239
# -------------------------------
# train error:
#  G loss: 0.000280, cell accuracy: 99.9%, board accuracy: 82.4%
#
# test error:
#  G loss: 0.002798, cell accuracy: 98.7%, board accuracy: 28.2%
#
# Epoch 240
# -------------------------------
# train error:
#  G loss: 0.000307, cell accuracy: 99.9%, board accuracy: 80.9%
#
# test error:
#  G loss: 0.002859, cell accuracy: 98.7%, board accuracy: 26.2%
#
# Epoch 241
# -------------------------------
# train error:
#  G loss: 0.000290, cell accuracy: 99.9%, board accuracy: 81.4%
#
# test error:
#  G loss: 0.002828, cell accuracy: 98.7%, board accuracy: 26.1%
#
# Epoch 242
# ...
# train error:
#  G loss: 0.000114, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002613, cell accuracy: 98.8%, board accuracy: 34.8%
#
# Epoch 1421
# -------------------------------
# train error:
#  G loss: 0.000116, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002632, cell accuracy: 98.8%, board accuracy: 33.3%
#
# Epoch 1422
# -------------------------------
# train error:
#  G loss: 0.000110, cell accuracy: 99.9%, board accuracy: 91.6%
#
# test error:
#  G loss: 0.002600, cell accuracy: 98.8%, board accuracy: 34.9%
#
# Epoch 1423
# -------------------------------
# train error:
#  G loss: 0.000113, cell accuracy: 99.9%, board accuracy: 91.3%
#
# test error:
#  G loss: 0.002598, cell accuracy: 98.8%, board accuracy: 34.5%
#
# Epoch 1424
# -------------------------------
# train error:
#  G loss: 0.000113, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002626, cell accuracy: 98.8%, board accuracy: 34.9%
#
# Epoch 1425
# -------------------------------
# train error:
#  G loss: 0.000110, cell accuracy: 99.9%, board accuracy: 91.6%
#
# test error:
#  G loss: 0.002577, cell accuracy: 98.8%, board accuracy: 35.5%
#
# Epoch 1426
# -------------------------------
# train error:
#  G loss: 0.000111, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002598, cell accuracy: 98.8%, board accuracy: 35.6%
#
# Epoch 1427
# -------------------------------
# train error:
#  G loss: 0.000111, cell accuracy: 99.9%, board accuracy: 91.6%
#
# test error:
#  G loss: 0.002616, cell accuracy: 98.8%, board accuracy: 35.9%
#
# Epoch 1428
# -------------------------------
# train error:
#  G loss: 0.000111, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002606, cell accuracy: 98.8%, board accuracy: 35.5%
#
# Epoch 1429
# -------------------------------
# train error:
#  G loss: 0.000112, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002573, cell accuracy: 98.8%, board accuracy: 35.9%
#
# Epoch 1430
# -------------------------------
# train error:
#  G loss: 0.000114, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002620, cell accuracy: 98.8%, board accuracy: 35.0%
#
# Epoch 1431
# -------------------------------
# train error:
#  G loss: 0.000111, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002642, cell accuracy: 98.8%, board accuracy: 34.8%
#
# Epoch 1432
# -------------------------------
# train error:
#  G loss: 0.000120, cell accuracy: 99.9%, board accuracy: 90.8%
#
# test error:
#  G loss: 0.002683, cell accuracy: 98.8%, board accuracy: 33.7%
#
# Epoch 1433
# -------------------------------
# train error:
#  G loss: 0.000112, cell accuracy: 99.9%, board accuracy: 91.4%
#
# test error:
#  G loss: 0.002635, cell accuracy: 98.8%, board accuracy: 34.4%
#
# Epoch 1434
# -------------------------------
# train error:
#  G loss: 0.000108, cell accuracy: 99.9%, board accuracy: 91.8%
#
# test error:
#  G loss: 0.002641, cell accuracy: 98.8%, board accuracy: 34.8%
#
# Epoch 1435
# -------------------------------
# train error:
#  G loss: 0.000116, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002659, cell accuracy: 98.8%, board accuracy: 34.5%
#
# Epoch 1436
# -------------------------------
# train error:
#  G loss: 0.000112, cell accuracy: 99.9%, board accuracy: 91.4%
#
# test error:
#  G loss: 0.002652, cell accuracy: 98.8%, board accuracy: 34.2%
#
# Epoch 1437
# -------------------------------
# train error:
#  G loss: 0.000115, cell accuracy: 99.9%, board accuracy: 91.4%
#
# test error:
#  G loss: 0.002643, cell accuracy: 98.8%, board accuracy: 34.4%
#
# Epoch 1438
# -------------------------------
# train error:
#  G loss: 0.000115, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002626, cell accuracy: 98.8%, board accuracy: 35.4%
#
# Epoch 1439
# -------------------------------
# train error:
#  G loss: 0.000114, cell accuracy: 99.9%, board accuracy: 91.3%
#
# test error:
#  G loss: 0.002639, cell accuracy: 98.8%, board accuracy: 34.4%
#
# Epoch 1440
# -------------------------------
# train error:
#  G loss: 0.000111, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002642, cell accuracy: 98.8%, board accuracy: 35.4%
#
# Epoch 1441
# -------------------------------
# train error:
#  G loss: 0.000114, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002642, cell accuracy: 98.8%, board accuracy: 35.0%
#
# Epoch 1442
# -------------------------------
# train error:
#  G loss: 0.000113, cell accuracy: 99.9%, board accuracy: 91.4%
#
# test error:
#  G loss: 0.002632, cell accuracy: 98.8%, board accuracy: 34.4%
#
# Epoch 1443
# -------------------------------
# train error:
#  G loss: 0.000116, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002621, cell accuracy: 98.8%, board accuracy: 34.4%
#
# Epoch 1444
# -------------------------------
# train error:
#  G loss: 0.000112, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002643, cell accuracy: 98.8%, board accuracy: 34.4%
#
# Epoch 1445
# -------------------------------
# train error:
#  G loss: 0.000116, cell accuracy: 99.9%, board accuracy: 91.0%
#
# test error:
#  G loss: 0.002636, cell accuracy: 98.8%, board accuracy: 34.5%
#
# Epoch 1446
# -------------------------------
# train error:
#  G loss: 0.000115, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002627, cell accuracy: 98.8%, board accuracy: 35.5%
#
# Epoch 1447
# -------------------------------
# train error:
#  G loss: 0.000110, cell accuracy: 99.9%, board accuracy: 91.7%
#
# test error:
#  G loss: 0.002600, cell accuracy: 98.8%, board accuracy: 35.5%
#
# Epoch 1448
# -------------------------------
# train error:
#  G loss: 0.000114, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002630, cell accuracy: 98.8%, board accuracy: 34.2%
#
# Epoch 1449
# -------------------------------
# train error:
#  G loss: 0.000110, cell accuracy: 99.9%, board accuracy: 91.6%
#
# test error:
#  G loss: 0.002592, cell accuracy: 98.8%, board accuracy: 35.9%
#
# Epoch 1450
# -------------------------------
# train error:
#  G loss: 0.000110, cell accuracy: 99.9%, board accuracy: 91.6%
#
# test error:
#  G loss: 0.002611, cell accuracy: 98.8%, board accuracy: 34.1%
#
# Epoch 1451
# -------------------------------
# train error:
#  G loss: 0.000119, cell accuracy: 99.9%, board accuracy: 91.0%
#
# test error:
#  G loss: 0.002604, cell accuracy: 98.8%, board accuracy: 34.2%
#
# Epoch 1452
# -------------------------------
# train error:
#  G loss: 0.000116, cell accuracy: 99.9%, board accuracy: 91.1%
#
# test error:
#  G loss: 0.002647, cell accuracy: 98.8%, board accuracy: 34.1%
#
# Epoch 1453
# -------------------------------
# train error:
#  G loss: 0.000117, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002661, cell accuracy: 98.8%, board accuracy: 34.1%
#
# Epoch 1454
# -------------------------------
# train error:
#  G loss: 0.000114, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002637, cell accuracy: 98.8%, board accuracy: 35.1%
#
# Epoch 1455
# -------------------------------
# train error:
#  G loss: 0.000114, cell accuracy: 99.9%, board accuracy: 91.3%
#
# test error:
#  G loss: 0.002654, cell accuracy: 98.8%, board accuracy: 33.7%
#
# Epoch 1456
# -------------------------------
# train error:
#  G loss: 0.000112, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002618, cell accuracy: 98.8%, board accuracy: 35.2%
#
# Epoch 1457
# -------------------------------
# train error:
#  G loss: 0.000117, cell accuracy: 99.9%, board accuracy: 91.1%
#
# test error:
#  G loss: 0.002654, cell accuracy: 98.8%, board accuracy: 34.7%
#
# Epoch 1458
# -------------------------------
# train error:
#  G loss: 0.000117, cell accuracy: 99.9%, board accuracy: 91.0%
#
# test error:
#  G loss: 0.002664, cell accuracy: 98.8%, board accuracy: 34.0%
#
# Epoch 1459
# -------------------------------
# train error:
#  G loss: 0.000110, cell accuracy: 99.9%, board accuracy: 91.6%
#
# test error:
#  G loss: 0.002645, cell accuracy: 98.8%, board accuracy: 35.5%
#
# Epoch 1460
# -------------------------------
# train error:
#  G loss: 0.000114, cell accuracy: 99.9%, board accuracy: 91.4%
#
# test error:
#  G loss: 0.002656, cell accuracy: 98.8%, board accuracy: 35.0%
#
# Epoch 1461
# -------------------------------
# train error:
#  G loss: 0.000115, cell accuracy: 99.9%, board accuracy: 91.3%
#
# test error:
#  G loss: 0.002607, cell accuracy: 98.8%, board accuracy: 35.4%
#
# Epoch 1462
# -------------------------------
# train error:
#  G loss: 0.000113, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002656, cell accuracy: 98.8%, board accuracy: 34.4%
#
# Epoch 1463
# -------------------------------
# train error:
#  G loss: 0.000112, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002638, cell accuracy: 98.8%, board accuracy: 34.9%
#
# Epoch 1464
# -------------------------------
# train error:
#  G loss: 0.000108, cell accuracy: 99.9%, board accuracy: 91.7%
#
# test error:
#  G loss: 0.002627, cell accuracy: 98.8%, board accuracy: 34.5%
#
# Epoch 1465
# -------------------------------
# train error:
#  G loss: 0.000122, cell accuracy: 99.9%, board accuracy: 90.9%
#
# test error:
#  G loss: 0.002654, cell accuracy: 98.8%, board accuracy: 34.4%
#
# Epoch 1466
# -------------------------------
# train error:
#  G loss: 0.000113, cell accuracy: 99.9%, board accuracy: 91.3%
#
# test error:
#  G loss: 0.002638, cell accuracy: 98.8%, board accuracy: 35.2%
#
# Epoch 1467
# -------------------------------
# train error:
#  G loss: 0.000113, cell accuracy: 99.9%, board accuracy: 91.3%
#
# test error:
#  G loss: 0.002609, cell accuracy: 98.8%, board accuracy: 34.2%
#
# Epoch 1468
# -------------------------------
# train error:
#  G loss: 0.000111, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002613, cell accuracy: 98.8%, board accuracy: 34.9%
#
# Epoch 1469
# -------------------------------
# train error:
#  G loss: 0.000119, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002699, cell accuracy: 98.8%, board accuracy: 34.2%
#
# Epoch 1470
# -------------------------------
# train error:
#  G loss: 0.000115, cell accuracy: 99.9%, board accuracy: 91.2%
#
# test error:
#  G loss: 0.002664, cell accuracy: 98.8%, board accuracy: 33.7%
#
# Epoch 1471
# -------------------------------
# train error:
#  G loss: 0.000109, cell accuracy: 99.9%, board accuracy: 91.9%
#
# test error:
#  G loss: 0.002649, cell accuracy: 98.8%, board accuracy: 35.1%
#
# Epoch 1472
# -------------------------------
# train error:
#  G loss: 0.000112, cell accuracy: 99.9%, board accuracy: 91.8%
#
# test error:
#  G loss: 0.002645, cell accuracy: 98.8%, board accuracy: 35.5%
#
# Epoch 1473
# -------------------------------
# train error:
#  G loss: 0.000105, cell accuracy: 100.0%, board accuracy: 92.3%
#
# test error:
#  G loss: 0.002641, cell accuracy: 98.8%, board accuracy: 36.2%
#
# Epoch 1474
# -------------------------------
# train error:
#  G loss: 0.000110, cell accuracy: 99.9%, board accuracy: 91.9%
#
# test error:
#  G loss: 0.002652, cell accuracy: 98.8%, board accuracy: 35.6%
#
# Epoch 1475
# -------------------------------
# train error:
#  G loss: 0.000109, cell accuracy: 99.9%, board accuracy: 92.1%
#
# test error:
#  G loss: 0.002643, cell accuracy: 98.8%, board accuracy: 34.8%
#
# Epoch 1476
# -------------------------------
# train error:
#  G loss: 0.000111, cell accuracy: 99.9%, board accuracy: 91.9%
#
# test error:
#  G loss: 0.002647, cell accuracy: 98.8%, board accuracy: 34.5%
#
# Epoch 1477
# -------------------------------
# train error:
#  G loss: 0.000108, cell accuracy: 100.0%, board accuracy: 92.1%
#
# test error:
#  G loss: 0.002654, cell accuracy: 98.8%, board accuracy: 34.6%
#
# Epoch 1478
# -------------------------------
# train error:
#  G loss: 0.000122, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002666, cell accuracy: 98.8%, board accuracy: 34.6%
#
# Epoch 1479
# -------------------------------
# train error:
#  G loss: 0.000107, cell accuracy: 100.0%, board accuracy: 92.1%
#
# test error:
#  G loss: 0.002630, cell accuracy: 98.8%, board accuracy: 34.3%
#
# Epoch 1480
# -------------------------------
# train error:
#  G loss: 0.000104, cell accuracy: 100.0%, board accuracy: 92.3%
#
# test error:
#  G loss: 0.002605, cell accuracy: 98.8%, board accuracy: 35.8%
#
# Epoch 1481
# -------------------------------
# train error:
#  G loss: 0.000113, cell accuracy: 99.9%, board accuracy: 91.6%
#
# test error:
#  G loss: 0.002681, cell accuracy: 98.8%, board accuracy: 34.0%
#
# Epoch 1482
# -------------------------------
# train error:
#  G loss: 0.000110, cell accuracy: 99.9%, board accuracy: 91.9%
#
# test error:
#  G loss: 0.002633, cell accuracy: 98.8%, board accuracy: 35.1%
#
# Epoch 1483
# -------------------------------
# train error:
#  G loss: 0.000109, cell accuracy: 99.9%, board accuracy: 92.0%
#
# test error:
#  G loss: 0.002617, cell accuracy: 98.8%, board accuracy: 35.3%
#
# Epoch 1484
# -------------------------------
# train error:
#  G loss: 0.000111, cell accuracy: 99.9%, board accuracy: 91.8%
#
# test error:
#  G loss: 0.002648, cell accuracy: 98.8%, board accuracy: 34.0%
#
# Epoch 1485
# -------------------------------
# train error:
#  G loss: 0.000114, cell accuracy: 99.9%, board accuracy: 91.5%
#
# test error:
#  G loss: 0.002669, cell accuracy: 98.8%, board accuracy: 34.1%
#
# Epoch 1486
# -------------------------------
# train error:
#  G loss: 0.000106, cell accuracy: 100.0%, board accuracy: 92.1%
#
# test error:
#  G loss: 0.002613, cell accuracy: 98.8%, board accuracy: 35.5%
#
# Epoch 1487
# -------------------------------
# train error:
#  G loss: 0.000109, cell accuracy: 99.9%, board accuracy: 91.8%
#
# test error:
#  G loss: 0.002604, cell accuracy: 98.8%, board accuracy: 36.0%
#
# Epoch 1488
# -------------------------------
# train error:
#  G loss: 0.000111, cell accuracy: 99.9%, board accuracy: 91.6%
#
# test error:
#  G loss: 0.002589, cell accuracy: 98.8%, board accuracy: 35.9%
#
# Epoch 1489
# -------------------------------
# train error:
#  G loss: 0.000108, cell accuracy: 99.9%, board accuracy: 91.8%
#
# test error:
#  G loss: 0.002577, cell accuracy: 98.8%, board accuracy: 37.1%
#
# Epoch 1490
# -------------------------------
# train error:
#  G loss: 0.000109, cell accuracy: 99.9%, board accuracy: 91.8%
#
# test error:
#  G loss: 0.002605, cell accuracy: 98.8%, board accuracy: 35.0%
#
# Epoch 1491
# -------------------------------
# train error:
#  G loss: 0.000108, cell accuracy: 100.0%, board accuracy: 92.0%
#
# test error:
#  G loss: 0.002585, cell accuracy: 98.8%, board accuracy: 35.9%
#
# Epoch 1492
# -------------------------------
# train error:
#  G loss: 0.000109, cell accuracy: 99.9%, board accuracy: 92.0%
#
# test error:
#  G loss: 0.002600, cell accuracy: 98.8%, board accuracy: 35.1%
#
# Epoch 1493
# -------------------------------
# train error:
#  G loss: 0.000108, cell accuracy: 100.0%, board accuracy: 91.9%
#
# test error:
#  G loss: 0.002619, cell accuracy: 98.8%, board accuracy: 35.4%
#
# Epoch 1494
# -------------------------------
# train error:
#  G loss: 0.000108, cell accuracy: 100.0%, board accuracy: 92.0%
#
# test error:
#  G loss: 0.002593, cell accuracy: 98.8%, board accuracy: 35.4%
#
# Epoch 1495
# -------------------------------
# train error:
#  G loss: 0.000106, cell accuracy: 100.0%, board accuracy: 92.2%
#
# test error:
#  G loss: 0.002637, cell accuracy: 98.8%, board accuracy: 35.4%
#
# Epoch 1496
# -------------------------------
# train error:
#  G loss: 0.000108, cell accuracy: 100.0%, board accuracy: 92.0%
#
# test error:
#  G loss: 0.002642, cell accuracy: 98.8%, board accuracy: 35.1%
#
# Epoch 1497
# -------------------------------
# train error:
#  G loss: 0.000116, cell accuracy: 99.9%, board accuracy: 91.4%
#
# test error:
#  G loss: 0.002719, cell accuracy: 98.8%, board accuracy: 33.5%
#
# Epoch 1498
# -------------------------------
# train error:
#  G loss: 0.000110, cell accuracy: 99.9%, board accuracy: 91.9%
#
# test error:
#  G loss: 0.002637, cell accuracy: 98.8%, board accuracy: 33.2%
#
# Epoch 1499
# -------------------------------
# train error:
#  G loss: 0.000105, cell accuracy: 100.0%, board accuracy: 92.1%
#
# test error:
#  G loss: 0.002623, cell accuracy: 98.8%, board accuracy: 35.2%
#
# Done!

# %%
cell_accuracies_train = compute_metric_by_event(metrics.CellAccuracy, train_dataloader)
cell_accuracies_test = compute_metric_by_event(metrics.CellAccuracy, test_dataloader)
board_accuracies_train = compute_metric_by_event(metrics.BoardAccuracy, train_dataloader)
board_accuracies_test = compute_metric_by_event(metrics.BoardAccuracy, test_dataloader)

for event_type in range(NUM_EVENT_TYPES):
    print(f"Stats for event type '{EVENT_NAMES[event_type]}':")
    print(f"  Cell accuracy (train): {cell_accuracies_train[event_type]:.2%}")
    print(f"  Cell accuracy (test): {cell_accuracies_test[event_type]:.2%}")
    print(f"  Board accuracy (train): {board_accuracies_train[event_type]:.2%}")
    print(f"  Board accuracy (test): {board_accuracies_test[event_type]:.2%}")
    print()
# Out:
# Stats for event type 'Drop':
#   Cell accuracy (train): 99.97%
#   Cell accuracy (test): 98.50%
#   Board accuracy (train): 93.98%
#   Board accuracy (test): 35.05%
#
# Stats for event type 'Left':
#   Cell accuracy (train): 99.95%
#   Cell accuracy (test): 99.22%
#   Board accuracy (train): 93.20%
#   Board accuracy (test): 38.46%
#
# Stats for event type 'Right':
#   Cell accuracy (train): 99.96%
#   Cell accuracy (test): 99.42%
#   Board accuracy (train): 93.84%
#   Board accuracy (test): 49.89%
#
# Stats for event type 'Rotate':
#   Cell accuracy (train): 99.93%
#   Cell accuracy (test): 99.09%
#   Board accuracy (train): 86.31%
#   Board accuracy (test): 34.52%
#
# Stats for event type 'Insta-drop':
#   Cell accuracy (train): 99.91%
#   Cell accuracy (test): 98.10%
#   Board accuracy (train): 86.04%
#   Board accuracy (test): 2.82%

# %%
def show_prediction(example):
    (b, e), y = example
    pred = gen(b.to(device).unsqueeze(0), e.to(device).unsqueeze(0)).squeeze(0).cpu()
    b, e, y, pred = b.argmax(0), e.argmax(0), y.argmax(0), pred.argmax(0)

    fig, axs = plt.subplots(1, 3)
    fig.suptitle(f"Prediction vs reality\nEvent = {EVENT_NAMES[e]}")

    for ax in axs:
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

    axs[0].set_title("Input")
    axs[1].set_title("Predicted")
    axs[2].set_title("Reality")

    num_mistakes = (y != pred).type(torch.int).sum().item()
    print(f"Mistakes: {num_mistakes}")
    axs[0].imshow(render_board(b).transpose((1, 2, 0)), vmin=0, vmax=1)
    axs[1].imshow(render_board(pred).transpose((1, 2, 0)), vmin=0, vmax=1)
    axs[2].imshow(render_board(y).transpose((1, 2, 0)), vmin=0, vmax=1)

    plt.show()

# %%
# Show a random training prediction vs reality
import random

idx = random.randrange(len(train_dataset))
print(f"Showing prediction for training example {idx}")
show_prediction(train_dataset[idx])
# Out:
# Showing prediction for training example 2388
# Mistakes: 0

# %%
torch.save(gen.state_dict(), "gamegan_emulator.pth")
