# %% [markdown]
# # Train generator with reconstruction loss
#
# In this notebook, we train the generator without a discriminator. We just take the MSE loss between the predicted next frame and actual next frame.

# %%
import os
from pathlib import Path
import shutil
import datetime

import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.utils.data import Dataset
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt


import models
import metrics
from recording import FileBasedDatabase
from engines import EVENT_NAMES

# %%
NUM_CELL_TYPES = 8
NUM_EVENT_TYPES = 5

class RecordingDataset(Dataset):
    def __init__(self, path: str):
        self._db = FileBasedDatabase(path)

    def __len__(self):
        return len(self._db)

    def __getitem__(self, idx):
        boards, events = self._db[idx]
        b = self._transform_board(boards[-2]) # Ignore all boards except the last two
        e = self._transform_event(events[-1])
        x = (b, e)
        y = self._transform_board(boards[-1])
        return x, y
    
    def _transform_board(self, board):
        board = torch.tensor(board, dtype=torch.long)
        board = F.one_hot(board, NUM_CELL_TYPES) # One-hot encode the cell types
        board = board.type(torch.float) # Convert to floating-point
        board = board.permute((2, 0, 1)) # Move channels/classes to dimension 0
        return board
    
    def _transform_event(self, event):
        event = torch.tensor(event, dtype=torch.long)
        event = F.one_hot(event, NUM_EVENT_TYPES) # One-hot encode the event
        event = event.type(torch.float) # Convert to floating-point
        return event

# %%
# Put datasets in memory for faster training
train_dataset = list(RecordingDataset(os.path.join("data", "tetris_emulator", "train")))
test_dataset = list(RecordingDataset(os.path.join("data", "tetris_emulator", "test")))
batch_size = 12
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

(b, e), y = next(iter(train_dataloader))
print(f"x: shape {b.shape}, dtype {b.dtype}")
print(f"e: shape {e.shape}, dtype {e.dtype}")
print(f"y: shape {y.shape}, dtype {y.dtype}")
# Out:
# x: shape torch.Size([12, 8, 22, 10]), dtype torch.float32
# e: shape torch.Size([12, 5]), dtype torch.float32
# y: shape torch.Size([12, 8, 22, 10]), dtype torch.float32

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Using device {device}")
# Out:
# Using device cuda

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def compute_metric_by_event(metric_cls, dataloader):
    metrics = [metric_cls() for _ in range(NUM_EVENT_TYPES)]

    with torch.no_grad():        
        for ((b, e), y) in dataloader:
            b = b.to(device)
            e = e.to(device)
            y = y.to(device)

            batch_size = b.size(0)

            y_fake = gen(b, e)
            
            classes_b = torch.argmax(b, dim=1)
            classes_e = torch.argmax(e, dim=1)
            classes_y = torch.argmax(y, dim=1)
            classes_y_fake = torch.argmax(y_fake, dim=1)

            for idx in range(batch_size):
                class_e = classes_e[idx]
                metric = metrics[class_e]
                metric.update_state(classes_x=classes_b[idx:idx+1], classes_y_pred=classes_y_fake[idx:idx+1], classes_y=classes_y[idx:idx+1])

    return [metric.result() for metric in metrics]

# %%
import itertools

from engines import EventTypes
from tetris import CELL_COLORS

def render_board(board):
    height, width = board.shape
    img = np.zeros((3, height, width))
    for row in range(height):
        for col in range(width):
            img[:, row, col] = CELL_COLORS[board[row, col]]
    img /= 255.0
    return img

real_label = 1.0
fake_label = 0.0

def train_loop(dataloader, gen, loss_fn, optimizer_gen):
    gen.train()

    size = len(dataloader.dataset)
    for batch, ((b, e), y) in enumerate(dataloader):
        batch_size = b.size(0)

        b = b.to(device)
        e = e.to(device)
        y = y.to(device)

        gen.zero_grad()

        y_fake = gen(b, e)
        err_dyn = loss_fn(y_fake, y)
        err_dyn.backward()

        optimizer_gen.step()


def test_loop(split_name, dataloader, gen, loss_fn, tb_writer, epoch):
    gen.eval()

    loss_gen = 0.0
    cell_accuracy = metrics.CellAccuracy()
    board_accuracy = metrics.BoardAccuracy()
    spawn_recall = metrics.SpawnRecall()

    num_batches = len(dataloader)
    with torch.no_grad():        
        for batch, ((b, e), y) in enumerate(dataloader):
            batch_size = b.size(0)

            b = b.to(device)
            e = e.to(device)
            y = y.to(device)

            y_fake = gen(b, e)
        
            loss_gen += loss_fn(y_fake, y).item()

            classes_b = torch.argmax(b, dim=1)
            classes_e = torch.argmax(e, dim=1)
            classes_y = torch.argmax(y, dim=1)
            classes_y_fake = torch.argmax(y_fake, dim=1)
            cell_accuracy.update_state(classes_y_fake, classes_y)
            board_accuracy.update_state(classes_y_fake, classes_y)

            spawn_recall.update_state(classes_b, classes_y_fake, classes_y)

    loss_gen /= num_batches

    print(f"{split_name} error: \n G loss: {loss_gen:>8f}, cell accuracy: {(cell_accuracy.result()):>0.1%}, board accuracy: {(board_accuracy.result()):>0.1%} \n")

    tb_writer.add_scalar(f"Loss/{split_name}", loss_gen, epoch)
    tb_writer.add_scalar(f"Cell accuracy/{split_name}", cell_accuracy.result(), epoch)
    tb_writer.add_scalar(f"Board accuracy/{split_name}", board_accuracy.result(), epoch)
    tb_writer.add_scalar(f"Spawn recall/{split_name}", spawn_recall.result(), epoch)
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.10.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def train(run_name, gen_factory, epochs):

    learning_rate = 1e-4

    gen = gen_factory()

    loss_fn = nn.MSELoss()
    optimizer_gen = torch.optim.Adam(gen.parameters(), lr=learning_rate, weight_decay=1e-5)

    log_dir = os.path.join("runs", "gen_with_rec_loss")
    log_subdir = os.path.join(log_dir, run_name + "_" + datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S"))
    tb_writer = SummaryWriter(log_subdir)

    try:
        for epoch in range(epochs):
            print(f"Epoch {epoch}\n-------------------------------")
            train_loop(train_dataloader, gen, loss_fn, optimizer_gen)
            test_loop("train", train_dataloader, gen, loss_fn, tb_writer, epoch)
            test_loop("test", test_dataloader, gen, loss_fn, tb_writer, epoch)
            gen_zero_grads = 0
            for name, weight in gen.named_parameters():
                tb_writer.add_histogram(f"Weights/{name}", weight, epoch)
                if weight.grad is not None:
                    tb_writer.add_histogram(f"Gradients/{name}", weight.grad, epoch)
                    gen_zero_grads += weight.grad.numel() - weight.grad.count_nonzero().item()
            tb_writer.add_scalar(f"Zero gradients", gen_zero_grads, epoch)
    finally:
        tb_writer.close()
        
    print("Done!")
    return gen

# %%
NUM_RANDOM_INPUTS = 4


from models import Conv2dLeakyReLU, ConvTranspose2dLeakyReLU, LinearLeakyReLU


class GameganGenerator(nn.Module):
    def __init__(self, leak=0.0):
        super().__init__()

        self.leak = leak

        self.board_encoder = models.GameganBoardEncoder()

        self.event_embedding = LinearLeakyReLU(NUM_EVENT_TYPES, 256, negative_slope=leak)
        self.random_embedding = LinearLeakyReLU(NUM_RANDOM_INPUTS, 256, negative_slope=leak)

        self.random_event_encoder = nn.Sequential(
            LinearLeakyReLU(512, 256, negative_slope=leak),
            nn.Linear(256, 256)
        )

        self.dynamics = nn.Sequential(
            LinearLeakyReLU(512, 256, negative_slope=leak),
            LinearLeakyReLU(256, 256, negative_slope=leak),
        )

        self.renderer = models.GameganRenderer()

    def forward(self, b, e):
        batch_size, cell_channels, height, width = b.shape

        # Encode board state
        s = self.board_encoder(b)

        # Embed events
        e = self.event_embedding(e)

        # Generate and embed random inputs
        z = torch.rand(batch_size, NUM_RANDOM_INPUTS, device=device)
        z = self.random_embedding(z)

        # Encode events and random inputs
        v = self.random_event_encoder(torch.cat((e, z), dim=1))

        # Apply game dynamics
        h = torch.cat((s, v), dim=1)
        h = self.dynamics(h)

        # Render new board
        y = self.renderer(h)
        return y


print(f"Parameters: {count_parameters(GameganGenerator())}")
# Out:
# Parameters: 779336

# %%
gen = train(
    run_name="weight_decay",
    gen_factory=lambda: GameganGenerator(leak=0.2).to(device),
    epochs=1500
)
# Out:
# Epoch 0
# -------------------------------
# train error:
#  G loss: 0.025656, cell accuracy: 86.0%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.025715, cell accuracy: 85.9%, board accuracy: 0.0%
#
# Epoch 1
# -------------------------------
# train error:
#  G loss: 0.016043, cell accuracy: 91.6%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.016224, cell accuracy: 91.5%, board accuracy: 0.0%
#
# Epoch 2
# -------------------------------
# train error:
#  G loss: 0.012220, cell accuracy: 93.8%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.012457, cell accuracy: 93.7%, board accuracy: 0.0%
#
# Epoch 3
# -------------------------------
# train error:
#  G loss: 0.009973, cell accuracy: 95.0%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.010248, cell accuracy: 94.9%, board accuracy: 0.0%
#
# Epoch 4
# -------------------------------
# train error:
#  G loss: 0.008491, cell accuracy: 95.8%, board accuracy: 0.0%
#
# test error:
#  G loss: 0.008806, cell accuracy: 95.7%, board accuracy: 0.0%
#
# Epoch 5
# -------------------------------
# train error:
#  G loss: 0.007447, cell accuracy: 96.3%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.007777, cell accuracy: 96.2%, board accuracy: 0.1%
#
# Epoch 6
# -------------------------------
# train error:
#  G loss: 0.006719, cell accuracy: 96.7%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.007076, cell accuracy: 96.5%, board accuracy: 0.1%
#
# Epoch 7
# -------------------------------
# train error:
#  G loss: 0.006176, cell accuracy: 96.9%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.006563, cell accuracy: 96.8%, board accuracy: 0.1%
#
# Epoch 8
# -------------------------------
# train error:
#  G loss: 0.005802, cell accuracy: 97.1%, board accuracy: 0.1%
#
# test error:
#  G loss: 0.006190, cell accuracy: 97.0%, board accuracy: 0.1%
#
# Epoch 9
# -------------------------------
# train error:
#  G loss: 0.005477, cell accuracy: 97.3%, board accuracy: 0.2%
#
# test error:
#  G loss: 0.005906, cell accuracy: 97.1%, board accuracy: 0.2%
#
# Epoch 10
# -------------------------------
# train error:
#  G loss: 0.005257, cell accuracy: 97.4%, board accuracy: 0.3%
#
# test error:
#  G loss: 0.005683, cell accuracy: 97.2%, board accuracy: 0.4%
#
# Epoch 11
# -------------------------------
# train error:
#  G loss: 0.004978, cell accuracy: 97.5%, board accuracy: 0.5%
#
# test error:
#  G loss: 0.005426, cell accuracy: 97.3%, board accuracy: 0.3%
#
# Epoch 12
# -------------------------------
# train error:
#  G loss: 0.004725, cell accuracy: 97.6%, board accuracy: 1.0%
#
# test error:
#  G loss: 0.005197, cell accuracy: 97.4%, board accuracy: 0.5%
#
# Epoch 13
# -------------------------------
# train error:
#  G loss: 0.004594, cell accuracy: 97.7%, board accuracy: 1.3%
#
# test error:
#  G loss: 0.005077, cell accuracy: 97.5%, board accuracy: 0.7%
#
# Epoch 14
# -------------------------------
# train error:
#  G loss: 0.004360, cell accuracy: 97.8%, board accuracy: 2.0%
#
# test error:
#  G loss: 0.004883, cell accuracy: 97.6%, board accuracy: 1.0%
#
# Epoch 15
# -------------------------------
# train error:
#  G loss: 0.004160, cell accuracy: 98.0%, board accuracy: 2.4%
#
# test error:
#  G loss: 0.004699, cell accuracy: 97.7%, board accuracy: 1.4%
#
# Epoch 16
# -------------------------------
# train error:
#  G loss: 0.003980, cell accuracy: 98.0%, board accuracy: 3.4%
#
# test error:
#  G loss: 0.004548, cell accuracy: 97.8%, board accuracy: 2.2%
#
# Epoch 17
# -------------------------------
# train error:
#  G loss: 0.003898, cell accuracy: 98.1%, board accuracy: 3.7%
#
# test error:
#  G loss: 0.004497, cell accuracy: 97.8%, board accuracy: 2.2%
#
# Epoch 18
# -------------------------------
# train error:
#  G loss: 0.003656, cell accuracy: 98.2%, board accuracy: 4.8%
#
# test error:
#  G loss: 0.004271, cell accuracy: 97.9%, board accuracy: 2.8%
#
# Epoch 19
# -------------------------------
# train error:
#  G loss: 0.003587, cell accuracy: 98.3%, board accuracy: 5.2%
#
# test error:
#  G loss: 0.004239, cell accuracy: 97.9%, board accuracy: 2.6%
#
# Epoch 20
# -------------------------------
# train error:
#  G loss: 0.003475, cell accuracy: 98.3%, board accuracy: 6.4%
#
# test error:
#  G loss: 0.004129, cell accuracy: 98.0%, board accuracy: 4.2%
#
# Epoch 21
# -------------------------------
# train error:
#  G loss: 0.003367, cell accuracy: 98.4%, board accuracy: 8.1%
#
# test error:
#  G loss: 0.004040, cell accuracy: 98.1%, board accuracy: 5.4%
#
# Epoch 22
# -------------------------------
# train error:
#  G loss: 0.003204, cell accuracy: 98.5%, board accuracy: 8.9%
#
# test error:
#  G loss: 0.003905, cell accuracy: 98.1%, board accuracy: 5.5%
#
# Epoch 23
# -------------------------------
# train error:
#  G loss: 0.003121, cell accuracy: 98.5%, board accuracy: 9.3%
#
# test error:
#  G loss: 0.003839, cell accuracy: 98.1%, board accuracy: 5.7%
#
# Epoch 24
# -------------------------------
# train error:
#  G loss: 0.003012, cell accuracy: 98.6%, board accuracy: 10.0%
#
# test error:
#  G loss: 0.003773, cell accuracy: 98.2%, board accuracy: 6.2%
#
# Epoch 25
# -------------------------------
# train error:
#  G loss: 0.002893, cell accuracy: 98.6%, board accuracy: 12.2%
#
# test error:
#  G loss: 0.003643, cell accuracy: 98.2%, board accuracy: 7.6%
#
# Epoch 26
# -------------------------------
# train error:
#  G loss: 0.002834, cell accuracy: 98.7%, board accuracy: 13.2%
#
# test error:
#  G loss: 0.003610, cell accuracy: 98.2%, board accuracy: 7.8%
#
# Epoch 27
# -------------------------------
# train error:
#  G loss: 0.002688, cell accuracy: 98.7%, board accuracy: 14.1%
#
# test error:
#  G loss: 0.003502, cell accuracy: 98.3%, board accuracy: 8.8%
#
# Epoch 28
# -------------------------------
# train error:
#  G loss: 0.002666, cell accuracy: 98.7%, board accuracy: 15.1%
#
# test error:
#  G loss: 0.003464, cell accuracy: 98.3%, board accuracy: 9.3%
#
# Epoch 29
# -------------------------------
# train error:
#  G loss: 0.002588, cell accuracy: 98.8%, board accuracy: 17.2%
#
# test error:
#  G loss: 0.003415, cell accuracy: 98.3%, board accuracy: 10.6%
#
# Epoch 30
# -------------------------------
# train error:
#  G loss: 0.002534, cell accuracy: 98.8%, board accuracy: 17.5%
#
# test error:
#  G loss: 0.003396, cell accuracy: 98.3%, board accuracy: 10.2%
#
# Epoch 31
# -------------------------------
# train error:
#  G loss: 0.002518, cell accuracy: 98.8%, board accuracy: 18.5%
#
# test error:
#  G loss: 0.003383, cell accuracy: 98.4%, board accuracy: 11.7%
#
# Epoch 32
# -------------------------------
# train error:
#  G loss: 0.002401, cell accuracy: 98.9%, board accuracy: 19.6%
#
# test error:
#  G loss: 0.003312, cell accuracy: 98.4%, board accuracy: 11.6%
#
# Epoch 33
# -------------------------------
# train error:
#  G loss: 0.002332, cell accuracy: 98.9%, board accuracy: 20.9%
#
# test error:
#  G loss: 0.003228, cell accuracy: 98.4%, board accuracy: 12.6%
#
# Epoch 34
# -------------------------------
# train error:
#  G loss: 0.002339, cell accuracy: 98.9%, board accuracy: 21.1%
#
# test error:
#  G loss: 0.003235, cell accuracy: 98.4%, board accuracy: 13.3%
#
# Epoch 35
# -------------------------------
# train error:
#  G loss: 0.002312, cell accuracy: 98.9%, board accuracy: 21.1%
#
# test error:
#  G loss: 0.003249, cell accuracy: 98.4%, board accuracy: 12.5%
#
# Epoch 36
# -------------------------------
# train error:
#  G loss: 0.002253, cell accuracy: 98.9%, board accuracy: 22.4%
#
# test error:
#  G loss: 0.003198, cell accuracy: 98.4%, board accuracy: 13.3%
#
# Epoch 37
# -------------------------------
# train error:
#  G loss: 0.002091, cell accuracy: 99.0%, board accuracy: 24.7%
#
# test error:
#  G loss: 0.003050, cell accuracy: 98.5%, board accuracy: 13.5%
#
# Epoch 38
# -------------------------------
# train error:
#  G loss: 0.002130, cell accuracy: 99.0%, board accuracy: 25.9%
#
# test error:
#  G loss: 0.003100, cell accuracy: 98.5%, board accuracy: 17.2%
#
# Epoch 39
# -------------------------------
# train error:
#  G loss: 0.002063, cell accuracy: 99.1%, board accuracy: 26.5%
#
# test error:
#  G loss: 0.003047, cell accuracy: 98.5%, board accuracy: 14.6%
#
# Epoch 40
# -------------------------------
# train error:
#  G loss: 0.002075, cell accuracy: 99.1%, board accuracy: 25.9%
#
# test error:
#  G loss: 0.003077, cell accuracy: 98.5%, board accuracy: 15.2%
#
# Epoch 41
# -------------------------------
# train error:
#  G loss: 0.002106, cell accuracy: 99.0%, board accuracy: 26.3%
#
# test error:
#  G loss: 0.003124, cell accuracy: 98.5%, board accuracy: 14.4%
#
# Epoch 42
# -------------------------------
# train error:
#  G loss: 0.001904, cell accuracy: 99.1%, board accuracy: 30.6%
#
# test error:
#  G loss: 0.002940, cell accuracy: 98.6%, board accuracy: 17.3%
#
# Epoch 43
# -------------------------------
# train error:
#  G loss: 0.001919, cell accuracy: 99.1%, board accuracy: 28.3%
#
# test error:
#  G loss: 0.002948, cell accuracy: 98.6%, board accuracy: 16.6%
#
# Epoch 44
# -------------------------------
# train error:
#  G loss: 0.001891, cell accuracy: 99.1%, board accuracy: 29.0%
#
# test error:
#  G loss: 0.002940, cell accuracy: 98.6%, board accuracy: 16.2%
#
# Epoch 45
# -------------------------------
# train error:
#  G loss: 0.001853, cell accuracy: 99.2%, board accuracy: 31.1%
#
# test error:
#  G loss: 0.002955, cell accuracy: 98.6%, board accuracy: 17.0%
#
# Epoch 46
# -------------------------------
# train error:
#  G loss: 0.001867, cell accuracy: 99.1%, board accuracy: 29.5%
#
# test error:
#  G loss: 0.002950, cell accuracy: 98.6%, board accuracy: 16.2%
#
# Epoch 47
# -------------------------------
# train error:
#  G loss: 0.001780, cell accuracy: 99.2%, board accuracy: 32.8%
#
# test error:
#  G loss: 0.002869, cell accuracy: 98.6%, board accuracy: 17.9%
#
# Epoch 48
# -------------------------------
# train error:
#  G loss: 0.001805, cell accuracy: 99.2%, board accuracy: 31.2%
#
# test error:
#  G loss: 0.002916, cell accuracy: 98.6%, board accuracy: 17.2%
#
# Epoch 49
# -------------------------------
# train error:
#  G loss: 0.001771, cell accuracy: 99.2%, board accuracy: 32.0%
#
# test error:
#  G loss: 0.002899, cell accuracy: 98.6%, board accuracy: 18.0%
#
# Epoch 50
# -------------------------------
# train error:
#  G loss: 0.001752, cell accuracy: 99.2%, board accuracy: 33.2%
#
# test error:
#  G loss: 0.002861, cell accuracy: 98.6%, board accuracy: 18.2%
#
# Epoch 51
# -------------------------------
# train error:
#  G loss: 0.001673, cell accuracy: 99.3%, board accuracy: 35.4%
#
# test error:
#  G loss: 0.002797, cell accuracy: 98.6%, board accuracy: 19.6%
#
# Epoch 52
# -------------------------------
# train error:
#  G loss: 0.001715, cell accuracy: 99.2%, board accuracy: 33.4%
#
# test error:
#  G loss: 0.002861, cell accuracy: 98.6%, board accuracy: 17.8%
#
# Epoch 53
# -------------------------------
# train error:
#  G loss: 0.001603, cell accuracy: 99.3%, board accuracy: 36.2%
#
# test error:
#  G loss: 0.002766, cell accuracy: 98.6%, board accuracy: 20.0%
#
# Epoch 54
# -------------------------------
# train error:
#  G loss: 0.001709, cell accuracy: 99.2%, board accuracy: 31.8%
#
# test error:
#  G loss: 0.002870, cell accuracy: 98.6%, board accuracy: 16.6%
#
# Epoch 55
# -------------------------------
# train error:
#  G loss: 0.001629, cell accuracy: 99.3%, board accuracy: 35.9%
#
# test error:
#  G loss: 0.002807, cell accuracy: 98.6%, board accuracy: 19.9%
#
# Epoch 56
# -------------------------------
# train error:
#  G loss: 0.001552, cell accuracy: 99.3%, board accuracy: 38.6%
#
# test error:
#  G loss: 0.002727, cell accuracy: 98.7%, board accuracy: 20.3%
#
# Epoch 57
# -------------------------------
# train error:
#  G loss: 0.001535, cell accuracy: 99.3%, board accuracy: 38.5%
#
# test error:
#  G loss: 0.002695, cell accuracy: 98.7%, board accuracy: 21.0%
#
# Epoch 58
# -------------------------------
# train error:
#  G loss: 0.001507, cell accuracy: 99.4%, board accuracy: 38.8%
#
# test error:
#  G loss: 0.002684, cell accuracy: 98.7%, board accuracy: 21.6%
#
# Epoch 59
# -------------------------------
# train error:
#  G loss: 0.001492, cell accuracy: 99.4%, board accuracy: 39.1%
#
# test error:
#  G loss: 0.002700, cell accuracy: 98.7%, board accuracy: 21.2%
#
# Epoch 60
# -------------------------------
# train error:
#  G loss: 0.001490, cell accuracy: 99.4%, board accuracy: 38.8%
#
# test error:
#  G loss: 0.002715, cell accuracy: 98.7%, board accuracy: 20.8%
#
# Epoch 61
# -------------------------------
# train error:
#  G loss: 0.001456, cell accuracy: 99.4%, board accuracy: 39.6%
#
# test error:
#  G loss: 0.002705, cell accuracy: 98.7%, board accuracy: 22.1%
#
# Epoch 62
# -------------------------------
# train error:
#  G loss: 0.001352, cell accuracy: 99.4%, board accuracy: 43.6%
#
# test error:
#  G loss: 0.002603, cell accuracy: 98.7%, board accuracy: 23.8%
#
# Epoch 63
# -------------------------------
# train error:
#  G loss: 0.001454, cell accuracy: 99.4%, board accuracy: 40.5%
#
# test error:
#  G loss: 0.002712, cell accuracy: 98.7%, board accuracy: 21.7%
#
# Epoch 64
# -------------------------------
# train error:
#  G loss: 0.001441, cell accuracy: 99.4%, board accuracy: 40.4%
#
# test error:
#  G loss: 0.002702, cell accuracy: 98.7%, board accuracy: 22.0%
#
# Epoch 65
# -------------------------------
# train error:
#  G loss: 0.001368, cell accuracy: 99.4%, board accuracy: 42.7%
#
# test error:
#  G loss: 0.002641, cell accuracy: 98.7%, board accuracy: 23.3%
#
# Epoch 66
# -------------------------------
# train error:
#  G loss: 0.001354, cell accuracy: 99.4%, board accuracy: 42.7%
#
# test error:
#  G loss: 0.002628, cell accuracy: 98.7%, board accuracy: 22.6%
#
# Epoch 67
# -------------------------------
# train error:
#  G loss: 0.001337, cell accuracy: 99.4%, board accuracy: 44.0%
#
# test error:
#  G loss: 0.002621, cell accuracy: 98.7%, board accuracy: 23.8%
#
# Epoch 68
# -------------------------------
# train error:
#  G loss: 0.001294, cell accuracy: 99.5%, board accuracy: 45.6%
#
# test error:
#  G loss: 0.002590, cell accuracy: 98.7%, board accuracy: 24.9%
#
# Epoch 69
# -------------------------------
# train error:
#  G loss: 0.001340, cell accuracy: 99.4%, board accuracy: 43.0%
#
# test error:
#  G loss: 0.002667, cell accuracy: 98.7%, board accuracy: 22.9%
#
# Epoch 70
# -------------------------------
# train error:
#  G loss: 0.001322, cell accuracy: 99.4%, board accuracy: 44.5%
#
# test error:
#  G loss: 0.002634, cell accuracy: 98.7%, board accuracy: 24.3%
#
# Epoch 71
# -------------------------------
# train error:
#  G loss: 0.001382, cell accuracy: 99.4%, board accuracy: 41.9%
#
# test error:
#  G loss: 0.002646, cell accuracy: 98.7%, board accuracy: 23.0%
#
# Epoch 72
# -------------------------------
# train error:
#  G loss: 0.001270, cell accuracy: 99.5%, board accuracy: 46.4%
#
# test error:
#  G loss: 0.002577, cell accuracy: 98.7%, board accuracy: 24.2%
#
# Epoch 73
# -------------------------------
# train error:
#  G loss: 0.001266, cell accuracy: 99.5%, board accuracy: 44.2%
#
# test error:
#  G loss: 0.002598, cell accuracy: 98.7%, board accuracy: 23.4%
#
# Epoch 74
# -------------------------------
# train error:
#  G loss: 0.001332, cell accuracy: 99.4%, board accuracy: 42.6%
#
# test error:
#  G loss: 0.002683, cell accuracy: 98.7%, board accuracy: 23.3%
#
# Epoch 75
# -------------------------------
# train error:
#  G loss: 0.001269, cell accuracy: 99.5%, board accuracy: 44.5%
#
# test error:
#  G loss: 0.002617, cell accuracy: 98.7%, board accuracy: 23.1%
#
# Epoch 76
# -------------------------------
# train error:
#  G loss: 0.001287, cell accuracy: 99.5%, board accuracy: 45.0%
#
# test error:
#  G loss: 0.002635, cell accuracy: 98.7%, board accuracy: 23.7%
#
# Epoch 77
# -------------------------------
# train error:
#  G loss: 0.001181, cell accuracy: 99.5%, board accuracy: 47.2%
#
# test error:
#  G loss: 0.002524, cell accuracy: 98.8%, board accuracy: 24.5%
#
# Epoch 78
# -------------------------------
# train error:
#  G loss: 0.001149, cell accuracy: 99.5%, board accuracy: 50.6%
#
# test error:
#  G loss: 0.002515, cell accuracy: 98.8%, board accuracy: 26.9%
#
# Epoch 79
# -------------------------------
# train error:
#  G loss: 0.001262, cell accuracy: 99.5%, board accuracy: 45.9%
#
# test error:
#  G loss: 0.002616, cell accuracy: 98.7%, board accuracy: 23.0%
#
# Epoch 80
# -------------------------------
# train error:
#  G loss: 0.001176, cell accuracy: 99.5%, board accuracy: 47.6%
#
# test error:
#  G loss: 0.002567, cell accuracy: 98.7%, board accuracy: 25.1%
#
# Epoch 81
# -------------------------------
# train error:
#  G loss: 0.001254, cell accuracy: 99.5%, board accuracy: 45.0%
#
# test error:
#  G loss: 0.002598, cell accuracy: 98.7%, board accuracy: 23.7%
#
# Epoch 82
# -------------------------------
# train error:
#  G loss: 0.001143, cell accuracy: 99.5%, board accuracy: 49.1%
#
# test error:
#  G loss: 0.002499, cell accuracy: 98.8%, board accuracy: 25.1%
#
# Epoch 83
# -------------------------------
# train error:
#  G loss: 0.001114, cell accuracy: 99.6%, board accuracy: 51.7%
#
# test error:
#  G loss: 0.002506, cell accuracy: 98.8%, board accuracy: 26.7%
#
# Epoch 84
# -------------------------------
# train error:
#  G loss: 0.001088, cell accuracy: 99.6%, board accuracy: 50.7%
#
# test error:
#  G loss: 0.002456, cell accuracy: 98.8%, board accuracy: 25.3%
#
# Epoch 85
# -------------------------------
# train error:
#  G loss: 0.001119, cell accuracy: 99.5%, board accuracy: 49.1%
#
# test error:
#  G loss: 0.002505, cell accuracy: 98.8%, board accuracy: 25.3%
#
# Epoch 86
# -------------------------------
# train error:
#  G loss: 0.001095, cell accuracy: 99.6%, board accuracy: 50.5%
#
# test error:
#  G loss: 0.002472, cell accuracy: 98.8%, board accuracy: 26.9%
#
# Epoch 87
# -------------------------------
# train error:
#  G loss: 0.001073, cell accuracy: 99.6%, board accuracy: 51.4%
#
# test error:
#  G loss: 0.002461, cell accuracy: 98.8%, board accuracy: 26.9%
#
# Epoch 88
# -------------------------------
# train error:
#  G loss: 0.001164, cell accuracy: 99.5%, board accuracy: 47.9%
#
# test error:
#  G loss: 0.002568, cell accuracy: 98.7%, board accuracy: 25.0%
#
# Epoch 89
# -------------------------------
# train error:
#  G loss: 0.001057, cell accuracy: 99.6%, board accuracy: 52.6%
#
# test error:
#  G loss: 0.002472, cell accuracy: 98.8%, board accuracy: 26.9%
#
# Epoch 90
# -------------------------------
# train error:
#  G loss: 0.001077, cell accuracy: 99.6%, board accuracy: 51.2%
#
# test error:
#  G loss: 0.002508, cell accuracy: 98.8%, board accuracy: 25.7%
#
# Epoch 91
# -------------------------------
# train error:
#  G loss: 0.001073, cell accuracy: 99.6%, board accuracy: 50.3%
#
# test error:
#  G loss: 0.002524, cell accuracy: 98.8%, board accuracy: 25.3%
#
# Epoch 92
# -------------------------------
# train error:
#  G loss: 0.001072, cell accuracy: 99.6%, board accuracy: 50.8%
#
# test error:
#  G loss: 0.002522, cell accuracy: 98.8%, board accuracy: 25.3%
#
# Epoch 93
# -------------------------------
# train error:
#  G loss: 0.001010, cell accuracy: 99.6%, board accuracy: 53.8%
#
# test error:
#  G loss: 0.002471, cell accuracy: 98.8%, board accuracy: 27.2%
#
# Epoch 94
# -------------------------------
# train error:
#  G loss: 0.001019, cell accuracy: 99.6%, board accuracy: 53.5%
#
# test error:
#  G loss: 0.002479, cell accuracy: 98.8%, board accuracy: 27.7%
#
# Epoch 95
# -------------------------------
# train error:
#  G loss: 0.001038, cell accuracy: 99.6%, board accuracy: 52.1%
#
# test error:
#  G loss: 0.002467, cell accuracy: 98.8%, board accuracy: 26.2%
#
# Epoch 96
# -------------------------------
# train error:
#  G loss: 0.000990, cell accuracy: 99.6%, board accuracy: 55.0%
#
# test error:
#  G loss: 0.002404, cell accuracy: 98.8%, board accuracy: 28.2%
#
# Epoch 97
# -------------------------------
# train error:
#  G loss: 0.000996, cell accuracy: 99.6%, board accuracy: 54.2%
#
# test error:
#  G loss: 0.002464, cell accuracy: 98.8%, board accuracy: 27.1%
#
# Epoch 98
# -------------------------------
# train error:
#  G loss: 0.001045, cell accuracy: 99.6%, board accuracy: 52.5%
#
# test error:
#  G loss: 0.002533, cell accuracy: 98.8%, board accuracy: 27.4%
#
# Epoch 99
# -------------------------------
# train error:
#  G loss: 0.001140, cell accuracy: 99.5%, board accuracy: 47.9%
#
# test error:
#  G loss: 0.002551, cell accuracy: 98.8%, board accuracy: 25.9%
#
# Epoch 100
# -------------------------------
# train error:
#  G loss: 0.001032, cell accuracy: 99.6%, board accuracy: 51.3%
#
# test error:
#  G loss: 0.002482, cell accuracy: 98.8%, board accuracy: 26.0%
#
# Epoch 101
# -------------------------------
# train error:
#  G loss: 0.000993, cell accuracy: 99.6%, board accuracy: 54.5%
#
# test error:
#  G loss: 0.002416, cell accuracy: 98.8%, board accuracy: 27.6%
#
# Epoch 102
# -------------------------------
# train error:
#  G loss: 0.001012, cell accuracy: 99.6%, board accuracy: 52.8%
#
# test error:
#  G loss: 0.002446, cell accuracy: 98.8%, board accuracy: 28.0%
#
# Epoch 103
# -------------------------------
# train error:
#  G loss: 0.000938, cell accuracy: 99.6%, board accuracy: 56.4%
#
# test error:
#  G loss: 0.002406, cell accuracy: 98.8%, board accuracy: 29.0%
#
# Epoch 104
# -------------------------------
# train error:
#  G loss: 0.000976, cell accuracy: 99.6%, board accuracy: 54.2%
#
# test error:
#  G loss: 0.002424, cell accuracy: 98.8%, board accuracy: 28.2%
#
# Epoch 105
# -------------------------------
# train error:
#  G loss: 0.000885, cell accuracy: 99.7%, board accuracy: 59.6%
#
# test error:
#  G loss: 0.002339, cell accuracy: 98.9%, board accuracy: 31.1%
#
# Epoch 106
# -------------------------------
# train error:
#  G loss: 0.000967, cell accuracy: 99.6%, board accuracy: 54.9%
#
# test error:
#  G loss: 0.002417, cell accuracy: 98.8%, board accuracy: 28.2%
#
# Epoch 107
# -------------------------------
# train error:
#  G loss: 0.001006, cell accuracy: 99.6%, board accuracy: 53.1%
#
# test error:
#  G loss: 0.002455, cell accuracy: 98.8%, board accuracy: 27.7%
#
# Epoch 108
# -------------------------------
# train error:
#  G loss: 0.000932, cell accuracy: 99.6%, board accuracy: 56.3%
#
# test error:
#  G loss: 0.002369, cell accuracy: 98.9%, board accuracy: 29.4%
#
# Epoch 109
# -------------------------------
# train error:
#  G loss: 0.000864, cell accuracy: 99.7%, board accuracy: 60.2%
#
# test error:
#  G loss: 0.002314, cell accuracy: 98.9%, board accuracy: 31.5%
#
# Epoch 110
# -------------------------------
# train error:
#  G loss: 0.000936, cell accuracy: 99.6%, board accuracy: 56.3%
#
# test error:
#  G loss: 0.002399, cell accuracy: 98.8%, board accuracy: 29.3%
#
# Epoch 111
# -------------------------------
# train error:
#  G loss: 0.000866, cell accuracy: 99.7%, board accuracy: 60.1%
#
# test error:
#  G loss: 0.002301, cell accuracy: 98.9%, board accuracy: 31.9%
#
# Epoch 112
# -------------------------------
# train error:
#  G loss: 0.000984, cell accuracy: 99.6%, board accuracy: 54.3%
#
# test error:
#  G loss: 0.002460, cell accuracy: 98.8%, board accuracy: 29.2%
#
# Epoch 113
# -------------------------------
# train error:
#  G loss: 0.000921, cell accuracy: 99.6%, board accuracy: 56.1%
#
# test error:
#  G loss: 0.002403, cell accuracy: 98.8%, board accuracy: 27.5%
#
# Epoch 114
# -------------------------------
# train error:
#  G loss: 0.000964, cell accuracy: 99.6%, board accuracy: 55.2%
#
# test error:
#  G loss: 0.002439, cell accuracy: 98.8%, board accuracy: 30.0%
#
# Epoch 115
# -------------------------------
# train error:
#  G loss: 0.000902, cell accuracy: 99.6%, board accuracy: 57.3%
#
# test error:
#  G loss: 0.002381, cell accuracy: 98.8%, board accuracy: 30.2%
#
# Epoch 116
# -------------------------------
# train error:
#  G loss: 0.000920, cell accuracy: 99.6%, board accuracy: 57.7%
#
# test error:
#  G loss: 0.002392, cell accuracy: 98.8%, board accuracy: 30.2%
#
# Epoch 117
# -------------------------------
# train error:
#  G loss: 0.000881, cell accuracy: 99.7%, board accuracy: 58.5%
#
# test error:
#  G loss: 0.002360, cell accuracy: 98.9%, board accuracy: 30.0%
#
# Epoch 118
# -------------------------------
# train error:
#  G loss: 0.000897, cell accuracy: 99.6%, board accuracy: 56.9%
#
# test error:
#  G loss: 0.002381, cell accuracy: 98.8%, board accuracy: 28.5%
#
# Epoch 119
# -------------------------------
# train error:
#  G loss: 0.000869, cell accuracy: 99.7%, board accuracy: 58.0%
#
# test error:
#  G loss: 0.002391, cell accuracy: 98.8%, board accuracy: 30.3%
#
# Epoch 120
# -------------------------------
# train error:
#  G loss: 0.000954, cell accuracy: 99.6%, board accuracy: 54.4%
#
# test error:
#  G loss: 0.002431, cell accuracy: 98.8%, board accuracy: 29.3%
#
# Epoch 121
# -------------------------------
# train error:
#  G loss: 0.000855, cell accuracy: 99.7%, board accuracy: 59.2%
#
# test error:
#  G loss: 0.002336, cell accuracy: 98.9%, board accuracy: 30.7%
#
# Epoch 122
# -------------------------------
# train error:
#  G loss: 0.000851, cell accuracy: 99.7%, board accuracy: 58.9%
#
# test error:
#  G loss: 0.002290, cell accuracy: 98.9%, board accuracy: 31.2%
#
# Epoch 123
# -------------------------------
# train error:
#  G loss: 0.000854, cell accuracy: 99.7%, board accuracy: 59.1%
#
# test error:
#  G loss: 0.002351, cell accuracy: 98.9%, board accuracy: 31.1%
#
# Epoch 124
# -------------------------------
# train error:
#  G loss: 0.000919, cell accuracy: 99.6%, board accuracy: 56.2%
#
# test error:
#  G loss: 0.002416, cell accuracy: 98.8%, board accuracy: 28.2%
#
# Epoch 125
# -------------------------------
# train error:
#  G loss: 0.000840, cell accuracy: 99.7%, board accuracy: 59.8%
#
# test error:
#  G loss: 0.002288, cell accuracy: 98.9%, board accuracy: 31.3%
#
# Epoch 126
# -------------------------------
# train error:
#  G loss: 0.000844, cell accuracy: 99.7%, board accuracy: 59.0%
#
# test error:
#  G loss: 0.002316, cell accuracy: 98.9%, board accuracy: 30.8%
#
# Epoch 127
# -------------------------------
# train error:
#  G loss: 0.000850, cell accuracy: 99.7%, board accuracy: 58.1%
#
# test error:
#  G loss: 0.002347, cell accuracy: 98.9%, board accuracy: 31.4%
#
# Epoch 128
# -------------------------------
# train error:
#  G loss: 0.000864, cell accuracy: 99.7%, board accuracy: 59.3%
#
# test error:
#  G loss: 0.002349, cell accuracy: 98.9%, board accuracy: 31.1%
#
# Epoch 129
# -------------------------------
# train error:
#  G loss: 0.000831, cell accuracy: 99.7%, board accuracy: 60.1%
#
# test error:
#  G loss: 0.002336, cell accuracy: 98.9%, board accuracy: 31.0%
#
# Epoch 130
# -------------------------------
# train error:
#  G loss: 0.000842, cell accuracy: 99.7%, board accuracy: 59.9%
#
# test error:
#  G loss: 0.002310, cell accuracy: 98.9%, board accuracy: 31.8%
#
# Epoch 131
# -------------------------------
# train error:
#  G loss: 0.000815, cell accuracy: 99.7%, board accuracy: 61.1%
#
# test error:
#  G loss: 0.002304, cell accuracy: 98.9%, board accuracy: 31.9%
#
# Epoch 132
# -------------------------------
# train error:
#  G loss: 0.000783, cell accuracy: 99.7%, board accuracy: 63.3%
#
# test error:
#  G loss: 0.002270, cell accuracy: 98.9%, board accuracy: 33.1%
#
# Epoch 133
# -------------------------------
# train error:
#  G loss: 0.000756, cell accuracy: 99.7%, board accuracy: 65.0%
#
# test error:
#  G loss: 0.002243, cell accuracy: 98.9%, board accuracy: 33.5%
#
# Epoch 134
# -------------------------------
# train error:
#  G loss: 0.000868, cell accuracy: 99.7%, board accuracy: 58.7%
#
# test error:
#  G loss: 0.002391, cell accuracy: 98.8%, board accuracy: 30.6%
#
# Epoch 135
# -------------------------------
# train error:
#  G loss: 0.000819, cell accuracy: 99.7%, board accuracy: 61.4%
#
# test error:
#  G loss: 0.002311, cell accuracy: 98.9%, board accuracy: 33.1%
#
# Epoch 136
# -------------------------------
# train error:
#  G loss: 0.000810, cell accuracy: 99.7%, board accuracy: 62.9%
#
# test error:
#  G loss: 0.002312, cell accuracy: 98.9%, board accuracy: 33.9%
#
# Epoch 137
# -------------------------------
# train error:
#  G loss: 0.000806, cell accuracy: 99.7%, board accuracy: 63.0%
#
# test error:
#  G loss: 0.002313, cell accuracy: 98.9%, board accuracy: 32.7%
#
# Epoch 138
# -------------------------------
# train error:
#  G loss: 0.000868, cell accuracy: 99.7%, board accuracy: 59.6%
#
# test error:
#  G loss: 0.002340, cell accuracy: 98.9%, board accuracy: 31.7%
#
# Epoch 139
# -------------------------------
# train error:
#  G loss: 0.000759, cell accuracy: 99.7%, board accuracy: 63.7%
#
# test error:
#  G loss: 0.002248, cell accuracy: 98.9%, board accuracy: 33.4%
#
# Epoch 140
# -------------------------------
# train error:
#  G loss: 0.000777, cell accuracy: 99.7%, board accuracy: 63.8%
#
# test error:
#  G loss: 0.002259, cell accuracy: 98.9%, board accuracy: 33.2%
#
# Epoch 141
# -------------------------------
# train error:
#  G loss: 0.000813, cell accuracy: 99.7%, board accuracy: 61.7%
#
# test error:
#  G loss: 0.002316, cell accuracy: 98.9%, board accuracy: 32.0%
#
# Epoch 142
# -------------------------------
# train error:
#  G loss: 0.000825, cell accuracy: 99.7%, board accuracy: 59.3%
#
# test error:
#  G loss: 0.002349, cell accuracy: 98.9%, board accuracy: 29.9%
#
# Epoch 143
# -------------------------------
# train error:
#  G loss: 0.000735, cell accuracy: 99.7%, board accuracy: 65.0%
#
# test error:
#  G loss: 0.002229, cell accuracy: 98.9%, board accuracy: 34.6%
#
# Epoch 144
# -------------------------------
# train error:
#  G loss: 0.000801, cell accuracy: 99.7%, board accuracy: 61.6%
#
# test error:
#  G loss: 0.002286, cell accuracy: 98.9%, board accuracy: 33.1%
#
# Epoch 145
# -------------------------------
# train error:
#  G loss: 0.000714, cell accuracy: 99.7%, board accuracy: 66.5%
#
# test error:
#  G loss: 0.002190, cell accuracy: 98.9%, board accuracy: 35.5%
#
# Epoch 146
# -------------------------------
# train error:
#  G loss: 0.000753, cell accuracy: 99.7%, board accuracy: 64.0%
#
# test error:
#  G loss: 0.002270, cell accuracy: 98.9%, board accuracy: 32.6%
#
# Epoch 147
# -------------------------------
# train error:
#  G loss: 0.000711, cell accuracy: 99.7%, board accuracy: 64.7%
#
# test error:
#  G loss: 0.002224, cell accuracy: 98.9%, board accuracy: 33.5%
#
# Epoch 148
# -------------------------------
# train error:
#  G loss: 0.000773, cell accuracy: 99.7%, board accuracy: 63.2%
#
# test error:
#  G loss: 0.002248, cell accuracy: 98.9%, board accuracy: 33.4%
#
# Epoch 149
# -------------------------------
# train error:
#  G loss: 0.000745, cell accuracy: 99.7%, board accuracy: 64.4%
#
# test error:
#  G loss: 0.002226, cell accuracy: 98.9%, board accuracy: 34.7%
#
# Epoch 150
# -------------------------------
# train error:
#  G loss: 0.000768, cell accuracy: 99.7%, board accuracy: 64.1%
#
# test error:
#  G loss: 0.002248, cell accuracy: 98.9%, board accuracy: 34.4%
#
# Epoch 151
# -------------------------------
# train error:
#  G loss: 0.000819, cell accuracy: 99.7%, board accuracy: 61.9%
#
# test error:
#  G loss: 0.002339, cell accuracy: 98.9%, board accuracy: 32.8%
#
# Epoch 152
# -------------------------------
# train error:
#  G loss: 0.000724, cell accuracy: 99.7%, board accuracy: 63.9%
#
# test error:
#  G loss: 0.002210, cell accuracy: 98.9%, board accuracy: 34.6%
#
# Epoch 153
# -------------------------------
# train error:
#  G loss: 0.000736, cell accuracy: 99.7%, board accuracy: 63.9%
#
# test error:
#  G loss: 0.002248, cell accuracy: 98.9%, board accuracy: 33.9%
#
# Epoch 154
# -------------------------------
# train error:
#  G loss: 0.000812, cell accuracy: 99.7%, board accuracy: 61.0%
#
# test error:
#  G loss: 0.002272, cell accuracy: 98.9%, board accuracy: 32.4%
#
# Epoch 155
# -------------------------------
# train error:
#  G loss: 0.000792, cell accuracy: 99.7%, board accuracy: 63.0%
#
# test error:
#  G loss: 0.002284, cell accuracy: 98.9%, board accuracy: 33.2%
#
# Epoch 156
# -------------------------------
# train error:
#  G loss: 0.000719, cell accuracy: 99.7%, board accuracy: 65.5%
#
# test error:
#  G loss: 0.002209, cell accuracy: 98.9%, board accuracy: 34.9%
#
# Epoch 157
# -------------------------------
# train error:
#  G loss: 0.000756, cell accuracy: 99.7%, board accuracy: 62.6%
#
# test error:
#  G loss: 0.002269, cell accuracy: 98.9%, board accuracy: 32.2%
#
# Epoch 158
# -------------------------------
# train error:
#  G loss: 0.000732, cell accuracy: 99.7%, board accuracy: 64.9%
#
# test error:
#  G loss: 0.002232, cell accuracy: 98.9%, board accuracy: 34.0%
#
# Epoch 159
# -------------------------------
# train error:
#  G loss: 0.000727, cell accuracy: 99.7%, board accuracy: 65.0%
#
# test error:
#  G loss: 0.002232, cell accuracy: 98.9%, board accuracy: 34.2%
#
# Epoch 160
# -------------------------------
# train error:
#  G loss: 0.000711, cell accuracy: 99.7%, board accuracy: 65.0%
#
# test error:
#  G loss: 0.002236, cell accuracy: 98.9%, board accuracy: 35.2%
#
# Epoch 161
# -------------------------------
# train error:
#  G loss: 0.000697, cell accuracy: 99.7%, board accuracy: 66.7%
#
# test error:
#  G loss: 0.002214, cell accuracy: 98.9%, board accuracy: 34.9%
#
# Epoch 162
# -------------------------------
# train error:
#  G loss: 0.000749, cell accuracy: 99.7%, board accuracy: 63.3%
#
# test error:
#  G loss: 0.002256, cell accuracy: 98.9%, board accuracy: 33.1%
#
# Epoch 163
# -------------------------------
# train error:
#  G loss: 0.000776, cell accuracy: 99.7%, board accuracy: 63.8%
#
# test error:
#  G loss: 0.002269, cell accuracy: 98.9%, board accuracy: 34.5%
#
# Epoch 164
# -------------------------------
# train error:
#  G loss: 0.000784, cell accuracy: 99.7%, board accuracy: 62.1%
#
# test error:
#  G loss: 0.002299, cell accuracy: 98.9%, board accuracy: 32.3%
#
# Epoch 165
# -------------------------------
# train error:
#  G loss: 0.000704, cell accuracy: 99.7%, board accuracy: 65.5%
#
# test error:
#  G loss: 0.002191, cell accuracy: 98.9%, board accuracy: 35.0%
#
# Epoch 166
# -------------------------------
# train error:
#  G loss: 0.000699, cell accuracy: 99.7%, board accuracy: 66.9%
#
# test error:
#  G loss: 0.002198, cell accuracy: 98.9%, board accuracy: 35.0%
#
# Epoch 167
# -------------------------------
# train error:
#  G loss: 0.000719, cell accuracy: 99.7%, board accuracy: 64.1%
#
# test error:
#  G loss: 0.002236, cell accuracy: 98.9%, board accuracy: 33.9%
#
# Epoch 168
# -------------------------------
# train error:
#  G loss: 0.000734, cell accuracy: 99.7%, board accuracy: 64.1%
#
# test error:
#  G loss: 0.002252, cell accuracy: 98.9%, board accuracy: 33.9%
#
# Epoch 169
# -------------------------------
# train error:
#  G loss: 0.000710, cell accuracy: 99.7%, board accuracy: 65.2%
#
# test error:
#  G loss: 0.002211, cell accuracy: 98.9%, board accuracy: 34.5%
#
# Epoch 170
# -------------------------------
# train error:
#  G loss: 0.000676, cell accuracy: 99.8%, board accuracy: 67.1%
#
# test error:
#  G loss: 0.002190, cell accuracy: 98.9%, board accuracy: 35.7%
#
# Epoch 171
# -------------------------------
# train error:
#  G loss: 0.000705, cell accuracy: 99.7%, board accuracy: 66.1%
#
# test error:
#  G loss: 0.002187, cell accuracy: 98.9%, board accuracy: 35.2%
#
# Epoch 172
# -------------------------------
# train error:
#  G loss: 0.000664, cell accuracy: 99.7%, board accuracy: 66.2%
#
# test error:
#  G loss: 0.002167, cell accuracy: 98.9%, board accuracy: 35.0%
#
# Epoch 173
# -------------------------------
# train error:
#  G loss: 0.000749, cell accuracy: 99.7%, board accuracy: 64.6%
#
# test error:
#  G loss: 0.002254, cell accuracy: 98.9%, board accuracy: 33.8%
#
# Epoch 174
# -------------------------------
# train error:
#  G loss: 0.000671, cell accuracy: 99.7%, board accuracy: 66.7%
#
# test error:
#  G loss: 0.002187, cell accuracy: 98.9%, board accuracy: 34.8%
#
# Epoch 175
# -------------------------------
# train error:
#  G loss: 0.000677, cell accuracy: 99.7%, board accuracy: 67.4%
#
# test error:
#  G loss: 0.002172, cell accuracy: 99.0%, board accuracy: 36.0%
#
# Epoch 176
# -------------------------------
# train error:
#  G loss: 0.000717, cell accuracy: 99.7%, board accuracy: 66.2%
#
# test error:
#  G loss: 0.002221, cell accuracy: 98.9%, board accuracy: 35.6%
#
# Epoch 177
# -------------------------------
# train error:
#  G loss: 0.000666, cell accuracy: 99.7%, board accuracy: 68.4%
#
# test error:
#  G loss: 0.002174, cell accuracy: 98.9%, board accuracy: 35.6%
#
# Epoch 178
# -------------------------------
# train error:
#  G loss: 0.000665, cell accuracy: 99.8%, board accuracy: 67.1%
#
# test error:
#  G loss: 0.002181, cell accuracy: 98.9%, board accuracy: 34.8%
#
# Epoch 179
# -------------------------------
# train error:
#  G loss: 0.000738, cell accuracy: 99.7%, board accuracy: 63.0%
#
# test error:
#  G loss: 0.002236, cell accuracy: 98.9%, board accuracy: 33.5%
#
# Epoch 180
# -------------------------------
# train error:
#  G loss: 0.000702, cell accuracy: 99.7%, board accuracy: 65.8%
#
# test error:
#  G loss: 0.002212, cell accuracy: 98.9%, board accuracy: 34.5%
#
# Epoch 181
# -------------------------------
# train error:
#  G loss: 0.000699, cell accuracy: 99.7%, board accuracy: 67.1%
#
# test error:
#  G loss: 0.002203, cell accuracy: 98.9%, board accuracy: 36.7%
#
# Epoch 182
# -------------------------------
# train error:
#  G loss: 0.000673, cell accuracy: 99.7%, board accuracy: 67.3%
#
# test error:
#  G loss: 0.002200, cell accuracy: 98.9%, board accuracy: 36.3%
#
# Epoch 183
# -------------------------------
# train error:
#  G loss: 0.000744, cell accuracy: 99.7%, board accuracy: 63.9%
#
# test error:
#  G loss: 0.002238, cell accuracy: 98.9%, board accuracy: 33.8%
#
# Epoch 184
# -------------------------------
# train error:
#  G loss: 0.000719, cell accuracy: 99.7%, board accuracy: 65.9%
#
# test error:
#  G loss: 0.002230, cell accuracy: 98.9%, board accuracy: 34.8%
#
# Epoch 185
# -------------------------------
# train error:
#  G loss: 0.000706, cell accuracy: 99.7%, board accuracy: 65.4%
#
# test error:
#  G loss: 0.002216, cell accuracy: 98.9%, board accuracy: 34.7%
#
# Epoch 186
# -------------------------------
# train error:
#  G loss: 0.000700, cell accuracy: 99.7%, board accuracy: 65.8%
#
# test error:
#  G loss: 0.002221, cell accuracy: 98.9%, board accuracy: 36.2%
#
# Epoch 187
# -------------------------------
# train error:
#  G loss: 0.000700, cell accuracy: 99.7%, board accuracy: 65.9%
#
# test error:
#  G loss: 0.002203, cell accuracy: 98.9%, board accuracy: 34.8%
#
# Epoch 188
# -------------------------------
# train error:
#  G loss: 0.000704, cell accuracy: 99.7%, board accuracy: 65.5%
#
# test error:
#  G loss: 0.002189, cell accuracy: 98.9%, board accuracy: 35.3%
#
# Epoch 189
# -------------------------------
# train error:
#  G loss: 0.000749, cell accuracy: 99.7%, board accuracy: 63.4%
#
# test error:
#  G loss: 0.002283, cell accuracy: 98.9%, board accuracy: 33.9%
#
# Epoch 190
# -------------------------------
# train error:
#  G loss: 0.000722, cell accuracy: 99.7%, board accuracy: 66.7%
#
# test error:
#  G loss: 0.002203, cell accuracy: 98.9%, board accuracy: 37.2%
#
# Epoch 191
# -------------------------------
# train error:
#  G loss: 0.000658, cell accuracy: 99.8%, board accuracy: 67.3%
#
# test error:
#  G loss: 0.002186, cell accuracy: 98.9%, board accuracy: 35.8%
#
# Epoch 192
# -------------------------------
# train error:
#  G loss: 0.000631, cell accuracy: 99.8%, board accuracy: 69.3%
#
# test error:
#  G loss: 0.002143, cell accuracy: 99.0%, board accuracy: 38.1%
#
# Epoch 193
# -------------------------------
# train error:
#  G loss: 0.000651, cell accuracy: 99.8%, board accuracy: 67.6%
#
# test error:
#  G loss: 0.002176, cell accuracy: 98.9%, board accuracy: 36.7%
#
# Epoch 194
# -------------------------------
# train error:
#  G loss: 0.000667, cell accuracy: 99.8%, board accuracy: 68.7%
#
# test error:
#  G loss: 0.002189, cell accuracy: 99.0%, board accuracy: 37.3%
#
# Epoch 195
# -------------------------------
# train error:
#  G loss: 0.000706, cell accuracy: 99.7%, board accuracy: 66.2%
#
# test error:
#  G loss: 0.002181, cell accuracy: 98.9%, board accuracy: 35.9%
#
# Epoch 196
# -------------------------------
# train error:
#  G loss: 0.000629, cell accuracy: 99.8%, board accuracy: 69.9%
#
# test error:
#  G loss: 0.002108, cell accuracy: 99.0%, board accuracy: 38.2%
#
# Epoch 197
# -------------------------------
# train error:
#  G loss: 0.000668, cell accuracy: 99.7%, board accuracy: 67.2%
#
# test error:
#  G loss: 0.002190, cell accuracy: 98.9%, board accuracy: 36.4%
#
# Epoch 198
# -------------------------------
# train error:
#  G loss: 0.000737, cell accuracy: 99.7%, board accuracy: 64.9%
#
# test error:
#  G loss: 0.002250, cell accuracy: 98.9%, board accuracy: 34.6%
#
# Epoch 199
# -------------------------------
# train error:
#  G loss: 0.000634, cell accuracy: 99.8%, board accuracy: 69.0%
#
# test error:
#  G loss: 0.002158, cell accuracy: 99.0%, board accuracy: 36.5%
#
# Epoch 200
# -------------------------------
# train error:
#  G loss: 0.000669, cell accuracy: 99.8%, board accuracy: 67.7%
#
# test error:
#  G loss: 0.002152, cell accuracy: 99.0%, board accuracy: 37.0%
#
# Epoch 201
# -------------------------------
# train error:
#  G loss: 0.000659, cell accuracy: 99.8%, board accuracy: 68.3%
#
# test error:
#  G loss: 0.002192, cell accuracy: 98.9%, board accuracy: 35.9%
#
# Epoch 202
# -------------------------------
# train error:
#  G loss: 0.000706, cell accuracy: 99.7%, board accuracy: 65.9%
#
# test error:
#  G loss: 0.002199, cell accuracy: 98.9%, board accuracy: 35.8%
#
# Epoch 203
# -------------------------------
# train error:
#  G loss: 0.000613, cell accuracy: 99.8%, board accuracy: 69.4%
#
# test error:
#  G loss: 0.002150, cell accuracy: 99.0%, board accuracy: 38.0%
#
# Epoch 204
# -------------------------------
# train error:
#  G loss: 0.000568, cell accuracy: 99.8%, board accuracy: 73.0%
#
# test error:
#  G loss: 0.002105, cell accuracy: 99.0%, board accuracy: 39.3%
#
# Epoch 205
# -------------------------------
# train error:
#  G loss: 0.000639, cell accuracy: 99.8%, board accuracy: 68.9%
#
# test error:
#  G loss: 0.002129, cell accuracy: 99.0%, board accuracy: 36.6%
#
# Epoch 206
# -------------------------------
# train error:
#  G loss: 0.000665, cell accuracy: 99.8%, board accuracy: 67.6%
#
# test error:
#  G loss: 0.002166, cell accuracy: 99.0%, board accuracy: 36.7%
#
# Epoch 207
# -------------------------------
# train error:
#  G loss: 0.000593, cell accuracy: 99.8%, board accuracy: 71.3%
#
# test error:
#  G loss: 0.002126, cell accuracy: 99.0%, board accuracy: 39.1%
#
# Epoch 208
# -------------------------------
# train error:
#  G loss: 0.000657, cell accuracy: 99.8%, board accuracy: 68.5%
#
# test error:
#  G loss: 0.002156, cell accuracy: 99.0%, board accuracy: 38.0%
#
# Epoch 209
# -------------------------------
# train error:
#  G loss: 0.000587, cell accuracy: 99.8%, board accuracy: 70.8%
#
# test error:
#  G loss: 0.002087, cell accuracy: 99.0%, board accuracy: 38.1%
#
# Epoch 210
# -------------------------------
# train error:
#  G loss: 0.000643, cell accuracy: 99.8%, board accuracy: 69.3%
#
# test error:
#  G loss: 0.002146, cell accuracy: 99.0%, board accuracy: 38.7%
#
# Epoch 211
# -------------------------------
# train error:
#  G loss: 0.000645, cell accuracy: 99.8%, board accuracy: 69.7%
#
# test error:
#  G loss: 0.002136, cell accuracy: 99.0%, board accuracy: 38.8%
#
# Epoch 212
# -------------------------------
# train error:
#  G loss: 0.000633, cell accuracy: 99.8%, board accuracy: 69.0%
#
# test error:
#  G loss: 0.002153, cell accuracy: 99.0%, board accuracy: 36.1%
#
# Epoch 213
# -------------------------------
# train error:
#  G loss: 0.000614, cell accuracy: 99.8%, board accuracy: 70.4%
#
# test error:
#  G loss: 0.002111, cell accuracy: 99.0%, board accuracy: 38.6%
#
# Epoch 214
# -------------------------------
# train error:
#  G loss: 0.000649, cell accuracy: 99.8%, board accuracy: 68.0%
#
# test error:
#  G loss: 0.002176, cell accuracy: 98.9%, board accuracy: 37.5%
#
# Epoch 215
# -------------------------------
# train error:
#  G loss: 0.000647, cell accuracy: 99.8%, board accuracy: 67.9%
#
# test error:
#  G loss: 0.002174, cell accuracy: 98.9%, board accuracy: 35.5%
#
# Epoch 216
# -------------------------------
# train error:
#  G loss: 0.000606, cell accuracy: 99.8%, board accuracy: 70.0%
#
# test error:
#  G loss: 0.002113, cell accuracy: 99.0%, board accuracy: 39.2%
#
# Epoch 217
# -------------------------------
# train error:
#  G loss: 0.000622, cell accuracy: 99.8%, board accuracy: 70.1%
#
# test error:
#  G loss: 0.002141, cell accuracy: 99.0%, board accuracy: 38.4%
#
# Epoch 218
# -------------------------------
# train error:
#  G loss: 0.000596, cell accuracy: 99.8%, board accuracy: 70.4%
#
# test error:
#  G loss: 0.002098, cell accuracy: 99.0%, board accuracy: 38.9%
#
# Epoch 219
# -------------------------------
# train error:
#  G loss: 0.000671, cell accuracy: 99.8%, board accuracy: 67.3%
#
# test error:
#  G loss: 0.002171, cell accuracy: 98.9%, board accuracy: 36.6%
#
# Epoch 220
# -------------------------------
# train error:
#  G loss: 0.000540, cell accuracy: 99.8%, board accuracy: 73.5%
#
# test error:
#  G loss: 0.002051, cell accuracy: 99.0%, board accuracy: 40.8%
#
# Epoch 221
# -------------------------------
# train error:
#  G loss: 0.000681, cell accuracy: 99.7%, board accuracy: 66.2%
#
# test error:
#  G loss: 0.002209, cell accuracy: 98.9%, board accuracy: 34.6%
#
# Epoch 222
# -------------------------------
# train error:
#  G loss: 0.000565, cell accuracy: 99.8%, board accuracy: 72.0%
#
# test error:
#  G loss: 0.002062, cell accuracy: 99.0%, board accuracy: 39.1%
#
# Epoch 223
# -------------------------------
# train error:
#  G loss: 0.000713, cell accuracy: 99.7%, board accuracy: 66.7%
#
# test error:
#  G loss: 0.002228, cell accuracy: 98.9%, board accuracy: 37.3%
#
# Epoch 224
# -------------------------------
# train error:
#  G loss: 0.000620, cell accuracy: 99.8%, board accuracy: 70.7%
#
# test error:
#  G loss: 0.002133, cell accuracy: 99.0%, board accuracy: 38.4%
#
# Epoch 225
# -------------------------------
# train error:
#  G loss: 0.000607, cell accuracy: 99.8%, board accuracy: 70.6%
#
# test error:
#  G loss: 0.002089, cell accuracy: 99.0%, board accuracy: 37.1%
#
# Epoch 226
# -------------------------------
# train error:
#  G loss: 0.000599, cell accuracy: 99.8%, board accuracy: 70.4%
#
# test error:
#  G loss: 0.002067, cell accuracy: 99.0%, board accuracy: 39.0%
#
# Epoch 227
# -------------------------------
# train error:
#  G loss: 0.000793, cell accuracy: 99.7%, board accuracy: 62.2%
#
# test error:
#  G loss: 0.002309, cell accuracy: 98.9%, board accuracy: 34.0%
#
# Epoch 228
# -------------------------------
# train error:
#  G loss: 0.000568, cell accuracy: 99.8%, board accuracy: 72.1%
#
# test error:
#  G loss: 0.002077, cell accuracy: 99.0%, board accuracy: 38.7%
#
# Epoch 229
# -------------------------------
# train error:
#  G loss: 0.000601, cell accuracy: 99.8%, board accuracy: 70.3%
#
# test error:
#  G loss: 0.002097, cell accuracy: 99.0%, board accuracy: 38.1%
#
# Epoch 230
# -------------------------------
# train error:
#  G loss: 0.000655, cell accuracy: 99.8%, board accuracy: 69.2%
#
# test error:
#  G loss: 0.002159, cell accuracy: 99.0%, board accuracy: 37.4%
#
# Epoch 231
# -------------------------------
# train error:
#  G loss: 0.000598, cell accuracy: 99.8%, board accuracy: 70.2%
#
# test error:
#  G loss: 0.002118, cell accuracy: 99.0%, board accuracy: 38.4%
#
# Epoch 232
# -------------------------------
# train error:
#  G loss: 0.000574, cell accuracy: 99.8%, board accuracy: 72.0%
#
# test error:
#  G loss: 0.002073, cell accuracy: 99.0%, board accuracy: 40.2%
#
# Epoch 233
# -------------------------------
# train error:
#  G loss: 0.000605, cell accuracy: 99.8%, board accuracy: 70.3%
#
# test error:
#  G loss: 0.002142, cell accuracy: 99.0%, board accuracy: 38.1%
#
# Epoch 234
# -------------------------------
# train error:
#  G loss: 0.000578, cell accuracy: 99.8%, board accuracy: 72.3%
#
# test error:
#  G loss: 0.002122, cell accuracy: 99.0%, board accuracy: 38.8%
#
# Epoch 235
# -------------------------------
# train error:
#  G loss: 0.000573, cell accuracy: 99.8%, board accuracy: 72.5%
#
# test error:
#  G loss: 0.002103, cell accuracy: 99.0%, board accuracy: 40.2%
#
# Epoch 236
# -------------------------------
# train error:
#  G loss: 0.000588, cell accuracy: 99.8%, board accuracy: 70.9%
#
# test error:
#  G loss: 0.002086, cell accuracy: 99.0%, board accuracy: 37.9%
#
# Epoch 237
# -------------------------------
# train error:
#  G loss: 0.000622, cell accuracy: 99.8%, board accuracy: 69.2%
#
# test error:
#  G loss: 0.002160, cell accuracy: 99.0%, board accuracy: 37.9%
#
# Epoch 238
# -------------------------------
# train error:
#  G loss: 0.000614, cell accuracy: 99.8%, board accuracy: 70.7%
#
# test error:
#  G loss: 0.002139, cell accuracy: 99.0%, board accuracy: 37.7%
#
# Epoch 239
# -------------------------------
# train error:
#  G loss: 0.000594, cell accuracy: 99.8%, board accuracy: 69.9%
#
# test error:
#  G loss: 0.002080, cell accuracy: 99.0%, board accuracy: 38.8%
#
# Epoch 240
# -------------------------------
# train error:
#  G loss: 0.000579, cell accuracy: 99.8%, board accuracy: 71.7%
#
# test error:
#  G loss: 0.002052, cell accuracy: 99.0%, board accuracy: 39.4%
#
# Epoch 241
# -------------------------------
# train error:
#  G loss: 0.000616, cell accuracy: 99.8%, board accuracy: 70.8%
#
# test error:
#  G loss: 0.002125, cell accuracy: 99.0%, board accuracy: 39.2%
#
# ...
# -------------------------------
# train error:
#  G loss: 0.000323, cell accuracy: 99.9%, board accuracy: 85.7%
#
# test error:
#  G loss: 0.001700, cell accuracy: 99.2%, board accuracy: 53.9%
#
# Epoch 1421
# -------------------------------
# train error:
#  G loss: 0.000304, cell accuracy: 99.9%, board accuracy: 86.0%
#
# test error:
#  G loss: 0.001627, cell accuracy: 99.2%, board accuracy: 54.5%
#
# Epoch 1422
# -------------------------------
# train error:
#  G loss: 0.000417, cell accuracy: 99.9%, board accuracy: 81.1%
#
# test error:
#  G loss: 0.001807, cell accuracy: 99.1%, board accuracy: 50.5%
#
# Epoch 1423
# -------------------------------
# train error:
#  G loss: 0.000341, cell accuracy: 99.9%, board accuracy: 83.7%
#
# test error:
#  G loss: 0.001708, cell accuracy: 99.2%, board accuracy: 51.6%
#
# Epoch 1424
# -------------------------------
# train error:
#  G loss: 0.000330, cell accuracy: 99.9%, board accuracy: 84.2%
#
# test error:
#  G loss: 0.001705, cell accuracy: 99.2%, board accuracy: 52.8%
#
# Epoch 1425
# -------------------------------
# train error:
#  G loss: 0.000397, cell accuracy: 99.9%, board accuracy: 80.0%
#
# test error:
#  G loss: 0.001758, cell accuracy: 99.2%, board accuracy: 50.6%
#
# Epoch 1426
# -------------------------------
# train error:
#  G loss: 0.000334, cell accuracy: 99.9%, board accuracy: 84.0%
#
# test error:
#  G loss: 0.001697, cell accuracy: 99.2%, board accuracy: 52.8%
#
# Epoch 1427
# -------------------------------
# train error:
#  G loss: 0.000359, cell accuracy: 99.9%, board accuracy: 83.1%
#
# test error:
#  G loss: 0.001749, cell accuracy: 99.2%, board accuracy: 51.2%
#
# Epoch 1428
# -------------------------------
# train error:
#  G loss: 0.000342, cell accuracy: 99.9%, board accuracy: 83.8%
#
# test error:
#  G loss: 0.001697, cell accuracy: 99.2%, board accuracy: 53.2%
#
# Epoch 1429
# -------------------------------
# train error:
#  G loss: 0.000332, cell accuracy: 99.9%, board accuracy: 84.1%
#
# test error:
#  G loss: 0.001684, cell accuracy: 99.2%, board accuracy: 53.7%
#
# Epoch 1430
# -------------------------------
# train error:
#  G loss: 0.000357, cell accuracy: 99.9%, board accuracy: 82.9%
#
# test error:
#  G loss: 0.001743, cell accuracy: 99.2%, board accuracy: 50.4%
#
# Epoch 1431
# -------------------------------
# train error:
#  G loss: 0.000341, cell accuracy: 99.9%, board accuracy: 84.0%
#
# test error:
#  G loss: 0.001709, cell accuracy: 99.2%, board accuracy: 51.5%
#
# Epoch 1432
# -------------------------------
# train error:
#  G loss: 0.000290, cell accuracy: 99.9%, board accuracy: 86.5%
#
# test error:
#  G loss: 0.001651, cell accuracy: 99.2%, board accuracy: 54.6%
#
# Epoch 1433
# -------------------------------
# train error:
#  G loss: 0.000357, cell accuracy: 99.9%, board accuracy: 83.7%
#
# test error:
#  G loss: 0.001694, cell accuracy: 99.2%, board accuracy: 53.9%
#
# Epoch 1434
# -------------------------------
# train error:
#  G loss: 0.000348, cell accuracy: 99.9%, board accuracy: 83.5%
#
# test error:
#  G loss: 0.001704, cell accuracy: 99.2%, board accuracy: 53.0%
#
# Epoch 1435
# -------------------------------
# train error:
#  G loss: 0.000353, cell accuracy: 99.9%, board accuracy: 83.4%
#
# test error:
#  G loss: 0.001720, cell accuracy: 99.2%, board accuracy: 52.6%
#
# Epoch 1436
# -------------------------------
# train error:
#  G loss: 0.000280, cell accuracy: 99.9%, board accuracy: 86.8%
#
# test error:
#  G loss: 0.001652, cell accuracy: 99.2%, board accuracy: 54.9%
#
# Epoch 1437
# -------------------------------
# train error:
#  G loss: 0.000382, cell accuracy: 99.9%, board accuracy: 82.2%
#
# test error:
#  G loss: 0.001736, cell accuracy: 99.2%, board accuracy: 52.0%
#
# Epoch 1438
# -------------------------------
# train error:
#  G loss: 0.000331, cell accuracy: 99.9%, board accuracy: 83.9%
#
# test error:
#  G loss: 0.001717, cell accuracy: 99.2%, board accuracy: 51.7%
#
# Epoch 1439
# -------------------------------
# train error:
#  G loss: 0.000321, cell accuracy: 99.9%, board accuracy: 84.8%
#
# test error:
#  G loss: 0.001690, cell accuracy: 99.2%, board accuracy: 52.5%
#
# Epoch 1440
# -------------------------------
# train error:
#  G loss: 0.000361, cell accuracy: 99.9%, board accuracy: 83.8%
#
# test error:
#  G loss: 0.001707, cell accuracy: 99.2%, board accuracy: 53.4%
#
# Epoch 1441
# -------------------------------
# train error:
#  G loss: 0.000394, cell accuracy: 99.9%, board accuracy: 82.0%
#
# test error:
#  G loss: 0.001749, cell accuracy: 99.2%, board accuracy: 52.0%
#
# Epoch 1442
# -------------------------------
# train error:
#  G loss: 0.000298, cell accuracy: 99.9%, board accuracy: 86.2%
#
# test error:
#  G loss: 0.001656, cell accuracy: 99.2%, board accuracy: 54.4%
#
# Epoch 1443
# -------------------------------
# train error:
#  G loss: 0.000339, cell accuracy: 99.9%, board accuracy: 84.7%
#
# test error:
#  G loss: 0.001673, cell accuracy: 99.2%, board accuracy: 54.0%
#
# Epoch 1444
# -------------------------------
# train error:
#  G loss: 0.000285, cell accuracy: 99.9%, board accuracy: 86.5%
#
# test error:
#  G loss: 0.001637, cell accuracy: 99.2%, board accuracy: 55.0%
#
# Epoch 1445
# -------------------------------
# train error:
#  G loss: 0.000390, cell accuracy: 99.9%, board accuracy: 81.6%
#
# test error:
#  G loss: 0.001727, cell accuracy: 99.2%, board accuracy: 51.4%
#
# Epoch 1446
# -------------------------------
# train error:
#  G loss: 0.000351, cell accuracy: 99.9%, board accuracy: 83.1%
#
# test error:
#  G loss: 0.001706, cell accuracy: 99.2%, board accuracy: 52.1%
#
# Epoch 1447
# -------------------------------
# train error:
#  G loss: 0.000317, cell accuracy: 99.9%, board accuracy: 85.4%
#
# test error:
#  G loss: 0.001668, cell accuracy: 99.2%, board accuracy: 53.4%
#
# Epoch 1448
# -------------------------------
# train error:
#  G loss: 0.000350, cell accuracy: 99.9%, board accuracy: 84.1%
#
# test error:
#  G loss: 0.001713, cell accuracy: 99.2%, board accuracy: 52.0%
#
# Epoch 1449
# -------------------------------
# train error:
#  G loss: 0.000369, cell accuracy: 99.9%, board accuracy: 82.5%
#
# test error:
#  G loss: 0.001729, cell accuracy: 99.2%, board accuracy: 52.2%
#
# Epoch 1450
# -------------------------------
# train error:
#  G loss: 0.000320, cell accuracy: 99.9%, board accuracy: 84.8%
#
# test error:
#  G loss: 0.001657, cell accuracy: 99.2%, board accuracy: 53.6%
#
# Epoch 1451
# -------------------------------
# train error:
#  G loss: 0.000327, cell accuracy: 99.9%, board accuracy: 84.8%
#
# test error:
#  G loss: 0.001702, cell accuracy: 99.2%, board accuracy: 53.3%
#
# Epoch 1452
# -------------------------------
# train error:
#  G loss: 0.000335, cell accuracy: 99.9%, board accuracy: 84.5%
#
# test error:
#  G loss: 0.001686, cell accuracy: 99.2%, board accuracy: 53.1%
#
# Epoch 1453
# -------------------------------
# train error:
#  G loss: 0.000294, cell accuracy: 99.9%, board accuracy: 86.0%
#
# test error:
#  G loss: 0.001657, cell accuracy: 99.2%, board accuracy: 54.5%
#
# Epoch 1454
# -------------------------------
# train error:
#  G loss: 0.000341, cell accuracy: 99.9%, board accuracy: 84.4%
#
# test error:
#  G loss: 0.001717, cell accuracy: 99.2%, board accuracy: 52.8%
#
# Epoch 1455
# -------------------------------
# train error:
#  G loss: 0.000361, cell accuracy: 99.9%, board accuracy: 83.1%
#
# test error:
#  G loss: 0.001740, cell accuracy: 99.2%, board accuracy: 52.8%
#
# Epoch 1456
# -------------------------------
# train error:
#  G loss: 0.000353, cell accuracy: 99.9%, board accuracy: 83.7%
#
# test error:
#  G loss: 0.001718, cell accuracy: 99.2%, board accuracy: 52.0%
#
# Epoch 1457
# -------------------------------
# train error:
#  G loss: 0.000336, cell accuracy: 99.9%, board accuracy: 84.8%
#
# test error:
#  G loss: 0.001682, cell accuracy: 99.2%, board accuracy: 52.1%
#
# Epoch 1458
# -------------------------------
# train error:
#  G loss: 0.000305, cell accuracy: 99.9%, board accuracy: 85.6%
#
# test error:
#  G loss: 0.001648, cell accuracy: 99.2%, board accuracy: 54.1%
#
# Epoch 1459
# -------------------------------
# train error:
#  G loss: 0.000341, cell accuracy: 99.9%, board accuracy: 84.0%
#
# test error:
#  G loss: 0.001700, cell accuracy: 99.2%, board accuracy: 51.7%
#
# Epoch 1460
# -------------------------------
# train error:
#  G loss: 0.000371, cell accuracy: 99.9%, board accuracy: 83.6%
#
# test error:
#  G loss: 0.001701, cell accuracy: 99.2%, board accuracy: 53.8%
#
# Epoch 1461
# -------------------------------
# train error:
#  G loss: 0.000329, cell accuracy: 99.9%, board accuracy: 84.6%
#
# test error:
#  G loss: 0.001677, cell accuracy: 99.2%, board accuracy: 53.2%
#
# Epoch 1462
# -------------------------------
# train error:
#  G loss: 0.000312, cell accuracy: 99.9%, board accuracy: 85.9%
#
# test error:
#  G loss: 0.001682, cell accuracy: 99.2%, board accuracy: 54.2%
#
# Epoch 1463
# -------------------------------
# train error:
#  G loss: 0.000370, cell accuracy: 99.9%, board accuracy: 82.6%
#
# test error:
#  G loss: 0.001710, cell accuracy: 99.2%, board accuracy: 52.3%
#
# Epoch 1464
# -------------------------------
# train error:
#  G loss: 0.000338, cell accuracy: 99.9%, board accuracy: 84.4%
#
# test error:
#  G loss: 0.001702, cell accuracy: 99.2%, board accuracy: 52.2%
#
# Epoch 1465
# -------------------------------
# train error:
#  G loss: 0.000367, cell accuracy: 99.9%, board accuracy: 82.6%
#
# test error:
#  G loss: 0.001724, cell accuracy: 99.2%, board accuracy: 52.8%
#
# Epoch 1466
# -------------------------------
# train error:
#  G loss: 0.000323, cell accuracy: 99.9%, board accuracy: 85.0%
#
# test error:
#  G loss: 0.001655, cell accuracy: 99.2%, board accuracy: 54.1%
#
# Epoch 1467
# -------------------------------
# train error:
#  G loss: 0.000393, cell accuracy: 99.9%, board accuracy: 80.6%
#
# test error:
#  G loss: 0.001758, cell accuracy: 99.2%, board accuracy: 50.3%
#
# Epoch 1468
# -------------------------------
# train error:
#  G loss: 0.000334, cell accuracy: 99.9%, board accuracy: 83.7%
#
# test error:
#  G loss: 0.001731, cell accuracy: 99.2%, board accuracy: 52.1%
#
# Epoch 1469
# -------------------------------
# train error:
#  G loss: 0.000317, cell accuracy: 99.9%, board accuracy: 85.9%
#
# test error:
#  G loss: 0.001650, cell accuracy: 99.2%, board accuracy: 55.1%
#
# Epoch 1470
# -------------------------------
# train error:
#  G loss: 0.000374, cell accuracy: 99.9%, board accuracy: 82.4%
#
# test error:
#  G loss: 0.001731, cell accuracy: 99.2%, board accuracy: 52.4%
#
# Epoch 1471
# -------------------------------
# train error:
#  G loss: 0.000327, cell accuracy: 99.9%, board accuracy: 84.4%
#
# test error:
#  G loss: 0.001684, cell accuracy: 99.2%, board accuracy: 52.5%
#
# Epoch 1472
# -------------------------------
# train error:
#  G loss: 0.000365, cell accuracy: 99.9%, board accuracy: 82.7%
#
# test error:
#  G loss: 0.001772, cell accuracy: 99.1%, board accuracy: 51.5%
#
# Epoch 1473
# -------------------------------
# train error:
#  G loss: 0.000399, cell accuracy: 99.9%, board accuracy: 81.5%
#
# test error:
#  G loss: 0.001737, cell accuracy: 99.2%, board accuracy: 51.0%
#
# Epoch 1474
# -------------------------------
# train error:
#  G loss: 0.000335, cell accuracy: 99.9%, board accuracy: 83.4%
#
# test error:
#  G loss: 0.001720, cell accuracy: 99.2%, board accuracy: 52.5%
#
# Epoch 1475
# -------------------------------
# train error:
#  G loss: 0.000332, cell accuracy: 99.9%, board accuracy: 84.1%
#
# test error:
#  G loss: 0.001691, cell accuracy: 99.2%, board accuracy: 52.6%
#
# Epoch 1476
# -------------------------------
# train error:
#  G loss: 0.000352, cell accuracy: 99.9%, board accuracy: 84.4%
#
# test error:
#  G loss: 0.001700, cell accuracy: 99.2%, board accuracy: 53.1%
#
# Epoch 1477
# -------------------------------
# train error:
#  G loss: 0.000346, cell accuracy: 99.9%, board accuracy: 83.2%
#
# test error:
#  G loss: 0.001716, cell accuracy: 99.2%, board accuracy: 52.1%
#
# Epoch 1478
# -------------------------------
# train error:
#  G loss: 0.000336, cell accuracy: 99.9%, board accuracy: 84.9%
#
# test error:
#  G loss: 0.001679, cell accuracy: 99.2%, board accuracy: 55.0%
#
# Epoch 1479
# -------------------------------
# train error:
#  G loss: 0.000349, cell accuracy: 99.9%, board accuracy: 84.2%
#
# test error:
#  G loss: 0.001704, cell accuracy: 99.2%, board accuracy: 52.9%
#
# Epoch 1480
# -------------------------------
# train error:
#  G loss: 0.000353, cell accuracy: 99.9%, board accuracy: 83.4%
#
# test error:
#  G loss: 0.001741, cell accuracy: 99.2%, board accuracy: 52.2%
#
# Epoch 1481
# -------------------------------
# train error:
#  G loss: 0.000317, cell accuracy: 99.9%, board accuracy: 85.9%
#
# test error:
#  G loss: 0.001637, cell accuracy: 99.2%, board accuracy: 54.8%
#
# Epoch 1482
# -------------------------------
# train error:
#  G loss: 0.000349, cell accuracy: 99.9%, board accuracy: 84.3%
#
# test error:
#  G loss: 0.001684, cell accuracy: 99.2%, board accuracy: 53.8%
#
# Epoch 1483
# -------------------------------
# train error:
#  G loss: 0.000407, cell accuracy: 99.9%, board accuracy: 80.5%
#
# test error:
#  G loss: 0.001728, cell accuracy: 99.2%, board accuracy: 51.4%
#
# Epoch 1484
# -------------------------------
# train error:
#  G loss: 0.000344, cell accuracy: 99.9%, board accuracy: 84.3%
#
# test error:
#  G loss: 0.001692, cell accuracy: 99.2%, board accuracy: 53.5%
#
# Epoch 1485
# -------------------------------
# train error:
#  G loss: 0.000296, cell accuracy: 99.9%, board accuracy: 86.8%
#
# test error:
#  G loss: 0.001642, cell accuracy: 99.2%, board accuracy: 55.2%
#
# Epoch 1486
# -------------------------------
# train error:
#  G loss: 0.000355, cell accuracy: 99.9%, board accuracy: 82.7%
#
# test error:
#  G loss: 0.001748, cell accuracy: 99.2%, board accuracy: 51.1%
#
# Epoch 1487
# -------------------------------
# train error:
#  G loss: 0.000347, cell accuracy: 99.9%, board accuracy: 83.7%
#
# test error:
#  G loss: 0.001711, cell accuracy: 99.2%, board accuracy: 52.4%
#
# Epoch 1488
# -------------------------------
# train error:
#  G loss: 0.000333, cell accuracy: 99.9%, board accuracy: 83.9%
#
# test error:
#  G loss: 0.001674, cell accuracy: 99.2%, board accuracy: 52.8%
#
# Epoch 1489
# -------------------------------
# train error:
#  G loss: 0.000319, cell accuracy: 99.9%, board accuracy: 85.3%
#
# test error:
#  G loss: 0.001681, cell accuracy: 99.2%, board accuracy: 53.9%
#
# Epoch 1490
# -------------------------------
# train error:
#  G loss: 0.000307, cell accuracy: 99.9%, board accuracy: 85.0%
#
# test error:
#  G loss: 0.001678, cell accuracy: 99.2%, board accuracy: 54.3%
#
# Epoch 1491
# -------------------------------
# train error:
#  G loss: 0.000381, cell accuracy: 99.9%, board accuracy: 82.2%
#
# test error:
#  G loss: 0.001752, cell accuracy: 99.2%, board accuracy: 52.2%
#
# Epoch 1492
# -------------------------------
# train error:
#  G loss: 0.000348, cell accuracy: 99.9%, board accuracy: 82.8%
#
# test error:
#  G loss: 0.001711, cell accuracy: 99.2%, board accuracy: 52.1%
#
# Epoch 1493
# -------------------------------
# train error:
#  G loss: 0.000328, cell accuracy: 99.9%, board accuracy: 84.6%
#
# test error:
#  G loss: 0.001681, cell accuracy: 99.2%, board accuracy: 54.0%
#
# Epoch 1494
# -------------------------------
# train error:
#  G loss: 0.000305, cell accuracy: 99.9%, board accuracy: 85.2%
#
# test error:
#  G loss: 0.001668, cell accuracy: 99.2%, board accuracy: 52.2%
#
# Epoch 1495
# -------------------------------
# train error:
#  G loss: 0.000318, cell accuracy: 99.9%, board accuracy: 84.7%
#
# test error:
#  G loss: 0.001681, cell accuracy: 99.2%, board accuracy: 52.6%
#
# Epoch 1496
# -------------------------------
# train error:
#  G loss: 0.000369, cell accuracy: 99.9%, board accuracy: 82.5%
#
# test error:
#  G loss: 0.001716, cell accuracy: 99.2%, board accuracy: 52.1%
#
# Epoch 1497
# -------------------------------
# train error:
#  G loss: 0.000351, cell accuracy: 99.9%, board accuracy: 83.2%
#
# test error:
#  G loss: 0.001705, cell accuracy: 99.2%, board accuracy: 52.5%
#
# Epoch 1498
# -------------------------------
# train error:
#  G loss: 0.000371, cell accuracy: 99.9%, board accuracy: 83.3%
#
# test error:
#  G loss: 0.001696, cell accuracy: 99.2%, board accuracy: 52.4%
#
# Epoch 1499
# -------------------------------
# train error:
#  G loss: 0.000311, cell accuracy: 99.9%, board accuracy: 86.3%
#
# test error:
#  G loss: 0.001669, cell accuracy: 99.2%, board accuracy: 54.8%
#
# Done!

# %%
cell_accuracies_train = compute_metric_by_event(metrics.CellAccuracy, train_dataloader)
cell_accuracies_test = compute_metric_by_event(metrics.CellAccuracy, test_dataloader)
board_accuracies_train = compute_metric_by_event(metrics.BoardAccuracy, train_dataloader)
board_accuracies_test = compute_metric_by_event(metrics.BoardAccuracy, test_dataloader)

for event_type in range(NUM_EVENT_TYPES):
    print(f"Stats for event type '{EVENT_NAMES[event_type]}':")
    print(f"  Cell accuracy (train): {cell_accuracies_train[event_type]:.2%}")
    print(f"  Cell accuracy (test): {cell_accuracies_test[event_type]:.2%}")
    print(f"  Board accuracy (train): {board_accuracies_train[event_type]:.2%}")
    print(f"  Board accuracy (test): {board_accuracies_test[event_type]:.2%}")
    print()
# Out:
# Stats for event type 'Drop':
#   Cell accuracy (train): 99.90%
#   Cell accuracy (test): 98.82%
#   Board accuracy (train): 86.96%
#   Board accuracy (test): 52.54%
#
# Stats for event type 'Left':
#   Cell accuracy (train): 99.93%
#   Cell accuracy (test): 99.62%
#   Board accuracy (train): 88.34%
#   Board accuracy (test): 63.67%
#
# Stats for event type 'Right':
#   Cell accuracy (train): 99.95%
#   Cell accuracy (test): 99.77%
#   Board accuracy (train): 91.22%
#   Board accuracy (test): 74.22%
#
# Stats for event type 'Rotate':
#   Cell accuracy (train): 99.89%
#   Cell accuracy (test): 99.44%
#   Board accuracy (train): 82.38%
#   Board accuracy (test): 55.30%
#
# Stats for event type 'Insta-drop':
#   Cell accuracy (train): 99.84%
#   Cell accuracy (test): 98.68%
#   Board accuracy (train): 75.60%
#   Board accuracy (test): 12.76%

# %%
def show_prediction(example):
    (b, e), y = example
    pred = gen(b.to(device).unsqueeze(0), e.to(device).unsqueeze(0)).squeeze(0).cpu()
    b, e, y, pred = b.argmax(0), e.argmax(0), y.argmax(0), pred.argmax(0)

    fig, axs = plt.subplots(1, 3)
    fig.suptitle(f"Prediction vs reality\nEvent = {EVENT_NAMES[e]}")

    for ax in axs:
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

    axs[0].set_title("Input")
    axs[1].set_title("Predicted")
    axs[2].set_title("Reality")

    num_mistakes = (y != pred).type(torch.int).sum().item()
    print(f"Mistakes: {num_mistakes}")
    axs[0].imshow(render_board(b).transpose((1, 2, 0)), vmin=0, vmax=1)
    axs[1].imshow(render_board(pred).transpose((1, 2, 0)), vmin=0, vmax=1)
    axs[2].imshow(render_board(y).transpose((1, 2, 0)), vmin=0, vmax=1)

    plt.show()

# %%
# Show a random training prediction vs reality
import random

idx = random.randrange(len(train_dataset))
print(f"Showing prediction for training example {idx}")
show_prediction(train_dataset[idx])
# Out:
# Showing prediction for training example 15000
# Mistakes: 0

# %%
torch.save(gen.state_dict(), "gamegan_emulator.pth")
