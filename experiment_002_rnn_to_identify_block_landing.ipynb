# %% [markdown]
# # Experiment 002
#
# We would like the Tetris emulator to model time-dependent phenomena like when a block lands and thus when a new block needs to spawn. Let's try and solve this problem separately with an RNN, which will inform the modifications we make to the main Tetris emulator model.

# %%
import os
from pathlib import Path

import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from torch.utils.data import Dataset
import numpy as np

# %%
class BlockLandingDataset(Dataset):
    def __init__(self, path: str):
        self.path = path
        if not os.path.exists(path):
            raise FileNotFoundError()
        with os.scandir(self.path) as it:
            entry: os.DirEntry = next(iter(it))
            _, self.ext = os.path.splitext(entry.name)
            self.highest_index = max((int(Path(file.path).stem) for file in it))

    def __len__(self):
        return self.highest_index

    def __getitem__(self, idx):
        file = os.path.join(self.path, f"{idx+1}{self.ext}")
        if not os.path.exists(file):
            raise IndexError()
        boards = np.load(file)
        x = boards[:2] # Just take the first two frames as that's what will be input to the main model
        b1 = boards[1] # We can identify a block landing by the fact that a block spawns in the next time step
        b2 = boards[2]
        y = (np.all(b1[0] == 0) & np.any(b2[0] == 1)).astype(np.float32)
        x, y = torch.tensor(x), torch.tensor(y)
        return x, y

# %%
dataset = BlockLandingDataset("data")
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

x, y = next(iter(dataloader))
print(x.shape, x.dtype)
print(y.shape, y.dtype)
# Out:
# torch.Size([4, 2, 22, 10]) torch.int32
# torch.Size([4]) torch.float32

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
class BlockLandingModel(nn.Module):
    """Predicts whether a block has landed.

    Inputs:
        x: Tensor of int32 of shape (batch_size, seq_length, height, width). height = 22 and width = 10 are the dimensions of the game
           board. seq_length = 2 is the number of game board inputs. The entries should be 0 for empty cells and 1 for blocks.
    
    Returns: float32 scalar, logit for block landing prediction.
    """

    def __init__(self):
        super().__init__()
        self.conv = nn.Conv2d(2, 5, 3)
        self.rnn = nn.GRU(5, 5)
        self.lin = nn.Linear(5, 1)

    def forward(self, x):
        x = F.one_hot(x.long(), 2) # One-hot encode the two cell classes
        x = x.type(torch.float) # Convert to floating-point
        x = x.permute((1, 0, 4, 2, 3)) # Move sequence to dimension 1 and channels/classes to dimension 2
        x1, x2 = x # Split up the two timesteps so we can apply convolution to them both separately
        x1 = F.relu(self.conv(F.pad(x1, (1, 1, 1, 1)))) # Pad height and width (the last 2 dimensions) with zeroes to represent the board boundaries
        x1 = F.avg_pool2d(x1, kernel_size=(22, 10)).squeeze(-1).squeeze(-1) # TODO: Ideally want global average pool that's size-independent
        x2 = F.relu(self.conv(F.pad(x2, (1, 1, 1, 1))))
        x2 = F.avg_pool2d(x2, kernel_size=(22, 10)).squeeze(-1).squeeze(-1)
        x = torch.concat((x1.unsqueeze(0), x2.unsqueeze(0)))
        x, rnn_state = self.rnn(x)
        x = x[-1] # Just take last predicted state
        logits = self.lin(x).squeeze(-1)
        return logits

# %%
model = BlockLandingModel().to(device)
print(model)

with torch.no_grad():
    X, y = next(iter(dataloader))
    logits = model(X)[0]
    preds = F.sigmoid(logits)
    print(f"Predicted states: {preds}")
# Out:
# BlockLandingModel(
#   (conv): Conv2d(2, 5, kernel_size=(3, 3), stride=(1, 1))
#   (rnn): GRU(5, 5)
#   (lin): Linear(in_features=5, out_features=1, bias=True)
# )
# Predicted states: 0.5360490083694458

# %%
num_block_landings = sum(y for x, y in dataset)
print(f"Number of block landings: {num_block_landings}")
# Out:
# Number of block landings: 9.0

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    avg_loss = 0.0

    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):

        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        avg_loss += loss.item()

        if batch % 20 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    avg_loss /= size
    return avg_loss


def test_loop(dataloader, model, loss_fn):
    num_batches = len(dataloader)
    test_loss, correct = 0, 0
    recall = 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            classes = (pred >= 0).type(torch.float)
            correct += (classes == y).type(torch.float).mean().item()
            recall += ((classes == 1.0) & (y == 1.0)).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= num_batches
    recall /= num_block_landings
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Recall: {(100*recall):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return {
        "loss": test_loss,
        "acc": correct,
        "recall": recall
    }

# %%
learning_rate = 1e-2
batch_size = 4
epochs = 100

model = BlockLandingModel().to(device)
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

loss_history = []
acc_history = []
recall_history = []

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    # Since our dataset represents the full set of possible states, we can safely use it for both training and testing
    epoch_loss = train_loop(dataloader, model, loss_fn, optimizer)
    loss_history.append(epoch_loss)
    # No need to plot test loss separately as in our case it's the same as training loss
    test_metrics = test_loop(dataloader, model, loss_fn)
    acc_history.append(test_metrics["acc"])
    recall_history.append(test_metrics["recall"])

print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.601624  [    4/  237]
# loss: 0.532664  [   84/  237]
# loss: 0.477071  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.457551
#
# Epoch 2
# -------------------------------
# loss: 0.434938  [    4/  237]
# loss: 0.392590  [   84/  237]
# loss: 0.361378  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.367338
#
# Epoch 3
# -------------------------------
# loss: 0.333029  [    4/  237]
# loss: 0.304616  [   84/  237]
# loss: 0.281191  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.308433
#
# Epoch 4
# -------------------------------
# loss: 0.262875  [    4/  237]
# loss: 0.566603  [   84/  237]
# loss: 0.229864  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.268599
#
# Epoch 5
# -------------------------------
# loss: 0.215386  [    4/  237]
# loss: 0.202793  [   84/  237]
# loss: 0.188874  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.240920
#
# Epoch 6
# -------------------------------
# loss: 0.179513  [    4/  237]
# loss: 0.589191  [   84/  237]
# loss: 0.160959  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.221264
#
# Epoch 7
# -------------------------------
# loss: 0.154718  [    4/  237]
# loss: 0.145940  [   84/  237]
# loss: 0.140543  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.206978
#
# Epoch 8
# -------------------------------
# loss: 0.135135  [    4/  237]
# loss: 0.130274  [   84/  237]
# loss: 0.123840  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.196494
#
# Epoch 9
# -------------------------------
# loss: 0.119539  [    4/  237]
# loss: 0.115598  [   84/  237]
# loss: 0.110815  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.188704
#
# Epoch 10
# -------------------------------
# loss: 0.107683  [    4/  237]
# loss: 0.104111  [   84/  237]
# loss: 0.100903  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.182761
#
# Epoch 11
# -------------------------------
# loss: 0.665693  [    4/  237]
# loss: 0.095528  [   84/  237]
# loss: 0.676078  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.178259
#
# Epoch 12
# -------------------------------
# loss: 0.090111  [    4/  237]
# loss: 0.087400  [   84/  237]
# loss: 0.086545  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.174735
#
# Epoch 13
# -------------------------------
# loss: 0.690950  [    4/  237]
# loss: 0.082415  [   84/  237]
# loss: 0.080611  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.171974
#
# Epoch 14
# -------------------------------
# loss: 0.078128  [    4/  237]
# loss: 0.075225  [   84/  237]
# loss: 0.074498  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.169821
#
# Epoch 15
# -------------------------------
# loss: 0.073262  [    4/  237]
# loss: 0.071541  [   84/  237]
# loss: 0.071025  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.168086
#
# Epoch 16
# -------------------------------
# loss: 0.069940  [    4/  237]
# loss: 0.068709  [   84/  237]
# loss: 0.736099  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.166662
#
# Epoch 17
# -------------------------------
# loss: 0.066310  [    4/  237]
# loss: 0.064913  [   84/  237]
# loss: 0.064251  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.165525
#
# Epoch 18
# -------------------------------
# loss: 0.745003  [    4/  237]
# loss: 0.742234  [   84/  237]
# loss: 0.062911  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.164551
#
# Epoch 19
# -------------------------------
# loss: 0.061826  [    4/  237]
# loss: 0.060054  [   84/  237]
# loss: 0.060089  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.163768
#
# Epoch 20
# -------------------------------
# loss: 0.058501  [    4/  237]
# loss: 0.057205  [   84/  237]
# loss: 0.058414  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.163123
#
# Epoch 21
# -------------------------------
# loss: 0.057464  [    4/  237]
# loss: 0.056794  [   84/  237]
# loss: 0.056175  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.162586
#
# Epoch 22
# -------------------------------
# loss: 0.055298  [    4/  237]
# loss: 0.054653  [   84/  237]
# loss: 0.053790  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.162493
#
# Epoch 23
# -------------------------------
# loss: 0.055017  [    4/  237]
# loss: 0.054753  [   84/  237]
# loss: 0.053686  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.162082
#
# Epoch 24
# -------------------------------
# loss: 0.780101  [    4/  237]
# loss: 0.053505  [   84/  237]
# loss: 0.053220  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.161706
#
# Epoch 25
# -------------------------------
# loss: 0.052381  [    4/  237]
# loss: 0.051845  [   84/  237]
# loss: 0.790029  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.161400
#
# Epoch 26
# -------------------------------
# loss: 0.783636  [    4/  237]
# loss: 0.050200  [   84/  237]
# loss: 0.050227  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.161135
#
# Epoch 27
# -------------------------------
# loss: 0.050113  [    4/  237]
# loss: 0.049661  [   84/  237]
# loss: 0.049788  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.160920
#
# Epoch 28
# -------------------------------
# loss: 0.049078  [    4/  237]
# loss: 0.793170  [   84/  237]
# loss: 0.048612  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.160728
#
# Epoch 29
# -------------------------------
# loss: 0.794630  [    4/  237]
# loss: 0.048279  [   84/  237]
# loss: 0.804386  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.160570
#
# Epoch 30
# -------------------------------
# loss: 0.047479  [    4/  237]
# loss: 0.047376  [   84/  237]
# loss: 0.046307  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.160429
#
# Epoch 31
# -------------------------------
# loss: 0.047116  [    4/  237]
# loss: 0.046354  [   84/  237]
# loss: 0.045736  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.160334
#
# Epoch 32
# -------------------------------
# loss: 0.046047  [    4/  237]
# loss: 0.046278  [   84/  237]
# loss: 0.046588  [  164/  237]
# Test Error:
#  Accuracy: 95.0%, Recall: 0.0%, Avg loss: 0.198450
#
# Epoch 33
# -------------------------------
# loss: 0.045250  [    4/  237]
# loss: 0.045009  [   84/  237]
# loss: 0.046076  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.160126
#
# Epoch 34
# -------------------------------
# loss: 0.044743  [    4/  237]
# loss: 0.816218  [   84/  237]
# loss: 0.045660  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.160063
#
# Epoch 35
# -------------------------------
# loss: 0.818668  [    4/  237]
# loss: 0.044667  [   84/  237]
# loss: 0.044328  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159983
#
# Epoch 36
# -------------------------------
# loss: 0.043808  [    4/  237]
# loss: 0.043333  [   84/  237]
# loss: 0.043367  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159934
#
# Epoch 37
# -------------------------------
# loss: 0.043837  [    4/  237]
# loss: 0.043061  [   84/  237]
# loss: 0.042693  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159889
#
# Epoch 38
# -------------------------------
# loss: 0.043500  [    4/  237]
# loss: 0.043303  [   84/  237]
# loss: 0.043174  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159857
#
# Epoch 39
# -------------------------------
# loss: 0.042718  [    4/  237]
# loss: 0.826195  [   84/  237]
# loss: 0.042837  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159813
#
# Epoch 40
# -------------------------------
# loss: 0.042427  [    4/  237]
# loss: 0.042303  [   84/  237]
# loss: 0.042807  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159781
#
# Epoch 41
# -------------------------------
# loss: 0.042368  [    4/  237]
# loss: 0.042602  [   84/  237]
# loss: 0.043054  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159762
#
# Epoch 42
# -------------------------------
# loss: 0.041515  [    4/  237]
# loss: 0.041616  [   84/  237]
# loss: 0.040759  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159741
#
# Epoch 43
# -------------------------------
# loss: 0.041730  [    4/  237]
# loss: 0.041933  [   84/  237]
# loss: 0.041560  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159720
#
# Epoch 44
# -------------------------------
# loss: 0.041461  [    4/  237]
# loss: 0.041091  [   84/  237]
# loss: 0.040986  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159714
#
# Epoch 45
# -------------------------------
# loss: 0.041272  [    4/  237]
# loss: 0.041622  [   84/  237]
# loss: 0.041437  [  164/  237]
# Test Error:
#  Accuracy: 95.0%, Recall: 0.0%, Avg loss: 0.199155
#
# Epoch 46
# -------------------------------
# loss: 0.041341  [    4/  237]
# loss: 0.041288  [   84/  237]
# loss: 0.040755  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159666
#
# Epoch 47
# -------------------------------
# loss: 0.040776  [    4/  237]
# loss: 0.040185  [   84/  237]
# loss: 0.040471  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159661
#
# Epoch 48
# -------------------------------
# loss: 0.831976  [    4/  237]
# loss: 0.040179  [   84/  237]
# loss: 0.837945  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159651
#
# Epoch 49
# -------------------------------
# loss: 0.040429  [    4/  237]
# loss: 0.040429  [   84/  237]
# loss: 0.040574  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159639
#
# Epoch 50
# -------------------------------
# loss: 0.040246  [    4/  237]
# loss: 0.040011  [   84/  237]
# loss: 0.040025  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159625
#
# Epoch 51
# -------------------------------
# loss: 0.039744  [    4/  237]
# loss: 0.040328  [   84/  237]
# loss: 0.040059  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159631
#
# Epoch 52
# -------------------------------
# loss: 0.039558  [    4/  237]
# loss: 0.040261  [   84/  237]
# loss: 0.040976  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159609
#
# Epoch 53
# -------------------------------
# loss: 0.039461  [    4/  237]
# loss: 0.040145  [   84/  237]
# loss: 0.040273  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159618
#
# Epoch 54
# -------------------------------
# loss: 0.039549  [    4/  237]
# loss: 0.039752  [   84/  237]
# loss: 0.040185  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159600
#
# Epoch 55
# -------------------------------
# loss: 0.039596  [    4/  237]
# loss: 0.040094  [   84/  237]
# loss: 0.040105  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159613
#
# Epoch 56
# -------------------------------
# loss: 0.039388  [    4/  237]
# loss: 0.039536  [   84/  237]
# loss: 0.038464  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159592
#
# Epoch 57
# -------------------------------
# loss: 0.039228  [    4/  237]
# loss: 0.039294  [   84/  237]
# loss: 0.038784  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159597
#
# Epoch 58
# -------------------------------
# loss: 0.038980  [    4/  237]
# loss: 0.039615  [   84/  237]
# loss: 0.038857  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159582
#
# Epoch 59
# -------------------------------
# loss: 0.846258  [    4/  237]
# loss: 0.842400  [   84/  237]
# loss: 0.038777  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159584
#
# Epoch 60
# -------------------------------
# loss: 0.039114  [    4/  237]
# loss: 0.039254  [   84/  237]
# loss: 0.039586  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159593
#
# Epoch 61
# -------------------------------
# loss: 0.838674  [    4/  237]
# loss: 0.843742  [   84/  237]
# loss: 0.039585  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159572
#
# Epoch 62
# -------------------------------
# loss: 0.039057  [    4/  237]
# loss: 0.039239  [   84/  237]
# loss: 0.039714  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159583
#
# Epoch 63
# -------------------------------
# loss: 0.039201  [    4/  237]
# loss: 0.038972  [   84/  237]
# loss: 0.039116  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159576
#
# Epoch 64
# -------------------------------
# loss: 0.039128  [    4/  237]
# loss: 0.039190  [   84/  237]
# loss: 0.039169  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159576
#
# Epoch 65
# -------------------------------
# loss: 0.848011  [    4/  237]
# loss: 0.038384  [   84/  237]
# loss: 0.038596  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159572
#
# Epoch 66
# -------------------------------
# loss: 0.038519  [    4/  237]
# loss: 0.839506  [   84/  237]
# loss: 0.849652  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159568
#
# Epoch 67
# -------------------------------
# loss: 0.038976  [    4/  237]
# loss: 0.038282  [   84/  237]
# loss: 1.655470  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159564
#
# Epoch 68
# -------------------------------
# loss: 0.039088  [    4/  237]
# loss: 0.851549  [   84/  237]
# loss: 0.847489  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159564
#
# Epoch 69
# -------------------------------
# loss: 0.038540  [    4/  237]
# loss: 0.037708  [   84/  237]
# loss: 0.038776  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159567
#
# Epoch 70
# -------------------------------
# loss: 0.038565  [    4/  237]
# loss: 0.039230  [   84/  237]
# loss: 0.040139  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159572
#
# Epoch 71
# -------------------------------
# loss: 0.038629  [    4/  237]
# loss: 0.038605  [   84/  237]
# loss: 0.848715  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159561
#
# Epoch 72
# -------------------------------
# loss: 0.038642  [    4/  237]
# loss: 0.037746  [   84/  237]
# loss: 0.037828  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159550
#
# Epoch 73
# -------------------------------
# loss: 0.039176  [    4/  237]
# loss: 0.839930  [   84/  237]
# loss: 0.038878  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159564
#
# Epoch 74
# -------------------------------
# loss: 0.038705  [    4/  237]
# loss: 0.037959  [   84/  237]
# loss: 0.038886  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159546
#
# Epoch 75
# -------------------------------
# loss: 0.038225  [    4/  237]
# loss: 0.038942  [   84/  237]
# loss: 0.038405  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159544
#
# Epoch 76
# -------------------------------
# loss: 0.038658  [    4/  237]
# loss: 0.038170  [   84/  237]
# loss: 0.846269  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159544
#
# Epoch 77
# -------------------------------
# loss: 0.038580  [    4/  237]
# loss: 0.038740  [   84/  237]
# loss: 0.038560  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159540
#
# Epoch 78
# -------------------------------
# loss: 0.038593  [    4/  237]
# loss: 0.840845  [   84/  237]
# loss: 0.038792  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159555
#
# Epoch 79
# -------------------------------
# loss: 0.038466  [    4/  237]
# loss: 0.038098  [   84/  237]
# loss: 0.038456  [  164/  237]
# Test Error:
#  Accuracy: 95.0%, Recall: 0.0%, Avg loss: 0.199571
#
# Epoch 80
# -------------------------------
# loss: 0.038426  [    4/  237]
# loss: 0.038536  [   84/  237]
# loss: 0.038237  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159545
#
# Epoch 81
# -------------------------------
# loss: 0.038187  [    4/  237]
# loss: 0.037872  [   84/  237]
# loss: 0.038003  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159535
#
# Epoch 82
# -------------------------------
# loss: 0.038974  [    4/  237]
# loss: 0.039064  [   84/  237]
# loss: 0.038248  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159537
#
# Epoch 83
# -------------------------------
# loss: 0.038879  [    4/  237]
# loss: 0.844696  [   84/  237]
# loss: 0.038870  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159531
#
# Epoch 84
# -------------------------------
# loss: 0.846816  [    4/  237]
# loss: 0.038108  [   84/  237]
# loss: 0.038789  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159536
#
# Epoch 85
# -------------------------------
# loss: 0.038350  [    4/  237]
# loss: 0.038334  [   84/  237]
# loss: 0.037996  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159529
#
# Epoch 86
# -------------------------------
# loss: 0.038427  [    4/  237]
# loss: 0.038042  [   84/  237]
# loss: 0.038505  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159525
#
# Epoch 87
# -------------------------------
# loss: 0.038330  [    4/  237]
# loss: 0.845944  [   84/  237]
# loss: 0.038264  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159540
#
# Epoch 88
# -------------------------------
# loss: 0.038380  [    4/  237]
# loss: 0.039236  [   84/  237]
# loss: 0.037831  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159536
#
# Epoch 89
# -------------------------------
# loss: 0.839274  [    4/  237]
# loss: 0.851146  [   84/  237]
# loss: 0.038014  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159533
#
# Epoch 90
# -------------------------------
# loss: 0.844624  [    4/  237]
# loss: 0.845462  [   84/  237]
# loss: 0.039132  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159522
#
# Epoch 91
# -------------------------------
# loss: 0.038450  [    4/  237]
# loss: 0.851735  [   84/  237]
# loss: 0.038724  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159518
#
# Epoch 92
# -------------------------------
# loss: 0.038297  [    4/  237]
# loss: 0.037769  [   84/  237]
# loss: 0.037711  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159526
#
# Epoch 93
# -------------------------------
# loss: 0.038585  [    4/  237]
# loss: 0.038189  [   84/  237]
# loss: 0.037849  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159524
#
# Epoch 94
# -------------------------------
# loss: 0.038570  [    4/  237]
# loss: 0.039345  [   84/  237]
# loss: 0.842329  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159518
#
# Epoch 95
# -------------------------------
# loss: 0.038356  [    4/  237]
# loss: 0.037185  [   84/  237]
# loss: 0.038057  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159518
#
# Epoch 96
# -------------------------------
# loss: 0.038627  [    4/  237]
# loss: 0.038395  [   84/  237]
# loss: 0.037892  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159512
#
# Epoch 97
# -------------------------------
# loss: 0.038091  [    4/  237]
# loss: 0.038063  [   84/  237]
# loss: 0.849026  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159531
#
# Epoch 98
# -------------------------------
# loss: 0.038726  [    4/  237]
# loss: 0.038193  [   84/  237]
# loss: 0.038028  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159505
#
# Epoch 99
# -------------------------------
# loss: 0.038463  [    4/  237]
# loss: 0.038799  [   84/  237]
# loss: 0.038301  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159503
#
# Epoch 100
# -------------------------------
# loss: 0.849614  [    4/  237]
# loss: 0.847525  [   84/  237]
# loss: 0.853816  [  164/  237]
# Test Error:
#  Accuracy: 96.2%, Recall: 0.0%, Avg loss: 0.159503
#
# Done!

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 4, figsize=(15, 3.5), constrained_layout=True)
axs = axs.flatten()
ax_loss_1, ax_loss_2, ax_acc, ax_recall = axs

ax_loss_1.plot(loss_history[:epochs//2])
ax_loss_1.set_title("Loss (start)")
ax_loss_1.set_xlabel("epoch")
ax_loss_1.set_ylabel("loss")

ax_loss_2.plot(list(range(epochs//2, epochs)), loss_history[epochs//2:])
ax_loss_2.set_title("Loss (end)")
ax_loss_2.set_xlabel("epoch")
ax_loss_2.set_ylabel("loss")

ax_acc.plot(acc_history)
ax_acc.set_title("Accuracy")
ax_acc.set_xlabel("epoch")
ax_acc.set_ylabel("accuracy")

ax_recall.plot(recall_history)
ax_recall.set_title("Recall")
ax_recall.set_xlabel("epoch")
ax_recall.set_ylabel("recall")

plt.plot()
# Out:
# []

# %%
def show_prediction(idx):
    x, y = dataset[idx]
    x1, x2 = x
    pred = model(x.unsqueeze(0)).squeeze(0)

    fig, axs = plt.subplots(1, 2)
    fig.suptitle("Example")

    for ax in axs:
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

    axs[0].set_title("Step 0")
    axs[1].set_title("Step 1")

    axs[0].imshow(x1)
    axs[1].imshow(x2)

    print(f"Predicted: {pred >= 0}, Actual: {y == 1.0}")
    plt.show()

# %%
# Show a random prediction vs reality
import random

idx = random.randrange(len(dataset))
print(f"Showing prediction for example {idx+1}")
show_prediction(idx)
# Out:
# Showing prediction for example 91
# Predicted: False, Actual: True

# %% [markdown]
# We can see from the training curves that the model just learns to classify all examples as "no block landed". This is likely because the dataset is heavily biased towards blocks not landing.

# %% [markdown]
# # Conclusion
#
# In conclusion, training a model to detect block landing is not as simple as throwing the first architecture we think of at the same dataset and expecting it to work. This may be because the model is not complex enough to learn the mapping, or it could be the fact that the dataset is very imbalanced.
#
# The next step is to prepare a more balanced dataset to see how the model performs.
